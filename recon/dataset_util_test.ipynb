# %% [markdown]
# # dataset_util_test

# %%
import sys
import os
from os import sep
from os.path import dirname, realpath
from pathlib import Path
from functools import reduce
import logging
logging.basicConfig(stream=sys.stdout, level=logging.DEBUG)

def get_cwd(fname, subdir, crunch_dir=realpath(Path.home()) +sep +'crunch' +sep):
    """
    Convenience function to make a directory string for the current file based on inputs.
    Jupyter Notebook in Anaconda invokes the Python interpreter in Anaconda's subdirectory
    which is why changing sys.argv[0] is necessary. In the future a better way to do this
    should be preferred..
    """
    return crunch_dir +subdir +fname
    
def fix_path(cwd):
    """
    Convenience function to fix argv and python path so that jupyter notebook can run the same as
    any script in crunch.
    """
    sys.argv[0] = cwd
    module_path = os.path.abspath(os.path.join('..'))
    if module_path not in sys.path:
        sys.path.append(module_path)

fix_path(get_cwd('dataset_util_test.ipynb', 'recon' +sep))

import numpy as np
import pandas as pd
from dask import delayed

from ipywidgets import interact, interactive, fixed
from IPython.display import display

pd.set_option("display.max_rows", 100)
pd.set_option("display.max_columns", 50)

from common_util import MUTATE_DIR, DT_HOURLY_FREQ, DT_CAL_DAILY_FREQ, is_valid, is_type, null_fn, identity_fn, pd_abs, pd_is_empty, ser_range_center_clip, pd_common_idx_rows, midx_split
from common_util import load_json, dump_json, ser_shift, df_sk_mw_transform, arr_nonzero, df_rows_in_year, get_variants, remove_dups_list, list_get_dict, is_empty_df, search_df, benchmark
from data.data_api import DataAPI
from recon.common import DATASET_DIR
from recon.dataset_util import *
# Out:
# DEBUG:matplotlib:$HOME=/home/kev
# DEBUG:matplotlib:CONFIGDIR=/home/kev/.config/matplotlib
# DEBUG:matplotlib:matplotlib data path: /home/kev/miniconda3/lib/python3.7/site-packages/matplotlib/mpl-data
# DEBUG:matplotlib:loaded rc file /home/kev/miniconda3/lib/python3.7/site-packages/matplotlib/mpl-data/matplotlibrc
# DEBUG:matplotlib:matplotlib version 3.1.0
# DEBUG:matplotlib:interactive is False
# DEBUG:matplotlib:platform is linux
# DEBUG:matplotlib:loaded modules: ['sys', 'builtins', '_frozen_importlib', '_imp', '_thread', '_warnings', '_weakref', 'zipimport', '_frozen_importlib_external', '_io', 'marshal', 'posix', 'encodings', 'codecs', '_codecs', 'encodings.aliases', 'encodings.utf_8', '_signal', '__main__', 'encodings.latin_1', 'io', 'abc', '_abc', '_bootlocale', '_locale', 'site', 'os', 'stat', '_stat', 'posixpath', 'genericpath', 'os.path', '_collections_abc', '_sitebuiltins', 'types', 'importlib', 'importlib._bootstrap', 'importlib._bootstrap_external', 'warnings', 'importlib.util', 'importlib.abc', 'importlib.machinery', 'contextlib', 'collections', 'operator', '_operator', 'keyword', 'heapq', '_heapq', 'itertools', 'reprlib', '_collections', 'functools', '_functools', 'mpl_toolkits', 'google', 'runpy', 'pkgutil', 'weakref', '_weakrefset', 'ipykernel', 'ipykernel._version', 'ipykernel.connect', '__future__', 'json', 'json.decoder', 're', 'enum', 'sre_compile', '_sre', 'sre_parse', 'sre_constants', 'copyreg', 'json.scanner', '_json', 'json.encoder', 'subprocess', 'time', 'signal', 'errno', '_posixsubprocess', 'select', 'selectors', 'collections.abc', 'math', 'threading', 'traceback', 'linecache', 'tokenize', 'token', 'IPython', 'IPython.core', 'IPython.core.getipython', 'IPython.core.release', 'IPython.core.application', 'atexit', 'copy', 'glob', 'fnmatch', 'logging', 'string', '_string', 'shutil', 'zlib', 'bz2', '_compression', '_bz2', 'lzma', '_lzma', 'pwd', 'grp', 'traitlets', 'traitlets.traitlets', 'inspect', 'dis', 'opcode', '_opcode', 'six', 'struct', '_struct', 'traitlets.utils', 'traitlets.utils.getargspec', 'traitlets.utils.importstring', 'ipython_genutils', 'ipython_genutils._version', 'ipython_genutils.py3compat', 'ipython_genutils.encoding', 'locale', 'platform', 'traitlets.utils.sentinel', 'traitlets.utils.bunch', 'traitlets._version', 'traitlets.config', 'traitlets.config.application', 'decorator', 'traitlets.config.configurable', 'traitlets.config.loader', 'argparse', 'gettext', 'ast', '_ast', 'ipython_genutils.path', 'random', 'hashlib', '_hashlib', '_blake2', '_sha3', 'bisect', '_bisect', '_random', 'ipython_genutils.text', 'textwrap', 'ipython_genutils.importstring', 'IPython.core.crashhandler', 'pprint', 'IPython.core.ultratb', 'pydoc', 'urllib', 'urllib.parse', 'IPython.core.debugger', 'bdb', 'IPython.utils', 'IPython.utils.PyColorize', 'IPython.utils.coloransi', 'IPython.utils.ipstruct', 'IPython.utils.colorable', 'pygments', 'pygments.util', 'IPython.utils.py3compat', 'IPython.utils.encoding', 'IPython.core.excolors', 'IPython.testing', 'IPython.testing.skipdoctest', 'pdb', 'cmd', 'code', 'codeop', 'IPython.core.display_trap', 'IPython.utils.path', 'IPython.utils.process', 'IPython.utils._process_posix', 'pexpect', 'pexpect.exceptions', 'pexpect.utils', 'pexpect.expect', 'pexpect.pty_spawn', 'pty', 'tty', 'termios', 'ptyprocess', 'ptyprocess.ptyprocess', 'fcntl', 'resource', 'ptyprocess.util', 'pexpect.spawnbase', 'pexpect.run', 'IPython.utils._process_common', 'shlex', 'IPython.utils.decorators', 'IPython.utils.data', 'IPython.utils.terminal', 'IPython.utils.sysinfo', 'IPython.utils._sysinfo', 'IPython.core.profiledir', 'IPython.paths', 'tempfile', 'IPython.utils.importstring', 'IPython.terminal', 'IPython.terminal.embed', 'IPython.core.compilerop', 'IPython.core.magic_arguments', 'IPython.core.error', 'IPython.utils.text', 'pathlib', 'ntpath', 'IPython.core.magic', 'getopt', 'IPython.core.oinspect', 'IPython.core.page', 'IPython.core.display', 'binascii', 'mimetypes', 'IPython.lib', 'IPython.lib.security', 'getpass', 'IPython.lib.pretty', 'datetime', '_datetime', 'IPython.utils.openpy', 'IPython.utils.dir2', 'IPython.utils.wildcard', 'pygments.lexers', 'pygments.lexers._mapping', 'pygments.modeline', 'pygments.plugin', 'pygments.lexers.python', 'pygments.lexer', 'pygments.filter', 'pygments.filters', 'pygments.token', 'pygments.regexopt', 'pygments.unistring', 'pygments.formatters', 'pygments.formatters._mapping', 'pygments ...
# CRITICAL:root:script location: /home/kev/crunch/recon/dataset_util_test.ipynb
# CRITICAL:root:using project dir: /home/kev/crunch/

# %% [markdown]
# ## Init DataAPI

# %%
DataAPI.__init__()
logging.basicConfig(stream=sys.stdout, level=logging.DEBUG)

# %% [markdown]
# ## System Test

# %%
list(prep_dataset('xg1.json')['features']['dfs'].keys())
# Out:
# [['dow_jones',
#   'dc',
#   'dc',
#   'trmi3_etf3_news_forecast_dc',
#   'trmi3_etf3_news_forecast_dc'],
#  ['dow_jones',
#   'dc',
#   'dc',
#   'trmi3_etf3_news_fundamental_dc',
#   'trmi3_etf3_news_fundamental_dc'],
#  ['dow_jones',
#   'dc',
#   'dc',
#   'trmi3_etf3_news_sentiment_dc',
#   'trmi3_etf3_news_sentiment_dc'],
#  ['dow_jones',
#   'dc',
#   'dc',
#   'trmi3_etf3_social_forecast_dc',
#   'trmi3_etf3_social_forecast_dc'],
#  ['dow_jones',
#   'dc',
#   'dc',
#   'trmi3_etf3_social_fundamental_dc',
#   'trmi3_etf3_social_fundamental_dc'],
#  ['dow_jones',
#   'dc',
#   'dc',
#   'trmi3_etf3_social_sentiment_dc',
#   'trmi3_etf3_social_sentiment_dc'],
#  ['dow_jones',
#   'dc',
#   'dc',
#   'trmi3_mkt3_news_bank_dc',
#   'trmi3_mkt3_news_bank_dc'],
#  ['dow_jones',
#   'dc',
#   'dc',
#   'trmi3_mkt3_news_bond_dc',
#   'trmi3_mkt3_news_bond_dc'],
#  ['dow_jones',
#   'dc',
#   'dc',
#   'trmi3_mkt3_news_stock_dc',
#   'trmi3_mkt3_news_stock_dc'],
#  ['dow_jones',
#   'dc',
#   'dc',
#   'trmi3_mkt3_social_bank_dc',
#   'trmi3_mkt3_social_bank_dc'],
#  ['dow_jones',
#   'dc',
#   'dc',
#   'trmi3_mkt3_social_bond_dc',
#   'trmi3_mkt3_social_bond_dc'],
#  ['dow_jones',
#   'dc',
#   'dc',
#   'trmi3_mkt3_social_stock_dc',
#   'trmi3_mkt3_social_stock_dc'],
#  ['dow_jones', 'dohlca', 'dohlca', 'pba_dohlca', 'pba_dohlca'],
#  ['dow_jones',
#   'dohlca',
#   'dohlca',
#   'trmi3_etf3_news_buzz_dohlca',
#   'trmi3_etf3_news_buzz_dohlca'],
#  ['dow_jones',
#   'dohlca',
#   'dohlca',
#   'trmi3_etf3_social_buzz_dohlca',
#   'trmi3_etf3_social_buzz_dohlca'],
#  ['dow_jones',
#   'dohlca',
#   'dohlca',
#   'trmi3_mkt3_news_bondBuzz_dohlca',
#   'trmi3_mkt3_news_bondBuzz_dohlca'],
#  ['dow_jones',
#   'dohlca',
#   'dohlca',
#   'trmi3_mkt3_news_ratesBuzz_dohlca',
#   'trmi3_mkt3_news_ratesBuzz_dohlca'],
#  ['dow_jones',
#   'dohlca',
#   'dohlca',
#   'trmi3_mkt3_news_stockIndexBuzz_dohlca',
#   'trmi3_mkt3_news_stockIndexBuzz_dohlca'],
#  ['dow_jones',
#   'dohlca',
#   'dohlca',
#   'trmi3_mkt3_social_bondBuzz_dohlca',
#   'trmi3_mkt3_social_bondBuzz_dohlca'],
#  ['dow_jones',
#   'dohlca',
#   'dohlca',
#   'trmi3_mkt3_social_ratesBuzz_dohlca',
#   'trmi3_mkt3_social_ratesBuzz_dohlca'],
#  ['dow_jones',
#   'dohlca',
#   'dohlca',
#   'trmi3_mkt3_social_stockIndexBuzz_dohlca',
#   'trmi3_mkt3_social_stockIndexBuzz_dohlca'],
#  ['dow_jones', 'dohlca', 'dohlca', 'vol_dohlca', 'vol_dohlca'],
#  ['dow_jones', 'hohlca', 'hohlca', 'pba_hohlca', 'pba_hohlca'],
#  ['dow_jones', 'hohlca', 'hohlca', 'vol_hohlca', 'vol_hohlca'],
#  ['nasdaq_100',
#   'dc',
#   'dc',
#   'trmi3_etf3_news_forecast_dc',
#   'trmi3_etf3_news_forecast_dc'],
#  ['nasdaq_100',
#   'dc',
#   'dc',
#   'trmi3_etf3_news_fundamental_dc',
#   'trmi3_etf3_news_fundamental_dc'],
#  ['nasdaq_100',
#   'dc',
#   'dc',
#   'trmi3_etf3_news_sentiment_dc',
#   'trmi3_etf3_news_sentiment_dc'],
#  ['nasdaq_100',
#   'dc',
#   'dc',
#   'trmi3_etf3_social_forecast_dc',
#   'trmi3_etf3_social_forecast_dc'],
#  ['nasdaq_100',
#   'dc',
#   'dc',
#   'trmi3_etf3_social_fundamental_dc',
#   'trmi3_etf3_social_fundamental_dc'],
#  ['nasdaq_100',
#   'dc',
#   'dc',
#   'trmi3_etf3_social_sentiment_dc',
#   'trmi3_etf3_social_sentiment_dc'],
#  ['nasdaq_100',
#   'dc',
#   'dc',
#   'trmi3_mkt3_news_bank_dc',
#   'trmi3_mkt3_news_bank_dc'],
#  ['nasdaq_100',
#   'dc',
#   'dc',
#   'trmi3_mkt3_news_bond_dc',
#   'trmi3_mkt3_news_bond_dc'],
#  ['nasdaq_100',
#   'dc',
#   'dc',
#   'trmi3_mkt3_news_stock_dc',
#   'trmi3_mkt3_news_stock_dc'],
#  ['nasdaq_100',
#   'dc',
#   'dc',
#   'trmi3_mkt3_social_bank_dc',
#   'trmi3_mkt3_social_bank_dc'],
#  ['nasdaq_100',
#   'dc',
#   'dc',
#   'trmi3_mkt3_social_bond_dc',
#   'trmi3_mkt3_social_bond_dc'],
#  ['nasdaq_100',
#   'dc',
#   'dc',
#   'trmi3_mkt3_social_stock_dc',
#   'trmi3_mkt3_social_stock_dc'],
#  ['nasdaq_100', 'dohlca', 'dohlca', 'pba_dohlca', 'pba_dohlca'],
#  ['nasdaq_100',
#   'dohlca',
#   'dohlca',
#   'trmi3_etf3_news_buzz_dohlca',
#   'trmi3_etf3_news_buzz_dohlca'],
#  ['nasdaq_100',
#   'dohlca',
#   'dohlca',
#   'trmi3_etf3_social_buzz_dohlca',
#   'trmi3_etf3_social_buzz_dohlca'],
#  ['nasdaq_100',
#   'dohlca',
#   'dohlca',
#   'trmi3_mkt3_news_bondBuzz_dohlca',
#   'trmi3_mkt3_news_bondBuzz_dohlca'],
#  ['nasdaq_100',
#   'dohlca',
#   'dohlca',
#   'trmi3_mkt3_news_ratesBuzz_dohlca',
#   'trmi3_mkt3_news_ratesBuzz_dohlca'],
#  ['nasdaq_100',
#   'dohlca',
#   'dohlca',
#   'trmi3_mkt3_news_stockIndexBuzz_dohlca',
#   'trmi3_mkt3_news_stockIndexBuzz_dohlca'],
#  ['nasdaq_100',
#   'dohlca',
#   'dohlca',
#   'trmi3_mkt3_social_bondBuzz_dohlca',
#   'trmi3_mkt3_social_bondBuzz_dohlca'],
#  ['nasdaq_100',
#   'dohlca',
#   'dohlca',
#   'trmi3_mkt3_social_ratesBuzz_dohlca',
#   'trmi3_mkt3_social_ratesBuzz_dohlca'],
#  ['nasdaq_100',
#   'dohlca',
#   'dohlca',
#   'trmi3_mkt3_social_stockIndexBuzz_dohlca',
#   'trmi3_mkt3_social_stockIndexBuzz_dohlca'],
#  ['nasdaq_100', 'dohlca', 'dohlca', 'vol_dohlca', 'vol_dohlca'],
#  ['nasdaq_100', 'hohlca', 'hohlca', 'pba_hohlca', 'pba_hohlca'],
#  ['nasdaq_100', 'hohlca', 'hohlca', 'vol_hohlca', 'vol_hohlca'],
#  ['russell_2000',
#   'dc',
#   'dc',
#   'trmi3_etf3_news_forecast_dc',
#   'trmi3_etf3_news_forecast_dc'],
#  ['russell_2000',
#   'dc',
#   'dc',
#   'trmi3_etf3_news_fundamental_dc',
#   'trmi3_etf3_news_fundamental_dc'],
#  ['russell_2000',
#   'dc',
#   'dc',
#   'trmi3_etf3_news_sentiment_dc',
#   'trmi3_etf3_news_sentiment_dc'],
#  ['russell_2000',
#   'dc',
#   'dc',
#   'trmi3_etf3_social_forecast_dc',
#   'trmi3_etf3_social_forecast_dc'],
#  ['russell_2000',
#   'dc',
#   'dc',
#   'trmi3_etf3_social_fundamental_dc',
#   'trmi3_etf3_social_fundamental_dc'],
#  ['russell_2000',
#   'dc',
#   'dc',
#   'trmi3_etf3_social_sentiment_dc',
#   'trmi3_etf3_social_sentiment_dc'],
#  ['russell_2000',
#   'dc',
#   'dc',
#   'trmi3_mkt3_news_bank_dc',
#   'trmi3_mkt3_news_bank_dc'],
#  ['russell_2000',
#   'dc',
#   'dc',
#   'trmi3_mkt3_news_bond_dc',
#   'trmi3_mkt3_news_bond_dc'],
#  ['russell_2000',
#   'dc',
#   'dc',
#   'trmi3_mkt3_news_stock_dc',
#   'trmi3_mkt3_news_stock_dc'],
#  ['russell_2000',
#   'dc',
#   'dc',
#   'trmi3_mkt3_social_bank_dc',
#   'trmi3_mkt3_social_bank_dc'],
#  ['russell_2000',
#   'dc',
#   'dc',
#   'trmi3_mkt3_social_bond_dc',
#   'trmi3_mkt3_social_bond_dc'],
#  ['russell_2000',
#   'dc',
#   'dc',
#   'trmi3_mkt3_social_stock_dc',
#   'trmi3_mkt3_social_stock_dc'],
#  ['russell_2000', 'dohlca', 'dohlca', 'pba_dohlca', 'pba_dohlca'],
#  ['russell_2000',
#   'dohlca',
#   'dohlca',
#   'trmi3_etf3_news_buzz_dohlca',
#   'trmi3_etf3_news_buzz_dohlca'],
#  ['russell_2000',
#   'dohlca',
#   'dohlca',
#   'trmi3_etf3_social_buzz_dohlca',
#   'trmi3_etf3_social_buzz_dohlca'],
#  ['russell_2000',
#   'dohlca',
#   'dohlca',
#   'trmi3_mkt3_news_bondBuzz_dohlca',
#   'trmi3_mkt3_news_bondBuzz_dohlca'],
#  ['russell_2000',
#   'dohlca',
#   'dohlca',
#   'trmi3_mkt3_news_ratesBuzz_dohlca',
#   'trmi3_mkt3_news_ratesBuzz_dohlca'],
#  ['russell_2000',
#   'dohlca',
#   'dohlca',
#   'trmi3_mkt3_news_stockIndexBuzz_dohlca',
#   'trmi3_mkt3_news_stockIndexBuzz_dohlca'],
#  ['russell_2000',
#   'dohlca',
#   'dohlca',
#   'trmi3_mkt3_social_bondBuzz_dohlca',
#   'trmi3_mkt3_social_bondBuzz_dohlca'],
#  ['russell_2000',
#   'dohlca',
#   'dohlca',
#   'trmi3_mkt3_social_ratesBuzz_dohlca',
#   'trmi3_mkt3_social_ratesBuzz_dohlca'],
#  ['russell_2000',
#   'dohlca',
#   'dohlca',
#   'trmi3_mkt3_social_stockIndexBuzz_dohlca',
#   'trmi3_mkt3_social_stockIndexBuzz_dohlca'],
#  ['russell_2000', 'dohlca', 'dohlca', 'vol_dohlca', 'vol_dohlca'],
#  ['russell_2000', 'hohlca', 'hohlca', 'pba_hohlca', 'pba_hohlca'],
#  ['russell_2000', 'hohlca', 'hohlca', 'vol_hohlca', 'vol_hohlca'],
#  ['sp_500',
#   'dc',
#   'dc',
#   'trmi3_etf3_news_forecast_dc',
#   'trmi3_etf3_news_forecast_dc'],
#  ['sp_500',
#   'dc',
#   'dc',
#   'trmi3_etf3_news_fundamental_dc',
#   'trmi3_etf3_news_fundamental_dc'],
#  ['sp_500',
#   'dc',
#   'dc',
#   'trmi3_etf3_news_sentiment_dc',
#   'trmi3_etf3_news_sentiment_dc'],
#  ['sp_500',
#   'dc',
#   'dc',
#   'trmi3_etf3_social_forecast_dc',
#   'trmi3_etf3_social_forecast_dc'],
#  ['sp_500',
#   'dc',
#   'dc',
#   'trmi3_etf3_social_fundamental_dc',
#   'trmi3_etf3_social_fundamental_dc'],
#  ['sp_500',
#   'dc',
#   'dc',
#   'trmi3_etf3_social_sentiment_dc',
#   'trmi3_etf3_social_sentiment_dc'],
#  ['sp_500', 'dc', 'dc', 'trmi3_mkt3_news_bank_dc', 'trmi3_mkt3_news_bank_dc'],
#  ['sp_500', 'dc', 'dc', 'trmi3_mkt3_news_bond_dc', 'trmi3_mkt3_news_bond_dc'],
#  ['sp_500',
#   'dc',
#   'dc',
#   'trmi3_mkt3_news_stock_dc',
#   'trmi3_mkt3_news_stock_dc'],
#  ['sp_500',
#   'dc',
#   'dc',
#   'trmi3_mkt3_social_bank_dc',
#   'trmi3_mkt3_social_bank_dc'],
#  ['sp_500',
#   'dc',
#   'dc',
#   'trmi3_mkt3_social_bond_dc',
#   'trmi3_mkt3_social_bond_dc'],
#  ['sp_500',
#   'dc',
#   'dc',
#   'trmi3_mkt3_social_stock_dc',
#   'trmi3_mkt3_social_stock_dc'],
#  ['sp_500', 'dohlca', 'dohlca', 'pba_dohlca', 'pba_dohlca'],
#  ['sp_500',
#   'dohlca',
#   'dohlca',
#   'trmi3_etf3_news_buzz_dohlca',
#   'trmi3_etf3_news_buzz_dohlca'],
#  ['sp_500',
#   'dohlca',
#   'dohlca',
#   'trmi3_etf3_social_buzz_dohlca',
#   'trmi3_etf3_social_buzz_dohlca'],
#  ['sp_500',
#   'dohlca',
#   'dohlca',
#   'trmi3_mkt3_news_bondBuzz_dohlca',
#   'trmi3_mkt3_news_bondBuzz_dohlca'],
#  ['sp_500',
#   'dohlca',
#   'dohlca',
#   'trmi3_mkt3_news_ratesBuzz_dohlca',
#   'trmi3_mkt3_news_ratesBuzz_dohlca'],
#  ['sp_500',
#   'dohlca',
#   'dohlca',
#   'trmi3_mkt3_news_stockIndexBuzz_dohlca',
#   'trmi3_mkt3_news_stockIndexBuzz_dohlca'],
#  ['sp_500',
#   'dohlca',
#   'dohlca',
#   'trmi3_mkt3_social_bondBuzz_dohlca',
#   'trmi3_mkt3_social_bondBuzz_dohlca'],
#  ['sp_500',
#   'dohlca',
#   'dohlca',
#   'trmi3_mkt3_social_ratesBuzz_dohlca',
#   'trmi3_mkt3_social_ratesBuzz_dohlca'],
#  ['sp_500',
#   'dohlca',
#   'dohlca',
#   'trmi3_mkt3_social_stockIndexBuzz_dohlca',
#   'trmi3_mkt3_social_stockIndexBuzz_dohlca'],
#  ['sp_500', 'dohlca', 'dohlca', 'vol_dohlca', 'vol_dohlca'],
#  ['sp_500', 'hohlca', 'hohlca', 'pba_hohlca', 'pba_hohlca'],
#  ['sp_500', 'hohlca', 'hohlca', 'vol_hohlca', 'vol_hohlca']]
