# %% [markdown]
# # Model Debug

# %%
import sys
import os
from os import sep
from os.path import dirname, realpath
from pathlib import Path
from functools import partial
from itertools import product
import logging

def get_cwd(fname, subdir, crunch_dir=realpath(Path.home()) +sep +'crunch' +sep):
    """
    Convenience function to make a directory string for the current file based on inputs.
    Jupyter Notebook in Anaconda invokes the Python interpreter in Anaconda's subdirectory
    which is why changing sys.argv[0] is necessary. In the future a better way to do this
    should be preferred..
    """
    return crunch_dir +subdir +fname
    
def fix_path(cwd):
    """
    Convenience function to fix argv and python path so that jupyter notebook can run the same as
    any script in crunch.
    """
    sys.argv[0] = cwd
    module_path = os.path.abspath(os.path.join('..'))
    if module_path not in sys.path:
        sys.path.append(module_path)

fname = 'model_debug_2.ipynb'   # FILL
dir_name = 'model'              # FILL
fix_path(get_cwd(fname, dir_name +sep))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from dask import delayed, compute

from ipywidgets import interact, interactive, fixed
from IPython.display import display

pd.set_option("display.max_rows", 100)
pd.set_option('display.max_columns', 50)

from common_util import RECON_DIR, JSON_SFX_LEN, DT_CAL_DAILY_FREQ, set_loglevel, str_to_list, ser_shift, get_cmd_args, in_debug_mode, pd_common_index_rows, load_json, filter_cols_below, inner_join, outer_join, list_get_dict, benchmark
from common_util import remove_dups_list, ser_shift, list_get_dict, list_set_dict, compose, pd_dti_index_to_date
from model.common import DATASET_DIR, FILTERSET_DIR, default_dataset, default_opt_filter, default_target_idx
from model.model_util import datagen, prepare_transpose_data, prepare_label_data
from recon.dataset_util import prep_dataset, gen_group
from recon.split_util import get_train_test_split, gen_time_series_split, pd_binary_clip
from data.access_util import df_getters as dg, col_subsetters2 as cs2
from data.data_api import DataAPI
# Out:
# WARNING:root:script location: /home/kevin/crunch/model/model_debug_2.ipynb
# WARNING:root:using project dir: /home/kevin/crunch/

# %%
set_loglevel('info')

# %%
cmd_arg_list = ['dataset=', 'filterset=', 'idxfilters=', 'assets=', 'target_idx=', 'strategy=', 'visualize']
cmd_input = dict.fromkeys(cmd_arg_list)
cmd_input['idxfilters='] = '1,2,3,4'
dataset_name = cmd_input['dataset='] if (cmd_input['dataset='] is not None) else default_dataset
assets = str_to_list(cmd_input['assets=']) if (cmd_input['assets='] is not None) else None
target_idx = str_to_list(cmd_input['target_idx='], cast_to=int) if (cmd_input['target_idx='] is not None) else default_target_idx
run_compute = True if (cmd_input['visualize'] is None) else False

dataset_dict = load_json(dataset_name, dir_path=DATASET_DIR)
dataset = prep_dataset(dataset_dict, assets=assets, filters_map=None)

logging.info('assets: ' +str('all' if (assets==None) else ', '.join(assets)))
# logging.info('dataset: {} {} df(s)'.format(len(dataset['features']['paths']), dataset_name[:-JSON_SFX_LEN]))
logging.debug('fpaths: {}'.format(str(dataset['features'])))
logging.debug('lpaths: {}'.format((dataset['labels'])))
logging.debug('rmpaths: {}'.format((dataset['row_masks'])))
# Out:
# INFO:root:assets: all

# %%
for k, v in dataset['labels']['dfs'].items():
    print(k)
# Out:
# ['dow_jones', 'direod', 'raw_pba_oa_retxeod_direod']
# ['dow_jones', 'direod', 'raw_pba_oa_retxeod_direod', 'raw_pba_oa_retxeod(0.25%)_direod']
# ['dow_jones', 'direod', 'raw_pba_oa_retxeod_direod', 'raw_pba_oa_retxeod(0.50%)_direod']
# ['dow_jones', 'direod', 'raw_pba_oa_retxeod_direod', 'raw_pba_oa_retxeod(1.00%)_direod']
# ['dow_jones', 'direod', 'raw_pba_oa_retxeod_direod', 'raw_pba_oa_retxeod(1.50%)_direod']
# ['dow_jones', 'direod', 'raw_pba_oa_retxeod_direod', 'raw_pba_oa_retxeod(2.00%)_direod']
# ['dow_jones', 'direod', 'raw_pba_oc_retxeod_direod']
# ['dow_jones', 'direod', 'raw_pba_oc_retxeod_direod', 'raw_pba_oc_retxeod(0.25%)_direod']
# ['dow_jones', 'direod', 'raw_pba_oc_retxeod_direod', 'raw_pba_oc_retxeod(0.50%)_direod']
# ['dow_jones', 'direod', 'raw_pba_oc_retxeod_direod', 'raw_pba_oc_retxeod(1.00%)_direod']
# ['dow_jones', 'direod', 'raw_pba_oc_retxeod_direod', 'raw_pba_oc_retxeod(1.50%)_direod']
# ['dow_jones', 'direod', 'raw_pba_oc_retxeod_direod', 'raw_pba_oc_retxeod(2.00%)_direod']
# ['nasdaq_100', 'direod', 'raw_pba_oa_retxeod_direod']
# ['nasdaq_100', 'direod', 'raw_pba_oa_retxeod_direod', 'raw_pba_oa_retxeod(0.25%)_direod']
# ['nasdaq_100', 'direod', 'raw_pba_oa_retxeod_direod', 'raw_pba_oa_retxeod(0.50%)_direod']
# ['nasdaq_100', 'direod', 'raw_pba_oa_retxeod_direod', 'raw_pba_oa_retxeod(1.00%)_direod']
# ['nasdaq_100', 'direod', 'raw_pba_oa_retxeod_direod', 'raw_pba_oa_retxeod(1.50%)_direod']
# ['nasdaq_100', 'direod', 'raw_pba_oa_retxeod_direod', 'raw_pba_oa_retxeod(2.00%)_direod']
# ['nasdaq_100', 'direod', 'raw_pba_oc_retxeod_direod']
# ['nasdaq_100', 'direod', 'raw_pba_oc_retxeod_direod', 'raw_pba_oc_retxeod(0.25%)_direod']
# ['nasdaq_100', 'direod', 'raw_pba_oc_retxeod_direod', 'raw_pba_oc_retxeod(0.50%)_direod']
# ['nasdaq_100', 'direod', 'raw_pba_oc_retxeod_direod', 'raw_pba_oc_retxeod(1.00%)_direod']
# ['nasdaq_100', 'direod', 'raw_pba_oc_retxeod_direod', 'raw_pba_oc_retxeod(1.50%)_direod']
# ['nasdaq_100', 'direod', 'raw_pba_oc_retxeod_direod', 'raw_pba_oc_retxeod(2.00%)_direod']
# ['russell_2000', 'direod', 'raw_pba_oa_retxeod_direod']
# ['russell_2000', 'direod', 'raw_pba_oa_retxeod_direod', 'raw_pba_oa_retxeod(0.25%)_direod']
# ['russell_2000', 'direod', 'raw_pba_oa_retxeod_direod', 'raw_pba_oa_retxeod(0.50%)_direod']
# ['russell_2000', 'direod', 'raw_pba_oa_retxeod_direod', 'raw_pba_oa_retxeod(1.00%)_direod']
# ['russell_2000', 'direod', 'raw_pba_oa_retxeod_direod', 'raw_pba_oa_retxeod(1.50%)_direod']
# ['russell_2000', 'direod', 'raw_pba_oa_retxeod_direod', 'raw_pba_oa_retxeod(2.00%)_direod']
# ['russell_2000', 'direod', 'raw_pba_oc_retxeod_direod']
# ['russell_2000', 'direod', 'raw_pba_oc_retxeod_direod', 'raw_pba_oc_retxeod(0.25%)_direod']
# ['russell_2000', 'direod', 'raw_pba_oc_retxeod_direod', 'raw_pba_oc_retxeod(0.50%)_direod']
# ['russell_2000', 'direod', 'raw_pba_oc_retxeod_direod', 'raw_pba_oc_retxeod(1.00%)_direod']
# ['russell_2000', 'direod', 'raw_pba_oc_retxeod_direod', 'raw_pba_oc_retxeod(1.50%)_direod']
# ['russell_2000', 'direod', 'raw_pba_oc_retxeod_direod', 'raw_pba_oc_retxeod(2.00%)_direod']
# ['sp_500', 'direod', 'raw_pba_oa_retxeod_direod']
# ['sp_500', 'direod', 'raw_pba_oa_retxeod_direod', 'raw_pba_oa_retxeod(0.25%)_direod']
# ['sp_500', 'direod', 'raw_pba_oa_retxeod_direod', 'raw_pba_oa_retxeod(0.50%)_direod']
# ['sp_500', 'direod', 'raw_pba_oa_retxeod_direod', 'raw_pba_oa_retxeod(1.00%)_direod']
# ['sp_500', 'direod', 'raw_pba_oa_retxeod_direod', 'raw_pba_oa_retxeod(1.50%)_direod']
# ['sp_500', 'direod', 'raw_pba_oa_retxeod_direod', 'raw_pba_oa_retxeod(2.00%)_direod']
# ['sp_500', 'direod', 'raw_pba_oc_retxeod_direod']
# ['sp_500', 'direod', 'raw_pba_oc_retxeod_direod', 'raw_pba_oc_retxeod(0.25%)_direod']
# ['sp_500', 'direod', 'raw_pba_oc_retxeod_direod', 'raw_pba_oc_retxeod(0.50%)_direod']
# ['sp_500', 'direod', 'raw_pba_oc_retxeod_direod', 'raw_pba_oc_retxeod(1.00%)_direod']
# ['sp_500', 'direod', 'raw_pba_oc_retxeod_direod', 'raw_pba_oc_retxeod(1.50%)_direod']
# ['sp_500', 'direod', 'raw_pba_oc_retxeod_direod', 'raw_pba_oc_retxeod(2.00%)_direod']

# %%
kc = ['dow_jones', 'direod', 'raw_vol_oa_retxeod_direod', 'raw_vol_oa_retxeod(2.00%)_direod']
d = dataset['labels']['dfs'][kc]

# %%
kc
# Out:
# ['dow_jones',
#  'direod',
#  'raw_vol_oa_retxeod_direod',
#  'raw_vol_oa_retxeod(2.00%)_direod']

# %%
d.compute().dropna()
# Out:
#                            vol_oa
# id
# 2005-03-18 00:00:00+00:00    -1.0
# 2005-03-21 00:00:00+00:00     1.0
# 2005-03-22 00:00:00+00:00     1.0
# 2005-03-23 00:00:00+00:00     0.0
# 2005-03-24 00:00:00+00:00    -1.0
# 2005-03-28 00:00:00+00:00    -1.0
# 2005-03-29 00:00:00+00:00     1.0
# 2005-03-30 00:00:00+00:00    -1.0
# 2005-03-31 00:00:00+00:00     0.0
# 2005-04-01 00:00:00+00:00     1.0
# 2005-04-04 00:00:00+00:00    -1.0
# 2005-04-05 00:00:00+00:00     0.0
# 2005-04-06 00:00:00+00:00    -1.0
# 2005-04-07 00:00:00+00:00    -1.0
# 2005-04-08 00:00:00+00:00     1.0
# 2005-04-11 00:00:00+00:00     0.0
# 2005-04-12 00:00:00+00:00    -1.0
# 2005-04-13 00:00:00+00:00     1.0
# 2005-04-14 00:00:00+00:00     1.0
# 2005-04-15 00:00:00+00:00     1.0
# 2005-04-18 00:00:00+00:00    -1.0
# 2005-04-19 00:00:00+00:00    -1.0
# 2005-04-20 00:00:00+00:00     1.0
# 2005-04-21 00:00:00+00:00    -1.0
# 2005-04-22 00:00:00+00:00     1.0
# 2005-04-25 00:00:00+00:00    -1.0
# 2005-04-26 00:00:00+00:00     0.0
# 2005-04-27 00:00:00+00:00    -1.0
# 2005-04-28 00:00:00+00:00     1.0
# 2005-04-29 00:00:00+00:00    -1.0
# 2005-05-02 00:00:00+00:00    -1.0
# 2005-05-03 00:00:00+00:00     0.0
# 2005-05-04 00:00:00+00:00    -1.0
# 2005-05-05 00:00:00+00:00     1.0
# 2005-05-06 00:00:00+00:00     1.0
# 2005-05-09 00:00:00+00:00    -1.0
# 2005-05-10 00:00:00+00:00     1.0
# 2005-05-11 00:00:00+00:00    -1.0
# 2005-05-12 00:00:00+00:00     1.0
# 2005-05-13 00:00:00+00:00     1.0
# 2005-05-16 00:00:00+00:00    -1.0
# 2005-05-17 00:00:00+00:00    -1.0
# 2005-05-18 00:00:00+00:00    -1.0
# 2005-05-19 00:00:00+00:00    -1.0
# 2005-05-20 00:00:00+00:00    -1.0
# 2005-05-23 00:00:00+00:00    -1.0
# 2005-05-24 00:00:00+00:00    -1.0
# 2005-05-25 00:00:00+00:00    -1.0
# 2005-05-26 00:00:00+00:00     0.0
# 2005-05-27 00:00:00+00:00     0.0
# ...                           ...
# 2017-10-19 00:00:00+00:00     1.0
# 2017-10-20 00:00:00+00:00     1.0
# 2017-10-23 00:00:00+00:00     1.0
# 2017-10-24 00:00:00+00:00     1.0
# 2017-10-25 00:00:00+00:00    -1.0
# 2017-10-26 00:00:00+00:00     1.0
# 2017-10-27 00:00:00+00:00    -1.0
# 2017-10-30 00:00:00+00:00     1.0
# 2017-10-31 00:00:00+00:00    -1.0
# 2017-11-01 00:00:00+00:00    -1.0
# 2017-11-02 00:00:00+00:00     0.0
# 2017-11-03 00:00:00+00:00    -1.0
# 2017-11-06 00:00:00+00:00     1.0
# 2017-11-07 00:00:00+00:00     0.0
# 2017-11-08 00:00:00+00:00    -1.0
# 2017-11-09 00:00:00+00:00     1.0
# 2017-11-10 00:00:00+00:00     1.0
# 2017-11-13 00:00:00+00:00     0.0
# 2017-11-14 00:00:00+00:00     1.0
# 2017-11-15 00:00:00+00:00     1.0
# 2017-11-16 00:00:00+00:00    -1.0
# 2017-11-17 00:00:00+00:00     1.0
# 2017-11-20 00:00:00+00:00    -1.0
# 2017-11-21 00:00:00+00:00    -1.0
# 2017-11-22 00:00:00+00:00     1.0
# 2017-11-24 00:00:00+00:00     1.0
# 2017-11-27 00:00:00+00:00    -1.0
# 2017-11-28 00:00:00+00:00    -1.0
# 2017-11-29 00:00:00+00:00     1.0
# 2017-11-30 00:00:00+00:00     1.0
# 2017-12-01 00:00:00+00:00     1.0
# 2017-12-04 00:00:00+00:00     0.0
# 2017-12-05 00:00:00+00:00    -1.0
# 2017-12-06 00:00:00+00:00    -1.0
# 2017-12-07 00:00:00+00:00    -1.0
# 2017-12-08 00:00:00+00:00    -1.0
# 2017-12-11 00:00:00+00:00    -1.0
# 2017-12-12 00:00:00+00:00     1.0
# 2017-12-13 00:00:00+00:00     0.0
# 2017-12-14 00:00:00+00:00     1.0
# 2017-12-15 00:00:00+00:00    -1.0
# 2017-12-18 00:00:00+00:00     1.0
# 2017-12-19 00:00:00+00:00    -1.0
# 2017-12-20 00:00:00+00:00    -1.0
# 2017-12-21 00:00:00+00:00     1.0
# 2017-12-22 00:00:00+00:00    -1.0
# 2017-12-26 00:00:00+00:00     1.0
# 2017-12-27 00:00:00+00:00    -1.0
# 2017-12-28 00:00:00+00:00    -1.0
# 2017-12-29 00:00:00+00:00     1.0
#
# [3220 rows x 1 columns]

# %%
kc = ['dow_jones', 'direod', 'raw_vol_oa_retxeod_direod']
d = dataset['labels']['dfs'][kc]

# %%
d.compute()
# Out:
#                            vol_oa
# id
# 2005-03-18 00:00:00+00:00    -1.0
# 2005-03-19 00:00:00+00:00     NaN
# 2005-03-20 00:00:00+00:00     NaN
# 2005-03-21 00:00:00+00:00     1.0
# 2005-03-22 00:00:00+00:00     1.0
# 2005-03-23 00:00:00+00:00     1.0
# 2005-03-24 00:00:00+00:00    -1.0
# 2005-03-25 00:00:00+00:00     NaN
# 2005-03-26 00:00:00+00:00     NaN
# 2005-03-27 00:00:00+00:00     NaN
# 2005-03-28 00:00:00+00:00    -1.0
# 2005-03-29 00:00:00+00:00     1.0
# 2005-03-30 00:00:00+00:00    -1.0
# 2005-03-31 00:00:00+00:00     1.0
# 2005-04-01 00:00:00+00:00     1.0
# 2005-04-02 00:00:00+00:00     NaN
# 2005-04-03 00:00:00+00:00     NaN
# 2005-04-04 00:00:00+00:00    -1.0
# 2005-04-05 00:00:00+00:00    -1.0
# 2005-04-06 00:00:00+00:00    -1.0
# 2005-04-07 00:00:00+00:00    -1.0
# 2005-04-08 00:00:00+00:00     1.0
# 2005-04-09 00:00:00+00:00     NaN
# 2005-04-10 00:00:00+00:00     NaN
# 2005-04-11 00:00:00+00:00     1.0
# 2005-04-12 00:00:00+00:00    -1.0
# 2005-04-13 00:00:00+00:00     1.0
# 2005-04-14 00:00:00+00:00     1.0
# 2005-04-15 00:00:00+00:00     1.0
# 2005-04-16 00:00:00+00:00     NaN
# 2005-04-17 00:00:00+00:00     NaN
# 2005-04-18 00:00:00+00:00    -1.0
# 2005-04-19 00:00:00+00:00    -1.0
# 2005-04-20 00:00:00+00:00     1.0
# 2005-04-21 00:00:00+00:00    -1.0
# 2005-04-22 00:00:00+00:00     1.0
# 2005-04-23 00:00:00+00:00     NaN
# 2005-04-24 00:00:00+00:00     NaN
# 2005-04-25 00:00:00+00:00    -1.0
# 2005-04-26 00:00:00+00:00    -1.0
# 2005-04-27 00:00:00+00:00    -1.0
# 2005-04-28 00:00:00+00:00     1.0
# 2005-04-29 00:00:00+00:00    -1.0
# 2005-04-30 00:00:00+00:00     NaN
# 2005-05-01 00:00:00+00:00     NaN
# 2005-05-02 00:00:00+00:00    -1.0
# 2005-05-03 00:00:00+00:00    -1.0
# 2005-05-04 00:00:00+00:00    -1.0
# 2005-05-05 00:00:00+00:00     1.0
# 2005-05-06 00:00:00+00:00     1.0
# ...                           ...
# 2017-11-10 00:00:00+00:00     1.0
# 2017-11-11 00:00:00+00:00     NaN
# 2017-11-12 00:00:00+00:00     NaN
# 2017-11-13 00:00:00+00:00     1.0
# 2017-11-14 00:00:00+00:00     1.0
# 2017-11-15 00:00:00+00:00     1.0
# 2017-11-16 00:00:00+00:00    -1.0
# 2017-11-17 00:00:00+00:00     1.0
# 2017-11-18 00:00:00+00:00     NaN
# 2017-11-19 00:00:00+00:00     NaN
# 2017-11-20 00:00:00+00:00    -1.0
# 2017-11-21 00:00:00+00:00    -1.0
# 2017-11-22 00:00:00+00:00     1.0
# 2017-11-23 00:00:00+00:00     NaN
# 2017-11-24 00:00:00+00:00     1.0
# 2017-11-25 00:00:00+00:00     NaN
# 2017-11-26 00:00:00+00:00     NaN
# 2017-11-27 00:00:00+00:00    -1.0
# 2017-11-28 00:00:00+00:00    -1.0
# 2017-11-29 00:00:00+00:00     1.0
# 2017-11-30 00:00:00+00:00     1.0
# 2017-12-01 00:00:00+00:00     1.0
# 2017-12-02 00:00:00+00:00     NaN
# 2017-12-03 00:00:00+00:00     NaN
# 2017-12-04 00:00:00+00:00     1.0
# 2017-12-05 00:00:00+00:00    -1.0
# 2017-12-06 00:00:00+00:00    -1.0
# 2017-12-07 00:00:00+00:00    -1.0
# 2017-12-08 00:00:00+00:00    -1.0
# 2017-12-09 00:00:00+00:00     NaN
# 2017-12-10 00:00:00+00:00     NaN
# 2017-12-11 00:00:00+00:00    -1.0
# 2017-12-12 00:00:00+00:00     1.0
# 2017-12-13 00:00:00+00:00    -1.0
# 2017-12-14 00:00:00+00:00     1.0
# 2017-12-15 00:00:00+00:00    -1.0
# 2017-12-16 00:00:00+00:00     NaN
# 2017-12-17 00:00:00+00:00     NaN
# 2017-12-18 00:00:00+00:00     1.0
# 2017-12-19 00:00:00+00:00    -1.0
# 2017-12-20 00:00:00+00:00    -1.0
# 2017-12-21 00:00:00+00:00     1.0
# 2017-12-22 00:00:00+00:00    -1.0
# 2017-12-23 00:00:00+00:00     NaN
# 2017-12-24 00:00:00+00:00     NaN
# 2017-12-25 00:00:00+00:00     NaN
# 2017-12-26 00:00:00+00:00     1.0
# 2017-12-27 00:00:00+00:00    -1.0
# 2017-12-28 00:00:00+00:00    -1.0
# 2017-12-29 00:00:00+00:00     1.0
#
# [4670 rows x 1 columns]

# %%
dataset_grid = {
    'feat_idx': [0, 1, 2, 3, 4],
    'label_idx': target_idx
}

# %%
logging.info('executing...')
for feature, label in datagen(dataset, feat_prep_fn=prepare_transpose_data, label_prep_fn=prepare_label_data):
    pos_label, neg_label = pd_binary_clip(label)
    f, lpos, lneg = pd_common_index_rows(feature, pos_label, neg_label)
    display(label)
#     logging.info('pos dir model experiment')
#     run_trials(ThreeLayerBinaryFFN, f, lpos)

#     logging.info('neg dir model experiment')
#     run_trials(ThreeLayerBinaryFFN, f, lneg)
# Out:
# INFO:root:executing...
# id
# 1998-01-02    1
# 1998-01-05    1
# 1998-01-06   -1
# 1998-01-07   -1
# 1998-01-08   -1
# 1998-01-09    1
# 1998-01-12    1
# 1998-01-13    1
# 1998-01-14   -1
# 1998-01-15    1
# 1998-01-16    1
# 1998-01-20   -1
# 1998-01-21    1
# 1998-01-22   -1
# 1998-01-23    1
# 1998-01-26    1
# 1998-01-27    1
# 1998-01-28    1
# 1998-01-29   -1
# 1998-01-30    1
# 1998-02-02    1
# 1998-02-03    1
# 1998-02-04   -1
# 1998-02-05    1
# 1998-02-06   -1
# 1998-02-09    1
# 1998-02-10    1
# 1998-02-11    1
# 1998-02-12    1
# 1998-02-13    1
# 1998-02-17    1
# 1998-02-18   -1
# 1998-02-19    1
# 1998-02-20   -1
# 1998-02-23   -1
# 1998-02-24    1
# 1998-02-25    1
# 1998-02-26    1
# 1998-02-27    1
# 1998-03-02    1
# 1998-03-03   -1
# 1998-03-04   -1
# 1998-03-05    1
# 1998-03-06    1
# 1998-03-09    1
# 1998-03-10    1
# 1998-03-11    1
# 1998-03-12   -1
# 1998-03-13    1
# 1998-03-16    1
#              ..
# 2017-10-18    1
# 2017-10-19    1
# 2017-10-20   -1
# 2017-10-23    1
# 2017-10-24   -1
# 2017-10-25    1
# 2017-10-26    1
# 2017-10-27    1
# 2017-10-30    1
# 2017-10-31   -1
# 2017-11-01    1
# 2017-11-02    1
# 2017-11-03    1
# 2017-11-06   -1
# 2017-11-07    1
# 2017-11-08    1
# 2017-11-09    1
# 2017-11-10    1
# 2017-11-13    1
# 2017-11-14    1
# 2017-11-15    1
# 2017-11-16   -1
# 2017-11-17    1
# 2017-11-20    1
# 2017-11-21   -1
# 2017-11-22    1
# 2017-11-24    1
# 2017-11-27    1
# 2017-11-28    1
# 2017-11-29    1
# 2017-11-30    1
# 2017-12-01   -1
# 2017-12-04   -1
# 2017-12-05   -1
# 2017-12-06    1
# 2017-12-07    1
# 2017-12-08    1
# 2017-12-11    1
# 2017-12-12    1
# 2017-12-13   -1
# 2017-12-14    1
# 2017-12-15    1
# 2017-12-18    1
# 2017-12-19   -1
# 2017-12-20    1
# 2017-12-21    1
# 2017-12-22    1
# 2017-12-26    1
# 2017-12-27    1
# 2017-12-28   -1
# Name: pba_lh, Length: 5012, dtype: int64
# id
# 1998-01-02    1
# 1998-01-05    1
# 1998-01-06   -1
# 1998-01-07   -1
# 1998-01-08   -1
# 1998-01-09    1
# 1998-01-12    1
# 1998-01-13    1
# 1998-01-14   -1
# 1998-01-15    1
# 1998-01-16    1
# 1998-01-20   -1
# 1998-01-21    1
# 1998-01-22   -1
# 1998-01-23    1
# 1998-01-26    1
# 1998-01-27    1
# 1998-01-28    1
# 1998-01-29   -1
# 1998-01-30    1
# 1998-02-02    1
# 1998-02-03    1
# 1998-02-04   -1
# 1998-02-05    1
# 1998-02-06   -1
# 1998-02-09    1
# 1998-02-10    1
# 1998-02-11    1
# 1998-02-12    1
# 1998-02-13    1
# 1998-02-17    1
# 1998-02-18   -1
# 1998-02-19    1
# 1998-02-20   -1
# 1998-02-23   -1
# 1998-02-24    1
# 1998-02-25    1
# 1998-02-26    1
# 1998-02-27    1
# 1998-03-02    1
# 1998-03-03   -1
# 1998-03-04   -1
# 1998-03-05    1
# 1998-03-06    1
# 1998-03-09    1
# 1998-03-10    1
# 1998-03-11    1
# 1998-03-12   -1
# 1998-03-13    1
# 1998-03-16    1
#              ..
# 2017-10-18    1
# 2017-10-19    1
# 2017-10-20   -1
# 2017-10-23    1
# 2017-10-24   -1
# 2017-10-25    1
# 2017-10-26    1
# 2017-10-27    1
# 2017-10-30    1
# 2017-10-31   -1
# 2017-11-01    1
# 2017-11-02    1
# 2017-11-03    1
# 2017-11-06   -1
# 2017-11-07    1
# 2017-11-08    1
# 2017-11-09    1
# 2017-11-10    1
# 2017-11-13    1
# 2017-11-14    1
# 2017-11-15    1
# 2017-11-16   -1
# 2017-11-17    1
# 2017-11-20    1
# 2017-11-21   -1
# 2017-11-22    1
# 2017-11-24    1
# 2017-11-27    1
# 2017-11-28    1
# 2017-11-29    1
# 2017-11-30    1
# 2017-12-01   -1
# 2017-12-04   -1
# 2017-12-05   -1
# 2017-12-06    1
# 2017-12-07    1
# 2017-12-08    1
# 2017-12-11    1
# 2017-12-12    1
# 2017-12-13   -1
# 2017-12-14    1
# 2017-12-15    1
# 2017-12-18    1
# 2017-12-19   -1
# 2017-12-20    1
# 2017-12-21    1
# 2017-12-22    1
# 2017-12-26    1
# 2017-12-27    1
# 2017-12-28   -1
# Name: pba_lh, Length: 5012, dtype: int64
# id
# 1998-01-02    1
# 1998-01-05    1
# 1998-01-06   -1
# 1998-01-07   -1
# 1998-01-08   -1
# 1998-01-09    1
# 1998-01-12    1
# 1998-01-13    1
# 1998-01-14   -1
# 1998-01-15    1
# 1998-01-16    1
# 1998-01-20   -1
# 1998-01-21    1
# 1998-01-22   -1
# 1998-01-23    1
# 1998-01-26    1
# 1998-01-27    1
# 1998-01-28    1
# 1998-01-29   -1
# 1998-01-30    1
# 1998-02-02    1
# 1998-02-03    1
# 1998-02-04   -1
# 1998-02-05    1
# 1998-02-06   -1
# 1998-02-09    1
# 1998-02-10    1
# 1998-02-11    1
# 1998-02-12    1
# 1998-02-13    1
# 1998-02-17    1
# 1998-02-18   -1
# 1998-02-19    1
# 1998-02-20   -1
# 1998-02-23   -1
# 1998-02-24    1
# 1998-02-25    1
# 1998-02-26    1
# 1998-02-27    1
# 1998-03-02    1
# 1998-03-03   -1
# 1998-03-04   -1
# 1998-03-05    1
# 1998-03-06    1
# 1998-03-09    1
# 1998-03-10    1
# 1998-03-11    1
# 1998-03-12   -1
# 1998-03-13    1
# 1998-03-16    1
#              ..
# 2017-10-18    1
# 2017-10-19    1
# 2017-10-20   -1
# 2017-10-23    1
# 2017-10-24   -1
# 2017-10-25    1
# 2017-10-26    1
# 2017-10-27    1
# 2017-10-30    1
# 2017-10-31   -1
# 2017-11-01    1
# 2017-11-02    1
# 2017-11-03    1
# 2017-11-06   -1
# 2017-11-07    1
# 2017-11-08    1
# 2017-11-09    1
# 2017-11-10    1
# 2017-11-13    1
# 2017-11-14    1
# 2017-11-15    1
# 2017-11-16   -1
# 2017-11-17    1
# 2017-11-20    1
# 2017-11-21   -1
# 2017-11-22    1
# 2017-11-24    1
# 2017-11-27    1
# 2017-11-28    1
# 2017-11-29    1
# 2017-11-30    1
# 2017-12-01   -1
# 2017-12-04   -1
# 2017-12-05   -1
# 2017-12-06    1
# 2017-12-07    1
# 2017-12-08    1
# 2017-12-11    1
# 2017-12-12    1
# 2017-12-13   -1
# 2017-12-14    1
# 2017-12-15    1
# 2017-12-18    1
# 2017-12-19   -1
# 2017-12-20    1
# 2017-12-21    1
# 2017-12-22    1
# 2017-12-26    1
# 2017-12-27    1
# 2017-12-28   -1
# Name: pba_lh, Length: 5012, dtype: int64
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-021e27e85562> in <module>()
#       1 logging.info('executing...')
# ----> 2 for feature, label in datagen(dataset, feat_prep_fn=prepare_transpose_data, label_prep_fn=prepare_label_data):
#       3     pos_label, neg_label = pd_binary_clip(label)
#       4     f, lpos, lneg = pd_common_index_rows(feature, pos_label, neg_label)
#       5     display(label)
#
# ~/crunch/model/model_util.py in datagen(dataset, feat_prep_fn, label_prep_fn, how)
#     112 	}.get(how)
#     113
# --> 114         yield from datagen_fn(dataset, feat_prep_fn, label_prep_fn)
#     115
#     116 def datagen_ser_to_ser(dataset, feat_prep_fn, label_prep_fn):
#
# ~/crunch/model/model_util.py in datagen_ser_to_ser(dataset, feat_prep_fn, label_prep_fn)
#     133
#     134                 for feat_col, label_col in product(features.columns, labels.columns):
# --> 135                         feature = feat_prep_fn(features.loc[:, [feat_col]], row_masks).dropna(axis=0, how='all')
#     136                         label = label_prep_fn(labels.loc[:, label_col]).dropna(axis=0, how='all')
#     137
#
# ~/crunch/model/model_util.py in prepare_transpose_data(feature_df, row_masks_df)
#      76 	prep_fn = compose(reindex_on_time_mask, gb_transpose, filter_cols_below,
#      77 		align_first_last,prune_nulls, partial(pd_dti_index_to_date, new_tz=None))
# ---> 78         return prep_fn(feature_df, row_masks_df)
#      79
#      80 def prepare_label_data(label_ser):
#
# ~/crunch/common_util.py in composed(*args, **kwargs)
#     419                 val = fns[0](*args, **kwargs)
#     420                 for fn in fns[1:]:
# --> 421                         val = fn(val)
#     422                 return val
#     423
#
# ~/crunch/common_util.py in gb_transpose(df, agg_freq, col_freq)
#    1051 	"""
#    1052         # Groupby aggfreq
# -> 1053         gbt = df.groupby(pd.Grouper(freq=agg_freq)).apply(df_freq_transpose, col_freq=col_freq)
#    1054
#    1055         # Drop empty columns and MultiIndex
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     916         with option_context('mode.chained_assignment', None):
#     917             try:
# --> 918                 result = self._python_apply_general(f)
#     919             except Exception:
#     920
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f)
#     934     def _python_apply_general(self, f):
#     935         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 936                                                    self.axis)
#     937
#     938         return self._wrap_applied_output(
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in apply(self, f, data, axis)
#    2255                 hasattr(splitter, 'fast_apply') and axis == 0):
#    2256             try:
# -> 2257                 values, mutated = splitter.fast_apply(f, group_keys)
#    2258                 return group_keys, values, mutated
#    2259             except reduction.InvalidApply:
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in fast_apply(self, f, names)
#    5086         sdata = self._get_sorted_data()
#    5087         results, mutated = reduction.apply_frame_axis0(sdata, f, names,
# -> 5088                                                        starts, ends)
#    5089
#    5090         return results, mutated
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.apply_frame_axis0()
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in f(g)
#     906                 def f(g):
#     907                     with np.errstate(all='ignore'):
# --> 908                         return func(g, *args, **kwargs)
#     909             else:
#     910                 raise ValueError('func must be a callable if args or '
#
# ~/crunch/common_util.py in df_freq_transpose(df, col_freq)
#     982                 day_date = df.index.date[0]
#     983                 day_cols = getattr(df.index, col_freq)
# --> 984                 transposed = pd.DataFrame(df.values.T, columns=day_cols, index=[day_date])
#     985         return transposed
#     986
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     377             else:
#     378                 mgr = self._init_ndarray(data, index, columns, dtype=dtype,
# --> 379                                          copy=copy)
#     380         elif isinstance(data, (list, types.GeneratorType)):
#     381             if isinstance(data, types.GeneratorType):
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/frame.py in _init_ndarray(self, values, index, columns, dtype, copy)
#     492         # we could have a categorical type passed or coerced to 'category'
#     493         # recast this to an _arrays_to_mgr
# --> 494         if (is_categorical_dtype(getattr(values, 'dtype', None)) or
#     495                 is_categorical_dtype(dtype)):
#     496
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/dtypes/common.py in is_categorical_dtype(arr_or_dtype)
#     541     if arr_or_dtype is None:
#     542         return False
# --> 543     return CategoricalDtype.is_dtype(arr_or_dtype)
#     544
#     545
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/dtypes/base.py in is_dtype(cls, dtype)
#      82            conditions is true for ``dtype.dtype``.
#      83         """
# ---> 84         dtype = getattr(dtype, 'dtype', dtype)
#      85
#      86         if isinstance(dtype, np.dtype):
#
# KeyboardInterrupt:

# %%
if (run_compute):
    logging.info('executing...')
    for paths, dfs, recs in gen_group(dataset, out=['dfs', 'recs']):
        fpaths, lpaths, rpaths = paths
        features, labels, row_masks = dfs
        features_rec, labels_rec, row_masks_rec = recs

        asset = fpaths[0]
        logging.info('fpaths: ' +str(fpaths))
        logging.info('lpaths: ' +str(lpaths))
        logging.info('rpaths: ' +str(rpaths))
        print(features_rec)

        for feat_idx, label_idx in product(*dataset_grid.values()):
            final_feature = prepare_transpose_data(features.iloc[:, [feat_idx]], row_masks).dropna(axis=0, how='all')
            final_label = prepare_labels(labels.iloc[:, label_idx]).dropna()
            final_label = delayed(ser_shift)(final_label)
            feat_lab = delayed(pd_common_index_rows)(final_feature, final_label)
            break
        break
# Out:
# INFO:root:executing...
# INFO:root:fpaths: ['dow_jones', 'dmx', 'raw_pba']
# INFO:root:lpaths: ['dow_jones', 'direod', 'raw_pba_oa_retxeod_direod']
# INFO:root:rpaths: ['dow_jones', 'id_rm', 'raw_pba']
# Pandas(Index=995, id=995, name='dow_jones_mutate_995', dir='dow_jones/dow_jones_raw_0/H/dmx/', freq='H', root='dow_jones', basis='dow_jones_raw_0', stage='mutate', recon_type=nan, mutate_type='dmx', raw_cat='us_equity_index', hist='->mutate_dmx', desc='raw_pba_dmx', size=2, dumptime=0.03, hash='367136082725478097496128', created='2018-08-12 02:13:23', modified='2018-10-29 01:00:24')
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-b3a7fcb3b3c6> in <module>
#      12         print(features_rec)
#      13
# ---> 14         for feat_idx, label_idx in product(*dataset_grid.values()):
#      15             final_feature = prepare_transpose_data(features.iloc[:, [feat_idx]], row_masks).dropna(axis=0, how='all')
#      16             final_label = prepare_labels(labels.iloc[:, label_idx]).dropna()
#
# NameError: name 'dataset_grid' is not defined

# %%
f, l = tuple(feat_lab.compute())

# %%
l
# Out:
# 1998-01-02    1
# 1998-01-05    1
# 1998-01-06   -1
# 1998-01-07   -1
# 1998-01-08   -1
# 1998-01-09    1
# 1998-01-12    1
# 1998-01-13    1
# 1998-01-14   -1
# 1998-01-15    1
# 1998-01-16    1
# 1998-01-20   -1
# 1998-01-21    1
# 1998-01-22   -1
# 1998-01-23    1
# 1998-01-26    1
# 1998-01-27    1
# 1998-01-28    1
# 1998-01-29   -1
# 1998-01-30    1
# 1998-02-02    1
# 1998-02-03    1
# 1998-02-04   -1
# 1998-02-05    1
# 1998-02-06   -1
# 1998-02-09    1
# 1998-02-10    1
# 1998-02-11    1
# 1998-02-12    1
# 1998-02-13    1
# 1998-02-17    1
# 1998-02-18   -1
# 1998-02-19    1
# 1998-02-20   -1
# 1998-02-23   -1
# 1998-02-24    1
# 1998-02-25    1
# 1998-02-26    1
# 1998-02-27    1
# 1998-03-02    1
# 1998-03-03   -1
# 1998-03-04   -1
# 1998-03-05    1
# 1998-03-06    1
# 1998-03-09    1
# 1998-03-10    1
# 1998-03-11    1
# 1998-03-12   -1
# 1998-03-13    1
# 1998-03-16    1
#              ..
# 2017-10-18    1
# 2017-10-19    1
# 2017-10-20   -1
# 2017-10-23    1
# 2017-10-24   -1
# 2017-10-25    1
# 2017-10-26    1
# 2017-10-27    1
# 2017-10-30    1
# 2017-10-31   -1
# 2017-11-01    1
# 2017-11-02    1
# 2017-11-03    1
# 2017-11-06   -1
# 2017-11-07    1
# 2017-11-08    1
# 2017-11-09    1
# 2017-11-10    1
# 2017-11-13    1
# 2017-11-14    1
# 2017-11-15    1
# 2017-11-16   -1
# 2017-11-17    1
# 2017-11-20    1
# 2017-11-21   -1
# 2017-11-22    1
# 2017-11-24    1
# 2017-11-27    1
# 2017-11-28    1
# 2017-11-29    1
# 2017-11-30    1
# 2017-12-01   -1
# 2017-12-04   -1
# 2017-12-05   -1
# 2017-12-06    1
# 2017-12-07    1
# 2017-12-08    1
# 2017-12-11    1
# 2017-12-12    1
# 2017-12-13   -1
# 2017-12-14    1
# 2017-12-15    1
# 2017-12-18    1
# 2017-12-19   -1
# 2017-12-20    1
# 2017-12-21    1
# 2017-12-22    1
# 2017-12-26    1
# 2017-12-27    1
# 2017-12-28   -1
# Name: pba_lh, Length: 4983, dtype: int64
