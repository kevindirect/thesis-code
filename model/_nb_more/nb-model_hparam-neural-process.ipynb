# %% [markdown]
# # nb-model_hparam-neural-process

# %%
import sys
import os
from os import sep
from os.path import dirname, realpath, exists
from pathlib import Path
from functools import partial
import random
import logging

def get_cwd(fname, subdir, crunch_dir=realpath(Path.home()) +sep +'crunch' +sep):
    """
    Convenience function to make a directory string for the current file based on inputs.
    Jupyter Notebook in Anaconda invokes the Python interpreter in Anaconda's subdirectory
    which is why changing sys.argv[0] is necessary. In the future a better way to do this
    should be preferred..
    """
    return crunch_dir +subdir +fname

def fix_path(cwd):
    """
    Convenience function to fix argv and python path so that jupyter notebook can run the same as
    any script in crunch.
    """
    sys.argv[0] = cwd
    module_path = os.path.abspath(os.path.join('..'))
    if module_path not in sys.path:
        sys.path.append(module_path)

fname = 'nb-model_xg-model-neural-process-clf-ddir.ipynb'
dir_name = 'model'
fix_path(get_cwd(fname, dir_name +sep))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import pytorch_lightning as pl
from pytorch_lightning.callbacks.early_stopping import EarlyStopping
from pytorch_lightning import loggers as pl_loggers
from verification.batch_norm import BatchNormVerificationCallback
from verification.batch_gradient import BatchGradientVerificationCallback

from ipywidgets import interact, interactive, fixed
from IPython.display import display

pd.set_option("display.max_rows", 100)
pd.set_option("display.max_columns", 50)

from common_util import MODEL_DIR, load_json, dump_json, rectify_json, load_df, str_now, makedir_if_not_exists, is_valid, isnt, compose, pd_split_ternary_to_binary, df_del_midx_level, midx_intersect, pd_get_midx_level, pd_rows, df_midx_restack
from model.common import ASSETS, DATASET_DIR, XG_PROCESS_DIR, XG_DATA_DIR, XG_DIR, PYTORCH_MODELS_DIR, TRAIN_RATIO, EXPECTED_NUM_HOURS
from model.pl_xgdm import XGDataModule
from model.pl_np import NPModel
from model.np_util2 import AttentiveNP
from recon.viz import *
logging.basicConfig(stream=sys.stdout, level=logging.DEBUG)
# Out:
# CRITICAL:root:script location: /home/kev/crunch/model/nb-model_xg-model-neural-process-clf-ddir.ipynb
# CRITICAL:root:using project dir: /home/kev/crunch/

# %% [markdown]
# Prune the xg data down to the data of interest to use in further experiments.

# %%
# %autoreload 1
# %aimport model.np_util2, model.train_util, model.pl_np, model.pl_generic, model.metrics_util, model.model_util, model.pl_xgdm

# %%
asset_name = 'dow_jones'

# %%
path = os.sep.join([MODEL_DIR, 'olog-02062021', 'NPModel_AttentiveNP', asset_name,
               '1996_2018_ddir_h_pba_h', 'val_f1.0', 'trials.csv'])

# %%
optuna_results = {}

for asset_name in ASSETS:
    path = os.sep.join([MODEL_DIR, 'olog-02062021', 'NPModel_AttentiveNP', asset_name,
               '1996_2018_ddir_h_pba_h', 'val_f1.0', 'trials.csv'])
    optuna_results[asset_name] = load_df(path, data_format='csv')

# %%
topn = 5

# %%
study_dir = MODEL_DIR +sep.join(['exp-log', asset_name, np_type, model_name, dm.name]) +sep

# %%
optuna_results[ASSETS[0]]
# Out:
#            value              datetime_start           datetime_complete  \
# number
# 207     0.577062  2021-05-26 23:21:30.835713  2021-05-26 23:26:00.251094
# 415     0.567410  2021-05-27 03:01:26.525607  2021-05-27 03:05:50.556929
# 316     0.565238  2021-05-27 01:21:16.777931  2021-05-27 01:28:02.776623
# 327     0.562580  2021-05-27 01:38:54.475482  2021-05-27 01:43:08.872137
# 774     0.562463  2021-06-01 13:13:59.376530  2021-06-01 13:17:57.208931
# ...          ...                         ...                         ...
# 930     0.314525  2021-06-01 15:19:37.126322  2021-06-01 15:25:11.733988
# 445     0.314525  2021-05-27 03:30:00.961056  2021-05-27 03:31:16.568369
# 806     0.314525  2021-06-01 13:40:59.223194  2021-06-01 13:41:05.335922
# 277     0.314525  2021-05-27 00:44:34.537239  2021-05-27 00:44:42.998408
# 170     0.314525  2021-05-26 22:54:26.528510  2021-05-26 22:54:45.821475
#
#                       duration  params_batch_size  \
# number
# 207     0 days 00:04:29.415381                 64
# 415     0 days 00:04:24.031322                 64
# 316     0 days 00:06:45.998692                 64
# 327     0 days 00:04:14.396655                 64
# 774     0 days 00:03:57.832401                 64
# ...                        ...                ...
# 930     0 days 00:05:34.607666                 64
# 445     0 days 00:01:15.607313                 64
# 806     0 days 00:00:06.112728                 64
# 277     0 days 00:00:08.461169                 64
# 170     0 days 00:00:19.292965                 64
#
#         params_ffn_de_global_dropout  params_ffn_de_input_dropout  \
# number
# 207                             0.10                         0.36
# 415                             0.57                         0.17
# 316                             0.42                         0.25
# 327                             0.40                         0.22
# 774                             0.47                         0.24
# ...                              ...                          ...
# 930                             0.42                         0.31
# 445                             0.50                         0.26
# 806                             0.60                         0.16
# 277                             0.15                         0.37
# 170                             0.48                         0.28
#
#         params_ffn_de_output_dropout  params_lat_encoder_cat_before_rt  \
# number
# 207                             0.18                             False
# 415                             0.02                              True
# 316                             0.06                              True
# 327                             0.05                              True
# 774                             0.08                             False
# ...                              ...                               ...
# 930                             0.08                              True
# 445                             0.08                              True
# 806                             0.06                             False
# 277                             0.05                             False
# 170                             0.44                              True
#
#         params_lat_encoder_class_agg params_lat_encoder_dist_type  \
# number
# 207                            False                       normal
# 415                             True                         beta
# 316                             True                         beta
# 327                             True                         beta
# 774                            False                       normal
# ...                              ...                          ...
# 930                             True                       normal
# 445                             True                       normal
# 806                             True                         beta
# 277                            False                       normal
# 170                            False                       normal
#
#        params_lat_encoder_latent_size  params_mha_rt_dropout  \
# number
# 207                              none                   0.54
# 415                              none                   0.27
# 316                              none                   0.29
# 327                              none                   0.29
# 774                              none                   0.16
# ...                               ...                    ...
# 930                              1024                   0.02
# 445                              1024                   0.08
# 806                              1024                   0.31
# 277                              none                   0.27
# 170                              none                   0.05
#
#         params_mha_rt_num_heads  params_sample_latent_post  \
# number
# 207                           1                       True
# 415                           1                       True
# 316                          10                       True
# 327                           1                       True
# 774                           1                       True
# ...                         ...                        ...
# 930                          10                       True
# 445                           1                       True
# 806                           1                       True
# 277                          10                       True
# 170                          10                      False
#
#         params_sample_latent_prior  params_sample_out  \
# number
# 207                          False              False
# 415                           True              False
# 316                          False              False
# 327                          False              False
# 774                          False              False
# ...                            ...                ...
# 930                           True              False
# 445                          False              False
# 806                          False              False
# 277                          False               True
# 170                          False               True
#
#         params_stcn_ft_dilation_power  params_stcn_ft_input_dropout  \
# number
# 207                                 2                          0.04
# 415                                 3                          0.35
# 316                                 2                          0.39
# 327                                 2                          0.37
# 774                                 1                          0.28
# ...                               ...                           ...
# 930                                 1                          0.16
# 445                                 2                          0.37
# 806                                 3                          0.13
# 277                                 3                          0.01
# 170                                 2                          0.13
#
#         params_stcn_ft_kernel_sizes  params_stcn_ft_output_dropout  \
# number
# 207                               8                           0.45
# 415                               8                           0.53
# 316                               8                           0.60
# 327                               8                           0.60
# 774                               9                           0.15
# ...                             ...                            ...
# 930                               9                           0.19
# 445                               8                           0.56
# 806                               9                           0.32
# 277                               7                           0.52
# 170                               8                           0.46
#
#         params_train_target_overlap  system_attrs_completed_rung_0  \
# number
# 207                               0                       0.560966
# 415                               8                       0.554010
# 316                               8                       0.542203
# 327                               8                       0.556460
# 774                               0                       0.568022
# ...                             ...                            ...
# 930                               8                       0.564607
# 445                               8                       0.314525
# 806                               8                       0.314525
# 277                               8                       0.314525
# 170                               0                       0.314525
#
#         system_attrs_completed_rung_1  system_attrs_completed_rung_2  \
# number
# 207                          0.572253                       0.578176
# 415                          0.555762                            NaN
# 316                          0.563780                            NaN
# 327                          0.564513                            NaN
# 774                          0.562463                       0.562463
# ...                               ...                            ...
# 930                          0.563495                       0.314525
# 445                               NaN                            NaN
# 806                               NaN                            NaN
# 277                               NaN                            NaN
# 170                               NaN                            NaN
#
#         system_attrs_completed_rung_3  system_attrs_completed_rung_4     state
# number
# 207                          0.554955                       0.577062  COMPLETE
# 415                               NaN                            NaN  COMPLETE
# 316                               NaN                            NaN  COMPLETE
# 327                               NaN                            NaN  COMPLETE
# 774                               NaN                            NaN  COMPLETE
# ...                               ...                            ...       ...
# 930                               NaN                            NaN    PRUNED
# 445                               NaN                            NaN    PRUNED
# 806                               NaN                            NaN    PRUNED
# 277                               NaN                            NaN    PRUNED
# 170                               NaN                            NaN    PRUNED
#
# [1000 rows x 28 columns]

# %% [markdown]
# ### Dropout

# %%
drop_cols = [col for col in optuna_results[ASSETS[0]].columns if ('dropout' in col and 'ft_' in col)]

# %%
for asset_name in ASSETS:
    print(asset_name, ':', optuna_results[asset_name].head(topn).loc[:, drop_cols].median())
# Out:
# sp_500 : params_stcn_ft_input_dropout     0.35
# params_stcn_ft_output_dropout    0.53
# dtype: float64
# russell_2000 : params_stcn_ft_input_dropout     0.05
# params_stcn_ft_output_dropout    0.42
# dtype: float64
# nasdaq_100 : params_stcn_ft_input_dropout     0.18
# params_stcn_ft_output_dropout    0.24
# dtype: float64
# dow_jones : params_stcn_ft_input_dropout     0.16
# params_stcn_ft_output_dropout    0.40
# dtype: float64

# %%
drop_cols = [col for col in optuna_results[ASSETS[0]].columns if ('params_train_target_overlap' in col)]
for asset_name in ASSETS:
    print(asset_name, ':', optuna_results[asset_name].head(topn).loc[:, drop_cols].describe())
# Out:
# sp_500 :        params_train_target_overlap
# count                      5.00000
# mean                       4.80000
# std                        4.38178
# min                        0.00000
# 25%                        0.00000
# 50%                        8.00000
# 75%                        8.00000
# max                        8.00000
# russell_2000 :        params_train_target_overlap
# count                     5.000000
# mean                      1.600000
# std                       3.577709
# min                       0.000000
# 25%                       0.000000
# 50%                       0.000000
# 75%                       0.000000
# max                       8.000000
# nasdaq_100 :        params_train_target_overlap
# count                      5.00000
# mean                      12.80000
# std                        4.38178
# min                        8.00000
# 25%                        8.00000
# 50%                       16.00000
# 75%                       16.00000
# max                       16.00000
# dow_jones :        params_train_target_overlap
# count                     5.000000
# mean                      8.000000
# std                       5.656854
# min                       0.000000
# 25%                       8.000000
# 50%                       8.000000
# 75%                       8.000000
# max                      16.000000
