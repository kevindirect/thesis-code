# %% [markdown]
# # nb-model_exp-results-2-2 (h_pba_h_h_vol_h)

# %%
import sys
import os
from os import sep
from os.path import dirname, realpath, exists, basename
from pathlib import Path
from glob import glob, iglob
import logging

def get_cwd(fname, subdir, crunch_dir=realpath(Path.home()) +sep +'crunch' +sep):
    """
    Convenience function to make a directory string for the current file based on inputs.
    Jupyter Notebook in Anaconda invokes the Python interpreter in Anaconda's subdirectory
    which is why changing sys.argv[0] is necessary. In the future a better way to do this
    should be preferred..
    """
    return crunch_dir +subdir +fname

def fix_path(cwd):
    """
    Convenience function to fix argv and python path so that jupyter notebook can run the same as
    any script in crunch.
    """
    sys.argv[0] = cwd
    module_path = os.path.abspath(os.path.join('..'))
    if module_path not in sys.path:
        sys.path.append(module_path)

fname = 'nb-model_exp-results-2-2.ipynb'
dir_name = 'model'
fix_path(get_cwd(fname, dir_name +sep))

import numpy as np
import pandas as pd

from ipywidgets import interact, interactive, fixed
from IPython.display import display

pd.set_option("display.max_rows", 300)
pd.set_option("display.max_columns", 50)

from common_util import MODEL_DIR, load_json, dump_json, rectify_json, load_df, str_now, makedir_if_not_exists, is_valid, isnt, compose, pd_split_ternary_to_binary, df_del_midx_level, midx_intersect, pd_get_midx_level, pd_rows, df_midx_restack
from common_util import NestedDefaultDict
from model.common import EXP_LOG_DIR, EXP_PARAMS_DIR, ASSETS, DATASET_DIR, XG_PROCESS_DIR, XG_DATA_DIR, XG_DIR, PYTORCH_MODELS_DIR, TRAIN_RATIO, EXPECTED_NUM_HOURS
from recon.viz import *
logging.basicConfig(stream=sys.stdout, level=logging.DEBUG)
# Out:
# CRITICAL:root:script location: /home/kev/crunch/model/nb-model_exp-results-2-2.ipynb
# CRITICAL:root:using project dir: /home/kev/crunch/

# %% [markdown]
# Prune the xg data down to the data of interest to use in further experiments.

# %%
def get_bench(pattern):
    ndd = NestedDefaultDict()
    for path in iglob(pattern, recursive=True):
        ndd[path.split('/')] = load_json(path)

    df_idx = [k[2] for k in ndd.keys()]
    df = pd.DataFrame.from_records([b['benchmark-hold'] for b in ndd.values()], index=df_idx)

    return df

# %%
def consolidate_results(pattern, bench_pattern=None):
    ndd = NestedDefaultDict()
    for path in iglob(pattern, recursive=True):
        ndd[path.split('/')] = load_json(path)
    df_keys = [(k[2], k[3], k[4], k[5], k[6]) for k in ndd.keys()]
    df_idx = pd.MultiIndex.from_tuples(df_keys, names=('asset', 'model', 'data', 'params', 'trial')) \
        .remove_unused_levels()
    df = pd.DataFrame.from_records(list(ndd.values()), index=df_idx) \
        .reset_index() \
        .groupby(['asset', 'model', 'params']).mean() # average across trials for each study

    if (is_valid(bench_pattern)):
        bench_df = get_bench(bench_pattern)
        mets = ['accuracy', 'precision', 'recall', 'f1']
        rets = ['profit', 'sharpe', 'cagr']
        for m in mets+rets:
            res_cols = [c for c in df.columns if (c.endswith(m))]
            bench_cols = [c for c in bench_df.columns if (c.endswith(m))]
            bench_col = bench_cols[0]

            for asset in bench_df.index:
#                 print(bench_df.loc[asset, bench_col])
#                 print(df.xs(asset, level=0, drop_level=False)[res_cols])
                df.xs(asset, level=0, drop_level=False).loc[:, res_cols] -= bench_df.loc[asset, bench_col]
#     df = df.style \
#         .background_gradient(subset=[c for c in df.columns if c.endswith(('accuracy', 'profit', 'sharpe', 'cagr'))], cmap='BuGn')
#     .set_sticky(axis="index") \
    return df

# %%
def agg_asset(res_df):
    agg_df = res_df.groupby(['model', 'params']).mean()
    return agg_df

# %%
def agg_model(res_df):
    agg_df = res_df.groupby(['params']).mean()
    return agg_df

# %%
def agg_asset_params(res_df):
    return res_df.groupby(['asset', 'params']).mean()

# %%
def add_style(df):
    df = df.style \
         .background_gradient(subset=[c for c in df.columns if c.endswith(('accuracy', 'f1', 'profit', 'sharpe', 'cagr'))], cmap='BuGn')
#     .set_sticky(axis="index") \
    return df

# %%
view = ('accuracy', 'f1', 'profit', 'sharpe', 'cagr')

def select_ends(df, ends=view):
    res_cols = [c for c in df.columns if (c.endswith(ends))]
#     for m in ends:
#         res_cols = [c for c in df.columns if (c.endswith(m))]
    return df.loc[:, res_cols]

# %%
def select_paramrange(df, r):
    params = map(str, r)
    return df.loc[(slice(None), slice(None), params), :]

# %%
def dropfirstmi(df):
    df.index = df.index.droplevel(0)
    return df

def gb_filter_monotonic(df, checkcol='val_binary_sharpe'):
    return dropfirstmi(df.reorder_levels(['asset', 'params', 'model']) \
            .groupby('params') \
            .apply(lambda g: g if (g[checkcol].is_monotonic_increasing) else None) \
            .sort_index())

subgt = lambda g, big, small='base': (g.xs(big, level=2) > g.xs(small, level=2)).all()
monotonic_partial = lambda g: (subgt(g, 'lnp') and subgt(g, 'np', 'lnp')) or (subgt(g, 'cnp') and subgt(g, 'np', 'cnp'))

def gb_filter_monotonic_partial(df, checkcol='val_binary_sharpe'):
    return dropfirstmi(df.reorder_levels(['asset', 'params', 'model']) \
            .groupby('params') \
            .apply(lambda g: g if (monotonic_partial(g[checkcol])) else None) \
            .sort_index())

nonneg = lambda g: (g.xs('np', level=2) > 0).all() and (g.xs('lnp', level=2) > 0).all()

def gb_filter_neg(df, checkcol='val_binary_sharpe'):
    return dropfirstmi(df.reorder_levels(['asset', 'params', 'model']) \
            .groupby('params') \
            .apply(lambda g: g if (nonneg(g[checkcol])) else None) \
            .sort_index())

def gb_filter_lf(df, checkcol='val_binary_longfreq'):
    return dropfirstmi(df.groupby('params') \
            .apply(lambda g: g if ((g[checkcol].between(.2, .8)).all()) else None))

# %%
# def get_params_per_dataset():
#     EXP_LOG_DIR

# %%
exp_base = basename(dirname(EXP_LOG_DIR))
sm_name = 'anp'

drange = '2009_2018'
xdata = 'h_pba_h_h_vol_h'
ydata = 'ddir'
data_name = f'{drange}_{ydata}_{xdata}'
bench_data_name = f'{drange}_{ydata}'

path_train = f"{exp_base}/{sm_name}/**/{data_name}/**/train.json"
path_val =   f"{exp_base}/{sm_name}/**/{data_name}/**/val.json"
# path_test = f"{exp_base}/{sm_name}/**/{data_name}/**/test.json"

path_bench_train = f"{exp_base}/bench/*/{bench_data_name}/train.json"
path_bench_val = f"{exp_base}/bench/*/{bench_data_name}/val.json"
# path_bench_test = f"{exp_base}/bench/*/{bench_data_name}/test.json"

# %%
PRANGE = range(200, 270)

# absolute results
dt = select_paramrange(consolidate_results(path_train), PRANGE);
dv = select_paramrange(consolidate_results(path_val), PRANGE);

# benchmark adjusted results
dt_adj = select_paramrange(consolidate_results(path_train, path_bench_train), PRANGE);
dv_adj = select_paramrange(consolidate_results(path_val, path_bench_val), PRANGE);
# Out:
# /home/kev/miniconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1787: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, val, pi)

# %% [markdown]
# ## Results
# Parameter sets >= 200

# %%
# sp_500: 120, 56
# russell_2000: 60, 54, 83
# nasdaq_100: 14, 124
# dow_jones: 107, 124, 62
# +110

# *0 -> 62
# *1 -> 83

# *2 -> 14
# *3 -> 54
# *4 -> 124

# *5 -> 56

# *6 -> 107

# *7 -> 60
# *8 -> 110
# *9 -> 120

# %%
# (200-209) -> (210-219): output init set to kaiming_uniform
# (200-209) -> (220-229): all in2d replaced with in15d
# (200-209) -> (230-239): all in15d->in2d, in2d->in15d
# (200-209) -> (240-249): double batch size
# (230-239) -> (250-259): double batch size
# (202, 210-212, 214, 221-222, 234-246) -> (260-269): set window size to 40
# final:

# %%
train_clf = [col for col in dt.columns if ('clf' in col)]
train_binary = [col for col in dt.columns if ('binary' in col)]
train_binary_sharpe = [col for col in train_binary if (col.endswith('sharpe'))]

# %%
val_clf = [col for col in dv.columns if ('clf' in col)]
val_binary = [col for col in dv.columns if ('binary' in col)]
val_binary_sharpe = [col for col in val_binary if (col.endswith('sharpe'))]

# %%
add_style(agg_model(agg_asset(dt_adj.loc[:, train_binary_sharpe])))
# Out:
# <style  type="text/css" >
# #T_5b1f0_row0_col0{
#             background-color:  #87d0bc;
#             color:  #000000;
#         }#T_5b1f0_row0_col1,#T_5b1f0_row68_col0{
#             background-color:  #6ac4a7;
#             color:  #000000;
#         }#T_5b1f0_row0_col2{
#             background-color:  #97d7c7;
#             color:  #000000;
#         }#T_5b1f0_row1_col0,#T_5b1f0_row56_col2,#T_5b1f0_row58_col1{
#             background-color:  #d7f0ee;
#             color:  #000000;
#         }#T_5b1f0_row1_col1,#T_5b1f0_row50_col1,#T_5b1f0_row52_col2{
#             background-color:  #cdece7;
#             color:  #000000;
#         }#T_5b1f0_row1_col2,#T_5b1f0_row2_col0,#T_5b1f0_row12_col2,#T_5b1f0_row27_col2{
#             background-color:  #def2f4;
#             color:  #000000;
#         }#T_5b1f0_row2_col1,#T_5b1f0_row8_col2,#T_5b1f0_row12_col1,#T_5b1f0_row18_col2,#T_5b1f0_row25_col2,#T_5b1f0_row27_col0,#T_5b1f0_row37_col2,#T_5b1f0_row63_col0{
#             background-color:  #d8f0ef;
#             color:  #000000;
#         }#T_5b1f0_row2_col2{
#             background-color:  #e1f4f6;
#             color:  #000000;
#         }#T_5b1f0_row3_col0,#T_5b1f0_row6_col0,#T_5b1f0_row13_col0,#T_5b1f0_row26_col2{
#             background-color:  #edf8fb;
#             color:  #000000;
#         }#T_5b1f0_row3_col1,#T_5b1f0_row16_col0{
#             background-color:  #ecf8fa;
#             color:  #000000;
#         }#T_5b1f0_row3_col2,#T_5b1f0_row42_col2,#T_5b1f0_row43_col0,#T_5b1f0_row43_col2,#T_5b1f0_row65_col1,#T_5b1f0_row65_col2{
#             background-color:  #eff9fb;
#             color:  #000000;
#         }#T_5b1f0_row4_col0,#T_5b1f0_row24_col1{
#             background-color:  #2c9553;
#             color:  #000000;
#         }#T_5b1f0_row4_col1{
#             background-color:  #238b45;
#             color:  #000000;
#         }#T_5b1f0_row4_col2{
#             background-color:  #2e9756;
#             color:  #000000;
#         }#T_5b1f0_row5_col0,#T_5b1f0_row18_col0,#T_5b1f0_row58_col0{
#             background-color:  #d6f0ee;
#             color:  #000000;
#         }#T_5b1f0_row5_col1,#T_5b1f0_row9_col0,#T_5b1f0_row29_col0{
#             background-color:  #cfede8;
#             color:  #000000;
#         }#T_5b1f0_row5_col2,#T_5b1f0_row7_col1,#T_5b1f0_row12_col0,#T_5b1f0_row33_col2,#T_5b1f0_row63_col1{
#             background-color:  #dbf2f2;
#             color:  #000000;
#         }#T_5b1f0_row6_col1,#T_5b1f0_row22_col2,#T_5b1f0_row31_col0{
#             background-color:  #ebf7fa;
#             color:  #000000;
#         }#T_5b1f0_row6_col2,#T_5b1f0_row16_col2,#T_5b1f0_row42_col0,#T_5b1f0_row46_col1{
#             background-color:  #f1fafc;
#             color:  #000000;
#         }#T_5b1f0_row7_col0{
#             background-color:  #e2f4f7;
#             color:  #000000;
#         }#T_5b1f0_row7_col2,#T_5b1f0_row16_col1,#T_5b1f0_row47_col2{
#             background-color:  #e6f5f9;
#             color:  #000000;
#         }#T_5b1f0_row8_col0,#T_5b1f0_row21_col2,#T_5b1f0_row58_col2{
#             background-color:  #d3eeeb;
#             color:  #000000;
#         }#T_5b1f0_row8_col1,#T_5b1f0_row28_col0{
#             background-color:  #caebe5;
#             color:  #000000;
#         }#T_5b1f0_row9_col1,#T_5b1f0_row40_col0{
#             background-color:  #c5e9e2;
#             color:  #000000;
#         }#T_5b1f0_row9_col2,#T_5b1f0_row25_col0{
#             background-color:  #d1eeea;
#             color:  #000000;
#         }#T_5b1f0_row10_col0{
#             background-color:  #68c3a6;
#             color:  #000000;
#         }#T_5b1f0_row10_col1{
#             background-color:  #64c1a2;
#             color:  #000000;
#         }#T_5b1f0_row10_col2,#T_5b1f0_row44_col0,#T_5b1f0_row68_col2{
#             background-color:  #60bf9c;
#             color:  #000000;
#         }#T_5b1f0_row11_col0{
#             background-color:  #7dccb5;
#             color:  #000000;
#         }#T_5b1f0_row11_col1,#T_5b1f0_row20_col1{
#             background-color:  #6dc5a9;
#             color:  #000000;
#         }#T_5b1f0_row11_col2{
#             background-color:  #7fcdb6;
#             color:  #000000;
#         }#T_5b1f0_row13_col1,#T_5b1f0_row22_col0{
#             background-color:  #e8f6fa;
#             color:  #000000;
#         }#T_5b1f0_row13_col2,#T_5b1f0_row23_col2,#T_5b1f0_row42_col1{
#             background-color:  #f2fafc;
#             color:  #000000;
#         }#T_5b1f0_row14_col0{
#             background-color:  #8fd4c2;
#             color:  #000000;
#         }#T_5b1f0_row14_col1{
#             background-color:  #80cdb7;
#             color:  #000000;
#         }#T_5b1f0_row14_col2{
#             background-color:  #95d6c6;
#             color:  #000000;
#         }#T_5b1f0_row15_col0,#T_5b1f0_row19_col1{
#             background-color:  #bae5dc;
#             color:  #000000;
#         }#T_5b1f0_row15_col1{
#             background-color:  #a4dccf;
#             color:  #000000;
#         }#T_5b1f0_row15_col2{
#             background-color:  #c2e8e0;
#             color:  #000000;
#         }#T_5b1f0_row17_col0,#T_5b1f0_row28_col2,#T_5b1f0_row36_col2{
#             background-color:  #c8ebe4;
#             color:  #000000;
#         }#T_5b1f0_row17_col1{
#             background-color:  #b5e3d9;
#             color:  #000000;
#         }#T_5b1f0_row17_col2,#T_5b1f0_row52_col0{
#             background-color:  #ceede8;
#             color:  #000000;
#         }#T_5b1f0_row18_col1,#T_5b1f0_row27_col1,#T_5b1f0_row63_col2{
#             background-color:  #d1eee9;
#             color:  #000000;
#         }#T_5b1f0_row19_col0,#T_5b1f0_row50_col0{
#             background-color:  #ccece6;
#             color:  #000000;
#         }#T_5b1f0_row19_col2,#T_5b1f0_row37_col1,#T_5b1f0_row66_col1{
#             background-color:  #d0ede9;
#             color:  #000000;
#         }#T_5b1f0_row20_col0{
#             background-color:  #82ceb8;
#             color:  #000000;
#         }#T_5b1f0_row20_col2,#T_5b1f0_row30_col1{
#             background-color:  #88d1bd;
#             color:  #000000;
#         }#T_5b1f0_row21_col0{
#             background-color:  #d4efec;
#             color:  #000000;
#         }#T_5b1f0_row21_col1,#T_5b1f0_row66_col0,#T_5b1f0_row66_col2{
#             background-color:  #d2eeeb;
#             color:  #000000;
#         }#T_5b1f0_row22_col1,#T_5b1f0_row47_col1{
#             background-color:  #e4f5f8;
#             color:  #000000;
#         }#T_5b1f0_row23_col0,#T_5b1f0_row43_col1,#T_5b1f0_row65_col0{
#             background-color:  #eef8fb;
#             color:  #000000;
#         }#T_5b1f0_row23_col1,#T_5b1f0_row26_col0,#T_5b1f0_row31_col1,#T_5b1f0_row31_col2,#T_5b1f0_row55_col1,#T_5b1f0_row57_col2{
#             background-color:  #e9f7fa;
#             color:  #000000;
#         }#T_5b1f0_row24_col0{
#             background-color:  #2f9858;
#             color:  #000000;
#         }#T_5b1f0_row24_col2{
#             background-color:  #28914d;
#             color:  #000000;
#         }#T_5b1f0_row25_col1,#T_5b1f0_row28_col1,#T_5b1f0_row36_col0,#T_5b1f0_row40_col1{
#             background-color:  #c4e9e1;
#             color:  #000000;
#         }#T_5b1f0_row26_col1,#T_5b1f0_row59_col1,#T_5b1f0_row60_col2{
#             background-color:  #e3f4f8;
#             color:  #000000;
#         }#T_5b1f0_row29_col1,#T_5b1f0_row29_col2,#T_5b1f0_row52_col1{
#             background-color:  #cdece6;
#             color:  #000000;
#         }#T_5b1f0_row30_col0,#T_5b1f0_row32_col1{
#             background-color:  #98d8c9;
#             color:  #000000;
#         }#T_5b1f0_row30_col2{
#             background-color:  #9ad8ca;
#             color:  #000000;
#         }#T_5b1f0_row32_col0{
#             background-color:  #a5ddd0;
#             color:  #000000;
#         }#T_5b1f0_row32_col2{
#             background-color:  #a8ded2;
#             color:  #000000;
#         }#T_5b1f0_row33_col0,#T_5b1f0_row35_col2,#T_5b1f0_row48_col0,#T_5b1f0_row49_col1{
#             background-color:  #dcf2f2;
#             color:  #000000;
#         }#T_5b1f0_row33_col1,#T_5b1f0_row49_col2,#T_5b1f0_row56_col1,#T_5b1f0_row59_col2{
#             background-color:  #dbf1f1;
#             color:  #000000;
#         }#T_5b1f0_row34_col0{
#             background-color:  #2b9452;

# %%
add_style(agg_model(dv_adj.loc[:, val_binary_sharpe]))
# Out:
# <style  type="text/css" >
# #T_ab4c6_row0_col0,#T_ab4c6_row26_col2,#T_ab4c6_row65_col1{
#             background-color:  #d8f0ef;
#             color:  #000000;
#         }#T_ab4c6_row0_col1{
#             background-color:  #d2eeeb;
#             color:  #000000;
#         }#T_ab4c6_row0_col2{
#             background-color:  #ceede8;
#             color:  #000000;
#         }#T_ab4c6_row1_col0,#T_ab4c6_row43_col0{
#             background-color:  #74c8ae;
#             color:  #000000;
#         }#T_ab4c6_row1_col1,#T_ab4c6_row20_col0,#T_ab4c6_row23_col1,#T_ab4c6_row30_col2,#T_ab4c6_row31_col0{
#             background-color:  #6dc5a9;
#             color:  #000000;
#         }#T_ab4c6_row1_col2,#T_ab4c6_row29_col2{
#             background-color:  #88d1bd;
#             color:  #000000;
#         }#T_ab4c6_row2_col0{
#             background-color:  #127c39;
#             color:  #f1f1f1;
#         }#T_ab4c6_row2_col1,#T_ab4c6_row10_col1{
#             background-color:  #1c8540;
#             color:  #000000;
#         }#T_ab4c6_row2_col2{
#             background-color:  #147e3a;
#             color:  #f1f1f1;
#         }#T_ab4c6_row3_col0,#T_ab4c6_row54_col1{
#             background-color:  #4bb382;
#             color:  #000000;
#         }#T_ab4c6_row3_col1,#T_ab4c6_row11_col2{
#             background-color:  #48b27f;
#             color:  #000000;
#         }#T_ab4c6_row3_col2{
#             background-color:  #62c09f;
#             color:  #000000;
#         }#T_ab4c6_row4_col0,#T_ab4c6_row60_col1{
#             background-color:  #92d5c4;
#             color:  #000000;
#         }#T_ab4c6_row4_col1{
#             background-color:  #9ad8ca;
#             color:  #000000;
#         }#T_ab4c6_row4_col2,#T_ab4c6_row58_col0{
#             background-color:  #84cfb9;
#             color:  #000000;
#         }#T_ab4c6_row5_col0,#T_ab4c6_row7_col2,#T_ab4c6_row37_col1{
#             background-color:  #7dccb5;
#             color:  #000000;
#         }#T_ab4c6_row5_col1,#T_ab4c6_row42_col2{
#             background-color:  #65c2a3;
#             color:  #000000;
#         }#T_ab4c6_row5_col2,#T_ab4c6_row25_col2{
#             background-color:  #9ddacb;
#             color:  #000000;
#         }#T_ab4c6_row6_col0,#T_ab4c6_row50_col0{
#             background-color:  #8ad2be;
#             color:  #000000;
#         }#T_ab4c6_row6_col1,#T_ab4c6_row40_col2,#T_ab4c6_row41_col0{
#             background-color:  #75c9af;
#             color:  #000000;
#         }#T_ab4c6_row6_col2,#T_ab4c6_row50_col2{
#             background-color:  #a2dcce;
#             color:  #000000;
#         }#T_ab4c6_row7_col0,#T_ab4c6_row9_col2,#T_ab4c6_row13_col2,#T_ab4c6_row63_col2{
#             background-color:  #60bf9c;
#             color:  #000000;
#         }#T_ab4c6_row7_col1,#T_ab4c6_row31_col2{
#             background-color:  #4eb586;
#             color:  #000000;
#         }#T_ab4c6_row8_col0{
#             background-color:  #bfe7de;
#             color:  #000000;
#         }#T_ab4c6_row8_col1{
#             background-color:  #a8ded2;
#             color:  #000000;
#         }#T_ab4c6_row8_col2{
#             background-color:  #d3eeeb;
#             color:  #000000;
#         }#T_ab4c6_row9_col0,#T_ab4c6_row58_col1{
#             background-color:  #4ab381;
#             color:  #000000;
#         }#T_ab4c6_row9_col1{
#             background-color:  #41ae77;
#             color:  #000000;
#         }#T_ab4c6_row10_col0{
#             background-color:  #0d7836;
#             color:  #f1f1f1;
#         }#T_ab4c6_row10_col2,#T_ab4c6_row22_col1,#T_ab4c6_row34_col1{
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }#T_ab4c6_row11_col0{
#             background-color:  #39a569;
#             color:  #000000;
#         }#T_ab4c6_row11_col1{
#             background-color:  #319c5c;
#             color:  #000000;
#         }#T_ab4c6_row12_col0,#T_ab4c6_row12_col2,#T_ab4c6_row36_col1{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_ab4c6_row12_col1{
#             background-color:  #00692a;
#             color:  #f1f1f1;
#         }#T_ab4c6_row13_col0,#T_ab4c6_row40_col0,#T_ab4c6_row48_col1{
#             background-color:  #55b98f;
#             color:  #000000;
#         }#T_ab4c6_row13_col1{
#             background-color:  #53b88c;
#             color:  #000000;
#         }#T_ab4c6_row14_col0,#T_ab4c6_row52_col0{
#             background-color:  #28914d;
#             color:  #000000;
#         }#T_ab4c6_row14_col1,#T_ab4c6_row21_col1,#T_ab4c6_row46_col1{
#             background-color:  #238b45;
#             color:  #000000;
#         }#T_ab4c6_row14_col2{
#             background-color:  #349f61;
#             color:  #000000;
#         }#T_ab4c6_row15_col0{
#             background-color:  #218944;
#             color:  #000000;
#         }#T_ab4c6_row15_col1,#T_ab4c6_row49_col1{
#             background-color:  #026f2e;
#             color:  #f1f1f1;
#         }#T_ab4c6_row15_col2,#T_ab4c6_row17_col1,#T_ab4c6_row43_col1,#T_ab4c6_row68_col2{
#             background-color:  #46b17c;
#             color:  #000000;
#         }#T_ab4c6_row16_col0{
#             background-color:  #3fab72;
#             color:  #000000;
#         }#T_ab4c6_row16_col1,#T_ab4c6_row56_col1{
#             background-color:  #2d9655;
#             color:  #000000;
#         }#T_ab4c6_row16_col2,#T_ab4c6_row49_col2{
#             background-color:  #5abb95;
#             color:  #000000;
#         }#T_ab4c6_row17_col0,#T_ab4c6_row41_col1{
#             background-color:  #54b88e;
#             color:  #000000;
#         }#T_ab4c6_row17_col2,#T_ab4c6_row45_col1,#T_ab4c6_row65_col2{
#             background-color:  #70c6ac;
#             color:  #000000;
#         }#T_ab4c6_row18_col0,#T_ab4c6_row33_col2,#T_ab4c6_row67_col1{
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }#T_ab4c6_row18_col1{
#             background-color:  #ecf8fa;
#             color:  #000000;
#         }#T_ab4c6_row18_col2{
#             background-color:  #f4fbfc;
#             color:  #000000;
#         }#T_ab4c6_row19_col0,#T_ab4c6_row50_col1{
#             background-color:  #6fc6aa;
#             color:  #000000;
#         }#T_ab4c6_row19_col1{
#             background-color:  #5cbd98;
#             color:  #000000;
#         }#T_ab4c6_row19_col2,#T_ab4c6_row69_col2{
#             background-color:  #8fd4c2;
#             color:  #000000;
#         }#T_ab4c6_row20_col1,#T_ab4c6_row27_col2{
#             background-color:  #6ac4a7;
#             color:  #000000;
#         }#T_ab4c6_row20_col2{
#             background-color:  #7acbb3;
#             color:  #000000;
#         }#T_ab4c6_row21_col0,#T_ab4c6_row34_col0,#T_ab4c6_row52_col1{
#             background-color:  #137d39;
#             color:  #f1f1f1;
#         }#T_ab4c6_row21_col2,#T_ab4c6_row22_col2{
#             background-color:  #17813d;
#             color:  #f1f1f1;
#         }#T_ab4c6_row22_col0{
#             background-color:  #097532;
#             color:  #f1f1f1;
#         }#T_ab4c6_row23_col0,#T_ab4c6_row39_col1{
#             background-color:  #77c9b0;
#             color:  #000000;
#         }#T_ab4c6_row23_col2,#T_ab4c6_row54_col2,#T_ab4c6_row63_col0{
#             background-color:  #94d6c5;
#             color:  #000000;
#         }#T_ab4c6_row24_col0{
#             background-color:  #8cd2bf;
#             color:  #000000;
#         }#T_ab4c6_row24_col1,#T_ab4c6_row24_col2,#T_ab4c6_row68_col1{
#             background-color:  #82ceb8;
#             color:  #000000;
#         }#T_ab4c6_row25_col0,#T_ab4c6_row41_col2,#T_ab4c6_row45_col0{
#             background-color:  #7fcdb6;
#             color:  #000000;
#         }#T_ab4c6_row25_col1,#T_ab4c6_row59_col0{
#             background-color:  #61bf9e;
#             color:  #000000;
#         }#T_ab4c6_row26_col0{
#             background-color:  #cfede8;
#             color:  #000000;
#         }#T_ab4c6_row26_col1,#T_ab4c6_row43_col2{
#             background-color:  #bae5dc;
#             color:  #000000;
#         }#T_ab4c6_row27_col0,#T_ab4c6_row27_col1,#T_ab4c6_row29_col0{
#             background-color:  #5bbc96;
#             color:  #000000;
#         }#T_ab4c6_row28_col0{
#             background-color:  #e0f3f5;
#             color:  #000000;
#         }#T_ab4c6_row

# %%
add_style(agg_asset_params(dv_adj.loc[:, val_binary_sharpe]).sort_index(level=[1, 0]).groupby('params').mean())
# Out:
# <style  type="text/css" >
# #T_e1d44_row0_col0,#T_e1d44_row26_col2,#T_e1d44_row65_col1{
#             background-color:  #d8f0ef;
#             color:  #000000;
#         }#T_e1d44_row0_col1{
#             background-color:  #d2eeeb;
#             color:  #000000;
#         }#T_e1d44_row0_col2{
#             background-color:  #ceede8;
#             color:  #000000;
#         }#T_e1d44_row1_col0,#T_e1d44_row43_col0{
#             background-color:  #74c8ae;
#             color:  #000000;
#         }#T_e1d44_row1_col1,#T_e1d44_row20_col0,#T_e1d44_row23_col1,#T_e1d44_row30_col2,#T_e1d44_row31_col0{
#             background-color:  #6dc5a9;
#             color:  #000000;
#         }#T_e1d44_row1_col2,#T_e1d44_row29_col2{
#             background-color:  #88d1bd;
#             color:  #000000;
#         }#T_e1d44_row2_col0{
#             background-color:  #127c39;
#             color:  #f1f1f1;
#         }#T_e1d44_row2_col1,#T_e1d44_row10_col1{
#             background-color:  #1c8540;
#             color:  #000000;
#         }#T_e1d44_row2_col2{
#             background-color:  #147e3a;
#             color:  #f1f1f1;
#         }#T_e1d44_row3_col0,#T_e1d44_row54_col1{
#             background-color:  #4bb382;
#             color:  #000000;
#         }#T_e1d44_row3_col1,#T_e1d44_row11_col2{
#             background-color:  #48b27f;
#             color:  #000000;
#         }#T_e1d44_row3_col2{
#             background-color:  #62c09f;
#             color:  #000000;
#         }#T_e1d44_row4_col0,#T_e1d44_row60_col1{
#             background-color:  #92d5c4;
#             color:  #000000;
#         }#T_e1d44_row4_col1{
#             background-color:  #9ad8ca;
#             color:  #000000;
#         }#T_e1d44_row4_col2,#T_e1d44_row58_col0{
#             background-color:  #84cfb9;
#             color:  #000000;
#         }#T_e1d44_row5_col0,#T_e1d44_row7_col2,#T_e1d44_row37_col1{
#             background-color:  #7dccb5;
#             color:  #000000;
#         }#T_e1d44_row5_col1,#T_e1d44_row42_col2{
#             background-color:  #65c2a3;
#             color:  #000000;
#         }#T_e1d44_row5_col2,#T_e1d44_row25_col2{
#             background-color:  #9ddacb;
#             color:  #000000;
#         }#T_e1d44_row6_col0,#T_e1d44_row50_col0{
#             background-color:  #8ad2be;
#             color:  #000000;
#         }#T_e1d44_row6_col1,#T_e1d44_row40_col2,#T_e1d44_row41_col0{
#             background-color:  #75c9af;
#             color:  #000000;
#         }#T_e1d44_row6_col2,#T_e1d44_row50_col2{
#             background-color:  #a2dcce;
#             color:  #000000;
#         }#T_e1d44_row7_col0,#T_e1d44_row9_col2,#T_e1d44_row13_col2,#T_e1d44_row63_col2{
#             background-color:  #60bf9c;
#             color:  #000000;
#         }#T_e1d44_row7_col1,#T_e1d44_row31_col2{
#             background-color:  #4eb586;
#             color:  #000000;
#         }#T_e1d44_row8_col0{
#             background-color:  #bfe7de;
#             color:  #000000;
#         }#T_e1d44_row8_col1{
#             background-color:  #a8ded2;
#             color:  #000000;
#         }#T_e1d44_row8_col2{
#             background-color:  #d3eeeb;
#             color:  #000000;
#         }#T_e1d44_row9_col0,#T_e1d44_row58_col1{
#             background-color:  #4ab381;
#             color:  #000000;
#         }#T_e1d44_row9_col1{
#             background-color:  #41ae77;
#             color:  #000000;
#         }#T_e1d44_row10_col0{
#             background-color:  #0d7836;
#             color:  #f1f1f1;
#         }#T_e1d44_row10_col2,#T_e1d44_row22_col1,#T_e1d44_row34_col1{
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }#T_e1d44_row11_col0{
#             background-color:  #39a569;
#             color:  #000000;
#         }#T_e1d44_row11_col1{
#             background-color:  #319c5c;
#             color:  #000000;
#         }#T_e1d44_row12_col0,#T_e1d44_row12_col2,#T_e1d44_row36_col1{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_e1d44_row12_col1{
#             background-color:  #00692a;
#             color:  #f1f1f1;
#         }#T_e1d44_row13_col0,#T_e1d44_row40_col0,#T_e1d44_row48_col1{
#             background-color:  #55b98f;
#             color:  #000000;
#         }#T_e1d44_row13_col1{
#             background-color:  #53b88c;
#             color:  #000000;
#         }#T_e1d44_row14_col0,#T_e1d44_row52_col0{
#             background-color:  #28914d;
#             color:  #000000;
#         }#T_e1d44_row14_col1,#T_e1d44_row21_col1,#T_e1d44_row46_col1{
#             background-color:  #238b45;
#             color:  #000000;
#         }#T_e1d44_row14_col2{
#             background-color:  #349f61;
#             color:  #000000;
#         }#T_e1d44_row15_col0{
#             background-color:  #218944;
#             color:  #000000;
#         }#T_e1d44_row15_col1,#T_e1d44_row49_col1{
#             background-color:  #026f2e;
#             color:  #f1f1f1;
#         }#T_e1d44_row15_col2,#T_e1d44_row17_col1,#T_e1d44_row43_col1,#T_e1d44_row68_col2{
#             background-color:  #46b17c;
#             color:  #000000;
#         }#T_e1d44_row16_col0{
#             background-color:  #3fab72;
#             color:  #000000;
#         }#T_e1d44_row16_col1,#T_e1d44_row56_col1{
#             background-color:  #2d9655;
#             color:  #000000;
#         }#T_e1d44_row16_col2,#T_e1d44_row49_col2{
#             background-color:  #5abb95;
#             color:  #000000;
#         }#T_e1d44_row17_col0,#T_e1d44_row41_col1{
#             background-color:  #54b88e;
#             color:  #000000;
#         }#T_e1d44_row17_col2,#T_e1d44_row45_col1,#T_e1d44_row65_col2{
#             background-color:  #70c6ac;
#             color:  #000000;
#         }#T_e1d44_row18_col0,#T_e1d44_row33_col2,#T_e1d44_row67_col1{
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }#T_e1d44_row18_col1{
#             background-color:  #ecf8fa;
#             color:  #000000;
#         }#T_e1d44_row18_col2{
#             background-color:  #f4fbfc;
#             color:  #000000;
#         }#T_e1d44_row19_col0,#T_e1d44_row50_col1{
#             background-color:  #6fc6aa;
#             color:  #000000;
#         }#T_e1d44_row19_col1{
#             background-color:  #5cbd98;
#             color:  #000000;
#         }#T_e1d44_row19_col2,#T_e1d44_row69_col2{
#             background-color:  #8fd4c2;
#             color:  #000000;
#         }#T_e1d44_row20_col1,#T_e1d44_row27_col2{
#             background-color:  #6ac4a7;
#             color:  #000000;
#         }#T_e1d44_row20_col2{
#             background-color:  #7acbb3;
#             color:  #000000;
#         }#T_e1d44_row21_col0,#T_e1d44_row34_col0,#T_e1d44_row52_col1{
#             background-color:  #137d39;
#             color:  #f1f1f1;
#         }#T_e1d44_row21_col2,#T_e1d44_row22_col2{
#             background-color:  #17813d;
#             color:  #f1f1f1;
#         }#T_e1d44_row22_col0{
#             background-color:  #097532;
#             color:  #f1f1f1;
#         }#T_e1d44_row23_col0,#T_e1d44_row39_col1{
#             background-color:  #77c9b0;
#             color:  #000000;
#         }#T_e1d44_row23_col2,#T_e1d44_row54_col2,#T_e1d44_row63_col0{
#             background-color:  #94d6c5;
#             color:  #000000;
#         }#T_e1d44_row24_col0{
#             background-color:  #8cd2bf;
#             color:  #000000;
#         }#T_e1d44_row24_col1,#T_e1d44_row24_col2,#T_e1d44_row68_col1{
#             background-color:  #82ceb8;
#             color:  #000000;
#         }#T_e1d44_row25_col0,#T_e1d44_row41_col2,#T_e1d44_row45_col0{
#             background-color:  #7fcdb6;
#             color:  #000000;
#         }#T_e1d44_row25_col1,#T_e1d44_row59_col0{
#             background-color:  #61bf9e;
#             color:  #000000;
#         }#T_e1d44_row26_col0{
#             background-color:  #cfede8;
#             color:  #000000;
#         }#T_e1d44_row26_col1,#T_e1d44_row43_col2{
#             background-color:  #bae5dc;
#             color:  #000000;
#         }#T_e1d44_row27_col0,#T_e1d44_row27_col1,#T_e1d44_row29_col0{
#             background-color:  #5bbc96;
#             color:  #000000;
#         }#T_e1d44_row28_col0{
#             background-color:  #e0f3f5;
#             color:  #000000;
#         }#T_e1d44_row

# %%
add_style(agg_asset_params(dv_adj.loc[:, val_binary_sharpe]).sort_index(level=[1, 0]))#.groupby('params').mean())
# Out:
# <style  type="text/css" >
# #T_b7faa_row0_col0,#T_b7faa_row99_col2,#T_b7faa_row116_col0,#T_b7faa_row129_col2,#T_b7faa_row131_col2,#T_b7faa_row159_col2,#T_b7faa_row179_col2,#T_b7faa_row216_col2,#T_b7faa_row243_col0{
#             background-color:  #95d6c6;
#             color:  #000000;
#         }#T_b7faa_row0_col1,#T_b7faa_row21_col2,#T_b7faa_row36_col0,#T_b7faa_row41_col2,#T_b7faa_row111_col0,#T_b7faa_row114_col0,#T_b7faa_row150_col1,#T_b7faa_row157_col0,#T_b7faa_row201_col0,#T_b7faa_row223_col1{
#             background-color:  #52b78b;
#             color:  #000000;
#         }#T_b7faa_row0_col2,#T_b7faa_row228_col2{
#             background-color:  #d8f0ef;
#             color:  #000000;
#         }#T_b7faa_row1_col0,#T_b7faa_row19_col2{
#             background-color:  #87d0bc;
#             color:  #000000;
#         }#T_b7faa_row1_col1,#T_b7faa_row31_col2,#T_b7faa_row79_col1{
#             background-color:  #a7ddd1;
#             color:  #000000;
#         }#T_b7faa_row1_col2,#T_b7faa_row81_col0,#T_b7faa_row111_col2,#T_b7faa_row115_col0,#T_b7faa_row190_col1,#T_b7faa_row226_col1{
#             background-color:  #7dccb5;
#             color:  #000000;
#         }#T_b7faa_row2_col0,#T_b7faa_row43_col2,#T_b7faa_row240_col2,#T_b7faa_row273_col2{
#             background-color:  #5ebe9b;
#             color:  #000000;
#         }#T_b7faa_row2_col1,#T_b7faa_row72_col1,#T_b7faa_row79_col0,#T_b7faa_row199_col2,#T_b7faa_row230_col1{
#             background-color:  #9ddacb;
#             color:  #000000;
#         }#T_b7faa_row2_col2,#T_b7faa_row70_col2,#T_b7faa_row105_col1,#T_b7faa_row147_col2,#T_b7faa_row169_col2,#T_b7faa_row185_col0,#T_b7faa_row258_col0{
#             background-color:  #3ba76c;
#             color:  #000000;
#         }#T_b7faa_row3_col0,#T_b7faa_row15_col1,#T_b7faa_row177_col0,#T_b7faa_row230_col0,#T_b7faa_row264_col0,#T_b7faa_row277_col0{
#             background-color:  #5abb95;
#             color:  #000000;
#         }#T_b7faa_row3_col1,#T_b7faa_row43_col1,#T_b7faa_row91_col1,#T_b7faa_row113_col1,#T_b7faa_row183_col2,#T_b7faa_row238_col1,#T_b7faa_row276_col0{
#             background-color:  #85cfbb;
#             color:  #000000;
#         }#T_b7faa_row3_col2,#T_b7faa_row17_col0,#T_b7faa_row47_col0,#T_b7faa_row103_col1,#T_b7faa_row119_col1,#T_b7faa_row123_col1,#T_b7faa_row148_col1,#T_b7faa_row176_col1,#T_b7faa_row205_col2,#T_b7faa_row227_col0,#T_b7faa_row235_col0,#T_b7faa_row261_col1,#T_b7faa_row267_col1,#T_b7faa_row272_col1{
#             background-color:  #6cc4a8;
#             color:  #000000;
#         }#T_b7faa_row4_col0,#T_b7faa_row9_col0,#T_b7faa_row86_col1,#T_b7faa_row126_col1,#T_b7faa_row172_col1{
#             background-color:  #3aa66a;
#             color:  #000000;
#         }#T_b7faa_row4_col1,#T_b7faa_row94_col2,#T_b7faa_row170_col1{
#             background-color:  #268f4a;
#             color:  #000000;
#         }#T_b7faa_row4_col2,#T_b7faa_row39_col2,#T_b7faa_row103_col2,#T_b7faa_row204_col0{
#             background-color:  #97d7c7;
#             color:  #000000;
#         }#T_b7faa_row5_col0,#T_b7faa_row42_col1,#T_b7faa_row102_col0,#T_b7faa_row183_col0,#T_b7faa_row218_col0{
#             background-color:  #329d5e;
#             color:  #000000;
#         }#T_b7faa_row5_col1,#T_b7faa_row6_col0,#T_b7faa_row21_col0,#T_b7faa_row44_col0,#T_b7faa_row51_col0,#T_b7faa_row84_col2,#T_b7faa_row101_col0,#T_b7faa_row165_col0,#T_b7faa_row174_col0,#T_b7faa_row182_col2{
#             background-color:  #3ca86d;
#             color:  #000000;
#         }#T_b7faa_row5_col2,#T_b7faa_row30_col2,#T_b7faa_row133_col1,#T_b7faa_row168_col1,#T_b7faa_row199_col0,#T_b7faa_row200_col1,#T_b7faa_row225_col2,#T_b7faa_row240_col0,#T_b7faa_row274_col1{
#             background-color:  #45b07b;
#             color:  #000000;
#         }#T_b7faa_row6_col1,#T_b7faa_row35_col1,#T_b7faa_row140_col1,#T_b7faa_row149_col2,#T_b7faa_row186_col1,#T_b7faa_row236_col0,#T_b7faa_row244_col1,#T_b7faa_row258_col1,#T_b7faa_row273_col1{
#             background-color:  #6ac4a7;
#             color:  #000000;
#         }#T_b7faa_row6_col2,#T_b7faa_row146_col2,#T_b7faa_row183_col1,#T_b7faa_row234_col2{
#             background-color:  #27904c;
#             color:  #000000;
#         }#T_b7faa_row7_col0,#T_b7faa_row7_col2,#T_b7faa_row56_col2,#T_b7faa_row227_col2,#T_b7faa_row279_col1{
#             background-color:  #bfe7de;
#             color:  #000000;
#         }#T_b7faa_row7_col1{
#             background-color:  #d7f0ee;
#             color:  #000000;
#         }#T_b7faa_row8_col0,#T_b7faa_row137_col0,#T_b7faa_row254_col2{
#             background-color:  #107a37;
#             color:  #f1f1f1;
#         }#T_b7faa_row8_col1{
#             background-color:  #006529;
#             color:  #f1f1f1;
#         }#T_b7faa_row8_col2,#T_b7faa_row16_col0,#T_b7faa_row22_col1,#T_b7faa_row28_col0,#T_b7faa_row39_col0,#T_b7faa_row106_col0,#T_b7faa_row149_col0,#T_b7faa_row178_col1,#T_b7faa_row208_col1,#T_b7faa_row231_col1,#T_b7faa_row240_col1,#T_b7faa_row262_col0{
#             background-color:  #5bbc96;
#             color:  #000000;
#         }#T_b7faa_row9_col1,#T_b7faa_row22_col0,#T_b7faa_row45_col2,#T_b7faa_row77_col2,#T_b7faa_row85_col2,#T_b7faa_row91_col0,#T_b7faa_row143_col2,#T_b7faa_row229_col2{
#             background-color:  #4db585;
#             color:  #000000;
#         }#T_b7faa_row9_col2,#T_b7faa_row46_col1,#T_b7faa_row158_col2,#T_b7faa_row228_col1{
#             background-color:  #46b17c;
#             color:  #000000;
#         }#T_b7faa_row10_col0,#T_b7faa_row38_col0,#T_b7faa_row130_col0,#T_b7faa_row147_col1,#T_b7faa_row166_col0{
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }#T_b7faa_row10_col1,#T_b7faa_row25_col1,#T_b7faa_row57_col2,#T_b7faa_row66_col1,#T_b7faa_row69_col2,#T_b7faa_row70_col1,#T_b7faa_row114_col2,#T_b7faa_row216_col0{
#             background-color:  #4bb382;
#             color:  #000000;
#         }#T_b7faa_row10_col2{
#             background-color:  #00692a;
#             color:  #f1f1f1;
#         }#T_b7faa_row11_col0,#T_b7faa_row63_col0,#T_b7faa_row89_col1,#T_b7faa_row93_col0,#T_b7faa_row103_col0,#T_b7faa_row161_col0,#T_b7faa_row180_col0,#T_b7faa_row252_col0,#T_b7faa_row253_col2{
#             background-color:  #63c0a0;
#             color:  #000000;
#         }#T_b7faa_row11_col1,#T_b7faa_row207_col1,#T_b7faa_row208_col0,#T_b7faa_row214_col1{
#             background-color:  #8ad2be;
#             color:  #000000;
#         }#T_b7faa_row11_col2,#T_b7faa_row28_col1,#T_b7faa_row31_col0,#T_b7faa_row270_col1{
#             background-color:  #6fc6aa;
#             color:  #000000;
#         }#T_b7faa_row12_col0,#T_b7faa_row15_col2,#T_b7faa_row231_col0{
#             background-color:  #7fcdb6;
#             color:  #000000;
#         }#T_b7faa_row12_col1,#T_b7faa_row228_col0,#T_b7faa_row262_col1{
#             background-color:  #8fd4c2;
#             color:  #000000;
#         }#T_b7faa_row12_col2,#T_b7faa_row151_col2,#T_b7faa_row279_col0{
#             background-color:  #a8ded2;
#             color:  #000000;
#         }#T_b7faa_row13_col0,#T_b7faa_row14_col2,#T_b7faa_row23_col0,#T_b7faa_row38_col1,#T_b7faa_row178_col2,#T_b7faa_row187_col1,#T_b7faa_row209_col2{
#             background-color:  #2a9350;
#             color:  #000000;
#         }#T_b7faa_row13_col1,#T_b7faa_row53_col0,#T_b7faa_row186_col0,#T_b7faa_row229_col0{
#             background-color:  #38a367;
#             color:  #000000;
#         }#T_b7faa_row13_col2,#T_b7faa_row29_col2,#T_b7faa_row51_col2,#T_b7faa_row102_col1,#T_b7faa_row109_col1,#T_b7faa_row226_col0{
#             background-color:  #3fab72;
#             color:  #000000;
#         }#T_b7faa_row14_col0,#T_b7faa_row202_col0,#T_b7faa_row211_col1,#T_b7faa_row212_col1,#T_b7faa_row238_col2,#T_b7faa_row270_col2{
#             background-color:  #2f9858;
#             color:  #000000;
#         }#T_b7faa_row14_col1,#T_b7faa_row45_col0,#T_b7faa_row101_col1,#T_b7faa_row117_col2,#T_b7faa_row133_col0,#T_b7faa_row150_col0,#T_b7faa_row154_col1,#T_b7faa_row169_col1{
#             background-color:  #3fac74;
#             color:  #000000;
#         }#T_b7faa_row15_col0,#T_b7faa_row53_col2,#T_b7faa_row78_co

# %%
#add_style(agg_asset(select_paramrange(dv_adj, range(260, 270))).sort_index(level=[1, 0]))

# %% [markdown]
# ## Compare Results Over Val by Params

# %%
sel_param = lambda d, p: d.xs(p, level=2, drop_level=False)
sel_asset = lambda d, a: d.xs(a, level=0, drop_level=False)

# %%
sp_500 = sel_asset(dv_adj.loc[:, val_binary_sharpe], 'sp_500').sort_index(level=2)
russell_2000 = sel_asset(dv_adj.loc[:, val_binary_sharpe], 'russell_2000').sort_index(level=2)
nasdaq_100 = sel_asset(dv_adj.loc[:, val_binary_sharpe], 'nasdaq_100').sort_index(level=2)
dow_jones = sel_asset(dv_adj.loc[:, val_binary_sharpe], 'dow_jones').sort_index(level=2)

# %%
add_style(sp_500)
# Out:
# <style  type="text/css" >
# #T_c6e82_row0_col0,#T_c6e82_row36_col0,#T_c6e82_row53_col1,#T_c6e82_row78_col2,#T_c6e82_row167_col2,#T_c6e82_row173_col1,#T_c6e82_row241_col2{
#             background-color:  #4ab381;
#             color:  #000000;
#         }#T_c6e82_row0_col1,#T_c6e82_row33_col0,#T_c6e82_row73_col0,#T_c6e82_row73_col1,#T_c6e82_row188_col2,#T_c6e82_row209_col0{
#             background-color:  #63c0a0;
#             color:  #000000;
#         }#T_c6e82_row0_col2,#T_c6e82_row27_col2,#T_c6e82_row92_col2,#T_c6e82_row95_col2,#T_c6e82_row157_col0,#T_c6e82_row253_col1{
#             background-color:  #3fab72;
#             color:  #000000;
#         }#T_c6e82_row1_col0,#T_c6e82_row25_col1,#T_c6e82_row83_col2,#T_c6e82_row117_col2,#T_c6e82_row167_col0,#T_c6e82_row182_col2,#T_c6e82_row206_col0,#T_c6e82_row220_col1,#T_c6e82_row226_col1,#T_c6e82_row238_col1,#T_c6e82_row240_col0,#T_c6e82_row258_col2,#T_c6e82_row268_col0{
#             background-color:  #349f61;
#             color:  #000000;
#         }#T_c6e82_row1_col1,#T_c6e82_row32_col1,#T_c6e82_row34_col0,#T_c6e82_row172_col0,#T_c6e82_row196_col0{
#             background-color:  #52b78b;
#             color:  #000000;
#         }#T_c6e82_row1_col2,#T_c6e82_row2_col2,#T_c6e82_row19_col0,#T_c6e82_row35_col2,#T_c6e82_row186_col1{
#             background-color:  #268f4a;
#             color:  #000000;
#         }#T_c6e82_row2_col0,#T_c6e82_row125_col0,#T_c6e82_row210_col2,#T_c6e82_row239_col0{
#             background-color:  #2a9350;
#             color:  #000000;
#         }#T_c6e82_row2_col1,#T_c6e82_row27_col0,#T_c6e82_row53_col0,#T_c6e82_row66_col0,#T_c6e82_row67_col1,#T_c6e82_row67_col2,#T_c6e82_row95_col0,#T_c6e82_row129_col1,#T_c6e82_row155_col0,#T_c6e82_row240_col1{
#             background-color:  #3aa66a;
#             color:  #000000;
#         }#T_c6e82_row3_col0,#T_c6e82_row7_col2,#T_c6e82_row34_col1,#T_c6e82_row34_col2,#T_c6e82_row98_col1,#T_c6e82_row233_col0,#T_c6e82_row264_col1{
#             background-color:  #5bbc96;
#             color:  #000000;
#         }#T_c6e82_row3_col1,#T_c6e82_row30_col2,#T_c6e82_row153_col1,#T_c6e82_row263_col1,#T_c6e82_row272_col1{
#             background-color:  #75c9af;
#             color:  #000000;
#         }#T_c6e82_row3_col2,#T_c6e82_row12_col1,#T_c6e82_row26_col1,#T_c6e82_row47_col1,#T_c6e82_row72_col0,#T_c6e82_row93_col1,#T_c6e82_row128_col2{
#             background-color:  #51b689;
#             color:  #000000;
#         }#T_c6e82_row4_col0,#T_c6e82_row164_col2,#T_c6e82_row170_col1{
#             background-color:  #acdfd4;
#             color:  #000000;
#         }#T_c6e82_row4_col1{
#             background-color:  #ccece6;
#             color:  #000000;
#         }#T_c6e82_row4_col2,#T_c6e82_row127_col2,#T_c6e82_row204_col2{
#             background-color:  #98d8c9;
#             color:  #000000;
#         }#T_c6e82_row5_col0,#T_c6e82_row124_col0,#T_c6e82_row191_col2,#T_c6e82_row222_col0{
#             background-color:  #65c2a3;
#             color:  #000000;
#         }#T_c6e82_row5_col1,#T_c6e82_row44_col1,#T_c6e82_row124_col1,#T_c6e82_row274_col1{
#             background-color:  #94d6c5;
#             color:  #000000;
#         }#T_c6e82_row5_col2,#T_c6e82_row11_col1,#T_c6e82_row71_col0,#T_c6e82_row72_col1,#T_c6e82_row72_col2,#T_c6e82_row124_col2,#T_c6e82_row154_col1,#T_c6e82_row166_col2,#T_c6e82_row263_col2{
#             background-color:  #5abb95;
#             color:  #000000;
#         }#T_c6e82_row6_col0,#T_c6e82_row76_col0,#T_c6e82_row105_col2,#T_c6e82_row148_col1,#T_c6e82_row158_col1,#T_c6e82_row209_col1,#T_c6e82_row224_col0,#T_c6e82_row238_col2,#T_c6e82_row272_col2,#T_c6e82_row273_col1{
#             background-color:  #5dbd99;
#             color:  #000000;
#         }#T_c6e82_row6_col1,#T_c6e82_row8_col0,#T_c6e82_row16_col2,#T_c6e82_row39_col1,#T_c6e82_row60_col1,#T_c6e82_row163_col1{
#             background-color:  #70c6ac;
#             color:  #000000;
#         }#T_c6e82_row6_col2,#T_c6e82_row18_col1,#T_c6e82_row36_col2,#T_c6e82_row50_col2,#T_c6e82_row123_col2,#T_c6e82_row160_col1,#T_c6e82_row175_col1,#T_c6e82_row219_col0,#T_c6e82_row219_col1,#T_c6e82_row242_col0{
#             background-color:  #53b88c;
#             color:  #000000;
#         }#T_c6e82_row7_col0,#T_c6e82_row30_col0,#T_c6e82_row33_col1,#T_c6e82_row120_col2,#T_c6e82_row193_col1,#T_c6e82_row194_col1,#T_c6e82_row204_col0,#T_c6e82_row218_col0,#T_c6e82_row219_col2,#T_c6e82_row270_col0{
#             background-color:  #68c3a6;
#             color:  #000000;
#         }#T_c6e82_row7_col1,#T_c6e82_row251_col2,#T_c6e82_row256_col1{
#             background-color:  #8cd2bf;
#             color:  #000000;
#         }#T_c6e82_row8_col1,#T_c6e82_row257_col2,#T_c6e82_row261_col2{
#             background-color:  #87d0bc;
#             color:  #000000;
#         }#T_c6e82_row8_col2,#T_c6e82_row64_col1,#T_c6e82_row87_col1,#T_c6e82_row97_col0,#T_c6e82_row111_col1,#T_c6e82_row118_col0,#T_c6e82_row223_col1,#T_c6e82_row259_col2{
#             background-color:  #60bf9c;
#             color:  #000000;
#         }#T_c6e82_row9_col0{
#             background-color:  #006729;
#             color:  #f1f1f1;
#         }#T_c6e82_row9_col1,#T_c6e82_row15_col2,#T_c6e82_row38_col0,#T_c6e82_row116_col2,#T_c6e82_row140_col2,#T_c6e82_row177_col2,#T_c6e82_row199_col1{
#             background-color:  #1f8742;
#             color:  #000000;
#         }#T_c6e82_row9_col2{
#             background-color:  #004c1e;
#             color:  #f1f1f1;
#         }#T_c6e82_row10_col0,#T_c6e82_row77_col1,#T_c6e82_row90_col1,#T_c6e82_row160_col2,#T_c6e82_row179_col2,#T_c6e82_row231_col0{
#             background-color:  #72c7ad;
#             color:  #000000;
#         }#T_c6e82_row10_col1,#T_c6e82_row31_col2,#T_c6e82_row75_col1,#T_c6e82_row139_col2,#T_c6e82_row150_col1,#T_c6e82_row235_col1,#T_c6e82_row257_col0,#T_c6e82_row270_col1,#T_c6e82_row271_col0,#T_c6e82_row276_col2{
#             background-color:  #82ceb8;
#             color:  #000000;
#         }#T_c6e82_row10_col2,#T_c6e82_row39_col0,#T_c6e82_row44_col2,#T_c6e82_row94_col2,#T_c6e82_row100_col1,#T_c6e82_row131_col1,#T_c6e82_row229_col0,#T_c6e82_row272_col0{
#             background-color:  #61bf9e;
#             color:  #000000;
#         }#T_c6e82_row11_col0,#T_c6e82_row37_col2,#T_c6e82_row42_col2,#T_c6e82_row51_col1,#T_c6e82_row54_col1,#T_c6e82_row66_col2,#T_c6e82_row85_col1,#T_c6e82_row131_col0,#T_c6e82_row149_col2,#T_c6e82_row156_col0,#T_c6e82_row159_col1,#T_c6e82_row172_col1,#T_c6e82_row191_col0,#T_c6e82_row215_col0,#T_c6e82_row264_col2{
#             background-color:  #45b07b;
#             color:  #000000;
#         }#T_c6e82_row11_col2,#T_c6e82_row25_col2,#T_c6e82_row29_col0,#T_c6e82_row54_col0,#T_c6e82_row91_col1,#T_c6e82_row113_col1,#T_c6e82_row201_col1,#T_c6e82_row238_col0,#T_c6e82_row250_col1{
#             background-color:  #3eaa70;
#             color:  #000000;
#         }#T_c6e82_row12_col0,#T_c6e82_row20_col2,#T_c6e82_row26_col0,#T_c6e82_row78_col0,#T_c6e82_row155_col1,#T_c6e82_row157_col2,#T_c6e82_row186_col2,#T_c6e82_row188_col0,#T_c6e82_row206_col2,#T_c6e82_row234_col2,#T_c6e82_row258_col1,#T_c6e82_row265_col2,#T_c6e82_row268_col1,#T_c6e82_row277_col0{
#             background-color:  #44af79;
#             color:  #000000;
#         }#T_c6e82_row12_col2,#T_c6e82_row42_col0,#T_c6e82_row135_col0,#T_c6e82_row157_col1,#T_c6e82_row217_col2,#T_c6e82_row229_col1,#T_c6e82_row241_col0{
#             background-color:  #4cb484;
#             color:  #000000;
#         }#T_c6e82_row13_col0,#T_c6e82_row76_col1,#T_c6e82_row100_col2,#T_c6e82_row102_col1,#T_c6e82_row165_col2,#T_c6e82_row176_col1,#T_c6e82_row192_col1,#T_c6e82_row225_col1,#T_c6e82_row270_col2{
#             background-color:  #67c2a5;
#             color:  #000000;
#         }#T_c6e82_row13_col1,#T_c6e82_row39_col2,#T_c6e82_row43_col2,#T_c6e82_row60_col2,#T_c6e82_row80_col0,#T_c6e82_row84_col2,#T_c6e82_row123_col1,#T_c6e82_row138_col2,#T_c6e82_row196_col2,#T_c6e82_row224_col2,#T_c6e82_row246_col2{
#             background-color:  #77c9b0;
#             color:  #000000;
#         }#T_c6e82_row13_col2,#T_c6e82_row218_col2,#T_c6e82_row233_col2{
#             background-co

# %%
add_style(gb_filter_monotonic(sp_500))
# Out:
# <style  type="text/css" >
# #T_be53f_row0_col0,#T_be53f_row0_col1,#T_be53f_row5_col2{
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }#T_be53f_row0_col2{
#             background-color:  #f4fbfc;
#             color:  #000000;
#         }#T_be53f_row1_col0{
#             background-color:  #3fac74;
#             color:  #000000;
#         }#T_be53f_row1_col1{
#             background-color:  #339e60;
#             color:  #000000;
#         }#T_be53f_row1_col2{
#             background-color:  #75c9af;
#             color:  #000000;
#         }#T_be53f_row2_col0,#T_be53f_row9_col2{
#             background-color:  #238b45;
#             color:  #000000;
#         }#T_be53f_row2_col1,#T_be53f_row13_col1{
#             background-color:  #5dbd99;
#             color:  #000000;
#         }#T_be53f_row2_col2{
#             background-color:  #4eb586;
#             color:  #000000;
#         }#T_be53f_row3_col0{
#             background-color:  #006529;
#             color:  #f1f1f1;
#         }#T_be53f_row3_col1,#T_be53f_row11_col0,#T_be53f_row15_col2{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_be53f_row3_col2{
#             background-color:  #2a9350;
#             color:  #000000;
#         }#T_be53f_row4_col0{
#             background-color:  #9ad8ca;
#             color:  #000000;
#         }#T_be53f_row4_col1{
#             background-color:  #87d0bc;
#             color:  #000000;
#         }#T_be53f_row4_col2{
#             background-color:  #f5fbfd;
#             color:  #000000;
#         }#T_be53f_row5_col0,#T_be53f_row6_col0{
#             background-color:  #98d8c9;
#             color:  #000000;
#         }#T_be53f_row5_col1,#T_be53f_row6_col1{
#             background-color:  #88d1bd;
#             color:  #000000;
#         }#T_be53f_row6_col2{
#             background-color:  #f6fcfd;
#             color:  #000000;
#         }#T_be53f_row7_col0,#T_be53f_row10_col0{
#             background-color:  #004a1e;
#             color:  #f1f1f1;
#         }#T_be53f_row7_col1{
#             background-color:  #00481d;
#             color:  #f1f1f1;
#         }#T_be53f_row7_col2{
#             background-color:  #268f4a;
#             color:  #000000;
#         }#T_be53f_row8_col0{
#             background-color:  #39a569;
#             color:  #000000;
#         }#T_be53f_row8_col1{
#             background-color:  #36a164;
#             color:  #000000;
#         }#T_be53f_row8_col2{
#             background-color:  #a0dbcd;
#             color:  #000000;
#         }#T_be53f_row9_col0{
#             background-color:  #004c1e;
#             color:  #f1f1f1;
#         }#T_be53f_row9_col1{
#             background-color:  #006027;
#             color:  #f1f1f1;
#         }#T_be53f_row10_col1{
#             background-color:  #00471c;
#             color:  #f1f1f1;
#         }#T_be53f_row10_col2,#T_be53f_row12_col0{
#             background-color:  #27904c;
#             color:  #000000;
#         }#T_be53f_row11_col1{
#             background-color:  #005120;
#             color:  #f1f1f1;
#         }#T_be53f_row11_col2,#T_be53f_row15_col1{
#             background-color:  #1c8540;
#             color:  #000000;
#         }#T_be53f_row12_col1{
#             background-color:  #65c2a3;
#             color:  #000000;
#         }#T_be53f_row12_col2{
#             background-color:  #208843;
#             color:  #000000;
#         }#T_be53f_row13_col0{
#             background-color:  #248c47;
#             color:  #000000;
#         }#T_be53f_row13_col2{
#             background-color:  #1f8742;
#             color:  #000000;
#         }#T_be53f_row14_col0{
#             background-color:  #03702e;
#             color:  #f1f1f1;
#         }#T_be53f_row14_col1{
#             background-color:  #3fab72;
#             color:  #000000;
#         }#T_be53f_row14_col2{
#             background-color:  #006328;
#             color:  #f1f1f1;
#         }#T_be53f_row15_col0{
#             background-color:  #004d1f;
#             color:  #f1f1f1;
#         }</style><table id="T_be53f_" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >val_binary_sharpe</th>        <th class="col_heading level0 col1" >val_binary_long_sharpe</th>        <th class="col_heading level0 col2" >val_binary_short_sharpe</th>    </tr>    <tr>        <th class="index_name level0" >asset</th>        <th class="index_name level1" >params</th>        <th class="index_name level2" >model</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_be53f_level0_row0" class="row_heading level0 row0" rowspan="16">sp_500</th>
#                         <th id="T_be53f_level1_row0" class="row_heading level1 row0" rowspan="4">241</th>
#                         <th id="T_be53f_level2_row0" class="row_heading level2 row0" >base</th>
#                         <td id="T_be53f_row0_col0" class="data row0 col0" >-1.222298</td>
#                         <td id="T_be53f_row0_col1" class="data row0 col1" >-0.565010</td>
#                         <td id="T_be53f_row0_col2" class="data row0 col2" >-1.222298</td>
#             </tr>
#             <tr>
#                                         <th id="T_be53f_level2_row1" class="row_heading level2 row1" >cnp</th>
#                         <td id="T_be53f_row1_col0" class="data row1 col0" >-0.116081</td>
#                         <td id="T_be53f_row1_col1" class="data row1 col1" >0.285326</td>
#                         <td id="T_be53f_row1_col2" class="data row1 col2" >-0.702000</td>
#             </tr>
#             <tr>
#                                         <th id="T_be53f_level2_row2" class="row_heading level2 row2" >lnp</th>
#                         <td id="T_be53f_row2_col0" class="data row2 col0" >0.092279</td>
#                         <td id="T_be53f_row2_col1" class="data row2 col1" >0.092279</td>
#                         <td id="T_be53f_row2_col2" class="data row2 col2" >-0.565010</td>
#             </tr>
#             <tr>
#                                         <th id="T_be53f_level2_row3" class="row_heading level2 row3" >np</th>
#                         <td id="T_be53f_row3_col0" class="data row3 col0" >0.352291</td>
#                         <td id="T_be53f_row3_col1" class="data row3 col1" >0.680041</td>
#                         <td id="T_be53f_row3_col2" class="data row3 col2" >-0.397613</td>
#             </tr>
#             <tr>
#                                 <th id="T_be53f_level1_row4" class="row_heading level1 row4" rowspan="4">248</th>
#                         <th id="T_be53f_level2_row4" class="row_heading level2 row4" >base</th>
#                         <td id="T_be53f_row4_col0" class="data row4 col0" >-0.564533</td>
#                         <td id="T_be53f_row4_col1" class="data row4 col1" >-0.043586</td>
#                         <td id="T_be53f_row4_col2" class="data row4 col2" >-1.236256</td>
#             </tr>
#             <tr>
#                                         <th id="T_be53f_level2_row5" class="row_heading level2 row5" >cnp</th>
#                         <td id="T_be53f_row5_col0" class="data row5 col0" >-0.558581</td>
#                         <td id="T_be53f_row5_col1" class="data row5 col1" >-0.048676</td>
#                         <td id="T_be53f_row5_col2" class="data row5 col2" >-1.251424</td>
#             </tr>
#             <tr>
#                                         <th id="T_be53f_level2_row6" class="row_heading level2 row6" >lnp</th>
#                         <td id="T_be53f_row6_col0" class="data row6 col0" >-0.557996</td>
#                         <td id="T_be53f_row6_col1" class="data row6 col1" >-0.045453</td>
#                         <td id="T_be53f_row6_col2" class="data row6 col2" >-1.244169</td>
#             </tr>
#             <tr>
#                                         <th id="T_be53f_level2_row7" class="row_heading level2 row7" >np</th>
#                         <td id="T_be53f_row7_col0" class="data row7 col0" >0.499841</td>
#                         <td id="T_be53f_row7_col1

# %%
add_style(gb_filter_neg(gb_filter_monotonic_partial(sp_500)))
# Out:
# <style  type="text/css" >
# #T_a5a5f_row0_col0{
#             background-color:  #5ebe9b;
#             color:  #000000;
#         }#T_a5a5f_row0_col1{
#             background-color:  #5cbd98;
#             color:  #000000;
#         }#T_a5a5f_row0_col2{
#             background-color:  #7dccb5;
#             color:  #000000;
#         }#T_a5a5f_row1_col0{
#             background-color:  #a2dcce;
#             color:  #000000;
#         }#T_a5a5f_row1_col1{
#             background-color:  #95d6c6;
#             color:  #000000;
#         }#T_a5a5f_row1_col2{
#             background-color:  #d9f1f0;
#             color:  #000000;
#         }#T_a5a5f_row2_col0{
#             background-color:  #218944;
#             color:  #000000;
#         }#T_a5a5f_row2_col1,#T_a5a5f_row11_col2{
#             background-color:  #208843;
#             color:  #000000;
#         }#T_a5a5f_row2_col2{
#             background-color:  #309b5b;
#             color:  #000000;
#         }#T_a5a5f_row3_col0,#T_a5a5f_row26_col1{
#             background-color:  #19833e;
#             color:  #f1f1f1;
#         }#T_a5a5f_row3_col1,#T_a5a5f_row24_col1{
#             background-color:  #1f8742;
#             color:  #000000;
#         }#T_a5a5f_row3_col2{
#             background-color:  #238b45;
#             color:  #000000;
#         }#T_a5a5f_row4_col0,#T_a5a5f_row13_col1{
#             background-color:  #c7eae3;
#             color:  #000000;
#         }#T_a5a5f_row4_col1{
#             background-color:  #ccece6;
#             color:  #000000;
#         }#T_a5a5f_row4_col2{
#             background-color:  #cdece6;
#             color:  #000000;
#         }#T_a5a5f_row5_col0,#T_a5a5f_row5_col1,#T_a5a5f_row28_col2{
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }#T_a5a5f_row5_col2{
#             background-color:  #f2fafc;
#             color:  #000000;
#         }#T_a5a5f_row6_col0,#T_a5a5f_row18_col1{
#             background-color:  #3ba76c;
#             color:  #000000;
#         }#T_a5a5f_row6_col1{
#             background-color:  #60bf9c;
#             color:  #000000;
#         }#T_a5a5f_row6_col2{
#             background-color:  #006d2c;
#             color:  #f1f1f1;
#         }#T_a5a5f_row7_col0,#T_a5a5f_row24_col0{
#             background-color:  #2d9655;
#             color:  #000000;
#         }#T_a5a5f_row7_col1,#T_a5a5f_row29_col1{
#             background-color:  #47b17e;
#             color:  #000000;
#         }#T_a5a5f_row7_col2{
#             background-color:  #157f3b;
#             color:  #f1f1f1;
#         }#T_a5a5f_row8_col0,#T_a5a5f_row32_col1,#T_a5a5f_row42_col0{
#             background-color:  #4ab381;
#             color:  #000000;
#         }#T_a5a5f_row8_col1,#T_a5a5f_row15_col2,#T_a5a5f_row39_col2{
#             background-color:  #2b9452;
#             color:  #000000;
#         }#T_a5a5f_row8_col2,#T_a5a5f_row18_col2,#T_a5a5f_row41_col2{
#             background-color:  #6cc4a8;
#             color:  #000000;
#         }#T_a5a5f_row9_col0{
#             background-color:  #2f9a59;
#             color:  #000000;
#         }#T_a5a5f_row9_col1{
#             background-color:  #3aa66a;
#             color:  #000000;
#         }#T_a5a5f_row9_col2,#T_a5a5f_row22_col0,#T_a5a5f_row35_col0{
#             background-color:  #319c5c;
#             color:  #000000;
#         }#T_a5a5f_row10_col0{
#             background-color:  #097532;
#             color:  #f1f1f1;
#         }#T_a5a5f_row10_col1{
#             background-color:  #107a37;
#             color:  #f1f1f1;
#         }#T_a5a5f_row10_col2,#T_a5a5f_row34_col1{
#             background-color:  #147e3a;
#             color:  #f1f1f1;
#         }#T_a5a5f_row11_col0,#T_a5a5f_row27_col2{
#             background-color:  #1d8640;
#             color:  #000000;
#         }#T_a5a5f_row11_col1{
#             background-color:  #268f4a;
#             color:  #000000;
#         }#T_a5a5f_row12_col0,#T_a5a5f_row21_col2{
#             background-color:  #a5ddd0;
#             color:  #000000;
#         }#T_a5a5f_row12_col1{
#             background-color:  #8cd2bf;
#             color:  #000000;
#         }#T_a5a5f_row12_col2{
#             background-color:  #d2eeeb;
#             color:  #000000;
#         }#T_a5a5f_row13_col0{
#             background-color:  #def2f4;
#             color:  #000000;
#         }#T_a5a5f_row13_col2{
#             background-color:  #f1fafc;
#             color:  #000000;
#         }#T_a5a5f_row14_col0,#T_a5a5f_row35_col1{
#             background-color:  #1a843f;
#             color:  #000000;
#         }#T_a5a5f_row14_col1{
#             background-color:  #17813d;
#             color:  #f1f1f1;
#         }#T_a5a5f_row14_col2{
#             background-color:  #2e9756;
#             color:  #000000;
#         }#T_a5a5f_row15_col0,#T_a5a5f_row31_col1{
#             background-color:  #137d39;
#             color:  #f1f1f1;
#         }#T_a5a5f_row15_col1{
#             background-color:  #067230;
#             color:  #f1f1f1;
#         }#T_a5a5f_row16_col0{
#             background-color:  #85cfbb;
#             color:  #000000;
#         }#T_a5a5f_row16_col1{
#             background-color:  #72c7ad;
#             color:  #000000;
#         }#T_a5a5f_row16_col2{
#             background-color:  #b2e2d7;
#             color:  #000000;
#         }#T_a5a5f_row17_col0{
#             background-color:  #004c1e;
#             color:  #f1f1f1;
#         }#T_a5a5f_row17_col1,#T_a5a5f_row25_col0,#T_a5a5f_row25_col2{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_a5a5f_row17_col2{
#             background-color:  #00682a;
#             color:  #f1f1f1;
#         }#T_a5a5f_row18_col0{
#             background-color:  #4db585;
#             color:  #000000;
#         }#T_a5a5f_row19_col0{
#             background-color:  #40ad75;
#             color:  #000000;
#         }#T_a5a5f_row19_col1{
#             background-color:  #3eaa70;
#             color:  #000000;
#         }#T_a5a5f_row19_col2{
#             background-color:  #56ba91;
#             color:  #000000;
#         }#T_a5a5f_row20_col0{
#             background-color:  #dff3f4;
#             color:  #000000;
#         }#T_a5a5f_row20_col1{
#             background-color:  #c5e9e2;
#             color:  #000000;
#         }#T_a5a5f_row20_col2{
#             background-color:  #edf8fb;
#             color:  #000000;
#         }#T_a5a5f_row21_col0{
#             background-color:  #7ccbb4;
#             color:  #000000;
#         }#T_a5a5f_row21_col1{
#             background-color:  #67c2a5;
#             color:  #000000;
#         }#T_a5a5f_row22_col1{
#             background-color:  #39a569;
#             color:  #000000;
#         }#T_a5a5f_row22_col2,#T_a5a5f_row43_col1{
#             background-color:  #38a367;
#             color:  #000000;
#         }#T_a5a5f_row23_col0{
#             background-color:  #53b88c;
#             color:  #000000;
#         }#T_a5a5f_row23_col1,#T_a5a5f_row24_col2{
#             background-color:  #45b07b;
#             color:  #000000;
#         }#T_a5a5f_row23_col2,#T_a5a5f_row33_col2{
#             background-color:  #70c6ac;
#             color:  #000000;
#         }#T_a5a5f_row25_col1{
#             background-color:  #005723;
#             color:  #f1f1f1;
#         }#T_a5a5f_row26_col0{
#             background-color:  #0a7633;
#             color:  #f1f1f1;
#         }#T_a5a5f_row26_col2{
#             background-color:  #077331;
#             color:  #f1f1f1;
#         }#T_a5a5f_row27_col0{
#             background-color:  #05712f;
#             color:  #f1f1f1;
#         }#T_a5a5f_row27_col1{
#             background-color:  #00692a;
#             color:  #f1f1f1;
#         }#T_a5a5f_row28_col0,#T_a5a5f_row37_col2{
#             background-color:  #f6fcfd;
#             color:  #000000;
#         }#T_a5a5f_row28_col1{
#             background-color:  #ddf2f3;
#             color:  #000000;
#         }#T_a5a5f_row29_col0,#T_a5a5f_row37_col1{
#             background-color:  #80cdb7;
#             color:  #000000;
#         }#T_a5a5f_row29_col2{
#             background-color:  #bde6de;
#             color:  #000000;
#         }#T_a5a5f_row30_col0{
#             background-color:  #61bf9e;
#             color:  #000000;
#         }#T_a5a5f_row30_col1,#T_a5a5f_row40_col0,#T_a5a5f_row41_col1{
#             background-color:  #64c1a

# %%
add_style(gb_filter_monotonic(russell_2000))
# Out:
# <style  type="text/css" >
# #T_a4b5e_row0_col0,#T_a4b5e_row0_col1,#T_a4b5e_row0_col2{
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }#T_a4b5e_row1_col0{
#             background-color:  #95d6c6;
#             color:  #000000;
#         }#T_a4b5e_row1_col1{
#             background-color:  #87d0bc;
#             color:  #000000;
#         }#T_a4b5e_row1_col2{
#             background-color:  #c2e8e0;
#             color:  #000000;
#         }#T_a4b5e_row2_col0{
#             background-color:  #208843;
#             color:  #000000;
#         }#T_a4b5e_row2_col1{
#             background-color:  #006b2b;
#             color:  #f1f1f1;
#         }#T_a4b5e_row2_col2{
#             background-color:  #5cbd98;
#             color:  #000000;
#         }#T_a4b5e_row3_col0,#T_a4b5e_row3_col1,#T_a4b5e_row3_col2{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }</style><table id="T_a4b5e_" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >val_binary_sharpe</th>        <th class="col_heading level0 col1" >val_binary_long_sharpe</th>        <th class="col_heading level0 col2" >val_binary_short_sharpe</th>    </tr>    <tr>        <th class="index_name level0" >asset</th>        <th class="index_name level1" >params</th>        <th class="index_name level2" >model</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a4b5e_level0_row0" class="row_heading level0 row0" rowspan="4">russell_2000</th>
#                         <th id="T_a4b5e_level1_row0" class="row_heading level1 row0" rowspan="4">247</th>
#                         <th id="T_a4b5e_level2_row0" class="row_heading level2 row0" >base</th>
#                         <td id="T_a4b5e_row0_col0" class="data row0 col0" >-0.028315</td>
#                         <td id="T_a4b5e_row0_col1" class="data row0 col1" >-0.171185</td>
#                         <td id="T_a4b5e_row0_col2" class="data row0 col2" >0.143836</td>
#             </tr>
#             <tr>
#                                         <th id="T_a4b5e_level2_row1" class="row_heading level2 row1" >cnp</th>
#                         <td id="T_a4b5e_row1_col0" class="data row1 col0" >0.279551</td>
#                         <td id="T_a4b5e_row1_col1" class="data row1 col1" >0.042350</td>
#                         <td id="T_a4b5e_row1_col2" class="data row1 col2" >0.337626</td>
#             </tr>
#             <tr>
#                                         <th id="T_a4b5e_level2_row2" class="row_heading level2 row2" >lnp</th>
#                         <td id="T_a4b5e_row2_col0" class="data row2 col0" >0.576315</td>
#                         <td id="T_a4b5e_row2_col1" class="data row2 col1" >0.277131</td>
#                         <td id="T_a4b5e_row2_col2" class="data row2 col2" >0.518862</td>
#             </tr>
#             <tr>
#                                         <th id="T_a4b5e_level2_row3" class="row_heading level2 row3" >np</th>
#                         <td id="T_a4b5e_row3_col0" class="data row3 col0" >0.768505</td>
#                         <td id="T_a4b5e_row3_col1" class="data row3 col1" >0.336708</td>
#                         <td id="T_a4b5e_row3_col2" class="data row3 col2" >0.844689</td>
#             </tr>
#     </tbody></table>

# %%
add_style(gb_filter_neg(gb_filter_monotonic_partial(russell_2000)))
# Out:
# <style  type="text/css" >
# #T_37bdd_row0_col0{
#             background-color:  #8fd4c2;
#             color:  #000000;
#         }#T_37bdd_row0_col1,#T_37bdd_row59_col2,#T_37bdd_row60_col1{
#             background-color:  #53b88c;
#             color:  #000000;
#         }#T_37bdd_row0_col2,#T_37bdd_row35_col2{
#             background-color:  #a7ddd1;
#             color:  #000000;
#         }#T_37bdd_row1_col0{
#             background-color:  #c2e8e0;
#             color:  #000000;
#         }#T_37bdd_row1_col1,#T_37bdd_row12_col2,#T_37bdd_row17_col1,#T_37bdd_row24_col2,#T_37bdd_row53_col2{
#             background-color:  #65c2a3;
#             color:  #000000;
#         }#T_37bdd_row1_col2{
#             background-color:  #d4efec;
#             color:  #000000;
#         }#T_37bdd_row2_col0,#T_37bdd_row63_col0,#T_37bdd_row67_col1{
#             background-color:  #41ae77;
#             color:  #000000;
#         }#T_37bdd_row2_col1,#T_37bdd_row22_col0{
#             background-color:  #2f9858;
#             color:  #000000;
#         }#T_37bdd_row2_col2,#T_37bdd_row52_col1,#T_37bdd_row63_col2{
#             background-color:  #54b88e;
#             color:  #000000;
#         }#T_37bdd_row3_col0{
#             background-color:  #3aa66a;
#             color:  #000000;
#         }#T_37bdd_row3_col1,#T_37bdd_row14_col0{
#             background-color:  #2b9452;
#             color:  #000000;
#         }#T_37bdd_row3_col2,#T_37bdd_row25_col0{
#             background-color:  #4ab381;
#             color:  #000000;
#         }#T_37bdd_row4_col0,#T_37bdd_row36_col1{
#             background-color:  #62c09f;
#             color:  #000000;
#         }#T_37bdd_row4_col1{
#             background-color:  #309b5b;
#             color:  #000000;
#         }#T_37bdd_row4_col2{
#             background-color:  #a2dcce;
#             color:  #000000;
#         }#T_37bdd_row5_col0,#T_37bdd_row37_col1,#T_37bdd_row51_col0{
#             background-color:  #4fb688;
#             color:  #000000;
#         }#T_37bdd_row5_col1,#T_37bdd_row14_col1{
#             background-color:  #29924f;
#             color:  #000000;
#         }#T_37bdd_row5_col2{
#             background-color:  #87d0bc;
#             color:  #000000;
#         }#T_37bdd_row6_col0{
#             background-color:  #5abb95;
#             color:  #000000;
#         }#T_37bdd_row6_col1,#T_37bdd_row66_col2{
#             background-color:  #329d5e;
#             color:  #000000;
#         }#T_37bdd_row6_col2,#T_37bdd_row37_col0,#T_37bdd_row43_col0,#T_37bdd_row58_col2{
#             background-color:  #84cfb9;
#             color:  #000000;
#         }#T_37bdd_row7_col0{
#             background-color:  #268f4a;
#             color:  #000000;
#         }#T_37bdd_row7_col1,#T_37bdd_row21_col0{
#             background-color:  #107a37;
#             color:  #f1f1f1;
#         }#T_37bdd_row7_col2,#T_37bdd_row8_col1,#T_37bdd_row27_col2,#T_37bdd_row41_col1,#T_37bdd_row53_col1{
#             background-color:  #48b27f;
#             color:  #000000;
#         }#T_37bdd_row8_col0,#T_37bdd_row40_col2{
#             background-color:  #9fdacc;
#             color:  #000000;
#         }#T_37bdd_row8_col2,#T_37bdd_row17_col0{
#             background-color:  #d8f0ef;
#             color:  #000000;
#         }#T_37bdd_row9_col0,#T_37bdd_row52_col0{
#             background-color:  #8cd2bf;
#             color:  #000000;
#         }#T_37bdd_row9_col1{
#             background-color:  #43af78;
#             color:  #000000;
#         }#T_37bdd_row9_col2{
#             background-color:  #caebe5;
#             color:  #000000;
#         }#T_37bdd_row10_col0,#T_37bdd_row35_col0,#T_37bdd_row42_col0{
#             background-color:  #92d5c4;
#             color:  #000000;
#         }#T_37bdd_row10_col1,#T_37bdd_row33_col0,#T_37bdd_row49_col1{
#             background-color:  #44af79;
#             color:  #000000;
#         }#T_37bdd_row10_col2,#T_37bdd_row65_col2{
#             background-color:  #d1eee9;
#             color:  #000000;
#         }#T_37bdd_row11_col0,#T_37bdd_row20_col0{
#             background-color:  #1a843f;
#             color:  #000000;
#         }#T_37bdd_row11_col1,#T_37bdd_row31_col0{
#             background-color:  #016e2d;
#             color:  #f1f1f1;
#         }#T_37bdd_row11_col2,#T_37bdd_row33_col2{
#             background-color:  #46b17c;
#             color:  #000000;
#         }#T_37bdd_row12_col0,#T_37bdd_row58_col1{
#             background-color:  #4cb484;
#             color:  #000000;
#         }#T_37bdd_row12_col1,#T_37bdd_row22_col2{
#             background-color:  #2f9a59;
#             color:  #000000;
#         }#T_37bdd_row13_col0,#T_37bdd_row64_col1{
#             background-color:  #64c1a2;
#             color:  #000000;
#         }#T_37bdd_row13_col1,#T_37bdd_row46_col1,#T_37bdd_row55_col0{
#             background-color:  #3fac74;
#             color:  #000000;
#         }#T_37bdd_row13_col2{
#             background-color:  #7dccb5;
#             color:  #000000;
#         }#T_37bdd_row14_col2{
#             background-color:  #1f8742;
#             color:  #000000;
#         }#T_37bdd_row15_col0{
#             background-color:  #006428;
#             color:  #f1f1f1;
#         }#T_37bdd_row15_col1{
#             background-color:  #006027;
#             color:  #f1f1f1;
#         }#T_37bdd_row15_col2{
#             background-color:  #17813d;
#             color:  #f1f1f1;
#         }#T_37bdd_row16_col0{
#             background-color:  #7ccbb4;
#             color:  #000000;
#         }#T_37bdd_row16_col1,#T_37bdd_row39_col2{
#             background-color:  #3ca86d;
#             color:  #000000;
#         }#T_37bdd_row16_col2{
#             background-color:  #bae5dc;
#             color:  #000000;
#         }#T_37bdd_row17_col2,#T_37bdd_row32_col0,#T_37bdd_row32_col1,#T_37bdd_row32_col2{
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }#T_37bdd_row18_col0{
#             background-color:  #7acbb3;
#             color:  #000000;
#         }#T_37bdd_row18_col1,#T_37bdd_row24_col1,#T_37bdd_row38_col1{
#             background-color:  #3da96f;
#             color:  #000000;
#         }#T_37bdd_row18_col2{
#             background-color:  #b7e4da;
#             color:  #000000;
#         }#T_37bdd_row19_col0,#T_37bdd_row19_col1,#T_37bdd_row45_col2{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_37bdd_row19_col2{
#             background-color:  #0c7735;
#             color:  #f1f1f1;
#         }#T_37bdd_row20_col1{
#             background-color:  #19833e;
#             color:  #f1f1f1;
#         }#T_37bdd_row20_col2,#T_37bdd_row21_col2{
#             background-color:  #228a44;
#             color:  #000000;
#         }#T_37bdd_row21_col1{
#             background-color:  #0e7936;
#             color:  #f1f1f1;
#         }#T_37bdd_row22_col1{
#             background-color:  #28914d;
#             color:  #000000;
#         }#T_37bdd_row23_col0{
#             background-color:  #006d2c;
#             color:  #f1f1f1;
#         }#T_37bdd_row23_col1{
#             background-color:  #127c39;
#             color:  #f1f1f1;
#         }#T_37bdd_row23_col2{
#             background-color:  #005723;
#             color:  #f1f1f1;
#         }#T_37bdd_row24_col0{
#             background-color:  #60bf9c;
#             color:  #000000;
#         }#T_37bdd_row25_col1,#T_37bdd_row63_col1{
#             background-color:  #2e9756;
#             color:  #000000;
#         }#T_37bdd_row25_col2,#T_37bdd_row49_col0{
#             background-color:  #67c2a5;
#             color:  #000000;
#         }#T_37bdd_row26_col0,#T_37bdd_row30_col0,#T_37bdd_row55_col2{
#             background-color:  #36a164;
#             color:  #000000;
#         }#T_37bdd_row26_col1,#T_37bdd_row27_col1,#T_37bdd_row62_col1{
#             background-color:  #27904c;
#             color:  #000000;
#         }#T_37bdd_row26_col2{
#             background-color:  #45b07b;
#             color:  #000000;
#         }#T_37bdd_row27_col0,#T_37bdd_row39_col1,#T_37bdd_row47_col1,#T_37bdd_row51_col1,#T_37bdd_row59_col1{
#             background-color:  #38a367;
#             color:  #000000;
#         }#T_37bdd_row28_col0,#T_37bdd_row34_col2{
#             background-color:  #b2e2d7;
#             color:  #000000;
#         }#T_37bdd_row

# %%
add_style(gb_filter_monotonic(nasdaq_100))
# Out:
# <style  type="text/css" >
# #T_21c3b_row0_col0,#T_21c3b_row5_col2{
#             background-color:  #bce6dd;
#             color:  #000000;
#         }#T_21c3b_row0_col1,#T_21c3b_row5_col1{
#             background-color:  #c0e7df;
#             color:  #000000;
#         }#T_21c3b_row0_col2{
#             background-color:  #bae5dc;
#             color:  #000000;
#         }#T_21c3b_row1_col0{
#             background-color:  #a5ddd0;
#             color:  #000000;
#         }#T_21c3b_row1_col1{
#             background-color:  #aadfd3;
#             color:  #000000;
#         }#T_21c3b_row1_col2{
#             background-color:  #a0dbcd;
#             color:  #000000;
#         }#T_21c3b_row2_col0{
#             background-color:  #74c8ae;
#             color:  #000000;
#         }#T_21c3b_row2_col1{
#             background-color:  #85cfbb;
#             color:  #000000;
#         }#T_21c3b_row2_col2{
#             background-color:  #60bf9c;
#             color:  #000000;
#         }#T_21c3b_row3_col0,#T_21c3b_row3_col1,#T_21c3b_row9_col1{
#             background-color:  #62c09f;
#             color:  #000000;
#         }#T_21c3b_row3_col2{
#             background-color:  #61bf9e;
#             color:  #000000;
#         }#T_21c3b_row4_col0,#T_21c3b_row4_col1,#T_21c3b_row4_col2{
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }#T_21c3b_row5_col0{
#             background-color:  #bde6de;
#             color:  #000000;
#         }#T_21c3b_row6_col0{
#             background-color:  #b4e2d8;
#             color:  #000000;
#         }#T_21c3b_row6_col1{
#             background-color:  #a8ded2;
#             color:  #000000;
#         }#T_21c3b_row6_col2{
#             background-color:  #b8e4db;
#             color:  #000000;
#         }#T_21c3b_row7_col0{
#             background-color:  #6dc5a9;
#             color:  #000000;
#         }#T_21c3b_row7_col1{
#             background-color:  #6fc6aa;
#             color:  #000000;
#         }#T_21c3b_row7_col2{
#             background-color:  #6ac4a7;
#             color:  #000000;
#         }#T_21c3b_row8_col0{
#             background-color:  #80cdb7;
#             color:  #000000;
#         }#T_21c3b_row8_col1{
#             background-color:  #75c9af;
#             color:  #000000;
#         }#T_21c3b_row8_col2{
#             background-color:  #92d5c4;
#             color:  #000000;
#         }#T_21c3b_row9_col0{
#             background-color:  #7acbb3;
#             color:  #000000;
#         }#T_21c3b_row9_col2{
#             background-color:  #90d4c3;
#             color:  #000000;
#         }#T_21c3b_row10_col0{
#             background-color:  #35a063;
#             color:  #000000;
#         }#T_21c3b_row10_col1{
#             background-color:  #38a367;
#             color:  #000000;
#         }#T_21c3b_row10_col2{
#             background-color:  #329d5e;
#             color:  #000000;
#         }#T_21c3b_row11_col0,#T_21c3b_row11_col1,#T_21c3b_row11_col2{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_21c3b_row12_col0{
#             background-color:  #e1f4f6;
#             color:  #000000;
#         }#T_21c3b_row12_col1{
#             background-color:  #d5efed;
#             color:  #000000;
#         }#T_21c3b_row12_col2{
#             background-color:  #ecf8fa;
#             color:  #000000;
#         }#T_21c3b_row13_col0{
#             background-color:  #caebe5;
#             color:  #000000;
#         }#T_21c3b_row13_col1{
#             background-color:  #b7e4da;
#             color:  #000000;
#         }#T_21c3b_row13_col2{
#             background-color:  #d8f0ef;
#             color:  #000000;
#         }#T_21c3b_row14_col0{
#             background-color:  #309b5b;
#             color:  #000000;
#         }#T_21c3b_row14_col1{
#             background-color:  #339e60;
#             color:  #000000;
#         }#T_21c3b_row14_col2{
#             background-color:  #2d9655;
#             color:  #000000;
#         }#T_21c3b_row15_col0{
#             background-color:  #0c7735;
#             color:  #f1f1f1;
#         }#T_21c3b_row15_col1{
#             background-color:  #00692a;
#             color:  #f1f1f1;
#         }#T_21c3b_row15_col2{
#             background-color:  #1a843f;
#             color:  #000000;
#         }</style><table id="T_21c3b_" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >val_binary_sharpe</th>        <th class="col_heading level0 col1" >val_binary_long_sharpe</th>        <th class="col_heading level0 col2" >val_binary_short_sharpe</th>    </tr>    <tr>        <th class="index_name level0" >asset</th>        <th class="index_name level1" >params</th>        <th class="index_name level2" >model</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_21c3b_level0_row0" class="row_heading level0 row0" rowspan="16">nasdaq_100</th>
#                         <th id="T_21c3b_level1_row0" class="row_heading level1 row0" rowspan="4">210</th>
#                         <th id="T_21c3b_level2_row0" class="row_heading level2 row0" >base</th>
#                         <td id="T_21c3b_row0_col0" class="data row0 col0" >-0.005665</td>
#                         <td id="T_21c3b_row0_col1" class="data row0 col1" >-0.032225</td>
#                         <td id="T_21c3b_row0_col2" class="data row0 col2" >-0.188084</td>
#             </tr>
#             <tr>
#                                         <th id="T_21c3b_level2_row1" class="row_heading level2 row1" >cnp</th>
#                         <td id="T_21c3b_row1_col0" class="data row1 col0" >0.138470</td>
#                         <td id="T_21c3b_row1_col1" class="data row1 col1" >0.067838</td>
#                         <td id="T_21c3b_row1_col2" class="data row1 col2" >-0.081068</td>
#             </tr>
#             <tr>
#                                         <th id="T_21c3b_level2_row2" class="row_heading level2 row2" >lnp</th>
#                         <td id="T_21c3b_row2_col0" class="data row2 col0" >0.446864</td>
#                         <td id="T_21c3b_row2_col1" class="data row2 col1" >0.232965</td>
#                         <td id="T_21c3b_row2_col2" class="data row2 col2" >0.208572</td>
#             </tr>
#             <tr>
#                                         <th id="T_21c3b_level2_row3" class="row_heading level2 row3" >np</th>
#                         <td id="T_21c3b_row3_col0" class="data row3 col0" >0.568990</td>
#                         <td id="T_21c3b_row3_col1" class="data row3 col1" >0.399496</td>
#                         <td id="T_21c3b_row3_col2" class="data row3 col2" >0.204025</td>
#             </tr>
#             <tr>
#                                 <th id="T_21c3b_level1_row4" class="row_heading level1 row4" rowspan="4">220</th>
#                         <th id="T_21c3b_level2_row4" class="row_heading level2 row4" >base</th>
#                         <td id="T_21c3b_row4_col0" class="data row4 col0" >-0.749615</td>
#                         <td id="T_21c3b_row4_col1" class="data row4 col1" >-0.541149</td>
#                         <td id="T_21c3b_row4_col2" class="data row4 col2" >-0.710509</td>
#             </tr>
#             <tr>
#                                         <th id="T_21c3b_level2_row5" class="row_heading level2 row5" >cnp</th>
#                         <td id="T_21c3b_row5_col0" class="data row5 col0" >-0.009824</td>
#                         <td id="T_21c3b_row5_col1" class="data row5 col1" >-0.028037</td>
#                         <td id="T_21c3b_row5_col2" class="data row5 col2" >-0.195887</td>
#             </tr>
#             <tr>
#                                         <th id="T_21c3b_level2_row6" class="row_heading level2 row6" >lnp</th>
#                         <td id="T_21c3b_row6_col0" class="data row6 col0" >0.046436</td>
#                         <td id="T_21c3b_row6_col1" class="data row6 col1" >0.075493</td>
#                         <td id="T_21c3b_row6_col2" class="data row6 col2" >-0.181308</td>
#             </tr>
#             <tr>

# %%
add_style(gb_filter_neg(gb_filter_monotonic_partial(nasdaq_100)))
# Out:
# <style  type="text/css" >
# #T_3db21_row0_col0,#T_3db21_row9_col1,#T_3db21_row77_col2{
#             background-color:  #94d6c5;
#             color:  #000000;
#         }#T_3db21_row0_col1{
#             background-color:  #97d7c7;
#             color:  #000000;
#         }#T_3db21_row0_col2,#T_3db21_row25_col2{
#             background-color:  #7dccb5;
#             color:  #000000;
#         }#T_3db21_row1_col0,#T_3db21_row11_col2,#T_3db21_row64_col1{
#             background-color:  #4ab381;
#             color:  #000000;
#         }#T_3db21_row1_col1{
#             background-color:  #319c5c;
#             color:  #000000;
#         }#T_3db21_row1_col2,#T_3db21_row6_col0,#T_3db21_row25_col1{
#             background-color:  #4cb484;
#             color:  #000000;
#         }#T_3db21_row2_col0,#T_3db21_row3_col0,#T_3db21_row13_col1,#T_3db21_row29_col1,#T_3db21_row38_col0{
#             background-color:  #60bf9c;
#             color:  #000000;
#         }#T_3db21_row2_col1{
#             background-color:  #4db585;
#             color:  #000000;
#         }#T_3db21_row2_col2,#T_3db21_row43_col2{
#             background-color:  #5dbd99;
#             color:  #000000;
#         }#T_3db21_row3_col1,#T_3db21_row37_col1{
#             background-color:  #43af78;
#             color:  #000000;
#         }#T_3db21_row3_col2,#T_3db21_row39_col2,#T_3db21_row47_col0,#T_3db21_row55_col2{
#             background-color:  #61bf9e;
#             color:  #000000;
#         }#T_3db21_row4_col0,#T_3db21_row47_col2{
#             background-color:  #5bbc96;
#             color:  #000000;
#         }#T_3db21_row4_col1{
#             background-color:  #68c3a6;
#             color:  #000000;
#         }#T_3db21_row4_col2,#T_3db21_row7_col1,#T_3db21_row14_col0,#T_3db21_row62_col1{
#             background-color:  #41ae77;
#             color:  #000000;
#         }#T_3db21_row5_col0{
#             background-color:  #e2f4f7;
#             color:  #000000;
#         }#T_3db21_row5_col1,#T_3db21_row24_col0,#T_3db21_row68_col0{
#             background-color:  #e1f4f6;
#             color:  #000000;
#         }#T_3db21_row5_col2,#T_3db21_row60_col2{
#             background-color:  #d7f0ee;
#             color:  #000000;
#         }#T_3db21_row6_col1,#T_3db21_row27_col2{
#             background-color:  #218944;
#             color:  #000000;
#         }#T_3db21_row6_col2{
#             background-color:  #53b88c;
#             color:  #000000;
#         }#T_3db21_row7_col0{
#             background-color:  #3eaa70;
#             color:  #000000;
#         }#T_3db21_row7_col2,#T_3db21_row19_col0{
#             background-color:  #349f61;
#             color:  #000000;
#         }#T_3db21_row8_col0,#T_3db21_row49_col0,#T_3db21_row49_col1{
#             background-color:  #d3eeeb;
#             color:  #000000;
#         }#T_3db21_row8_col1,#T_3db21_row48_col1{
#             background-color:  #ccece6;
#             color:  #000000;
#         }#T_3db21_row8_col2,#T_3db21_row24_col1{
#             background-color:  #d4efec;
#             color:  #000000;
#         }#T_3db21_row9_col0,#T_3db21_row9_col2,#T_3db21_row42_col0,#T_3db21_row44_col1,#T_3db21_row76_col0{
#             background-color:  #b4e2d8;
#             color:  #000000;
#         }#T_3db21_row10_col0{
#             background-color:  #27904c;
#             color:  #000000;
#         }#T_3db21_row10_col1,#T_3db21_row30_col2,#T_3db21_row34_col0,#T_3db21_row67_col0{
#             background-color:  #228a44;
#             color:  #000000;
#         }#T_3db21_row10_col2,#T_3db21_row67_col2,#T_3db21_row70_col2{
#             background-color:  #28914d;
#             color:  #000000;
#         }#T_3db21_row11_col0{
#             background-color:  #47b17e;
#             color:  #000000;
#         }#T_3db21_row11_col1,#T_3db21_row51_col1{
#             background-color:  #3ca86d;
#             color:  #000000;
#         }#T_3db21_row12_col0,#T_3db21_row21_col1,#T_3db21_row76_col2{
#             background-color:  #aadfd3;
#             color:  #000000;
#         }#T_3db21_row12_col1,#T_3db21_row42_col1,#T_3db21_row78_col1{
#             background-color:  #a8ded2;
#             color:  #000000;
#         }#T_3db21_row12_col2,#T_3db21_row13_col2,#T_3db21_row76_col1,#T_3db21_row78_col2{
#             background-color:  #a0dbcd;
#             color:  #000000;
#         }#T_3db21_row13_col0,#T_3db21_row28_col0{
#             background-color:  #98d8c9;
#             color:  #000000;
#         }#T_3db21_row14_col1{
#             background-color:  #329d5e;
#             color:  #000000;
#         }#T_3db21_row14_col2,#T_3db21_row27_col1,#T_3db21_row75_col2{
#             background-color:  #48b27f;
#             color:  #000000;
#         }#T_3db21_row15_col0,#T_3db21_row15_col2,#T_3db21_row16_col0,#T_3db21_row16_col2,#T_3db21_row46_col1{
#             background-color:  #78cab1;
#             color:  #000000;
#         }#T_3db21_row15_col1,#T_3db21_row35_col2{
#             background-color:  #67c2a5;
#             color:  #000000;
#         }#T_3db21_row16_col1,#T_3db21_row62_col0,#T_3db21_row75_col0{
#             background-color:  #65c2a3;
#             color:  #000000;
#         }#T_3db21_row17_col0,#T_3db21_row38_col1{
#             background-color:  #3da96f;
#             color:  #000000;
#         }#T_3db21_row17_col1{
#             background-color:  #2a9350;
#             color:  #000000;
#         }#T_3db21_row17_col2{
#             background-color:  #46b17c;
#             color:  #000000;
#         }#T_3db21_row18_col0{
#             background-color:  #64c1a2;
#             color:  #000000;
#         }#T_3db21_row18_col1{
#             background-color:  #51b689;
#             color:  #000000;
#         }#T_3db21_row18_col2,#T_3db21_row38_col2{
#             background-color:  #6cc4a8;
#             color:  #000000;
#         }#T_3db21_row19_col1{
#             background-color:  #248c47;
#             color:  #000000;
#         }#T_3db21_row19_col2,#T_3db21_row27_col0{
#             background-color:  #3ba76c;
#             color:  #000000;
#         }#T_3db21_row20_col0{
#             background-color:  #bce6dd;
#             color:  #000000;
#         }#T_3db21_row20_col1,#T_3db21_row41_col1{
#             background-color:  #c0e7df;
#             color:  #000000;
#         }#T_3db21_row20_col2,#T_3db21_row32_col1{
#             background-color:  #a4dccf;
#             color:  #000000;
#         }#T_3db21_row21_col0,#T_3db21_row41_col2{
#             background-color:  #a5ddd0;
#             color:  #000000;
#         }#T_3db21_row21_col2,#T_3db21_row28_col2,#T_3db21_row29_col0,#T_3db21_row61_col0,#T_3db21_row64_col2{
#             background-color:  #8dd3c0;
#             color:  #000000;
#         }#T_3db21_row22_col0{
#             background-color:  #74c8ae;
#             color:  #000000;
#         }#T_3db21_row22_col1,#T_3db21_row45_col0,#T_3db21_row53_col1{
#             background-color:  #85cfbb;
#             color:  #000000;
#         }#T_3db21_row22_col2{
#             background-color:  #55b98f;
#             color:  #000000;
#         }#T_3db21_row23_col0,#T_3db21_row23_col1,#T_3db21_row57_col1{
#             background-color:  #62c09f;
#             color:  #000000;
#         }#T_3db21_row23_col2,#T_3db21_row39_col0,#T_3db21_row47_col1,#T_3db21_row55_col0{
#             background-color:  #56ba91;
#             color:  #000000;
#         }#T_3db21_row24_col2{
#             background-color:  #ddf2f3;
#             color:  #000000;
#         }#T_3db21_row25_col0,#T_3db21_row62_col2,#T_3db21_row63_col0{
#             background-color:  #72c7ad;
#             color:  #000000;
#         }#T_3db21_row26_col0{
#             background-color:  #37a266;
#             color:  #000000;
#         }#T_3db21_row26_col1{
#             background-color:  #238b45;
#             color:  #000000;
#         }#T_3db21_row26_col2{
#             background-color:  #3fac74;
#             color:  #000000;
#         }#T_3db21_row28_col1,#T_3db21_row29_col2,#T_3db21_row79_col1{
#             background-color:  #95d6c6;
#             color:  #000000;
#         }#T_3db21_row30_col0{
#             background-color:  #1f8742;
#             color:  #000000;
#         }#T_3db21_row30_col1,#T_3db21_row67_col1{
#             background-color:  #157f3b;
#             color:  #f1f1f1;
#         }#T_3db21_

# %%
add_style(gb_filter_monotonic(dow_jones))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_4021/2733708192.py in <module>
# ----> 1 add_style(gb_filter_monotonic(dow_jones))
#
# /tmp/ipykernel_4021/3997490940.py in gb_filter_monotonic(df, checkcol)
#       4
#       5 def gb_filter_monotonic(df, checkcol='val_binary_sharpe'):
# ----> 6     return dropfirstmi(df.reorder_levels(['asset', 'params', 'model']) \
#       7             .groupby('params') \
#       8             .apply(lambda g: g if (g[checkcol].is_monotonic_increasing) else None) \
#
# /tmp/ipykernel_4021/3997490940.py in dropfirstmi(df)
#       1 def dropfirstmi(df):
# ----> 2     df.index = df.index.droplevel(0)
#       3     return df
#       4
#       5 def gb_filter_monotonic(df, checkcol='val_binary_sharpe'):
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in droplevel(self, level)
#    1609         levnums = sorted(self._get_level_number(lev) for lev in level)[::-1]
#    1610
# -> 1611         return self._drop_level_numbers(levnums)
#    1612
#    1613     def _drop_level_numbers(self, levnums: List[int]):
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in _drop_level_numbers(self, levnums)
#    1619             return self
#    1620         if len(levnums) >= self.nlevels:
# -> 1621             raise ValueError(
#    1622                 f"Cannot remove {len(levnums)} levels from an index with "
#    1623                 f"{self.nlevels} levels: at least one level must be left."
#
# ValueError: Cannot remove 1 levels from an index with 1 levels: at least one level must be left.

# %%
add_style(gb_filter_neg(gb_filter_monotonic_partial(dow_jones)))
# Out:
# <style  type="text/css" >
# #T_007fb_row0_col0,#T_007fb_row17_col2{
#             background-color:  #5abb95;
#             color:  #000000;
#         }#T_007fb_row0_col1,#T_007fb_row15_col1{
#             background-color:  #4fb688;
#             color:  #000000;
#         }#T_007fb_row0_col2{
#             background-color:  #80cdb7;
#             color:  #000000;
#         }#T_007fb_row1_col0,#T_007fb_row25_col2{
#             background-color:  #3da96f;
#             color:  #000000;
#         }#T_007fb_row1_col1{
#             background-color:  #16803c;
#             color:  #f1f1f1;
#         }#T_007fb_row1_col2,#T_007fb_row18_col1{
#             background-color:  #5ebe9b;
#             color:  #000000;
#         }#T_007fb_row2_col0{
#             background-color:  #56ba91;
#             color:  #000000;
#         }#T_007fb_row2_col1{
#             background-color:  #5dbd99;
#             color:  #000000;
#         }#T_007fb_row2_col2{
#             background-color:  #7dccb5;
#             color:  #000000;
#         }#T_007fb_row3_col0,#T_007fb_row23_col0,#T_007fb_row23_col1{
#             background-color:  #53b88c;
#             color:  #000000;
#         }#T_007fb_row3_col1{
#             background-color:  #7acbb3;
#             color:  #000000;
#         }#T_007fb_row3_col2{
#             background-color:  #77c9b0;
#             color:  #000000;
#         }#T_007fb_row4_col0{
#             background-color:  #afe1d5;
#             color:  #000000;
#         }#T_007fb_row4_col1{
#             background-color:  #87d0bc;
#             color:  #000000;
#         }#T_007fb_row4_col2,#T_007fb_row5_col1{
#             background-color:  #cdece6;
#             color:  #000000;
#         }#T_007fb_row5_col0,#T_007fb_row29_col1{
#             background-color:  #ceede8;
#             color:  #000000;
#         }#T_007fb_row5_col2{
#             background-color:  #edf8fb;
#             color:  #000000;
#         }#T_007fb_row6_col0,#T_007fb_row12_col0{
#             background-color:  #4db585;
#             color:  #000000;
#         }#T_007fb_row6_col1,#T_007fb_row8_col0,#T_007fb_row17_col1{
#             background-color:  #339e60;
#             color:  #000000;
#         }#T_007fb_row6_col2{
#             background-color:  #6fc6aa;
#             color:  #000000;
#         }#T_007fb_row7_col0,#T_007fb_row14_col0{
#             background-color:  #36a164;
#             color:  #000000;
#         }#T_007fb_row7_col1{
#             background-color:  #17813d;
#             color:  #f1f1f1;
#         }#T_007fb_row7_col2{
#             background-color:  #55b98f;
#             color:  #000000;
#         }#T_007fb_row8_col1{
#             background-color:  #309b5b;
#             color:  #000000;
#         }#T_007fb_row8_col2{
#             background-color:  #4cb484;
#             color:  #000000;
#         }#T_007fb_row9_col0{
#             background-color:  #00451c;
#             color:  #f1f1f1;
#         }#T_007fb_row9_col1,#T_007fb_row11_col0,#T_007fb_row11_col2{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_007fb_row9_col2{
#             background-color:  #005e26;
#             color:  #f1f1f1;
#         }#T_007fb_row10_col0,#T_007fb_row12_col2,#T_007fb_row15_col0{
#             background-color:  #319c5c;
#             color:  #000000;
#         }#T_007fb_row10_col1{
#             background-color:  #2f9858;
#             color:  #000000;
#         }#T_007fb_row10_col2{
#             background-color:  #4bb382;
#             color:  #000000;
#         }#T_007fb_row11_col1{
#             background-color:  #005924;
#             color:  #f1f1f1;
#         }#T_007fb_row12_col1{
#             background-color:  #8cd2bf;
#             color:  #000000;
#         }#T_007fb_row13_col0{
#             background-color:  #e2f4f7;
#             color:  #000000;
#         }#T_007fb_row13_col1,#T_007fb_row16_col0,#T_007fb_row21_col1,#T_007fb_row21_col2{
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }#T_007fb_row13_col2{
#             background-color:  #d2eeeb;
#             color:  #000000;
#         }#T_007fb_row14_col1{
#             background-color:  #65c2a3;
#             color:  #000000;
#         }#T_007fb_row14_col2{
#             background-color:  #1d8640;
#             color:  #000000;
#         }#T_007fb_row15_col2{
#             background-color:  #228a44;
#             color:  #000000;
#         }#T_007fb_row16_col1{
#             background-color:  #e7f6f9;
#             color:  #000000;
#         }#T_007fb_row16_col2{
#             background-color:  #f4fbfc;
#             color:  #000000;
#         }#T_007fb_row17_col0{
#             background-color:  #3ba76c;
#             color:  #000000;
#         }#T_007fb_row18_col0,#T_007fb_row26_col2{
#             background-color:  #61bf9e;
#             color:  #000000;
#         }#T_007fb_row18_col2,#T_007fb_row20_col1,#T_007fb_row30_col0,#T_007fb_row31_col1{
#             background-color:  #92d5c4;
#             color:  #000000;
#         }#T_007fb_row19_col0{
#             background-color:  #45b07b;
#             color:  #000000;
#         }#T_007fb_row19_col1{
#             background-color:  #40ad75;
#             color:  #000000;
#         }#T_007fb_row19_col2{
#             background-color:  #67c2a5;
#             color:  #000000;
#         }#T_007fb_row20_col0,#T_007fb_row22_col2{
#             background-color:  #a4dccf;
#             color:  #000000;
#         }#T_007fb_row20_col2,#T_007fb_row33_col2{
#             background-color:  #b0e1d6;
#             color:  #000000;
#         }#T_007fb_row21_col0{
#             background-color:  #f6fcfd;
#             color:  #000000;
#         }#T_007fb_row22_col0{
#             background-color:  #94d6c5;
#             color:  #000000;
#         }#T_007fb_row22_col1{
#             background-color:  #82ceb8;
#             color:  #000000;
#         }#T_007fb_row23_col2,#T_007fb_row30_col2,#T_007fb_row35_col1{
#             background-color:  #63c0a0;
#             color:  #000000;
#         }#T_007fb_row24_col0{
#             background-color:  #c4e9e1;
#             color:  #000000;
#         }#T_007fb_row24_col1{
#             background-color:  #a0dbcd;
#             color:  #000000;
#         }#T_007fb_row24_col2{
#             background-color:  #d9f1f0;
#             color:  #000000;
#         }#T_007fb_row25_col0,#T_007fb_row25_col1{
#             background-color:  #268f4a;
#             color:  #000000;
#         }#T_007fb_row26_col0{
#             background-color:  #3eaa70;
#             color:  #000000;
#         }#T_007fb_row26_col1,#T_007fb_row34_col0{
#             background-color:  #2a9350;
#             color:  #000000;
#         }#T_007fb_row27_col0{
#             background-color:  #329d5e;
#             color:  #000000;
#         }#T_007fb_row27_col1{
#             background-color:  #157f3b;
#             color:  #f1f1f1;
#         }#T_007fb_row27_col2{
#             background-color:  #54b88e;
#             color:  #000000;
#         }#T_007fb_row28_col0{
#             background-color:  #cfede8;
#             color:  #000000;
#         }#T_007fb_row28_col1{
#             background-color:  #eff9fb;
#             color:  #000000;
#         }#T_007fb_row28_col2{
#             background-color:  #a5ddd0;
#             color:  #000000;
#         }#T_007fb_row29_col0{
#             background-color:  #70c6ac;
#             color:  #000000;
#         }#T_007fb_row29_col2{
#             background-color:  #3ca86d;
#             color:  #000000;
#         }#T_007fb_row30_col1{
#             background-color:  #d8f0ef;
#             color:  #000000;
#         }#T_007fb_row31_col0{
#             background-color:  #4ab381;
#             color:  #000000;
#         }#T_007fb_row31_col2{
#             background-color:  #27904c;
#             color:  #000000;
#         }#T_007fb_row32_col0{
#             background-color:  #bce6dd;
#             color:  #000000;
#         }#T_007fb_row32_col1{
#             background-color:  #e8f6fa;
#             color:  #000000;
#         }#T_007fb_row32_col2{
#             background-color:  #90d4c3;
#             color:  #000000;
#         }#T_007fb_row33_col0{
#             background-color:  #d0ede9;
#             color:  #000000;
#         }#T_007fb_row33_col1{
#             background-color:  #f1fafc;
#             color:  #000000;
