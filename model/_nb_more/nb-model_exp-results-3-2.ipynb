# %% [markdown]
# # nb-model_exp-results-3-2 (h_pba_h_h_vol_h)

# %%
import sys
import os
from os import sep
from os.path import dirname, realpath, exists, basename
from pathlib import Path
from glob import glob, iglob
import logging

def get_cwd(fname, subdir, crunch_dir=realpath(Path.home()) +sep +'crunch' +sep):
    """
    Convenience function to make a directory string for the current file based on inputs.
    Jupyter Notebook in Anaconda invokes the Python interpreter in Anaconda's subdirectory
    which is why changing sys.argv[0] is necessary. In the future a better way to do this
    should be preferred..
    """
    return crunch_dir +subdir +fname

def fix_path(cwd):
    """
    Convenience function to fix argv and python path so that jupyter notebook can run the same as
    any script in crunch.
    """
    sys.argv[0] = cwd
    module_path = os.path.abspath(os.path.join('..'))
    if module_path not in sys.path:
        sys.path.append(module_path)

fname = 'nb-model_exp-results-3-2.ipynb'
dir_name = 'model'
fix_path(get_cwd(fname, dir_name +sep))

import numpy as np
import pandas as pd

from ipywidgets import interact, interactive, fixed
from IPython.display import display

pd.set_option("display.max_rows", 300)
pd.set_option("display.max_columns", 50)

from common_util import MODEL_DIR, load_json, dump_json, rectify_json, load_df, str_now, makedir_if_not_exists, is_valid, isnt, compose, pd_split_ternary_to_binary, df_del_midx_level, midx_intersect, pd_get_midx_level, pd_rows, df_midx_restack
from common_util import NestedDefaultDict
from model.common import EXP_LOG_DIR, EXP_PARAMS_DIR, ASSETS, DATASET_DIR, XG_PROCESS_DIR, XG_DATA_DIR, XG_DIR, PYTORCH_MODELS_DIR, TRAIN_RATIO, EXPECTED_NUM_HOURS
from recon.viz import *
logging.basicConfig(stream=sys.stdout, level=logging.DEBUG)
# Out:
# CRITICAL:root:script location: /home/kev/crunch/model/nb-model_exp-results-3-2.ipynb
# CRITICAL:root:using project dir: /home/kev/crunch/

# %% [markdown]
# Prune the xg data down to the data of interest to use in further experiments.

# %%
def get_bench(pattern):
    ndd = NestedDefaultDict()
    for path in iglob(pattern, recursive=True):
        ndd[path.split('/')] = load_json(path)

    df_idx = [k[2] for k in ndd.keys()]
    df = pd.DataFrame.from_records([b['benchmark-hold'] for b in ndd.values()], index=df_idx)

    return df

# %%
def consolidate_results(pattern, bench_pattern=None):
    ndd = NestedDefaultDict()
    for path in iglob(pattern, recursive=True):
        ndd[path.split('/')] = load_json(path)
    df_keys = [(k[2], k[3], k[4], k[5], k[6]) for k in ndd.keys()]
    df_idx = pd.MultiIndex.from_tuples(df_keys, names=('asset', 'model', 'data', 'params', 'trial')) \
        .remove_unused_levels()
    df = pd.DataFrame.from_records(list(ndd.values()), index=df_idx) \
        .reset_index() \
        .groupby(['asset', 'model', 'params']).mean() # average across trials for each study

    if (is_valid(bench_pattern)):
        bench_df = get_bench(bench_pattern)
        mets = ['accuracy', 'precision', 'recall', 'f1']
        rets = ['profit', 'sharpe', 'cagr']
        for m in mets+rets:
            res_cols = [c for c in df.columns if (c.endswith(m))]
            bench_cols = [c for c in bench_df.columns if (c.endswith(m))]
            bench_col = bench_cols[0]

            for asset in bench_df.index:
#                 print(bench_df.loc[asset, bench_col])
#                 print(df.xs(asset, level=0, drop_level=False)[res_cols])
                df.xs(asset, level=0, drop_level=False).loc[:, res_cols] -= bench_df.loc[asset, bench_col]
#     df = df.style \
#         .background_gradient(subset=[c for c in df.columns if c.endswith(('accuracy', 'profit', 'sharpe', 'cagr'))], cmap='BuGn')
#     .set_sticky(axis="index") \
    return df

# %%
def agg_asset(res_df):
    agg_df = res_df.groupby(['model', 'params']).mean()
    return agg_df

# %%
def agg_model(res_df):
    agg_df = res_df.groupby(['params']).mean()
    return agg_df

# %%
def agg_asset_params(res_df):
    return res_df.groupby(['asset', 'params']).mean()

# %%
def add_style(df):
    df = df.style \
         .background_gradient(subset=[c for c in df.columns if c.endswith(('accuracy', 'f1', 'profit', 'sharpe', 'cagr'))], cmap='BuGn')
#     .set_sticky(axis="index") \
    return df

# %%
view = ('accuracy', 'f1', 'profit', 'sharpe', 'cagr')

def select_ends(df, ends=view):
    res_cols = [c for c in df.columns if (c.endswith(ends))]
#     for m in ends:
#         res_cols = [c for c in df.columns if (c.endswith(m))]
    return df.loc[:, res_cols]

# %%
def select_paramrange(df, r):
    params = map(str, r)
    return df.loc[(slice(None), slice(None), params), :]

# %%
def dropfirstmi(df):
    df.index = df.index.droplevel(0)
    return df

def gb_filter_monotonic(df, checkcol='val_binary_sharpe'):
    return dropfirstmi(df.reorder_levels(['asset', 'params', 'model']) \
            .groupby('params') \
            .apply(lambda g: g if (g[checkcol].is_monotonic_increasing) else None) \
            .sort_index())

subgt = lambda g, big, small='base': (g.xs(big, level=2) > g.xs(small, level=2)).all()
monotonic_partial = lambda g: (subgt(g, 'lnp') and subgt(g, 'np', 'lnp')) or (subgt(g, 'cnp') and subgt(g, 'np', 'cnp'))

def gb_filter_monotonic_partial(df, checkcol='val_binary_sharpe'):
    return dropfirstmi(df.reorder_levels(['asset', 'params', 'model']) \
            .groupby('params') \
            .apply(lambda g: g if (monotonic_partial(g[checkcol])) else None) \
            .sort_index())

nonneg = lambda g: (g.xs('np', level=2) > 0).all() and (g.xs('lnp', level=2) > 0).all()

def gb_filter_neg(df, checkcol='val_binary_sharpe'):
    return dropfirstmi(df.reorder_levels(['asset', 'params', 'model']) \
            .groupby('params') \
            .apply(lambda g: g if (nonneg(g[checkcol])) else None) \
            .sort_index())

def gb_filter_lf(df, checkcol='val_binary_longfreq'):
    return dropfirstmi(df.groupby('params') \
            .apply(lambda g: g if ((g[checkcol].between(.2, .8)).all()) else None))

# %%
def range_diff(df, target_range, base_range):
    tgt = df.loc[map(str, target_range)]
    return tgt - df.loc[map(str, base_range)].set_index(tgt.index)

# %%
# def get_params_per_dataset():
#     EXP_LOG_DIR

# %%
exp_base = basename(dirname(EXP_LOG_DIR))
sm_name = 'anp'

drange = '2009_2018'
xdata = 'h_pba_h_h_vol_h'
ydata = 'ddir'
data_name = f'{drange}_{ydata}_{xdata}'
bench_data_name = f'{drange}_{ydata}'

path_train = f"{exp_base}/{sm_name}/**/{data_name}/**/train.json"
path_val =   f"{exp_base}/{sm_name}/**/{data_name}/**/val.json"
# path_test = f"{exp_base}/{sm_name}/**/{data_name}/**/test.json"

path_bench_train = f"{exp_base}/bench/*/{bench_data_name}/train.json"
path_bench_val = f"{exp_base}/bench/*/{bench_data_name}/val.json"
# path_bench_test = f"{exp_base}/bench/*/{bench_data_name}/test.json"

# %%
STUDY_START = 300
STUDY_END = 490
PRANGE = range(STUDY_START, STUDY_END)

# absolute results
dt = select_paramrange(consolidate_results(path_train), PRANGE);
dv = select_paramrange(consolidate_results(path_val), PRANGE);

# benchmark adjusted results
dt_adj = select_paramrange(consolidate_results(path_train, path_bench_train), PRANGE);
dv_adj = select_paramrange(consolidate_results(path_val, path_bench_val), PRANGE);
# Out:
# /home/kev/miniconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1787: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, val, pi)

# %% [markdown]
# ## Results
# Parameter sets >= 300

# %%
train_clf = [col for col in dt.columns if ('clf' in col)]
train_binary = [col for col in dt.columns if ('binary' in col)]
train_binary_sharpe = [col for col in train_binary if (col.endswith('sharpe'))]

# %%
val_clf = [col for col in dv.columns if ('clf' in col)]
val_binary = [col for col in dv.columns if ('binary' in col)]
val_binary_sharpe = [col for col in val_binary if (col.endswith('sharpe'))]

# %%
add_style(agg_model(agg_asset(dt_adj.loc[:, train_binary_sharpe])))
# Out:
# <style  type="text/css" >
# #T_60db4_row0_col0,#T_60db4_row44_col2,#T_60db4_row79_col1,#T_60db4_row143_col2{
#             background-color:  #40ad75;
#             color:  #000000;
#         }#T_60db4_row0_col1,#T_60db4_row44_col0,#T_60db4_row63_col2,#T_60db4_row173_col0{
#             background-color:  #3ca86d;
#             color:  #000000;
#         }#T_60db4_row0_col2,#T_60db4_row120_col0,#T_60db4_row157_col1,#T_60db4_row157_col2{
#             background-color:  #36a164;
#             color:  #000000;
#         }#T_60db4_row1_col0{
#             background-color:  #077331;
#             color:  #f1f1f1;
#         }#T_60db4_row1_col1,#T_60db4_row30_col2{
#             background-color:  #005522;
#             color:  #f1f1f1;
#         }#T_60db4_row1_col2,#T_60db4_row34_col1,#T_60db4_row54_col2,#T_60db4_row90_col1,#T_60db4_row100_col1,#T_60db4_row171_col1,#T_60db4_row174_col0{
#             background-color:  #16803c;
#             color:  #f1f1f1;
#         }#T_60db4_row2_col0,#T_60db4_row2_col2,#T_60db4_row22_col0,#T_60db4_row22_col1,#T_60db4_row122_col2,#T_60db4_row142_col1{
#             background-color:  #e3f4f7;
#             color:  #000000;
#         }#T_60db4_row2_col1,#T_60db4_row165_col0,#T_60db4_row165_col2{
#             background-color:  #dcf2f2;
#             color:  #000000;
#         }#T_60db4_row3_col0,#T_60db4_row60_col1,#T_60db4_row131_col0,#T_60db4_row171_col2{
#             background-color:  #228a44;
#             color:  #000000;
#         }#T_60db4_row3_col1,#T_60db4_row27_col1,#T_60db4_row41_col0,#T_60db4_row47_col1,#T_60db4_row111_col0,#T_60db4_row117_col1,#T_60db4_row133_col1,#T_60db4_row164_col2,#T_60db4_row171_col0{
#             background-color:  #258d48;
#             color:  #000000;
#         }#T_60db4_row3_col2,#T_60db4_row7_col0,#T_60db4_row17_col1,#T_60db4_row74_col1,#T_60db4_row93_col1,#T_60db4_row101_col2,#T_60db4_row111_col1{
#             background-color:  #147e3a;
#             color:  #f1f1f1;
#         }#T_60db4_row4_col0,#T_60db4_row70_col1,#T_60db4_row150_col1,#T_60db4_row151_col2{
#             background-color:  #349f61;
#             color:  #000000;
#         }#T_60db4_row4_col1,#T_60db4_row27_col0,#T_60db4_row57_col2,#T_60db4_row114_col0,#T_60db4_row114_col2,#T_60db4_row144_col0,#T_60db4_row164_col0{
#             background-color:  #218944;
#             color:  #000000;
#         }#T_60db4_row4_col2,#T_60db4_row13_col1,#T_60db4_row47_col0,#T_60db4_row53_col2{
#             background-color:  #39a569;
#             color:  #000000;
#         }#T_60db4_row5_col0{
#             background-color:  #ade0d4;
#             color:  #000000;
#         }#T_60db4_row5_col1,#T_60db4_row96_col0,#T_60db4_row106_col2,#T_60db4_row138_col0,#T_60db4_row138_col1,#T_60db4_row178_col0,#T_60db4_row178_col2{
#             background-color:  #a0dbcd;
#             color:  #000000;
#         }#T_60db4_row5_col2,#T_60db4_row8_col2,#T_60db4_row9_col1,#T_60db4_row119_col2{
#             background-color:  #a7ddd1;
#             color:  #000000;
#         }#T_60db4_row6_col0,#T_60db4_row95_col2,#T_60db4_row172_col1,#T_60db4_row175_col1{
#             background-color:  #d6f0ee;
#             color:  #000000;
#         }#T_60db4_row6_col1{
#             background-color:  #d1eee9;
#             color:  #000000;
#         }#T_60db4_row6_col2,#T_60db4_row86_col0{
#             background-color:  #cdece7;
#             color:  #000000;
#         }#T_60db4_row7_col1,#T_60db4_row23_col1,#T_60db4_row77_col2,#T_60db4_row101_col0{
#             background-color:  #127c39;
#             color:  #f1f1f1;
#         }#T_60db4_row7_col2,#T_60db4_row23_col0,#T_60db4_row120_col1,#T_60db4_row137_col0{
#             background-color:  #107a37;
#             color:  #f1f1f1;
#         }#T_60db4_row8_col0,#T_60db4_row106_col1,#T_60db4_row128_col1,#T_60db4_row146_col2,#T_60db4_row168_col1{
#             background-color:  #9fdacc;
#             color:  #000000;
#         }#T_60db4_row8_col1{
#             background-color:  #87d0bc;
#             color:  #000000;
#         }#T_60db4_row9_col0,#T_60db4_row188_col2{
#             background-color:  #b0e1d6;
#             color:  #000000;
#         }#T_60db4_row9_col2,#T_60db4_row96_col2{
#             background-color:  #a8ded2;
#             color:  #000000;
#         }#T_60db4_row10_col0,#T_60db4_row67_col0,#T_60db4_row77_col0,#T_60db4_row141_col2{
#             background-color:  #0d7836;
#             color:  #f1f1f1;
#         }#T_60db4_row10_col1,#T_60db4_row67_col2,#T_60db4_row97_col2,#T_60db4_row101_col1,#T_60db4_row144_col1{
#             background-color:  #0a7633;
#             color:  #f1f1f1;
#         }#T_60db4_row10_col2,#T_60db4_row123_col1{
#             background-color:  #087432;
#             color:  #f1f1f1;
#         }#T_60db4_row11_col0,#T_60db4_row133_col0,#T_60db4_row150_col2,#T_60db4_row187_col0{
#             background-color:  #3ba76c;
#             color:  #000000;
#         }#T_60db4_row11_col1,#T_60db4_row73_col1{
#             background-color:  #37a266;
#             color:  #000000;
#         }#T_60db4_row11_col2{
#             background-color:  #319c5c;
#             color:  #000000;
#         }#T_60db4_row12_col0,#T_60db4_row182_col0,#T_60db4_row182_col2{
#             background-color:  #dbf1f1;
#             color:  #000000;
#         }#T_60db4_row12_col1,#T_60db4_row155_col1,#T_60db4_row176_col0{
#             background-color:  #ccece6;
#             color:  #000000;
#         }#T_60db4_row12_col2,#T_60db4_row42_col2,#T_60db4_row95_col0,#T_60db4_row105_col2,#T_60db4_row125_col2,#T_60db4_row142_col0{
#             background-color:  #dff3f4;
#             color:  #000000;
#         }#T_60db4_row13_col0,#T_60db4_row127_col2,#T_60db4_row143_col0,#T_60db4_row183_col1{
#             background-color:  #46b17c;
#             color:  #000000;
#         }#T_60db4_row13_col2,#T_60db4_row50_col2,#T_60db4_row170_col1,#T_60db4_row181_col0{
#             background-color:  #45b07b;
#             color:  #000000;
#         }#T_60db4_row14_col0,#T_60db4_row31_col2{
#             background-color:  #006529;
#             color:  #f1f1f1;
#         }#T_60db4_row14_col1{
#             background-color:  #005120;
#             color:  #f1f1f1;
#         }#T_60db4_row14_col2,#T_60db4_row117_col2,#T_60db4_row141_col1{
#             background-color:  #03702e;
#             color:  #f1f1f1;
#         }#T_60db4_row15_col0,#T_60db4_row42_col1,#T_60db4_row65_col0,#T_60db4_row102_col1,#T_60db4_row105_col1,#T_60db4_row156_col2,#T_60db4_row162_col1{
#             background-color:  #d5efed;
#             color:  #000000;
#         }#T_60db4_row15_col1,#T_60db4_row75_col2{
#             background-color:  #d3eeeb;
#             color:  #000000;
#         }#T_60db4_row15_col2{
#             background-color:  #ceede8;
#             color:  #000000;
#         }#T_60db4_row16_col0,#T_60db4_row146_col0,#T_60db4_row159_col2{
#             background-color:  #b2e2d7;
#             color:  #000000;
#         }#T_60db4_row16_col1,#T_60db4_row56_col0,#T_60db4_row148_col0{
#             background-color:  #a4dccf;
#             color:  #000000;
#         }#T_60db4_row16_col2,#T_60db4_row139_col0,#T_60db4_row159_col1,#T_60db4_row188_col0,#T_60db4_row189_col1{
#             background-color:  #a5ddd0;
#             color:  #000000;
#         }#T_60db4_row17_col0,#T_60db4_row20_col2,#T_60db4_row21_col1,#T_60db4_row33_col1,#T_60db4_row91_col0,#T_60db4_row114_col1{
#             background-color:  #157f3b;
#             color:  #f1f1f1;
#         }#T_60db4_row17_col2,#T_60db4_row141_col0{
#             background-color:  #0c7735;
#             color:  #f1f1f1;
#         }#T_60db4_row18_col0,#T_60db4_row46_col0,#T_60db4_row56_col1,#T_60db4_row69_col1,#T_60db4_row136_col1{
#             background-color:  #9cd9ca;
#             color:  #000000;
#         }#T_60db4_row18_col1,#T_60db4_row49_col2,#T_60db4_row119_col1,#T_60db4_row158_col2{
#             background-color:  #9ddacb;
#             color:  #000000;
#         }#T_60db4_row18_col2,#T_60db4_row26_col2,#T_60db4_row109_col2,#T_60db4_row149_col0,#T_60db4_row188_col1{
#             background-color:  #88d1bd;
#             color:  #000000;
#         }#T_60db4_row19_col0,#T_60db4_row38_col2,#T_60db4_row48_col0{
#             background-color:

# %%
add_style(agg_model(dv_adj.loc[:, val_binary_sharpe]))
# Out:
# <style  type="text/css" >
# #T_f22e0_row0_col0,#T_f22e0_row130_col0{
#             background-color:  #03702e;
#             color:  #f1f1f1;
#         }#T_f22e0_row0_col1,#T_f22e0_row25_col1{
#             background-color:  #0a7633;
#             color:  #f1f1f1;
#         }#T_f22e0_row0_col2,#T_f22e0_row142_col0{
#             background-color:  #006d2c;
#             color:  #f1f1f1;
#         }#T_f22e0_row1_col0,#T_f22e0_row38_col0,#T_f22e0_row126_col1{
#             background-color:  #80cdb7;
#             color:  #000000;
#         }#T_f22e0_row1_col1,#T_f22e0_row166_col0,#T_f22e0_row179_col1,#T_f22e0_row189_col1{
#             background-color:  #97d7c7;
#             color:  #000000;
#         }#T_f22e0_row1_col2,#T_f22e0_row17_col1,#T_f22e0_row63_col2,#T_f22e0_row74_col2,#T_f22e0_row84_col0,#T_f22e0_row84_col1,#T_f22e0_row133_col1{
#             background-color:  #6ac4a7;
#             color:  #000000;
#         }#T_f22e0_row2_col0,#T_f22e0_row5_col0,#T_f22e0_row95_col0,#T_f22e0_row162_col0,#T_f22e0_row177_col2,#T_f22e0_row182_col1{
#             background-color:  #2f9858;
#             color:  #000000;
#         }#T_f22e0_row2_col1,#T_f22e0_row34_col2,#T_f22e0_row42_col1,#T_f22e0_row42_col2,#T_f22e0_row62_col1,#T_f22e0_row170_col0{
#             background-color:  #3ba76c;
#             color:  #000000;
#         }#T_f22e0_row2_col2,#T_f22e0_row45_col2,#T_f22e0_row57_col1,#T_f22e0_row174_col2{
#             background-color:  #228a44;
#             color:  #000000;
#         }#T_f22e0_row3_col0,#T_f22e0_row36_col1,#T_f22e0_row50_col0,#T_f22e0_row70_col1,#T_f22e0_row103_col1,#T_f22e0_row121_col1,#T_f22e0_row150_col2,#T_f22e0_row153_col0,#T_f22e0_row181_col0{
#             background-color:  #54b88e;
#             color:  #000000;
#         }#T_f22e0_row3_col1,#T_f22e0_row10_col0,#T_f22e0_row91_col0{
#             background-color:  #64c1a2;
#             color:  #000000;
#         }#T_f22e0_row3_col2,#T_f22e0_row11_col2,#T_f22e0_row34_col1,#T_f22e0_row80_col0,#T_f22e0_row127_col1,#T_f22e0_row155_col2,#T_f22e0_row172_col0{
#             background-color:  #45b07b;
#             color:  #000000;
#         }#T_f22e0_row4_col0,#T_f22e0_row66_col1,#T_f22e0_row98_col0,#T_f22e0_row136_col1{
#             background-color:  #c5e9e2;
#             color:  #000000;
#         }#T_f22e0_row4_col1,#T_f22e0_row19_col1,#T_f22e0_row66_col0,#T_f22e0_row87_col1{
#             background-color:  #cfede8;
#             color:  #000000;
#         }#T_f22e0_row4_col2,#T_f22e0_row53_col1,#T_f22e0_row67_col1,#T_f22e0_row86_col0,#T_f22e0_row89_col0{
#             background-color:  #b4e2d8;
#             color:  #000000;
#         }#T_f22e0_row5_col1,#T_f22e0_row72_col2,#T_f22e0_row95_col2,#T_f22e0_row104_col0,#T_f22e0_row163_col0,#T_f22e0_row175_col2{
#             background-color:  #2b9452;
#             color:  #000000;
#         }#T_f22e0_row5_col2,#T_f22e0_row20_col0,#T_f22e0_row71_col0,#T_f22e0_row173_col1,#T_f22e0_row177_col0,#T_f22e0_row183_col1{
#             background-color:  #2d9655;
#             color:  #000000;
#         }#T_f22e0_row6_col0,#T_f22e0_row168_col2{
#             background-color:  #e3f4f8;
#             color:  #000000;
#         }#T_f22e0_row6_col1{
#             background-color:  #e8f6fa;
#             color:  #000000;
#         }#T_f22e0_row6_col2{
#             background-color:  #dff3f4;
#             color:  #000000;
#         }#T_f22e0_row7_col0,#T_f22e0_row115_col0{
#             background-color:  #218944;
#             color:  #000000;
#         }#T_f22e0_row7_col1,#T_f22e0_row41_col2,#T_f22e0_row71_col2,#T_f22e0_row76_col1,#T_f22e0_row163_col2{
#             background-color:  #28914d;
#             color:  #000000;
#         }#T_f22e0_row7_col2,#T_f22e0_row40_col0,#T_f22e0_row41_col0,#T_f22e0_row64_col0{
#             background-color:  #238b45;
#             color:  #000000;
#         }#T_f22e0_row8_col0,#T_f22e0_row59_col2,#T_f22e0_row99_col0,#T_f22e0_row176_col2{
#             background-color:  #daf1f1;
#             color:  #000000;
#         }#T_f22e0_row8_col1{
#             background-color:  #dbf2f2;
#             color:  #000000;
#         }#T_f22e0_row8_col2,#T_f22e0_row139_col0{
#             background-color:  #d6f0ee;
#             color:  #000000;
#         }#T_f22e0_row9_col0,#T_f22e0_row86_col2{
#             background-color:  #ade0d4;
#             color:  #000000;
#         }#T_f22e0_row9_col1,#T_f22e0_row113_col0,#T_f22e0_row129_col0,#T_f22e0_row169_col0{
#             background-color:  #a7ddd1;
#             color:  #000000;
#         }#T_f22e0_row9_col2,#T_f22e0_row53_col0,#T_f22e0_row86_col1,#T_f22e0_row87_col2,#T_f22e0_row169_col1{
#             background-color:  #afe1d5;
#             color:  #000000;
#         }#T_f22e0_row10_col1,#T_f22e0_row63_col1,#T_f22e0_row74_col0,#T_f22e0_row75_col1,#T_f22e0_row106_col1,#T_f22e0_row133_col0{
#             background-color:  #74c8ae;
#             color:  #000000;
#         }#T_f22e0_row10_col2,#T_f22e0_row48_col0,#T_f22e0_row73_col0,#T_f22e0_row83_col1,#T_f22e0_row180_col0,#T_f22e0_row180_col2{
#             background-color:  #5dbd99;
#             color:  #000000;
#         }#T_f22e0_row11_col0,#T_f22e0_row44_col0,#T_f22e0_row60_col2,#T_f22e0_row65_col2,#T_f22e0_row107_col0,#T_f22e0_row140_col0,#T_f22e0_row144_col1,#T_f22e0_row144_col2{
#             background-color:  #41ae77;
#             color:  #000000;
#         }#T_f22e0_row11_col1,#T_f22e0_row30_col2,#T_f22e0_row65_col0,#T_f22e0_row65_col1,#T_f22e0_row172_col2{
#             background-color:  #43af78;
#             color:  #000000;
#         }#T_f22e0_row12_col0{
#             background-color:  #005120;
#             color:  #f1f1f1;
#         }#T_f22e0_row12_col1,#T_f22e0_row135_col0,#T_f22e0_row135_col1{
#             background-color:  #00491d;
#             color:  #f1f1f1;
#         }#T_f22e0_row12_col2{
#             background-color:  #006529;
#             color:  #f1f1f1;
#         }#T_f22e0_row13_col0,#T_f22e0_row31_col1,#T_f22e0_row93_col1,#T_f22e0_row123_col0,#T_f22e0_row123_col1,#T_f22e0_row123_col2{
#             background-color:  #56ba91;
#             color:  #000000;
#         }#T_f22e0_row13_col1{
#             background-color:  #5bbc96;
#             color:  #000000;
#         }#T_f22e0_row13_col2,#T_f22e0_row50_col2,#T_f22e0_row70_col0,#T_f22e0_row75_col2,#T_f22e0_row149_col2,#T_f22e0_row187_col0{
#             background-color:  #52b78b;
#             color:  #000000;
#         }#T_f22e0_row14_col0{
#             background-color:  #b8e4db;
#             color:  #000000;
#         }#T_f22e0_row14_col1,#T_f22e0_row87_col0{
#             background-color:  #c7eae3;
#             color:  #000000;
#         }#T_f22e0_row14_col2{
#             background-color:  #aadfd3;
#             color:  #000000;
#         }#T_f22e0_row15_col0,#T_f22e0_row130_col1{
#             background-color:  #006729;
#             color:  #f1f1f1;
#         }#T_f22e0_row15_col1{
#             background-color:  #005622;
#             color:  #f1f1f1;
#         }#T_f22e0_row15_col2,#T_f22e0_row25_col0,#T_f22e0_row55_col1,#T_f22e0_row185_col1{
#             background-color:  #077331;
#             color:  #f1f1f1;
#         }#T_f22e0_row16_col0,#T_f22e0_row18_col1,#T_f22e0_row29_col0,#T_f22e0_row29_col2{
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }#T_f22e0_row16_col1{
#             background-color:  #eff9fb;
#             color:  #000000;
#         }#T_f22e0_row16_col2,#T_f22e0_row18_col2{
#             background-color:  #f4fbfc;
#             color:  #000000;
#         }#T_f22e0_row17_col0,#T_f22e0_row31_col0,#T_f22e0_row50_col1,#T_f22e0_row83_col0,#T_f22e0_row180_col1,#T_f22e0_row187_col1{
#             background-color:  #57ba92;
#             color:  #000000;
#         }#T_f22e0_row17_col2,#T_f22e0_row21_col2,#T_f22e0_row62_col2,#T_f22e0_row102_col0,#T_f22e0_row134_col1,#T_f22e0_row152_col2,#T_f22e0_row157_col1{
#             background-color:  #4db585;
#             color:  #000000;
#         }#T_f22e0_row18_col0{
#             background-color:  #f6fcfd;
#             color:  #000000;
#         }#T_f22e0_row19_col0,#T_f22e0_row28_col2,#T_f22e0_row98_col1{
#             background-color:  #cdece6;
#             color:  #000000;
#         }#T_f22e0_row19_c

# %%
base_range = range(STUDY_START, STUDY_START+10)

# %% [markdown]
# ### Compare study interventions globally

# %%
pavg = agg_asset_params(dv_adj.loc[:, val_binary_sharpe]).sort_index(level=[1, 0]).groupby('params').mean()

# %%
res = []
for start in range(STUDY_START+10, STUDY_END, 10):
    r = range(start, start+10)
    ser = range_diff(pavg, r, base_range).mean()
    ser.name = start
    res.append(ser)
res = pd.concat(res, axis=1).transpose()
add_style(res)
# Out:
# <style  type="text/css" >
# #T_0c390_row0_col0{
#             background-color:  #b4e2d8;
#             color:  #000000;
#         }#T_0c390_row0_col1{
#             background-color:  #c0e7df;
#             color:  #000000;
#         }#T_0c390_row0_col2{
#             background-color:  #e1f4f6;
#             color:  #000000;
#         }#T_0c390_row1_col0{
#             background-color:  #2c9553;
#             color:  #000000;
#         }#T_0c390_row1_col1{
#             background-color:  #40ad75;
#             color:  #000000;
#         }#T_0c390_row1_col2{
#             background-color:  #27904c;
#             color:  #000000;
#         }#T_0c390_row2_col0,#T_0c390_row16_col1{
#             background-color:  #37a266;
#             color:  #000000;
#         }#T_0c390_row2_col1,#T_0c390_row13_col0{
#             background-color:  #3ca86d;
#             color:  #000000;
#         }#T_0c390_row2_col2{
#             background-color:  #52b78b;
#             color:  #000000;
#         }#T_0c390_row3_col0,#T_0c390_row3_col1,#T_0c390_row3_col2{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_0c390_row4_col0{
#             background-color:  #a4dccf;
#             color:  #000000;
#         }#T_0c390_row4_col1{
#             background-color:  #9ddacb;
#             color:  #000000;
#         }#T_0c390_row4_col2{
#             background-color:  #c8ebe4;
#             color:  #000000;
#         }#T_0c390_row5_col0{
#             background-color:  #bce6dd;
#             color:  #000000;
#         }#T_0c390_row5_col1{
#             background-color:  #a2dcce;
#             color:  #000000;
#         }#T_0c390_row5_col2{
#             background-color:  #e6f5f9;
#             color:  #000000;
#         }#T_0c390_row6_col0{
#             background-color:  #16803c;
#             color:  #f1f1f1;
#         }#T_0c390_row6_col1{
#             background-color:  #2b9452;
#             color:  #000000;
#         }#T_0c390_row6_col2{
#             background-color:  #00692a;
#             color:  #f1f1f1;
#         }#T_0c390_row7_col0,#T_0c390_row7_col1,#T_0c390_row7_col2{
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }#T_0c390_row8_col0{
#             background-color:  #98d8c9;
#             color:  #000000;
#         }#T_0c390_row8_col1{
#             background-color:  #c7eae3;
#             color:  #000000;
#         }#T_0c390_row8_col2{
#             background-color:  #c4e9e1;
#             color:  #000000;
#         }#T_0c390_row9_col0{
#             background-color:  #3da96f;
#             color:  #000000;
#         }#T_0c390_row9_col1{
#             background-color:  #309b5b;
#             color:  #000000;
#         }#T_0c390_row9_col2{
#             background-color:  #64c1a2;
#             color:  #000000;
#         }#T_0c390_row10_col0{
#             background-color:  #53b88c;
#             color:  #000000;
#         }#T_0c390_row10_col1{
#             background-color:  #38a367;
#             color:  #000000;
#         }#T_0c390_row10_col2{
#             background-color:  #88d1bd;
#             color:  #000000;
#         }#T_0c390_row11_col0{
#             background-color:  #329d5e;
#             color:  #000000;
#         }#T_0c390_row11_col1{
#             background-color:  #28914d;
#             color:  #000000;
#         }#T_0c390_row11_col2{
#             background-color:  #44af79;
#             color:  #000000;
#         }#T_0c390_row12_col0{
#             background-color:  #1e8741;
#             color:  #000000;
#         }#T_0c390_row12_col1{
#             background-color:  #268f4a;
#             color:  #000000;
#         }#T_0c390_row12_col2{
#             background-color:  #1d8640;
#             color:  #000000;
#         }#T_0c390_row13_col1{
#             background-color:  #35a063;
#             color:  #000000;
#         }#T_0c390_row13_col2{
#             background-color:  #57ba92;
#             color:  #000000;
#         }#T_0c390_row14_col0{
#             background-color:  #78cab1;
#             color:  #000000;
#         }#T_0c390_row14_col1{
#             background-color:  #87d0bc;
#             color:  #000000;
#         }#T_0c390_row14_col2{
#             background-color:  #92d5c4;
#             color:  #000000;
#         }#T_0c390_row15_col0{
#             background-color:  #228a44;
#             color:  #000000;
#         }#T_0c390_row15_col1{
#             background-color:  #208843;
#             color:  #000000;
#         }#T_0c390_row15_col2,#T_0c390_row16_col0{
#             background-color:  #2a9350;
#             color:  #000000;
#         }#T_0c390_row16_col2{
#             background-color:  #2f9858;
#             color:  #000000;
#         }#T_0c390_row17_col0{
#             background-color:  #006c2c;
#             color:  #f1f1f1;
#         }#T_0c390_row17_col1{
#             background-color:  #006227;
#             color:  #f1f1f1;
#         }#T_0c390_row17_col2{
#             background-color:  #0e7936;
#             color:  #f1f1f1;
#         }</style><table id="T_0c390_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >val_binary_sharpe</th>        <th class="col_heading level0 col1" >val_binary_long_sharpe</th>        <th class="col_heading level0 col2" >val_binary_short_sharpe</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0c390_level0_row0" class="row_heading level0 row0" >310</th>
#                         <td id="T_0c390_row0_col0" class="data row0 col0" >-0.029467</td>
#                         <td id="T_0c390_row0_col1" class="data row0 col1" >-0.004883</td>
#                         <td id="T_0c390_row0_col2" class="data row0 col2" >-0.043608</td>
#             </tr>
#             <tr>
#                         <th id="T_0c390_level0_row1" class="row_heading level0 row1" >320</th>
#                         <td id="T_0c390_row1_col0" class="data row1 col0" >0.044431</td>
#                         <td id="T_0c390_row1_col1" class="data row1 col1" >0.034736</td>
#                         <td id="T_0c390_row1_col2" class="data row1 col2" >0.028535</td>
#             </tr>
#             <tr>
#                         <th id="T_0c390_level0_row2" class="row_heading level0 row2" >330</th>
#                         <td id="T_0c390_row2_col0" class="data row2 col0" >0.035463</td>
#                         <td id="T_0c390_row2_col1" class="data row2 col1" >0.037212</td>
#                         <td id="T_0c390_row2_col2" class="data row2 col2" >0.008379</td>
#             </tr>
#             <tr>
#                         <th id="T_0c390_level0_row3" class="row_heading level0 row3" >340</th>
#                         <td id="T_0c390_row3_col0" class="data row3 col0" >0.096903</td>
#                         <td id="T_0c390_row3_col1" class="data row3 col1" >0.077551</td>
#                         <td id="T_0c390_row3_col2" class="data row3 col2" >0.061900</td>
#             </tr>
#             <tr>
#                         <th id="T_0c390_level0_row4" class="row_heading level0 row4" >350</th>
#                         <td id="T_0c390_row4_col0" class="data row4 col0" >-0.022193</td>
#                         <td id="T_0c390_row4_col1" class="data row4 col1" >0.005214</td>
#                         <td id="T_0c390_row4_col2" class="data row4 col2" >-0.029594</td>
#             </tr>
#             <tr>
#                         <th id="T_0c390_level0_row5" class="row_heading level0 row5" >360</th>
#                         <td id="T_0c390_row5_col0" class="data row5 col0" >-0.033363</td>
#                         <td id="T_0c390_row5_col1" class="data row5 col1" >0.003716</td>
#                         <td id="T_0c390_row5_col2" class="data row5 col2" >-0.047365</td>
#             </tr>
#             <tr>
#                         <th id="T_0c390_level0_row6" class="row_heading level0 row6" >370</th>
#                         <td id="T_0c390_row6_col0" class="data row6 col0" >0.059465</td>
#                         <td id="T_0c390_row6_col1" class="data row6 col1" >0.044978</td>
#                         <td id="T_0c390_row6_col2" class="data row6 col2" >0.047438</td>
#             </tr>
#             <tr>
#                         <th id="T_0c390_level0_row7" class="row_heading level0 row7

# %%
# Information Ratio:
res = []
for start in range(STUDY_START+10, STUDY_END, 10):
    r = range(start, start+10)
    ser = range_diff(pavg, r, base_range).mean() / range_diff(pavg, r, base_range).std()
    ser.name = start
    res.append(ser)
res = pd.concat(res, axis=1).transpose()
add_style(res)
# Out:
# <style  type="text/css" >
# #T_60ace_row0_col0{
#             background-color:  #c7eae3;
#             color:  #000000;
#         }#T_60ace_row0_col1{
#             background-color:  #d1eeea;
#             color:  #000000;
#         }#T_60ace_row0_col2{
#             background-color:  #edf8fb;
#             color:  #000000;
#         }#T_60ace_row1_col0{
#             background-color:  #46b17c;
#             color:  #000000;
#         }#T_60ace_row1_col1{
#             background-color:  #6cc4a8;
#             color:  #000000;
#         }#T_60ace_row1_col2{
#             background-color:  #3eaa70;
#             color:  #000000;
#         }#T_60ace_row2_col0{
#             background-color:  #4fb688;
#             color:  #000000;
#         }#T_60ace_row2_col1{
#             background-color:  #68c3a6;
#             color:  #000000;
#         }#T_60ace_row2_col2{
#             background-color:  #5dbd99;
#             color:  #000000;
#         }#T_60ace_row3_col0,#T_60ace_row3_col1,#T_60ace_row3_col2{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_60ace_row4_col0{
#             background-color:  #afe1d5;
#             color:  #000000;
#         }#T_60ace_row4_col1{
#             background-color:  #b8e4db;
#             color:  #000000;
#         }#T_60ace_row4_col2{
#             background-color:  #c4e9e1;
#             color:  #000000;
#         }#T_60ace_row5_col0{
#             background-color:  #c0e7df;
#             color:  #000000;
#         }#T_60ace_row5_col1,#T_60ace_row8_col0{
#             background-color:  #bde6de;
#             color:  #000000;
#         }#T_60ace_row5_col2{
#             background-color:  #dbf2f2;
#             color:  #000000;
#         }#T_60ace_row6_col0{
#             background-color:  #329d5e;
#             color:  #000000;
#         }#T_60ace_row6_col1{
#             background-color:  #5abb95;
#             color:  #000000;
#         }#T_60ace_row6_col2{
#             background-color:  #16803c;
#             color:  #f1f1f1;
#         }#T_60ace_row7_col0,#T_60ace_row7_col1,#T_60ace_row7_col2{
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }#T_60ace_row8_col1{
#             background-color:  #dbf1f1;
#             color:  #000000;
#         }#T_60ace_row8_col2{
#             background-color:  #dff3f5;
#             color:  #000000;
#         }#T_60ace_row9_col0{
#             background-color:  #4bb382;
#             color:  #000000;
#         }#T_60ace_row9_col1,#T_60ace_row15_col1,#T_60ace_row16_col1{
#             background-color:  #47b17e;
#             color:  #000000;
#         }#T_60ace_row9_col2{
#             background-color:  #6dc5a9;
#             color:  #000000;
#         }#T_60ace_row10_col0{
#             background-color:  #5cbd98;
#             color:  #000000;
#         }#T_60ace_row10_col1{
#             background-color:  #339e60;
#             color:  #000000;
#         }#T_60ace_row10_col2{
#             background-color:  #94d6c5;
#             color:  #000000;
#         }#T_60ace_row11_col0{
#             background-color:  #3ba76c;
#             color:  #000000;
#         }#T_60ace_row11_col1{
#             background-color:  #28914d;
#             color:  #000000;
#         }#T_60ace_row11_col2{
#             background-color:  #4cb484;
#             color:  #000000;
#         }#T_60ace_row12_col0{
#             background-color:  #2f9a59;
#             color:  #000000;
#         }#T_60ace_row12_col1{
#             background-color:  #36a164;
#             color:  #000000;
#         }#T_60ace_row12_col2{
#             background-color:  #2b9452;
#             color:  #000000;
#         }#T_60ace_row13_col0{
#             background-color:  #4ab381;
#             color:  #000000;
#         }#T_60ace_row13_col1{
#             background-color:  #59bb93;
#             color:  #000000;
#         }#T_60ace_row13_col2{
#             background-color:  #5ebe9b;
#             color:  #000000;
#         }#T_60ace_row14_col0{
#             background-color:  #88d1bd;
#             color:  #000000;
#         }#T_60ace_row14_col1{
#             background-color:  #a8ded2;
#             color:  #000000;
#         }#T_60ace_row14_col2{
#             background-color:  #97d7c7;
#             color:  #000000;
#         }#T_60ace_row15_col0{
#             background-color:  #38a367;
#             color:  #000000;
#         }#T_60ace_row15_col2{
#             background-color:  #39a569;
#             color:  #000000;
#         }#T_60ace_row16_col0,#T_60ace_row16_col2{
#             background-color:  #319c5c;
#             color:  #000000;
#         }#T_60ace_row17_col0{
#             background-color:  #17813d;
#             color:  #f1f1f1;
#         }#T_60ace_row17_col1{
#             background-color:  #1a843f;
#             color:  #000000;
#         }#T_60ace_row17_col2{
#             background-color:  #228a44;
#             color:  #000000;
#         }</style><table id="T_60ace_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >val_binary_sharpe</th>        <th class="col_heading level0 col1" >val_binary_long_sharpe</th>        <th class="col_heading level0 col2" >val_binary_short_sharpe</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_60ace_level0_row0" class="row_heading level0 row0" >310</th>
#                         <td id="T_60ace_row0_col0" class="data row0 col0" >-0.145773</td>
#                         <td id="T_60ace_row0_col1" class="data row0 col1" >-0.034170</td>
#                         <td id="T_60ace_row0_col2" class="data row0 col2" >-0.305852</td>
#             </tr>
#             <tr>
#                         <th id="T_60ace_level0_row1" class="row_heading level0 row1" >320</th>
#                         <td id="T_60ace_row1_col0" class="data row1 col0" >0.160951</td>
#                         <td id="T_60ace_row1_col1" class="data row1 col1" >0.204853</td>
#                         <td id="T_60ace_row1_col2" class="data row1 col2" >0.122536</td>
#             </tr>
#             <tr>
#                         <th id="T_60ace_level0_row2" class="row_heading level0 row2" >330</th>
#                         <td id="T_60ace_row2_col0" class="data row2 col0" >0.133387</td>
#                         <td id="T_60ace_row2_col1" class="data row2 col1" >0.209404</td>
#                         <td id="T_60ace_row2_col2" class="data row2 col2" >0.039314</td>
#             </tr>
#             <tr>
#                         <th id="T_60ace_level0_row3" class="row_heading level0 row3" >340</th>
#                         <td id="T_60ace_row3_col0" class="data row3 col0" >0.511987</td>
#                         <td id="T_60ace_row3_col1" class="data row3 col1" >0.667484</td>
#                         <td id="T_60ace_row3_col2" class="data row3 col2" >0.398281</td>
#             </tr>
#             <tr>
#                         <th id="T_60ace_level0_row4" class="row_heading level0 row4" >350</th>
#                         <td id="T_60ace_row4_col0" class="data row4 col0" >-0.094099</td>
#                         <td id="T_60ace_row4_col1" class="data row4 col1" >0.033089</td>
#                         <td id="T_60ace_row4_col2" class="data row4 col2" >-0.153683</td>
#             </tr>
#             <tr>
#                         <th id="T_60ace_level0_row5" class="row_heading level0 row5" >360</th>
#                         <td id="T_60ace_row5_col0" class="data row5 col0" >-0.134607</td>
#                         <td id="T_60ace_row5_col1" class="data row5 col1" >0.024122</td>
#                         <td id="T_60ace_row5_col2" class="data row5 col2" >-0.227862</td>
#             </tr>
#             <tr>
#                         <th id="T_60ace_level0_row6" class="row_heading level0 row6" >370</th>
#                         <td id="T_60ace_row6_col0" class="data row6 col0" >0.229919</td>
#                         <td id="T_60ace_row6_col1" class="data row6 col1" >0.252351</td>
#                         <td id="T_60ace_row6_col2" class="data row6 col2" >0.243373</td>
#             </tr>
#             <tr>
#                         <th id="T_60ace_level0_row7" class="row_heading level0 row7" >380</th>
#                         <td id="T_60ace_row7_col0" class="data row7

# %% [markdown]
# ### Compare study interventions for each asset

# %%
asset_pavg = dv_adj.loc[:, val_binary_sharpe].groupby(['params', 'asset']).mean()

# %%
res = []
for start in range(STUDY_START+10, STUDY_END, 10):
    r = range(start, start+10)
    ad = range_diff(asset_pavg, r, base_range).groupby('asset').mean()
    ad = ad.assign(start=start).set_index('start', append=True)
    res.append(ad)
res = pd.concat(res, axis=0).sort_index(level=[0, 1])
add_style(res)
# Out:
# <style  type="text/css" >
# #T_723eb_row0_col0,#T_723eb_row59_col1{
#             background-color:  #92d5c4;
#             color:  #000000;
#         }#T_723eb_row0_col1,#T_723eb_row1_col1{
#             background-color:  #ade0d4;
#             color:  #000000;
#         }#T_723eb_row0_col2,#T_723eb_row4_col2,#T_723eb_row32_col2{
#             background-color:  #72c7ad;
#             color:  #000000;
#         }#T_723eb_row1_col0{
#             background-color:  #a0dbcd;
#             color:  #000000;
#         }#T_723eb_row1_col2{
#             background-color:  #78cab1;
#             color:  #000000;
#         }#T_723eb_row2_col0{
#             background-color:  #d6f0ee;
#             color:  #000000;
#         }#T_723eb_row2_col1{
#             background-color:  #dff3f5;
#             color:  #000000;
#         }#T_723eb_row2_col2,#T_723eb_row5_col2,#T_723eb_row6_col1{
#             background-color:  #bde6de;
#             color:  #000000;
#         }#T_723eb_row3_col0,#T_723eb_row61_col0{
#             background-color:  #d8f0ef;
#             color:  #000000;
#         }#T_723eb_row3_col1,#T_723eb_row65_col1{
#             background-color:  #daf1f1;
#             color:  #000000;
#         }#T_723eb_row3_col2{
#             background-color:  #c2e8e0;
#             color:  #000000;
#         }#T_723eb_row4_col0,#T_723eb_row17_col2,#T_723eb_row63_col2{
#             background-color:  #98d8c9;
#             color:  #000000;
#         }#T_723eb_row4_col1,#T_723eb_row7_col2{
#             background-color:  #9ad8ca;
#             color:  #000000;
#         }#T_723eb_row5_col0{
#             background-color:  #d1eeea;
#             color:  #000000;
#         }#T_723eb_row5_col1,#T_723eb_row17_col1,#T_723eb_row65_col0{
#             background-color:  #d2eeeb;
#             color:  #000000;
#         }#T_723eb_row6_col0{
#             background-color:  #afe1d5;
#             color:  #000000;
#         }#T_723eb_row6_col2{
#             background-color:  #85cfbb;
#             color:  #000000;
#         }#T_723eb_row7_col0{
#             background-color:  #b2e2d7;
#             color:  #000000;
#         }#T_723eb_row7_col1{
#             background-color:  #95d6c6;
#             color:  #000000;
#         }#T_723eb_row8_col0,#T_723eb_row24_col0,#T_723eb_row25_col1,#T_723eb_row50_col0{
#             background-color:  #51b689;
#             color:  #000000;
#         }#T_723eb_row8_col1,#T_723eb_row14_col1,#T_723eb_row68_col2{
#             background-color:  #4fb688;
#             color:  #000000;
#         }#T_723eb_row8_col2{
#             background-color:  #3eaa70;
#             color:  #000000;
#         }#T_723eb_row9_col0{
#             background-color:  #9fdacc;
#             color:  #000000;
#         }#T_723eb_row9_col1,#T_723eb_row26_col1,#T_723eb_row67_col1{
#             background-color:  #acdfd4;
#             color:  #000000;
#         }#T_723eb_row9_col2{
#             background-color:  #70c6ac;
#             color:  #000000;
#         }#T_723eb_row10_col0{
#             background-color:  #7ccbb4;
#             color:  #000000;
#         }#T_723eb_row10_col1{
#             background-color:  #80cdb7;
#             color:  #000000;
#         }#T_723eb_row10_col2{
#             background-color:  #62c09f;
#             color:  #000000;
#         }#T_723eb_row11_col0,#T_723eb_row34_col2,#T_723eb_row69_col2{
#             background-color:  #43af78;
#             color:  #000000;
#         }#T_723eb_row11_col1,#T_723eb_row19_col2{
#             background-color:  #39a569;
#             color:  #000000;
#         }#T_723eb_row11_col2{
#             background-color:  #329d5e;
#             color:  #000000;
#         }#T_723eb_row12_col0,#T_723eb_row18_col1,#T_723eb_row56_col2{
#             background-color:  #5ebe9b;
#             color:  #000000;
#         }#T_723eb_row12_col1{
#             background-color:  #60bf9c;
#             color:  #000000;
#         }#T_723eb_row12_col2{
#             background-color:  #46b17c;
#             color:  #000000;
#         }#T_723eb_row13_col0,#T_723eb_row49_col0{
#             background-color:  #29924f;
#             color:  #000000;
#         }#T_723eb_row13_col1,#T_723eb_row36_col1,#T_723eb_row40_col1{
#             background-color:  #3ba76c;
#             color:  #000000;
#         }#T_723eb_row13_col2{
#             background-color:  #137d39;
#             color:  #f1f1f1;
#         }#T_723eb_row14_col0{
#             background-color:  #59bb93;
#             color:  #000000;
#         }#T_723eb_row14_col2{
#             background-color:  #4eb586;
#             color:  #000000;
#         }#T_723eb_row15_col0,#T_723eb_row15_col1{
#             background-color:  #349f61;
#             color:  #000000;
#         }#T_723eb_row15_col2,#T_723eb_row20_col2,#T_723eb_row37_col1,#T_723eb_row44_col2{
#             background-color:  #238b45;
#             color:  #000000;
#         }#T_723eb_row16_col0,#T_723eb_row18_col2,#T_723eb_row43_col2{
#             background-color:  #4db585;
#             color:  #000000;
#         }#T_723eb_row16_col1,#T_723eb_row18_col0{
#             background-color:  #56ba91;
#             color:  #000000;
#         }#T_723eb_row16_col2,#T_723eb_row19_col0{
#             background-color:  #38a367;
#             color:  #000000;
#         }#T_723eb_row17_col0{
#             background-color:  #c4e9e1;
#             color:  #000000;
#         }#T_723eb_row19_col1,#T_723eb_row48_col1,#T_723eb_row51_col0,#T_723eb_row69_col0,#T_723eb_row69_col1{
#             background-color:  #3aa66a;
#             color:  #000000;
#         }#T_723eb_row20_col0{
#             background-color:  #1d8640;
#             color:  #000000;
#         }#T_723eb_row20_col1,#T_723eb_row37_col0{
#             background-color:  #157f3b;
#             color:  #f1f1f1;
#         }#T_723eb_row21_col0{
#             background-color:  #005e26;
#             color:  #f1f1f1;
#         }#T_723eb_row21_col1{
#             background-color:  #004e1f;
#             color:  #f1f1f1;
#         }#T_723eb_row21_col2{
#             background-color:  #016e2d;
#             color:  #f1f1f1;
#         }#T_723eb_row22_col0,#T_723eb_row42_col2,#T_723eb_row71_col2{
#             background-color:  #006729;
#             color:  #f1f1f1;
#         }#T_723eb_row22_col1,#T_723eb_row71_col0{
#             background-color:  #005321;
#             color:  #f1f1f1;
#         }#T_723eb_row22_col2{
#             background-color:  #00682a;
#             color:  #f1f1f1;
#         }#T_723eb_row23_col0{
#             background-color:  #5abb95;
#             color:  #000000;
#         }#T_723eb_row23_col1{
#             background-color:  #5dbd99;
#             color:  #000000;
#         }#T_723eb_row23_col2,#T_723eb_row64_col0{
#             background-color:  #4bb382;
#             color:  #000000;
#         }#T_723eb_row24_col1{
#             background-color:  #5bbc96;
#             color:  #000000;
#         }#T_723eb_row24_col2{
#             background-color:  #45b07b;
#             color:  #000000;
#         }#T_723eb_row25_col0,#T_723eb_row68_col1{
#             background-color:  #53b88c;
#             color:  #000000;
#         }#T_723eb_row25_col2,#T_723eb_row51_col1,#T_723eb_row55_col1{
#             background-color:  #41ae77;
#             color:  #000000;
#         }#T_723eb_row26_col0,#T_723eb_row43_col0{
#             background-color:  #8cd2bf;
#             color:  #000000;
#         }#T_723eb_row26_col2,#T_723eb_row56_col1,#T_723eb_row70_col1{
#             background-color:  #77c9b0;
#             color:  #000000;
#         }#T_723eb_row27_col0{
#             background-color:  #03702e;
#             color:  #f1f1f1;
#         }#T_723eb_row27_col1,#T_723eb_row38_col2,#T_723eb_row60_col2{
#             background-color:  #005a24;
#             color:  #f1f1f1;
#         }#T_723eb_row27_col2,#T_723eb_row52_col0,#T_723eb_row53_col1{
#             background-color:  #127c39;
#             color:  #f1f1f1;
#         }#T_723eb_row28_col0{
#             background-color:  #17813d;
#             color:  #f1f1f1;
#         }#T_723eb_row28_col1{
#             background-color:  #005020;
#             color:  #f1f1f1;
#         }#T_723eb_row28_col2,#T_723eb_row40_col0{
#             background-color:  #2c9553;
#             color:  #000000;
#         }#T_723eb_row29_col0,#T_723eb_row60_col0{

# %%
res = []
for start in range(STUDY_START+10, STUDY_END, 10):
    r = range(start, start+10)
    #ad = range_diff(asset_pavg, r, base_range).groupby('asset').mean()
    ad = range_diff(asset_pavg, r, base_range).groupby('asset').mean() / range_diff(asset_pavg, r, base_range).groupby('asset').std()
    ad = ad.assign(start=start).set_index('start', append=True)
    res.append(ad)
res = pd.concat(res, axis=0).sort_index(level=[0, 1])
add_style(res)
# Out:
# <style  type="text/css" >
# #T_812f0_row0_col0,#T_812f0_row5_col0{
#             background-color:  #dff3f5;
#             color:  #000000;
#         }#T_812f0_row0_col1,#T_812f0_row2_col2,#T_812f0_row54_col1,#T_812f0_row65_col0{
#             background-color:  #e4f5f8;
#             color:  #000000;
#         }#T_812f0_row0_col2,#T_812f0_row1_col0{
#             background-color:  #d1eee9;
#             color:  #000000;
#         }#T_812f0_row1_col1,#T_812f0_row5_col2{
#             background-color:  #d7f0ee;
#             color:  #000000;
#         }#T_812f0_row1_col2,#T_812f0_row32_col0{
#             background-color:  #b4e2d8;
#             color:  #000000;
#         }#T_812f0_row2_col0,#T_812f0_row3_col1,#T_812f0_row17_col1{
#             background-color:  #eff9fb;
#             color:  #000000;
#         }#T_812f0_row2_col1,#T_812f0_row58_col0,#T_812f0_row58_col2{
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }#T_812f0_row3_col0,#T_812f0_row26_col1{
#             background-color:  #ebf7fa;
#             color:  #000000;
#         }#T_812f0_row3_col2,#T_812f0_row5_col1,#T_812f0_row62_col0{
#             background-color:  #e2f4f7;
#             color:  #000000;
#         }#T_812f0_row4_col0{
#             background-color:  #caebe5;
#             color:  #000000;
#         }#T_812f0_row4_col1,#T_812f0_row7_col0{
#             background-color:  #c2e8e0;
#             color:  #000000;
#         }#T_812f0_row4_col2,#T_812f0_row10_col0,#T_812f0_row10_col1{
#             background-color:  #acdfd4;
#             color:  #000000;
#         }#T_812f0_row6_col0{
#             background-color:  #c8ebe4;
#             color:  #000000;
#         }#T_812f0_row6_col1,#T_812f0_row61_col2{
#             background-color:  #d1eeea;
#             color:  #000000;
#         }#T_812f0_row6_col2{
#             background-color:  #aadfd3;
#             color:  #000000;
#         }#T_812f0_row7_col1,#T_812f0_row32_col1{
#             background-color:  #b2e2d7;
#             color:  #000000;
#         }#T_812f0_row7_col2,#T_812f0_row32_col2{
#             background-color:  #b5e3d9;
#             color:  #000000;
#         }#T_812f0_row8_col0,#T_812f0_row12_col2{
#             background-color:  #77c9b0;
#             color:  #000000;
#         }#T_812f0_row8_col1,#T_812f0_row11_col2{
#             background-color:  #61bf9e;
#             color:  #000000;
#         }#T_812f0_row8_col2,#T_812f0_row31_col2,#T_812f0_row36_col0{
#             background-color:  #65c2a3;
#             color:  #000000;
#         }#T_812f0_row9_col0{
#             background-color:  #ccece6;
#             color:  #000000;
#         }#T_812f0_row9_col1{
#             background-color:  #d0ede9;
#             color:  #000000;
#         }#T_812f0_row9_col2,#T_812f0_row70_col2{
#             background-color:  #a5ddd0;
#             color:  #000000;
#         }#T_812f0_row10_col2{
#             background-color:  #95d6c6;
#             color:  #000000;
#         }#T_812f0_row11_col0{
#             background-color:  #70c6ac;
#             color:  #000000;
#         }#T_812f0_row11_col1,#T_812f0_row35_col2{
#             background-color:  #57ba92;
#             color:  #000000;
#         }#T_812f0_row12_col0,#T_812f0_row50_col1{
#             background-color:  #90d4c3;
#             color:  #000000;
#         }#T_812f0_row12_col1,#T_812f0_row18_col0,#T_812f0_row64_col2{
#             background-color:  #85cfbb;
#             color:  #000000;
#         }#T_812f0_row13_col0{
#             background-color:  #38a367;
#             color:  #000000;
#         }#T_812f0_row13_col1{
#             background-color:  #46b17c;
#             color:  #000000;
#         }#T_812f0_row13_col2{
#             background-color:  #2c9553;
#             color:  #000000;
#         }#T_812f0_row14_col0,#T_812f0_row23_col0{
#             background-color:  #88d1bd;
#             color:  #000000;
#         }#T_812f0_row14_col1,#T_812f0_row25_col1{
#             background-color:  #75c9af;
#             color:  #000000;
#         }#T_812f0_row14_col2{
#             background-color:  #80cdb7;
#             color:  #000000;
#         }#T_812f0_row15_col0,#T_812f0_row50_col2,#T_812f0_row66_col2{
#             background-color:  #60bf9c;
#             color:  #000000;
#         }#T_812f0_row15_col1,#T_812f0_row31_col1{
#             background-color:  #59bb93;
#             color:  #000000;
#         }#T_812f0_row15_col2,#T_812f0_row19_col1{
#             background-color:  #51b689;
#             color:  #000000;
#         }#T_812f0_row16_col0,#T_812f0_row18_col2,#T_812f0_row25_col0{
#             background-color:  #7fcdb6;
#             color:  #000000;
#         }#T_812f0_row16_col1,#T_812f0_row68_col2{
#             background-color:  #84cfb9;
#             color:  #000000;
#         }#T_812f0_row16_col2{
#             background-color:  #68c3a6;
#             color:  #000000;
#         }#T_812f0_row17_col0{
#             background-color:  #e0f3f5;
#             color:  #000000;
#         }#T_812f0_row17_col2,#T_812f0_row67_col0{
#             background-color:  #cfede8;
#             color:  #000000;
#         }#T_812f0_row18_col1{
#             background-color:  #8cd2bf;
#             color:  #000000;
#         }#T_812f0_row19_col0,#T_812f0_row35_col0,#T_812f0_row51_col1{
#             background-color:  #56ba91;
#             color:  #000000;
#         }#T_812f0_row19_col2,#T_812f0_row55_col0,#T_812f0_row66_col1{
#             background-color:  #5ebe9b;
#             color:  #000000;
#         }#T_812f0_row20_col0,#T_812f0_row27_col0,#T_812f0_row57_col1{
#             background-color:  #319c5c;
#             color:  #000000;
#         }#T_812f0_row20_col1,#T_812f0_row21_col2{
#             background-color:  #2e9756;
#             color:  #000000;
#         }#T_812f0_row20_col2,#T_812f0_row37_col0{
#             background-color:  #37a266;
#             color:  #000000;
#         }#T_812f0_row21_col0,#T_812f0_row28_col0,#T_812f0_row47_col0,#T_812f0_row52_col1{
#             background-color:  #268f4a;
#             color:  #000000;
#         }#T_812f0_row21_col1{
#             background-color:  #1a843f;
#             color:  #000000;
#         }#T_812f0_row22_col0{
#             background-color:  #1d8640;
#             color:  #000000;
#         }#T_812f0_row22_col1,#T_812f0_row45_col2{
#             background-color:  #006d2c;
#             color:  #f1f1f1;
#         }#T_812f0_row22_col2{
#             background-color:  #17813d;
#             color:  #f1f1f1;
#         }#T_812f0_row23_col1{
#             background-color:  #8ad2be;
#             color:  #000000;
#         }#T_812f0_row23_col2{
#             background-color:  #7ccbb4;
#             color:  #000000;
#         }#T_812f0_row24_col0{
#             background-color:  #7acbb3;
#             color:  #000000;
#         }#T_812f0_row24_col1,#T_812f0_row43_col2{
#             background-color:  #82ceb8;
#             color:  #000000;
#         }#T_812f0_row24_col2,#T_812f0_row33_col0,#T_812f0_row68_col0{
#             background-color:  #74c8ae;
#             color:  #000000;
#         }#T_812f0_row25_col2{
#             background-color:  #6dc5a9;
#             color:  #000000;
#         }#T_812f0_row26_col0{
#             background-color:  #e5f5f9;
#             color:  #000000;
#         }#T_812f0_row26_col2{
#             background-color:  #e9f7fa;
#             color:  #000000;
#         }#T_812f0_row27_col1{
#             background-color:  #2b9452;
#             color:  #000000;
#         }#T_812f0_row27_col2{
#             background-color:  #36a164;
#             color:  #000000;
#         }#T_812f0_row28_col1{
#             background-color:  #00692a;
#             color:  #f1f1f1;
#         }#T_812f0_row28_col2,#T_812f0_row49_col0{
#             background-color:  #41ae77;
#             color:  #000000;
#         }#T_812f0_row29_col0{
#             background-color:  #107a37;
#             color:  #f1f1f1;
#         }#T_812f0_row29_col1{
#             background-color:  #026f2e;
#             color:  #f1f1f1;
#         }#T_812f0_row29_col2,#T_812f0_row42_col0{
#             background-color:  #147e3a;
#             color:  #f1f1f1;
#         }#T_812f0_row30_col0,#T_812f0_row30_col2,#T_812f0_row48_col1,#T_812f0_row55_col2{
#             background-color:  #5dbd99;
#             color:  #000000;

# %%
#add_style(agg_asset_params(dv_adj.loc[:, val_binary_sharpe]).sort_index(level=[1, 0]))

# %% [markdown]
# ## Recover Best Params By Asset

# %%
res = []
for start in range(STUDY_START+10, STUDY_END, 10):
    r = range(start, start+10)
    ad = range_diff(asset_pavg, r, base_range).groupby('asset').mean()
    ad = ad.assign(start=start).set_index('start', append=True)
    res.append(ad)
res = pd.concat(res, axis=0).sort_index(level=[0, 1])
topgroups = res.loc[res.groupby(['asset'])['val_binary_sharpe'].idxmax()]
add_style(topgroups)
# Out:
# <style  type="text/css" >
# #T_e9788_row0_col0,#T_e9788_row0_col1,#T_e9788_row0_col2{
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }#T_e9788_row1_col0{
#             background-color:  #29924f;
#             color:  #000000;
#         }#T_e9788_row1_col1{
#             background-color:  #006027;
#             color:  #f1f1f1;
#         }#T_e9788_row1_col2{
#             background-color:  #70c6ac;
#             color:  #000000;
#         }#T_e9788_row2_col0,#T_e9788_row2_col1,#T_e9788_row2_col2{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_e9788_row3_col0{
#             background-color:  #107a37;
#             color:  #f1f1f1;
#         }#T_e9788_row3_col1{
#             background-color:  #005b25;
#             color:  #f1f1f1;
#         }#T_e9788_row3_col2{
#             background-color:  #7fcdb6;
#             color:  #000000;
#         }</style><table id="T_e9788_" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >val_binary_sharpe</th>        <th class="col_heading level0 col1" >val_binary_long_sharpe</th>        <th class="col_heading level0 col2" >val_binary_short_sharpe</th>    </tr>    <tr>        <th class="index_name level0" >asset</th>        <th class="index_name level1" >start</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e9788_level0_row0" class="row_heading level0 row0" >dow_jones</th>
#                         <th id="T_e9788_level1_row0" class="row_heading level1 row0" >440</th>
#                         <td id="T_e9788_row0_col0" class="data row0 col0" >0.092930</td>
#                         <td id="T_e9788_row0_col1" class="data row0 col1" >0.054415</td>
#                         <td id="T_e9788_row0_col2" class="data row0 col2" >0.086379</td>
#             </tr>
#             <tr>
#                         <th id="T_e9788_level0_row1" class="row_heading level0 row1" >nasdaq_100</th>
#                         <th id="T_e9788_level1_row1" class="row_heading level1 row1" >420</th>
#                         <td id="T_e9788_row1_col0" class="data row1 col0" >0.192853</td>
#                         <td id="T_e9788_row1_col1" class="data row1 col1" >0.153162</td>
#                         <td id="T_e9788_row1_col2" class="data row1 col2" >0.125751</td>
#             </tr>
#             <tr>
#                         <th id="T_e9788_level0_row2" class="row_heading level0 row2" >russell_2000</th>
#                         <th id="T_e9788_level1_row2" class="row_heading level1 row2" >340</th>
#                         <td id="T_e9788_row2_col0" class="data row2 col0" >0.231008</td>
#                         <td id="T_e9788_row2_col1" class="data row2 col1" >0.162620</td>
#                         <td id="T_e9788_row2_col2" class="data row2 col2" >0.169652</td>
#             </tr>
#             <tr>
#                         <th id="T_e9788_level0_row3" class="row_heading level0 row3" >sp_500</th>
#                         <th id="T_e9788_level1_row3" class="row_heading level1 row3" >480</th>
#                         <td id="T_e9788_row3_col0" class="data row3 col0" >0.205879</td>
#                         <td id="T_e9788_row3_col1" class="data row3 col1" >0.154731</td>
#                         <td id="T_e9788_row3_col2" class="data row3 col2" >0.122951</td>
#             </tr>
#     </tbody></table>

# %%
res = []
for start in range(STUDY_START+10, STUDY_END, 10):
    r = range(start, start+10)
    #ad = range_diff(asset_pavg, r, base_range).groupby('asset').mean()
    ad = range_diff(asset_pavg, r, base_range).groupby('asset').mean() / range_diff(asset_pavg, r, base_range).groupby('asset').std()
    ad = ad.assign(start=start).set_index('start', append=True)
    res.append(ad)
res = pd.concat(res, axis=0).sort_index(level=[0, 1])
topgroups = res.loc[res.groupby(['asset'])['val_binary_sharpe'].idxmax()]
add_style(topgroups)
# Out:
# <style  type="text/css" >
# #T_5f2d4_row0_col0,#T_5f2d4_row0_col1,#T_5f2d4_row0_col2{
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }#T_5f2d4_row1_col0{
#             background-color:  #75c9af;
#             color:  #000000;
#         }#T_5f2d4_row1_col1{
#             background-color:  #39a569;
#             color:  #000000;
#         }#T_5f2d4_row1_col2{
#             background-color:  #b2e2d7;
#             color:  #000000;
#         }#T_5f2d4_row2_col0,#T_5f2d4_row2_col1,#T_5f2d4_row2_col2{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_5f2d4_row3_col0{
#             background-color:  #309b5b;
#             color:  #000000;
#         }#T_5f2d4_row3_col1{
#             background-color:  #127c39;
#             color:  #f1f1f1;
#         }#T_5f2d4_row3_col2{
#             background-color:  #67c2a5;
#             color:  #000000;
#         }</style><table id="T_5f2d4_" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >val_binary_sharpe</th>        <th class="col_heading level0 col1" >val_binary_long_sharpe</th>        <th class="col_heading level0 col2" >val_binary_short_sharpe</th>    </tr>    <tr>        <th class="index_name level0" >asset</th>        <th class="index_name level1" >start</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5f2d4_level0_row0" class="row_heading level0 row0" >dow_jones</th>
#                         <th id="T_5f2d4_level1_row0" class="row_heading level1 row0" >440</th>
#                         <td id="T_5f2d4_row0_col0" class="data row0 col0" >0.336784</td>
#                         <td id="T_5f2d4_row0_col1" class="data row0 col1" >0.294276</td>
#                         <td id="T_5f2d4_row0_col2" class="data row0 col2" >0.352172</td>
#             </tr>
#             <tr>
#                         <th id="T_5f2d4_level0_row1" class="row_heading level0 row1" >nasdaq_100</th>
#                         <th id="T_5f2d4_level1_row1" class="row_heading level1 row1" >420</th>
#                         <td id="T_5f2d4_row1_col0" class="data row1 col0" >0.545928</td>
#                         <td id="T_5f2d4_row1_col1" class="data row1 col1" >0.621254</td>
#                         <td id="T_5f2d4_row1_col2" class="data row1 col2" >0.474867</td>
#             </tr>
#             <tr>
#                         <th id="T_5f2d4_level0_row2" class="row_heading level0 row2" >russell_2000</th>
#                         <th id="T_5f2d4_level1_row2" class="row_heading level1 row2" >330</th>
#                         <td id="T_5f2d4_row2_col0" class="data row2 col0" >0.789184</td>
#                         <td id="T_5f2d4_row2_col1" class="data row2 col1" >0.789900</td>
#                         <td id="T_5f2d4_row2_col2" class="data row2 col2" >0.742820</td>
#             </tr>
#             <tr>
#                         <th id="T_5f2d4_level0_row3" class="row_heading level0 row3" >sp_500</th>
#                         <th id="T_5f2d4_level1_row3" class="row_heading level1 row3" >370</th>
#                         <td id="T_5f2d4_row3_col0" class="data row3 col0" >0.650053</td>
#                         <td id="T_5f2d4_row3_col1" class="data row3 col1" >0.695652</td>
#                         <td id="T_5f2d4_row3_col2" class="data row3 col2" >0.547383</td>
#             </tr>
#     </tbody></table>

# %%
bestparams = {}
for group in topgroups.index:
    asset, start = group
    bestgroup = dv_adj.xs((asset, 'np')).loc[str(start):str(start+9), val_binary_sharpe]
    bestidx = bestgroup.loc[:, ['val_binary_long_sharpe', 'val_binary_short_sharpe']].mean(axis=1).idxmax()
    bestparams[asset] = int(bestidx)
    display(asset, add_style(bestgroup))
# Out:
# 'dow_jones'
# <style  type="text/css" >
# #T_ed863_row0_col0{
#             background-color:  #b8e4db;
#             color:  #000000;
#         }#T_ed863_row0_col1{
#             background-color:  #7fcdb6;
#             color:  #000000;
#         }#T_ed863_row0_col2{
#             background-color:  #c2e8e0;
#             color:  #000000;
#         }#T_ed863_row1_col0{
#             background-color:  #43af78;
#             color:  #000000;
#         }#T_ed863_row1_col1{
#             background-color:  #127c39;
#             color:  #f1f1f1;
#         }#T_ed863_row1_col2{
#             background-color:  #4bb382;
#             color:  #000000;
#         }#T_ed863_row2_col0{
#             background-color:  #39a569;
#             color:  #000000;
#         }#T_ed863_row2_col1{
#             background-color:  #29924f;
#             color:  #000000;
#         }#T_ed863_row2_col2{
#             background-color:  #3ca86d;
#             color:  #000000;
#         }#T_ed863_row3_col0,#T_ed863_row8_col1{
#             background-color:  #f4fbfc;
#             color:  #000000;
#         }#T_ed863_row3_col1{
#             background-color:  #d1eee9;
#             color:  #000000;
#         }#T_ed863_row3_col2,#T_ed863_row6_col0,#T_ed863_row6_col1{
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }#T_ed863_row4_col0{
#             background-color:  #d7f0ee;
#             color:  #000000;
#         }#T_ed863_row4_col1{
#             background-color:  #9ddacb;
#             color:  #000000;
#         }#T_ed863_row4_col2{
#             background-color:  #dbf2f2;
#             color:  #000000;
#         }#T_ed863_row5_col0{
#             background-color:  #00692a;
#             color:  #f1f1f1;
#         }#T_ed863_row5_col1{
#             background-color:  #006027;
#             color:  #f1f1f1;
#         }#T_ed863_row5_col2{
#             background-color:  #006b2b;
#             color:  #f1f1f1;
#         }#T_ed863_row6_col2{
#             background-color:  #bde6de;
#             color:  #000000;
#         }#T_ed863_row7_col0,#T_ed863_row7_col1,#T_ed863_row7_col2{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_ed863_row8_col0{
#             background-color:  #e6f5f9;
#             color:  #000000;
#         }#T_ed863_row8_col2{
#             background-color:  #97d7c7;
#             color:  #000000;
#         }#T_ed863_row9_col0{
#             background-color:  #78cab1;
#             color:  #000000;
#         }#T_ed863_row9_col1{
#             background-color:  #90d4c3;
#             color:  #000000;
#         }#T_ed863_row9_col2{
#             background-color:  #2c9553;
#             color:  #000000;
#         }</style><table id="T_ed863_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >val_binary_sharpe</th>        <th class="col_heading level0 col1" >val_binary_long_sharpe</th>        <th class="col_heading level0 col2" >val_binary_short_sharpe</th>    </tr>    <tr>        <th class="index_name level0" >params</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ed863_level0_row0" class="row_heading level0 row0" >440</th>
#                         <td id="T_ed863_row0_col0" class="data row0 col0" >0.187772</td>
#                         <td id="T_ed863_row0_col1" class="data row0 col1" >0.555028</td>
#                         <td id="T_ed863_row0_col2" class="data row0 col2" >-0.649138</td>
#             </tr>
#             <tr>
#                         <th id="T_ed863_level0_row1" class="row_heading level0 row1" >441</th>
#                         <td id="T_ed863_row1_col0" class="data row1 col0" >0.670668</td>
#                         <td id="T_ed863_row1_col1" class="data row1 col1" >1.007231</td>
#                         <td id="T_ed863_row1_col2" class="data row1 col2" >-0.294709</td>
#             </tr>
#             <tr>
#                         <th id="T_ed863_level0_row2" class="row_heading level0 row2" >442</th>
#                         <td id="T_ed863_row2_col0" class="data row2 col0" >0.726510</td>
#                         <td id="T_ed863_row2_col1" class="data row2 col1" >0.900953</td>
#                         <td id="T_ed863_row2_col2" class="data row2 col2" >-0.232050</td>
#             </tr>
#             <tr>
#                         <th id="T_ed863_level0_row3" class="row_heading level0 row3" >443</th>
#                         <td id="T_ed863_row3_col0" class="data row3 col0" >-0.222758</td>
#                         <td id="T_ed863_row3_col1" class="data row3 col1" >0.293060</td>
#                         <td id="T_ed863_row3_col2" class="data row3 col2" >-0.959779</td>
#             </tr>
#             <tr>
#                         <th id="T_ed863_level0_row4" class="row_heading level0 row4" >444</th>
#                         <td id="T_ed863_row4_col0" class="data row4 col0" >0.037985</td>
#                         <td id="T_ed863_row4_col1" class="data row4 col1" >0.460463</td>
#                         <td id="T_ed863_row4_col2" class="data row4 col2" >-0.763169</td>
#             </tr>
#             <tr>
#                         <th id="T_ed863_level0_row5" class="row_heading level0 row5" >445</th>
#                         <td id="T_ed863_row5_col0" class="data row5 col0" >1.070577</td>
#                         <td id="T_ed863_row5_col1" class="data row5 col1" >1.134597</td>
#                         <td id="T_ed863_row5_col2" class="data row5 col2" >0.030018</td>
#             </tr>
#             <tr>
#                         <th id="T_ed863_level0_row6" class="row_heading level0 row6" >446</th>
#                         <td id="T_ed863_row6_col0" class="data row6 col0" >-0.261372</td>
#                         <td id="T_ed863_row6_col1" class="data row6 col1" >0.013514</td>
#                         <td id="T_ed863_row6_col2" class="data row6 col2" >-0.637902</td>
#             </tr>
#             <tr>
#                         <th id="T_ed863_level0_row7" class="row_heading level0 row7" >447</th>
#                         <td id="T_ed863_row7_col0" class="data row7 col0" >1.242551</td>
#                         <td id="T_ed863_row7_col1" class="data row7 col1" >1.241026</td>
#                         <td id="T_ed863_row7_col2" class="data row7 col2" >0.164595</td>
#             </tr>
#             <tr>
#                         <th id="T_ed863_level0_row8" class="row_heading level0 row8" >448</th>
#                         <td id="T_ed863_row8_col0" class="data row8 col0" >-0.079876</td>
#                         <td id="T_ed863_row8_col1" class="data row8 col1" >0.044587</td>
#                         <td id="T_ed863_row8_col2" class="data row8 col2" >-0.530593</td>
#             </tr>
#             <tr>
#                         <th id="T_ed863_level0_row9" class="row_heading level0 row9" >449</th>
#                         <td id="T_ed863_row9_col0" class="data row9 col0" >0.425887</td>
#                         <td id="T_ed863_row9_col1" class="data row9 col1" >0.498622</td>
#                         <td id="T_ed863_row9_col2" class="data row9 col2" >-0.156492</td>
#             </tr>
#     </tbody></table>
# 'nasdaq_100'
# <style  type="text/css" >
# #T_9f427_row0_col0{
#             background-color:  #005a24;
#             color:  #f1f1f1;
#         }#T_9f427_row0_col1{
#             background-color:  #329d5e;
#             color:  #000000;
#         }#T_9f427_row0_col2{
#             background-color:  #005b25;
#             color:  #f1f1f1;
#         }#T_9f427_row1_col0{
#             background-color:  #107a37;
#             color:  #f1f1f1;
#         }#T_9f427_row1_col1,#T_9f427_row3_col1{
#             background-color:  #3ba76c;
#             color:  #000000;
#         }#T_9f427_row1_col2{
#             background-color:  #1f8742;
#             color:  #000000;
#         }#T_9f427_row2_col0{
#             background-color:  #19833e;
#             color:  #f1f1f1;
#         }#T_9f427_row2_col1{
#             background-color:  #5bbc96;
#             color:  #000000;
#         }#T_9f427_row2_col2{
#             background-color:  #03702e;
#             color:  #f1f1f1;
#         }#T_9f427_row3_col0{
#             background-color:  #005924;
#             color:  #f1f1f1;
#         }#T_9f427_row3_col2,#T_9f427_row5_col0,#T_9f427_row5_col1{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_9f427_row4_col0{
#             background-color:  #68c3a6;
#             color:  #000000;
#         }#T_9f427_row4_col1{
#             background-color:  #82ceb8;
#             color:  #000000;
#         }#T_9f427_row4_col2{
#             background-color:  #7fcdb6;
#             color:  #000000;
#         }#T_9f427_row5_col2{
#             background-color:  #0a7633;
#             color:  #f1f1f1;
#         }#T_9f427_row6_col0{
#             background-color:  #3eaa70;
#             color:  #000000;
#         }#T_9f427_row6_col1{
#             background-color:  #55b98f;
#             color:  #000000;
#         }#T_9f427_row6_col2{
#             background-color:  #5dbd99;
#             color:  #000000;
#         }#T_9f427_row7_col0,#T_9f427_row7_col1,#T_9f427_row7_col2{
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }#T_9f427_row8_col0{
#             background-color:  #1c8540;
#             color:  #000000;
#         }#T_9f427_row8_col1{
#             background-color:  #2a9350;
#             color:  #000000;
#         }#T_9f427_row8_col2{
#             background-color:  #3fac74;
#             color:  #000000;
#         }#T_9f427_row9_col0{
#             background-color:  #4cb484;
#             color:  #000000;
#         }#T_9f427_row9_col1{
#             background-color:  #5ebe9b;
#             color:  #000000;
#         }#T_9f427_row9_col2{
#             background-color:  #6fc6aa;
#             color:  #000000;
#         }</style><table id="T_9f427_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >val_binary_sharpe</th>        <th class="col_heading level0 col1" >val_binary_long_sharpe</th>        <th class="col_heading level0 col2" >val_binary_short_sharpe</th>    </tr>    <tr>        <th class="index_name level0" >params</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9f427_level0_row0" class="row_heading level0 row0" >420</th>
#                         <td id="T_9f427_row0_col0" class="data row0 col0" >0.882257</td>
#                         <td id="T_9f427_row0_col1" class="data row0 col1" >0.568874</td>
#                         <td id="T_9f427_row0_col2" class="data row0 col2" >0.474093</td>
#             </tr>
#             <tr>
#                         <th id="T_9f427_level0_row1" class="row_heading level0 row1" >421</th>
#                         <td id="T_9f427_row1_col0" class="data row1 col0" >0.693506</td>
#                         <td id="T_9f427_row1_col1" class="data row1 col1" >0.515261</td>
#                         <td id="T_9f427_row1_col2" class="data row1 col2" >0.272301</td>
#             </tr>
#             <tr>
#                         <th id="T_9f427_level0_row2" class="row_heading level0 row2" >422</th>
#                         <td id="T_9f427_row2_col0" class="data row2 col0" >0.634334</td>
#                         <td id="T_9f427_row2_col1" class="data row2 col1" >0.337087</td>
#                         <td id="T_9f427_row2_col2" class="data row2 col2" >0.391644</td>
#             </tr>
#             <tr>
#                         <th id="T_9f427_level0_row3" class="row_heading level0 row3" >423</th>
#                         <td id="T_9f427_row3_col0" class="data row3 col0" >0.888994</td>
#                         <td id="T_9f427_row3_col1" class="data row3 col1" >0.516510</td>
#                         <td id="T_9f427_row3_col2" class="data row3 col2" >0.561733</td>
#             </tr>
#             <tr>
#                         <th id="T_9f427_level0_row4" class="row_heading level0 row4" >424</th>
#                         <td id="T_9f427_row4_col0" class="data row4 col0" >0.142539</td>
#                         <td id="T_9f427_row4_col1" class="data row4 col1" >0.172645</td>
#                         <td id="T_9f427_row4_col2" class="data row4 col2" >-0.125052</td>
#             </tr>
#             <tr>
#                         <th id="T_9f427_level0_row5" class="row_heading level0 row5" >425</th>
#                         <td id="T_9f427_row5_col0" class="data row5 col0" >0.998522</td>
#                         <td id="T_9f427_row5_col1" class="data row5 col1" >1.060146</td>
#                         <td id="T_9f427_row5_col2" class="data row5 col2" >0.363212</td>
#             </tr>
#             <tr>
#                         <th id="T_9f427_level0_row6" class="row_heading level0 row6" >426</th>
#                         <td id="T_9f427_row6_col0" class="data row6 col0" >0.391034</td>
#                         <td id="T_9f427_row6_col1" class="data row6 col1" >0.369036</td>
#                         <td id="T_9f427_row6_col2" class="data row6 col2" >-0.015196</td>
#             </tr>
#             <tr>
#                         <th id="T_9f427_level0_row7" class="row_heading level0 row7" >427</th>
#                         <td id="T_9f427_row7_col0" class="data row7 col0" >-0.690148</td>
#                         <td id="T_9f427_row7_col1" class="data row7 col1" >-0.499025</td>
#                         <td id="T_9f427_row7_col2" class="data row7 col2" >-0.666756</td>
#             </tr>
#             <tr>
#                         <th id="T_9f427_level0_row8" class="row_heading level0 row8" >428</th>
#                         <td id="T_9f427_row8_col0" class="data row8 col0" >0.622521</td>
#                         <td id="T_9f427_row8_col1" class="data row8 col1" >0.626127</td>
#                         <td id="T_9f427_row8_col2" class="data row8 col2" >0.108532</td>
#             </tr>
#             <tr>
#                         <th id="T_9f427_level0_row9" class="row_heading level0 row9" >429</th>
#                         <td id="T_9f427_row9_col0" class="data row9 col0" >0.305082</td>
#                         <td id="T_9f427_row9_col1" class="data row9 col1" >0.322553</td>
#                         <td id="T_9f427_row9_col2" class="data row9 col2" >-0.081179</td>
#             </tr>
#     </tbody></table>
# 'russell_2000'
# <style  type="text/css" >
# #T_41c45_row0_col0{
#             background-color:  #2f9858;
#             color:  #000000;
#         }#T_41c45_row0_col1{
#             background-color:  #4fb688;
#             color:  #000000;
#         }#T_41c45_row0_col2{
#             background-color:  #147e3a;
#             color:  #f1f1f1;
#         }#T_41c45_row1_col0{
#             background-color:  #9cd9ca;
#             color:  #000000;
#         }#T_41c45_row1_col1{
#             background-color:  #a2dcce;
#             color:  #000000;
#         }#T_41c45_row1_col2{
#             background-color:  #b4e2d8;
#             color:  #000000;
#         }#T_41c45_row2_col0{
#             background-color:  #85cfbb;
#             color:  #000000;
#         }#T_41c45_row2_col1{
#             background-color:  #a7ddd1;
#             color:  #000000;
#         }#T_41c45_row2_col2{
#             background-color:  #65c2a3;
#             color:  #000000;
#         }#T_41c45_row3_col0{
#             background-color:  #1f8742;
#             color:  #000000;
#         }#T_41c45_row3_col1{
#             background-color:  #4ab381;
#             color:  #000000;
#         }#T_41c45_row3_col2{
#             background-color:  #004e1f;
#             color:  #f1f1f1;
#         }#T_41c45_row4_col0,#T_41c45_row4_col1,#T_41c45_row4_col2{
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }#T_41c45_row5_col0{
#             background-color:  #268f4a;
#             color:  #000000;
#         }#T_41c45_row5_col1{
#             background-color:  #3eaa70;
#             color:  #000000;
#         }#T_41c45_row5_col2{
#             background-color:  #1e8741;
#             color:  #000000;
#         }#T_41c45_row6_col0{
#             background-color:  #54b88e;
#             color:  #000000;
#         }#T_41c45_row6_col1{
#             background-color:  #218944;
#             color:  #000000;
#         }#T_41c45_row6_col2{
#             background-color:  #bce6dd;
#             color:  #000000;
#         }#T_41c45_row7_col0{
#             background-color:  #005221;
#             color:  #f1f1f1;
#         }#T_41c45_row7_col1{
#             background-color:  #0e7936;
#             color:  #f1f1f1;
#         }#T_41c45_row7_col2,#T_41c45_row8_col0,#T_41c45_row8_col1{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_41c45_row8_col2{
#             background-color:  #00692a;
#             color:  #f1f1f1;
#         }#T_41c45_row9_col0{
#             background-color:  #9ad8ca;
#             color:  #000000;
#         }#T_41c45_row9_col1{
#             background-color:  #6fc6aa;
#             color:  #000000;
#         }#T_41c45_row9_col2{
#             background-color:  #d9f1f0;
#             color:  #000000;
#         }</style><table id="T_41c45_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >val_binary_sharpe</th>        <th class="col_heading level0 col1" >val_binary_long_sharpe</th>        <th class="col_heading level0 col2" >val_binary_short_sharpe</th>    </tr>    <tr>        <th class="index_name level0" >params</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_41c45_level0_row0" class="row_heading level0 row0" >330</th>
#                         <td id="T_41c45_row0_col0" class="data row0 col0" >0.948569</td>
#                         <td id="T_41c45_row0_col1" class="data row0 col1" >0.501786</td>
#                         <td id="T_41c45_row0_col2" class="data row0 col2" >0.869883</td>
#             </tr>
#             <tr>
#                         <th id="T_41c45_level0_row1" class="row_heading level0 row1" >331</th>
#                         <td id="T_41c45_row1_col0" class="data row1 col0" >0.526484</td>
#                         <td id="T_41c45_row1_col1" class="data row1 col1" >0.276769</td>
#                         <td id="T_41c45_row1_col2" class="data row1 col2" >0.451787</td>
#             </tr>
#             <tr>
#                         <th id="T_41c45_level0_row2" class="row_heading level0 row2" >332</th>
#                         <td id="T_41c45_row2_col0" class="data row2 col0" >0.596270</td>
#                         <td id="T_41c45_row2_col1" class="data row2 col1" >0.265069</td>
#                         <td id="T_41c45_row2_col2" class="data row2 col2" >0.615159</td>
#             </tr>
#             <tr>
#                         <th id="T_41c45_level0_row3" class="row_heading level0 row3" >333</th>
#                         <td id="T_41c45_row3_col0" class="data row3 col0" >1.023553</td>
#                         <td id="T_41c45_row3_col1" class="data row3 col1" >0.521640</td>
#                         <td id="T_41c45_row3_col2" class="data row3 col2" >1.009463</td>
#             </tr>
#             <tr>
#                         <th id="T_41c45_level0_row4" class="row_heading level0 row4" >334</th>
#                         <td id="T_41c45_row4_col0" class="data row4 col0" >0.062597</td>
#                         <td id="T_41c45_row4_col1" class="data row4 col1" >-0.084747</td>
#                         <td id="T_41c45_row4_col2" class="data row4 col2" >0.186100</td>
#             </tr>
#             <tr>
#                         <th id="T_41c45_level0_row5" class="row_heading level0 row5" >335</th>
#                         <td id="T_41c45_row5_col0" class="data row5 col0" >0.993460</td>
#                         <td id="T_41c45_row5_col1" class="data row5 col1" >0.566102</td>
#                         <td id="T_41c45_row5_col2" class="data row5 col2" >0.839471</td>
#             </tr>
#             <tr>
#                         <th id="T_41c45_level0_row6" class="row_heading level0 row6" >336</th>
#                         <td id="T_41c45_row6_col0" class="data row6 col0" >0.770481</td>
#                         <td id="T_41c45_row6_col1" class="data row6 col1" >0.686785</td>
#                         <td id="T_41c45_row6_col2" class="data row6 col2" >0.433397</td>
#             </tr>
#             <tr>
#                         <th id="T_41c45_level0_row7" class="row_heading level0 row7" >337</th>
#                         <td id="T_41c45_row7_col0" class="data row7 col0" >1.267252</td>
#                         <td id="T_41c45_row7_col1" class="data row7 col1" >0.754539</td>
#                         <td id="T_41c45_row7_col2" class="data row7 col2" >1.038182</td>
#             </tr>
#             <tr>
#                         <th id="T_41c45_level0_row8" class="row_heading level0 row8" >338</th>
#                         <td id="T_41c45_row8_col0" class="data row8 col0" >1.323636</td>
#                         <td id="T_41c45_row8_col1" class="data row8 col1" >0.935125</td>
#                         <td id="T_41c45_row8_col2" class="data row8 col2" >0.940239</td>
#             </tr>
#             <tr>
#                         <th id="T_41c45_level0_row9" class="row_heading level0 row9" >339</th>
#                         <td id="T_41c45_row9_col0" class="data row9 col0" >0.530956</td>
#                         <td id="T_41c45_row9_col1" class="data row9 col1" >0.404979</td>
#                         <td id="T_41c45_row9_col2" class="data row9 col2" >0.344041</td>
#             </tr>
#     </tbody></table>
# 'sp_500'
# <style  type="text/css" >
# #T_e0ab8_row0_col0{
#             background-color:  #caebe5;
#             color:  #000000;
#         }#T_e0ab8_row0_col1{
#             background-color:  #d2eeeb;
#             color:  #000000;
#         }#T_e0ab8_row0_col2{
#             background-color:  #bde6de;
#             color:  #000000;
#         }#T_e0ab8_row1_col0{
#             background-color:  #3eaa70;
#             color:  #000000;
#         }#T_e0ab8_row1_col1{
#             background-color:  #5bbc96;
#             color:  #000000;
#         }#T_e0ab8_row1_col2{
#             background-color:  #28914d;
#             color:  #000000;
#         }#T_e0ab8_row2_col0{
#             background-color:  #94d6c5;
#             color:  #000000;
#         }#T_e0ab8_row2_col1,#T_e0ab8_row2_col2{
#             background-color:  #8fd4c2;
#             color:  #000000;
#         }#T_e0ab8_row3_col0{
#             background-color:  #339e60;
#             color:  #000000;
#         }#T_e0ab8_row3_col1{
#             background-color:  #67c2a5;
#             color:  #000000;
#         }#T_e0ab8_row3_col2,#T_e0ab8_row6_col0,#T_e0ab8_row6_col1{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_e0ab8_row4_col0,#T_e0ab8_row4_col1,#T_e0ab8_row4_col2{
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }#T_e0ab8_row5_col0{
#             background-color:  #85cfbb;
#             color:  #000000;
#         }#T_e0ab8_row5_col1{
#             background-color:  #a4dccf;
#             color:  #000000;
#         }#T_e0ab8_row5_col2{
#             background-color:  #68c3a6;
#             color:  #000000;
#         }#T_e0ab8_row6_col2{
#             background-color:  #005a24;
#             color:  #f1f1f1;
#         }#T_e0ab8_row7_col0{
#             background-color:  #77c9b0;
#             color:  #000000;
#         }#T_e0ab8_row7_col1{
#             background-color:  #65c2a3;
#             color:  #000000;
#         }#T_e0ab8_row7_col2{
#             background-color:  #78cab1;
#             color:  #000000;
#         }#T_e0ab8_row8_col0{
#             background-color:  #afe1d5;
#             color:  #000000;
#         }#T_e0ab8_row8_col1{
#             background-color:  #98d8c9;
#             color:  #000000;
#         }#T_e0ab8_row8_col2{
#             background-color:  #d1eeea;
#             color:  #000000;
#         }#T_e0ab8_row9_col0{
#             background-color:  #16803c;
#             color:  #f1f1f1;
#         }#T_e0ab8_row9_col1{
#             background-color:  #00682a;
#             color:  #f1f1f1;
#         }#T_e0ab8_row9_col2{
#             background-color:  #349f61;
#             color:  #000000;
#         }</style><table id="T_e0ab8_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >val_binary_sharpe</th>        <th class="col_heading level0 col1" >val_binary_long_sharpe</th>        <th class="col_heading level0 col2" >val_binary_short_sharpe</th>    </tr>    <tr>        <th class="index_name level0" >params</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e0ab8_level0_row0" class="row_heading level0 row0" >370</th>
#                         <td id="T_e0ab8_row0_col0" class="data row0 col0" >-0.186759</td>
#                         <td id="T_e0ab8_row0_col1" class="data row0 col1" >-0.153632</td>
#                         <td id="T_e0ab8_row0_col2" class="data row0 col2" >-0.467439</td>
#             </tr>
#             <tr>
#                         <th id="T_e0ab8_level0_row1" class="row_heading level0 row1" >371</th>
#                         <td id="T_e0ab8_row1_col0" class="data row1 col0" >0.662980</td>
#                         <td id="T_e0ab8_row1_col1" class="data row1 col1" >0.371009</td>
#                         <td id="T_e0ab8_row1_col2" class="data row1 col2" >0.228998</td>
#             </tr>
#             <tr>
#                         <th id="T_e0ab8_level0_row2" class="row_heading level0 row2" >372</th>
#                         <td id="T_e0ab8_row2_col0" class="data row2 col0" >0.111107</td>
#                         <td id="T_e0ab8_row2_col1" class="data row2 col1" >0.146512</td>
#                         <td id="T_e0ab8_row2_col2" class="data row2 col2" >-0.286004</td>
#             </tr>
#             <tr>
#                         <th id="T_e0ab8_level0_row3" class="row_heading level0 row3" >373</th>
#                         <td id="T_e0ab8_row3_col0" class="data row3 col0" >0.753098</td>
#                         <td id="T_e0ab8_row3_col1" class="data row3 col1" >0.306746</td>
#                         <td id="T_e0ab8_row3_col2" class="data row3 col2" >0.654490</td>
#             </tr>
#             <tr>
#                         <th id="T_e0ab8_level0_row4" class="row_heading level0 row4" >374</th>
#                         <td id="T_e0ab8_row4_col0" class="data row4 col0" >-0.747420</td>
#                         <td id="T_e0ab8_row4_col1" class="data row4 col1" >-0.520121</td>
#                         <td id="T_e0ab8_row4_col2" class="data row4 col2" >-0.917762</td>
#             </tr>
#             <tr>
#                         <th id="T_e0ab8_level0_row5" class="row_heading level0 row5" >375</th>
#                         <td id="T_e0ab8_row5_col0" class="data row5 col0" >0.187640</td>
#                         <td id="T_e0ab8_row5_col1" class="data row5 col1" >0.059074</td>
#                         <td id="T_e0ab8_row5_col2" class="data row5 col2" >-0.143860</td>
#             </tr>
#             <tr>
#                         <th id="T_e0ab8_level0_row6" class="row_heading level0 row6" >376</th>
#                         <td id="T_e0ab8_row6_col0" class="data row6 col0" >1.454403</td>
#                         <td id="T_e0ab8_row6_col1" class="data row6 col1" >1.136989</td>
#                         <td id="T_e0ab8_row6_col2" class="data row6 col2" >0.549227</td>
#             </tr>
#             <tr>
#                         <th id="T_e0ab8_level0_row7" class="row_heading level0 row7" >377</th>
#                         <td id="T_e0ab8_row7_col0" class="data row7 col0" >0.260497</td>
#                         <td id="T_e0ab8_row7_col1" class="data row7 col1" >0.311212</td>
#                         <td id="T_e0ab8_row7_col2" class="data row7 col2" >-0.202349</td>
#             </tr>
#             <tr>
#                         <th id="T_e0ab8_level0_row8" class="row_heading level0 row8" >378</th>
#                         <td id="T_e0ab8_row8_col0" class="data row8 col0" >-0.038702</td>
#                         <td id="T_e0ab8_row8_col1" class="data row8 col1" >0.104451</td>
#                         <td id="T_e0ab8_row8_col2" class="data row8 col2" >-0.565158</td>
#             </tr>
#             <tr>
#                         <th id="T_e0ab8_level0_row9" class="row_heading level0 row9" >379</th>
#                         <td id="T_e0ab8_row9_col0" class="data row9 col0" >1.000423</td>
#                         <td id="T_e0ab8_row9_col1" class="data row9 col1" >0.952508</td>
#                         <td id="T_e0ab8_row9_col2" class="data row9 col2" >0.148187</td>
#             </tr>
#     </tbody></table>

# %%
bestparams
# Out:
# {'dow_jones': 447, 'nasdaq_100': 425, 'russell_2000': 338, 'sp_500': 376}

# %% [markdown]
# ## Compare Results Over Val by Params

# %%
sel_param = lambda d, p: d.xs(p, level=2, drop_level=False)
sel_asset = lambda d, a: d.xs(a, level=0, drop_level=False)

# %%
sp_500 = sel_asset(dv_adj.loc[:, val_binary_sharpe], 'sp_500').sort_index(level=2)
russell_2000 = sel_asset(dv_adj.loc[:, val_binary_sharpe], 'russell_2000').sort_index(level=2)
nasdaq_100 = sel_asset(dv_adj.loc[:, val_binary_sharpe], 'nasdaq_100').sort_index(level=2)
dow_jones = sel_asset(dv_adj.loc[:, val_binary_sharpe], 'dow_jones').sort_index(level=2)

# %%
add_style(sp_500)
# Out:
# <style  type="text/css" >
# #T_179df_row0_col0,#T_179df_row160_col2,#T_179df_row204_col2,#T_179df_row219_col2,#T_179df_row252_col1,#T_179df_row293_col2,#T_179df_row310_col1,#T_179df_row367_col0,#T_179df_row380_col2,#T_179df_row396_col0,#T_179df_row408_col1,#T_179df_row408_col2,#T_179df_row477_col1,#T_179df_row537_col2,#T_179df_row560_col0,#T_179df_row578_col0,#T_179df_row697_col1,#T_179df_row724_col2,#T_179df_row744_col1{
#             background-color:  #2a9350;
#             color:  #000000;
#         }#T_179df_row0_col1,#T_179df_row30_col2,#T_179df_row48_col2,#T_179df_row93_col0,#T_179df_row115_col0,#T_179df_row155_col1,#T_179df_row173_col1,#T_179df_row176_col1,#T_179df_row191_col2,#T_179df_row192_col2,#T_179df_row220_col0,#T_179df_row223_col0,#T_179df_row224_col0,#T_179df_row238_col1,#T_179df_row287_col2,#T_179df_row293_col0,#T_179df_row341_col0,#T_179df_row380_col1,#T_179df_row417_col1,#T_179df_row459_col2,#T_179df_row466_col0,#T_179df_row519_col0,#T_179df_row548_col0,#T_179df_row571_col0,#T_179df_row624_col1,#T_179df_row632_col1,#T_179df_row690_col2,#T_179df_row720_col2{
#             background-color:  #2c9553;
#             color:  #000000;
#         }#T_179df_row0_col2,#T_179df_row4_col0,#T_179df_row96_col2,#T_179df_row101_col2,#T_179df_row111_col0,#T_179df_row127_col1,#T_179df_row131_col0,#T_179df_row131_col1,#T_179df_row140_col0,#T_179df_row177_col0,#T_179df_row187_col1,#T_179df_row284_col0,#T_179df_row302_col1,#T_179df_row308_col0,#T_179df_row308_col2,#T_179df_row310_col2,#T_179df_row326_col2,#T_179df_row398_col1,#T_179df_row467_col1,#T_179df_row511_col0,#T_179df_row578_col1,#T_179df_row580_col2,#T_179df_row624_col2,#T_179df_row677_col0,#T_179df_row719_col0,#T_179df_row739_col1{
#             background-color:  #339e60;
#             color:  #000000;
#         }#T_179df_row1_col0,#T_179df_row13_col0,#T_179df_row15_col1,#T_179df_row33_col1,#T_179df_row107_col0,#T_179df_row120_col0,#T_179df_row161_col1,#T_179df_row260_col1,#T_179df_row289_col0,#T_179df_row336_col2,#T_179df_row358_col0,#T_179df_row448_col2,#T_179df_row450_col0,#T_179df_row472_col2,#T_179df_row531_col2,#T_179df_row622_col0,#T_179df_row642_col2,#T_179df_row665_col2,#T_179df_row684_col0,#T_179df_row707_col1,#T_179df_row709_col1,#T_179df_row737_col1,#T_179df_row744_col0,#T_179df_row751_col2{
#             background-color:  #36a164;
#             color:  #000000;
#         }#T_179df_row1_col1,#T_179df_row66_col0,#T_179df_row85_col1,#T_179df_row120_col2,#T_179df_row137_col0,#T_179df_row221_col1,#T_179df_row293_col1,#T_179df_row394_col1,#T_179df_row398_col0,#T_179df_row402_col1,#T_179df_row451_col1,#T_179df_row457_col0,#T_179df_row457_col1,#T_179df_row477_col0,#T_179df_row515_col2,#T_179df_row522_col0,#T_179df_row524_col1,#T_179df_row527_col1,#T_179df_row527_col2,#T_179df_row544_col2,#T_179df_row573_col2,#T_179df_row587_col1,#T_179df_row608_col2,#T_179df_row742_col2{
#             background-color:  #37a266;
#             color:  #000000;
#         }#T_179df_row1_col2,#T_179df_row26_col1,#T_179df_row47_col0,#T_179df_row58_col2,#T_179df_row105_col0,#T_179df_row116_col0,#T_179df_row127_col2,#T_179df_row194_col2,#T_179df_row226_col1,#T_179df_row257_col2,#T_179df_row267_col1,#T_179df_row290_col0,#T_179df_row291_col1,#T_179df_row296_col2,#T_179df_row361_col0,#T_179df_row386_col1,#T_179df_row412_col1,#T_179df_row442_col0,#T_179df_row448_col1,#T_179df_row450_col1,#T_179df_row463_col0,#T_179df_row516_col1,#T_179df_row522_col2,#T_179df_row590_col0,#T_179df_row622_col1,#T_179df_row648_col1,#T_179df_row669_col0,#T_179df_row683_col2,#T_179df_row710_col2,#T_179df_row714_col1,#T_179df_row737_col2,#T_179df_row739_col0{
#             background-color:  #3fab72;
#             color:  #000000;
#         }#T_179df_row2_col0,#T_179df_row51_col0,#T_179df_row54_col0,#T_179df_row88_col1,#T_179df_row233_col0,#T_179df_row234_col2,#T_179df_row314_col1,#T_179df_row341_col2,#T_179df_row342_col0,#T_179df_row447_col0,#T_179df_row500_col0,#T_179df_row616_col2,#T_179df_row625_col1,#T_179df_row637_col1,#T_179df_row654_col2{
#             background-color:  #16803c;
#             color:  #f1f1f1;
#         }#T_179df_row2_col1,#T_179df_row98_col0,#T_179df_row145_col1,#T_179df_row364_col0,#T_179df_row370_col2,#T_179df_row490_col0,#T_179df_row538_col2,#T_179df_row543_col0,#T_179df_row625_col0,#T_179df_row625_col2,#T_179df_row668_col0,#T_179df_row668_col1{
#             background-color:  #117b38;
#             color:  #f1f1f1;
#         }#T_179df_row2_col2,#T_179df_row62_col1,#T_179df_row90_col2,#T_179df_row106_col1,#T_179df_row106_col2,#T_179df_row137_col2,#T_179df_row171_col1,#T_179df_row459_col1,#T_179df_row490_col2,#T_179df_row529_col1,#T_179df_row597_col0,#T_179df_row615_col0,#T_179df_row620_col2,#T_179df_row631_col0,#T_179df_row631_col2{
#             background-color:  #27904c;
#             color:  #000000;
#         }#T_179df_row3_col0,#T_179df_row50_col2,#T_179df_row82_col2,#T_179df_row92_col0,#T_179df_row116_col2,#T_179df_row164_col0,#T_179df_row282_col1,#T_179df_row330_col2,#T_179df_row363_col1,#T_179df_row400_col0,#T_179df_row407_col2,#T_179df_row588_col1,#T_179df_row604_col1,#T_179df_row686_col1,#T_179df_row688_col0,#T_179df_row718_col1{
#             background-color:  #55b98f;
#             color:  #000000;
#         }#T_179df_row3_col1,#T_179df_row29_col2,#T_179df_row36_col0,#T_179df_row247_col1,#T_179df_row283_col2,#T_179df_row331_col0,#T_179df_row362_col0,#T_179df_row441_col0,#T_179df_row452_col0,#T_179df_row455_col1,#T_179df_row479_col1,#T_179df_row495_col0,#T_179df_row525_col2,#T_179df_row576_col0,#T_179df_row596_col2,#T_179df_row632_col2,#T_179df_row639_col2,#T_179df_row695_col2{
#             background-color:  #62c09f;
#             color:  #000000;
#         }#T_179df_row3_col2,#T_179df_row25_col1,#T_179df_row71_col0,#T_179df_row105_col2,#T_179df_row121_col0,#T_179df_row136_col0,#T_179df_row138_col2,#T_179df_row163_col1,#T_179df_row172_col2,#T_179df_row210_col1,#T_179df_row213_col0,#T_179df_row257_col1,#T_179df_row335_col1,#T_179df_row337_col0,#T_179df_row338_col1,#T_179df_row357_col1,#T_179df_row423_col1,#T_179df_row453_col1,#T_179df_row453_col2,#T_179df_row481_col1,#T_179df_row501_col0,#T_179df_row512_col2,#T_179df_row514_col1,#T_179df_row553_col1,#T_179df_row588_col2,#T_179df_row601_col1,#T_179df_row604_col0,#T_179df_row667_col0,#T_179df_row693_col0,#T_179df_row705_col0{
#             background-color:  #54b88e;
#             color:  #000000;
#         }#T_179df_row4_col1,#T_179df_row16_col2,#T_179df_row27_col1,#T_179df_row47_col1,#T_179df_row53_col0,#T_179df_row115_col2,#T_179df_row134_col2,#T_179df_row193_col0,#T_179df_row264_col1,#T_179df_row303_col0,#T_179df_row321_col1,#T_179df_row340_col1,#T_179df_row373_col0,#T_179df_row423_col2,#T_179df_row440_col0,#T_179df_row445_col0,#T_179df_row457_col2,#T_179df_row465_col1,#T_179df_row466_col2,#T_179df_row554_col0,#T_179df_row567_col1,#T_179df_row595_col0,#T_179df_row597_col2,#T_179df_row614_col0,#T_179df_row633_col1,#T_179df_row655_col0,#T_179df_row664_col1,#T_179df_row667_col1,#T_179df_row684_col1,#T_179df_row704_col1,#T_179df_row736_col2,#T_179df_row748_col1{
#             background-color:  #40ad75;
#             color:  #000000;
#         }#T_179df_row4_col2,#T_179df_row48_col0,#T_179df_row108_col1,#T_179df_row139_col1,#T_179df_row276_col0,#T_179df_row382_col0,#T_179df_row388_col1,#T_179df_row414_col0,#T_179df_row447_col2,#T_179df_row464_col0,#T_179df_row468_col0,#T_179df_row592_col1,#T_179df_row644_col0,#T_179df_row663_col1,#T_179df_row682_col0,#T_179df_row690_col0,#T_179df_row758_col2{
#             background-color:  #28914d;
#             color:  #000000;
#         }#T_179df_row5_col0,#T_179df_row38_col1,#T_179df_row47_col2,#T_179df_row68_col1,#T_179df_row69_col2,#T_179df_row84_col1,#T_179df_row133_col2,#T_179df_row137_col1,#T_179df_row147_col0,#T_179df_row154_col0,#T_179df_row163_col0,#T_179df_row189_col0,#T_179df_row303_col1,#T_179df_row338_col0,#T_179df_row368_col0,#T_179df_row372_col0,#T_179df_row379_col0,#T_179df_row442_col2,#T_179df_row469_col1,#T_179df_row532_col1,#T_179df_row600_col0,#T_179df_row614_col1,#T_17

# %%
add_style(gb_filter_monotonic(sp_500))
# Out:
# <style  type="text/css" >
# #T_4c851_row0_col0{
#             background-color:  #97d7c7;
#             color:  #000000;
#         }#T_4c851_row0_col1{
#             background-color:  #8fd4c2;
#             color:  #000000;
#         }#T_4c851_row0_col2{
#             background-color:  #a5ddd0;
#             color:  #000000;
#         }#T_4c851_row1_col0{
#             background-color:  #45b07b;
#             color:  #000000;
#         }#T_4c851_row1_col1{
#             background-color:  #47b17e;
#             color:  #000000;
#         }#T_4c851_row1_col2{
#             background-color:  #4fb688;
#             color:  #000000;
#         }#T_4c851_row2_col0{
#             background-color:  #3da96f;
#             color:  #000000;
#         }#T_4c851_row2_col1{
#             background-color:  #17813d;
#             color:  #f1f1f1;
#         }#T_4c851_row2_col2{
#             background-color:  #5cbd98;
#             color:  #000000;
#         }#T_4c851_row3_col0{
#             background-color:  #005622;
#             color:  #f1f1f1;
#         }#T_4c851_row3_col1{
#             background-color:  #067230;
#             color:  #f1f1f1;
#         }#T_4c851_row3_col2,#T_4c851_row11_col0,#T_4c851_row11_col1{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_4c851_row4_col0{
#             background-color:  #5ebe9b;
#             color:  #000000;
#         }#T_4c851_row4_col1{
#             background-color:  #41ae77;
#             color:  #000000;
#         }#T_4c851_row4_col2{
#             background-color:  #9fdacc;
#             color:  #000000;
#         }#T_4c851_row5_col0{
#             background-color:  #5dbd99;
#             color:  #000000;
#         }#T_4c851_row5_col1{
#             background-color:  #40ad75;
#             color:  #000000;
#         }#T_4c851_row5_col2{
#             background-color:  #9ddacb;
#             color:  #000000;
#         }#T_4c851_row6_col0{
#             background-color:  #157f3b;
#             color:  #f1f1f1;
#         }#T_4c851_row6_col1{
#             background-color:  #0e7936;
#             color:  #f1f1f1;
#         }#T_4c851_row6_col2{
#             background-color:  #2b9452;
#             color:  #000000;
#         }#T_4c851_row7_col0{
#             background-color:  #03702e;
#             color:  #f1f1f1;
#         }#T_4c851_row7_col1{
#             background-color:  #00451c;
#             color:  #f1f1f1;
#         }#T_4c851_row7_col2{
#             background-color:  #36a164;
#             color:  #000000;
#         }#T_4c851_row8_col0{
#             background-color:  #9ad8ca;
#             color:  #000000;
#         }#T_4c851_row8_col1{
#             background-color:  #a7ddd1;
#             color:  #000000;
#         }#T_4c851_row8_col2{
#             background-color:  #a0dbcd;
#             color:  #000000;
#         }#T_4c851_row9_col0{
#             background-color:  #67c2a5;
#             color:  #000000;
#         }#T_4c851_row9_col1,#T_4c851_row14_col1{
#             background-color:  #7dccb5;
#             color:  #000000;
#         }#T_4c851_row9_col2{
#             background-color:  #62c09f;
#             color:  #000000;
#         }#T_4c851_row10_col0{
#             background-color:  #3ba76c;
#             color:  #000000;
#         }#T_4c851_row10_col1{
#             background-color:  #2c9553;
#             color:  #000000;
#         }#T_4c851_row10_col2{
#             background-color:  #52b78b;
#             color:  #000000;
#         }#T_4c851_row11_col2{
#             background-color:  #005b25;
#             color:  #f1f1f1;
#         }#T_4c851_row12_col0,#T_4c851_row12_col1,#T_4c851_row12_col2{
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }#T_4c851_row13_col0{
#             background-color:  #bde6de;
#             color:  #000000;
#         }#T_4c851_row13_col1{
#             background-color:  #c4e9e1;
#             color:  #000000;
#         }#T_4c851_row13_col2{
#             background-color:  #c8ebe4;
#             color:  #000000;
#         }#T_4c851_row14_col0{
#             background-color:  #75c9af;
#             color:  #000000;
#         }#T_4c851_row14_col2{
#             background-color:  #80cdb7;
#             color:  #000000;
#         }#T_4c851_row15_col0{
#             background-color:  #6cc4a8;
#             color:  #000000;
#         }#T_4c851_row15_col1{
#             background-color:  #87d0bc;
#             color:  #000000;
#         }#T_4c851_row15_col2{
#             background-color:  #60bf9c;
#             color:  #000000;
#         }</style><table id="T_4c851_" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >val_binary_sharpe</th>        <th class="col_heading level0 col1" >val_binary_long_sharpe</th>        <th class="col_heading level0 col2" >val_binary_short_sharpe</th>    </tr>    <tr>        <th class="index_name level0" >asset</th>        <th class="index_name level1" >params</th>        <th class="index_name level2" >model</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4c851_level0_row0" class="row_heading level0 row0" rowspan="16">sp_500</th>
#                         <th id="T_4c851_level1_row0" class="row_heading level1 row0" rowspan="4">315</th>
#                         <th id="T_4c851_level2_row0" class="row_heading level2 row0" >base</th>
#                         <td id="T_4c851_row0_col0" class="data row0 col0" >-0.120492</td>
#                         <td id="T_4c851_row0_col1" class="data row0 col1" >-0.083955</td>
#                         <td id="T_4c851_row0_col2" class="data row0 col2" >-0.426082</td>
#             </tr>
#             <tr>
#                                         <th id="T_4c851_level2_row1" class="row_heading level2 row1" >cnp</th>
#                         <td id="T_4c851_row1_col0" class="data row1 col0" >0.328323</td>
#                         <td id="T_4c851_row1_col1" class="data row1 col1" >0.175940</td>
#                         <td id="T_4c851_row1_col2" class="data row1 col2" >-0.060771</td>
#             </tr>
#             <tr>
#                                         <th id="T_4c851_level2_row2" class="row_heading level2 row2" >lnp</th>
#                         <td id="T_4c851_row2_col0" class="data row2 col0" >0.382831</td>
#                         <td id="T_4c851_row2_col1" class="data row2 col1" >0.416396</td>
#                         <td id="T_4c851_row2_col2" class="data row2 col2" >-0.126580</td>
#             </tr>
#             <tr>
#                                         <th id="T_4c851_level2_row3" class="row_heading level2 row3" >np</th>
#                         <td id="T_4c851_row3_col0" class="data row3 col0" >0.972211</td>
#                         <td id="T_4c851_row3_col1" class="data row3 col1" >0.500420</td>
#                         <td id="T_4c851_row3_col2" class="data row3 col2" >0.610574</td>
#             </tr>
#             <tr>
#                                 <th id="T_4c851_level1_row4" class="row_heading level1 row4" rowspan="4">319</th>
#                         <th id="T_4c851_level2_row4" class="row_heading level2 row4" >base</th>
#                         <td id="T_4c851_row4_col0" class="data row4 col0" >0.155068</td>
#                         <td id="T_4c851_row4_col1" class="data row4 col1" >0.203363</td>
#                         <td id="T_4c851_row4_col2" class="data row4 col2" >-0.399764</td>
#             </tr>
#             <tr>
#                                         <th id="T_4c851_level2_row5" class="row_heading level2 row5" >cnp</th>
#                         <td id="T_4c851_row5_col0" class="data row5 col0" >0.162822</td>
#                         <td id="T_4c851_row5_col1" class="data row5 col1" >0.207847</td>
#                         <td id="T_4c851_row5_col2" class="data row5 col2" >-0.393022</td>
#             </tr>
#             <tr>
#                                         <th id="T_4c851_level2_row6" class="row_heading level2 row6" >lnp</th>
#                         <td id="T_4c851_row6_col0" class="data row6 col0" >0.686884</

# %%
add_style(gb_filter_neg(gb_filter_monotonic_partial(sp_500)))
# Out:
# <style  type="text/css" >
# #T_32e44_row0_col0,#T_32e44_row4_col2,#T_32e44_row40_col0{
#             background-color:  #a7ddd1;
#             color:  #000000;
#         }#T_32e44_row0_col1{
#             background-color:  #acdfd4;
#             color:  #000000;
#         }#T_32e44_row0_col2,#T_32e44_row12_col0,#T_32e44_row13_col0,#T_32e44_row44_col2{
#             background-color:  #8dd3c0;
#             color:  #000000;
#         }#T_32e44_row1_col0,#T_32e44_row30_col2,#T_32e44_row61_col2{
#             background-color:  #6dc5a9;
#             color:  #000000;
#         }#T_32e44_row1_col1,#T_32e44_row33_col1,#T_32e44_row69_col2{
#             background-color:  #82ceb8;
#             color:  #000000;
#         }#T_32e44_row1_col2,#T_32e44_row62_col1,#T_32e44_row81_col0{
#             background-color:  #37a266;
#             color:  #000000;
#         }#T_32e44_row2_col0,#T_32e44_row24_col0,#T_32e44_row78_col0{
#             background-color:  #8ad2be;
#             color:  #000000;
#         }#T_32e44_row2_col1,#T_32e44_row38_col2,#T_32e44_row84_col0{
#             background-color:  #7dccb5;
#             color:  #000000;
#         }#T_32e44_row2_col2,#T_32e44_row22_col2,#T_32e44_row55_col2,#T_32e44_row66_col2{
#             background-color:  #7fcdb6;
#             color:  #000000;
#         }#T_32e44_row3_col0,#T_32e44_row55_col0,#T_32e44_row77_col0{
#             background-color:  #5cbd98;
#             color:  #000000;
#         }#T_32e44_row3_col1{
#             background-color:  #5abb95;
#             color:  #000000;
#         }#T_32e44_row3_col2,#T_32e44_row17_col1,#T_32e44_row54_col1,#T_32e44_row77_col2{
#             background-color:  #53b88c;
#             color:  #000000;
#         }#T_32e44_row4_col0,#T_32e44_row11_col2{
#             background-color:  #b7e4da;
#             color:  #000000;
#         }#T_32e44_row4_col1{
#             background-color:  #a8ded2;
#             color:  #000000;
#         }#T_32e44_row5_col0,#T_32e44_row84_col2{
#             background-color:  #74c8ae;
#             color:  #000000;
#         }#T_32e44_row5_col1,#T_32e44_row27_col2{
#             background-color:  #67c2a5;
#             color:  #000000;
#         }#T_32e44_row5_col2,#T_32e44_row6_col0,#T_32e44_row25_col1,#T_32e44_row38_col1{
#             background-color:  #6cc4a8;
#             color:  #000000;
#         }#T_32e44_row6_col1,#T_32e44_row10_col0,#T_32e44_row15_col0{
#             background-color:  #3ca86d;
#             color:  #000000;
#         }#T_32e44_row6_col2,#T_32e44_row25_col0,#T_32e44_row56_col2{
#             background-color:  #77c9b0;
#             color:  #000000;
#         }#T_32e44_row7_col0,#T_32e44_row31_col2{
#             background-color:  #2e9756;
#             color:  #000000;
#         }#T_32e44_row7_col1{
#             background-color:  #2f9a59;
#             color:  #000000;
#         }#T_32e44_row7_col2{
#             background-color:  #228a44;
#             color:  #000000;
#         }#T_32e44_row8_col0{
#             background-color:  #f5fbfc;
#             color:  #000000;
#         }#T_32e44_row8_col1,#T_32e44_row48_col2{
#             background-color:  #e5f5f9;
#             color:  #000000;
#         }#T_32e44_row8_col2,#T_32e44_row85_col0,#T_32e44_row85_col1{
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }#T_32e44_row9_col0{
#             background-color:  #ecf8fb;
#             color:  #000000;
#         }#T_32e44_row9_col1{
#             background-color:  #d9f1f0;
#             color:  #000000;
#         }#T_32e44_row9_col2{
#             background-color:  #eef8fb;
#             color:  #000000;
#         }#T_32e44_row10_col1,#T_32e44_row65_col1{
#             background-color:  #1f8742;
#             color:  #000000;
#         }#T_32e44_row10_col2,#T_32e44_row79_col1{
#             background-color:  #52b78b;
#             color:  #000000;
#         }#T_32e44_row11_col0{
#             background-color:  #a5ddd0;
#             color:  #000000;
#         }#T_32e44_row11_col1{
#             background-color:  #78cab1;
#             color:  #000000;
#         }#T_32e44_row12_col1,#T_32e44_row17_col0,#T_32e44_row17_col2,#T_32e44_row86_col2,#T_32e44_row87_col1{
#             background-color:  #62c09f;
#             color:  #000000;
#         }#T_32e44_row12_col2,#T_32e44_row13_col2,#T_32e44_row32_col2{
#             background-color:  #a2dcce;
#             color:  #000000;
#         }#T_32e44_row13_col1,#T_32e44_row75_col0{
#             background-color:  #61bf9e;
#             color:  #000000;
#         }#T_32e44_row14_col0,#T_32e44_row43_col2{
#             background-color:  #48b27f;
#             color:  #000000;
#         }#T_32e44_row14_col1,#T_32e44_row43_col0,#T_32e44_row80_col2{
#             background-color:  #36a164;
#             color:  #000000;
#         }#T_32e44_row14_col2,#T_32e44_row16_col1,#T_32e44_row47_col1{
#             background-color:  #4fb688;
#             color:  #000000;
#         }#T_32e44_row15_col1,#T_32e44_row39_col1{
#             background-color:  #147e3a;
#             color:  #f1f1f1;
#         }#T_32e44_row15_col2,#T_32e44_row36_col2,#T_32e44_row65_col2,#T_32e44_row87_col2{
#             background-color:  #59bb93;
#             color:  #000000;
#         }#T_32e44_row16_col0,#T_32e44_row45_col0,#T_32e44_row79_col2{
#             background-color:  #57ba92;
#             color:  #000000;
#         }#T_32e44_row16_col2,#T_32e44_row21_col2{
#             background-color:  #55b98f;
#             color:  #000000;
#         }#T_32e44_row18_col0,#T_32e44_row81_col2{
#             background-color:  #2c9553;
#             color:  #000000;
#         }#T_32e44_row18_col1{
#             background-color:  #1c8540;
#             color:  #000000;
#         }#T_32e44_row18_col2,#T_32e44_row26_col1,#T_32e44_row83_col2{
#             background-color:  #349f61;
#             color:  #000000;
#         }#T_32e44_row19_col0{
#             background-color:  #28914d;
#             color:  #000000;
#         }#T_32e44_row19_col1{
#             background-color:  #268f4a;
#             color:  #000000;
#         }#T_32e44_row19_col2,#T_32e44_row55_col1{
#             background-color:  #258d48;
#             color:  #000000;
#         }#T_32e44_row20_col0{
#             background-color:  #e8f6fa;
#             color:  #000000;
#         }#T_32e44_row20_col1{
#             background-color:  #e6f5f9;
#             color:  #000000;
#         }#T_32e44_row20_col2{
#             background-color:  #d8f0ef;
#             color:  #000000;
#         }#T_32e44_row21_col0,#T_32e44_row27_col1{
#             background-color:  #54b88e;
#             color:  #000000;
#         }#T_32e44_row21_col1,#T_32e44_row37_col0,#T_32e44_row37_col1,#T_32e44_row63_col2,#T_32e44_row71_col1,#T_32e44_row73_col1{
#             background-color:  #47b17e;
#             color:  #000000;
#         }#T_32e44_row22_col0,#T_32e44_row38_col0,#T_32e44_row41_col2{
#             background-color:  #80cdb7;
#             color:  #000000;
#         }#T_32e44_row22_col1,#T_32e44_row73_col0{
#             background-color:  #64c1a2;
#             color:  #000000;
#         }#T_32e44_row23_col0{
#             background-color:  #097532;
#             color:  #f1f1f1;
#         }#T_32e44_row23_col1,#T_32e44_row39_col0{
#             background-color:  #0b7734;
#             color:  #f1f1f1;
#         }#T_32e44_row23_col2{
#             background-color:  #016e2d;
#             color:  #f1f1f1;
#         }#T_32e44_row24_col1{
#             background-color:  #90d4c3;
#             color:  #000000;
#         }#T_32e44_row24_col2,#T_32e44_row25_col2,#T_32e44_row61_col0,#T_32e44_row86_col1{
#             background-color:  #6fc6aa;
#             color:  #000000;
#         }#T_32e44_row26_col0{
#             background-color:  #29924f;
#             color:  #000000;
#         }#T_32e44_row26_col2{
#             background-color:  #077331;
#             color:  #f1f1f1;
#         }#T_32e44_row27_col0,#T_32e44_row36_col0,#T_32e44_row36_col1{
#             background-color:  #65c2a3;
#             color:  #000000;
#         }#T_32e44_row28_col0,#T_32e44_row28_col1{
#             background-color:  #bae5dc;
#             color:  #000000;
#         }#T_32e44_row28_col2,#T_32e44_row34_col0{
#             background-color:  #a4dccf;
#             color:  #000000

# %%
add_style(gb_filter_monotonic(russell_2000))
# Out:
# <style  type="text/css" >
# #T_57f8a_row0_col0,#T_57f8a_row12_col0{
#             background-color:  #88d1bd;
#             color:  #000000;
#         }#T_57f8a_row0_col1,#T_57f8a_row25_col1{
#             background-color:  #b5e3d9;
#             color:  #000000;
#         }#T_57f8a_row0_col2,#T_57f8a_row2_col1{
#             background-color:  #56ba91;
#             color:  #000000;
#         }#T_57f8a_row1_col0,#T_57f8a_row33_col2,#T_57f8a_row34_col0,#T_57f8a_row34_col2{
#             background-color:  #4eb586;
#             color:  #000000;
#         }#T_57f8a_row1_col1{
#             background-color:  #53b88c;
#             color:  #000000;
#         }#T_57f8a_row1_col2,#T_57f8a_row18_col2,#T_57f8a_row23_col1{
#             background-color:  #4ab381;
#             color:  #000000;
#         }#T_57f8a_row2_col0{
#             background-color:  #4bb382;
#             color:  #000000;
#         }#T_57f8a_row2_col2{
#             background-color:  #41ae77;
#             color:  #000000;
#         }#T_57f8a_row3_col0{
#             background-color:  #3da96f;
#             color:  #000000;
#         }#T_57f8a_row3_col1{
#             background-color:  #47b17e;
#             color:  #000000;
#         }#T_57f8a_row3_col2,#T_57f8a_row11_col1{
#             background-color:  #349f61;
#             color:  #000000;
#         }#T_57f8a_row4_col0,#T_57f8a_row4_col1,#T_57f8a_row4_col2,#T_57f8a_row5_col0,#T_57f8a_row5_col1{
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }#T_57f8a_row5_col2{
#             background-color:  #f3fafc;
#             color:  #000000;
#         }#T_57f8a_row6_col0,#T_57f8a_row9_col0{
#             background-color:  #90d4c3;
#             color:  #000000;
#         }#T_57f8a_row6_col1,#T_57f8a_row22_col1,#T_57f8a_row24_col2,#T_57f8a_row26_col0,#T_57f8a_row27_col1{
#             background-color:  #80cdb7;
#             color:  #000000;
#         }#T_57f8a_row6_col2,#T_57f8a_row10_col1{
#             background-color:  #95d6c6;
#             color:  #000000;
#         }#T_57f8a_row7_col0,#T_57f8a_row14_col1{
#             background-color:  #6fc6aa;
#             color:  #000000;
#         }#T_57f8a_row7_col1{
#             background-color:  #5cbd98;
#             color:  #000000;
#         }#T_57f8a_row7_col2,#T_57f8a_row10_col2{
#             background-color:  #7acbb3;
#             color:  #000000;
#         }#T_57f8a_row8_col0{
#             background-color:  #acdfd4;
#             color:  #000000;
#         }#T_57f8a_row8_col1{
#             background-color:  #d6f0ee;
#             color:  #000000;
#         }#T_57f8a_row8_col2{
#             background-color:  #52b78b;
#             color:  #000000;
#         }#T_57f8a_row9_col1{
#             background-color:  #a4dccf;
#             color:  #000000;
#         }#T_57f8a_row9_col2{
#             background-color:  #7fcdb6;
#             color:  #000000;
#         }#T_57f8a_row10_col0,#T_57f8a_row17_col0{
#             background-color:  #87d0bc;
#             color:  #000000;
#         }#T_57f8a_row11_col0{
#             background-color:  #37a266;
#             color:  #000000;
#         }#T_57f8a_row11_col2{
#             background-color:  #39a569;
#             color:  #000000;
#         }#T_57f8a_row12_col1{
#             background-color:  #a7ddd1;
#             color:  #000000;
#         }#T_57f8a_row12_col2,#T_57f8a_row32_col0{
#             background-color:  #6cc4a8;
#             color:  #000000;
#         }#T_57f8a_row13_col0,#T_57f8a_row32_col1{
#             background-color:  #82ceb8;
#             color:  #000000;
#         }#T_57f8a_row13_col1{
#             background-color:  #ade0d4;
#             color:  #000000;
#         }#T_57f8a_row13_col2,#T_57f8a_row18_col0{
#             background-color:  #51b689;
#             color:  #000000;
#         }#T_57f8a_row14_col0,#T_57f8a_row33_col0{
#             background-color:  #60bf9c;
#             color:  #000000;
#         }#T_57f8a_row14_col2{
#             background-color:  #55b98f;
#             color:  #000000;
#         }#T_57f8a_row15_col0,#T_57f8a_row35_col2{
#             background-color:  #17813d;
#             color:  #f1f1f1;
#         }#T_57f8a_row15_col1{
#             background-color:  #006729;
#             color:  #f1f1f1;
#         }#T_57f8a_row15_col2{
#             background-color:  #29924f;
#             color:  #000000;
#         }#T_57f8a_row16_col0{
#             background-color:  #94d6c5;
#             color:  #000000;
#         }#T_57f8a_row16_col1{
#             background-color:  #bce6dd;
#             color:  #000000;
#         }#T_57f8a_row16_col2,#T_57f8a_row28_col0{
#             background-color:  #68c3a6;
#             color:  #000000;
#         }#T_57f8a_row17_col1{
#             background-color:  #a8ded2;
#             color:  #000000;
#         }#T_57f8a_row17_col2,#T_57f8a_row22_col2,#T_57f8a_row25_col2{
#             background-color:  #64c1a2;
#             color:  #000000;
#         }#T_57f8a_row18_col1{
#             background-color:  #59bb93;
#             color:  #000000;
#         }#T_57f8a_row19_col0{
#             background-color:  #19833e;
#             color:  #f1f1f1;
#         }#T_57f8a_row19_col1{
#             background-color:  #05712f;
#             color:  #f1f1f1;
#         }#T_57f8a_row19_col2{
#             background-color:  #27904c;
#             color:  #000000;
#         }#T_57f8a_row20_col0{
#             background-color:  #afe1d5;
#             color:  #000000;
#         }#T_57f8a_row20_col1{
#             background-color:  #d4efec;
#             color:  #000000;
#         }#T_57f8a_row20_col2{
#             background-color:  #7dccb5;
#             color:  #000000;
#         }#T_57f8a_row21_col0{
#             background-color:  #aadfd3;
#             color:  #000000;
#         }#T_57f8a_row21_col1{
#             background-color:  #cdece6;
#             color:  #000000;
#         }#T_57f8a_row21_col2{
#             background-color:  #8cd2bf;
#             color:  #000000;
#         }#T_57f8a_row22_col0{
#             background-color:  #72c7ad;
#             color:  #000000;
#         }#T_57f8a_row23_col0,#T_57f8a_row34_col1{
#             background-color:  #4cb484;
#             color:  #000000;
#         }#T_57f8a_row23_col2,#T_57f8a_row29_col1{
#             background-color:  #4db585;
#             color:  #000000;
#         }#T_57f8a_row24_col0{
#             background-color:  #a5ddd0;
#             color:  #000000;
#         }#T_57f8a_row24_col1{
#             background-color:  #ccece6;
#             color:  #000000;
#         }#T_57f8a_row25_col0{
#             background-color:  #8dd3c0;
#             color:  #000000;
#         }#T_57f8a_row26_col1{
#             background-color:  #a0dbcd;
#             color:  #000000;
#         }#T_57f8a_row26_col2{
#             background-color:  #62c09f;
#             color:  #000000;
#         }#T_57f8a_row27_col0{
#             background-color:  #70c6ac;
#             color:  #000000;
#         }#T_57f8a_row27_col2{
#             background-color:  #63c0a0;
#             color:  #000000;
#         }#T_57f8a_row28_col1{
#             background-color:  #85cfbb;
#             color:  #000000;
#         }#T_57f8a_row28_col2{
#             background-color:  #54b88e;
#             color:  #000000;
#         }#T_57f8a_row29_col0{
#             background-color:  #46b17c;
#             color:  #000000;
#         }#T_57f8a_row29_col2,#T_57f8a_row30_col0,#T_57f8a_row30_col2{
#             background-color:  #40ad75;
#             color:  #000000;
#         }#T_57f8a_row30_col1{
#             background-color:  #3fac74;
#             color:  #000000;
#         }#T_57f8a_row31_col0,#T_57f8a_row31_col1,#T_57f8a_row31_col2{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_57f8a_row32_col2{
#             background-color:  #5abb95;
#             color:  #000000;
#         }#T_57f8a_row33_col1{
#             background-color:  #77c9b0;
#             color:  #000000;
#         }#T_57f8a_row35_col0{
#             background-color:  #208843;
#             color:  #000000;
#         }#T_57f8a_row35_col1{
#             background-color:  #28914d;
#             color:  #000000;
#         }</style><table id="T_57f8a_" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank level0" ></th>

# %%
add_style(gb_filter_neg(gb_filter_monotonic_partial(russell_2000)))
# Out:
# <style  type="text/css" >
# #T_d7c20_row0_col0,#T_d7c20_row17_col2{
#             background-color:  #a8ded2;
#             color:  #000000;
#         }#T_d7c20_row0_col1,#T_d7c20_row2_col2,#T_d7c20_row88_col2,#T_d7c20_row163_col0{
#             background-color:  #87d0bc;
#             color:  #000000;
#         }#T_d7c20_row0_col2,#T_d7c20_row50_col0,#T_d7c20_row92_col0,#T_d7c20_row160_col2,#T_d7c20_row184_col0{
#             background-color:  #bfe7de;
#             color:  #000000;
#         }#T_d7c20_row1_col0{
#             background-color:  #e0f3f5;
#             color:  #000000;
#         }#T_d7c20_row1_col1,#T_d7c20_row186_col2{
#             background-color:  #cdece6;
#             color:  #000000;
#         }#T_d7c20_row1_col2{
#             background-color:  #eaf7fa;
#             color:  #000000;
#         }#T_d7c20_row2_col0,#T_d7c20_row70_col0,#T_d7c20_row73_col0,#T_d7c20_row101_col1,#T_d7c20_row110_col2,#T_d7c20_row136_col1{
#             background-color:  #74c8ae;
#             color:  #000000;
#         }#T_d7c20_row2_col1,#T_d7c20_row5_col1,#T_d7c20_row14_col1,#T_d7c20_row21_col2,#T_d7c20_row29_col0,#T_d7c20_row29_col1,#T_d7c20_row29_col2,#T_d7c20_row71_col0,#T_d7c20_row131_col1,#T_d7c20_row168_col1{
#             background-color:  #5abb95;
#             color:  #000000;
#         }#T_d7c20_row3_col0,#T_d7c20_row4_col2,#T_d7c20_row72_col2,#T_d7c20_row93_col1,#T_d7c20_row98_col0{
#             background-color:  #4db585;
#             color:  #000000;
#         }#T_d7c20_row3_col1,#T_d7c20_row119_col1,#T_d7c20_row183_col2{
#             background-color:  #2f9858;
#             color:  #000000;
#         }#T_d7c20_row3_col2,#T_d7c20_row11_col2,#T_d7c20_row20_col0,#T_d7c20_row52_col0,#T_d7c20_row84_col0,#T_d7c20_row86_col2,#T_d7c20_row118_col2{
#             background-color:  #6dc5a9;
#             color:  #000000;
#         }#T_d7c20_row4_col0,#T_d7c20_row76_col1,#T_d7c20_row121_col2,#T_d7c20_row143_col0,#T_d7c20_row167_col0{
#             background-color:  #43af78;
#             color:  #000000;
#         }#T_d7c20_row4_col1,#T_d7c20_row35_col0,#T_d7c20_row41_col1,#T_d7c20_row63_col1,#T_d7c20_row117_col1,#T_d7c20_row143_col2{
#             background-color:  #3ba76c;
#             color:  #000000;
#         }#T_d7c20_row5_col0,#T_d7c20_row96_col1,#T_d7c20_row166_col0{
#             background-color:  #53b88c;
#             color:  #000000;
#         }#T_d7c20_row5_col2,#T_d7c20_row17_col1,#T_d7c20_row31_col1,#T_d7c20_row39_col2,#T_d7c20_row133_col1{
#             background-color:  #47b17e;
#             color:  #000000;
#         }#T_d7c20_row6_col0,#T_d7c20_row137_col2{
#             background-color:  #349f61;
#             color:  #000000;
#         }#T_d7c20_row6_col1,#T_d7c20_row16_col1,#T_d7c20_row27_col0,#T_d7c20_row31_col2,#T_d7c20_row63_col0{
#             background-color:  #329d5e;
#             color:  #000000;
#         }#T_d7c20_row6_col2,#T_d7c20_row93_col2,#T_d7c20_row98_col2,#T_d7c20_row111_col1,#T_d7c20_row169_col1{
#             background-color:  #38a367;
#             color:  #000000;
#         }#T_d7c20_row7_col0,#T_d7c20_row170_col1{
#             background-color:  #2f9a59;
#             color:  #000000;
#         }#T_d7c20_row7_col1,#T_d7c20_row47_col0,#T_d7c20_row78_col2{
#             background-color:  #2b9452;
#             color:  #000000;
#         }#T_d7c20_row7_col2,#T_d7c20_row27_col1,#T_d7c20_row33_col1,#T_d7c20_row41_col0,#T_d7c20_row105_col2,#T_d7c20_row170_col0,#T_d7c20_row187_col1{
#             background-color:  #35a063;
#             color:  #000000;
#         }#T_d7c20_row8_col0,#T_d7c20_row148_col2{
#             background-color:  #e8f6fa;
#             color:  #000000;
#         }#T_d7c20_row8_col1,#T_d7c20_row134_col2,#T_d7c20_row180_col2{
#             background-color:  #d5efed;
#             color:  #000000;
#         }#T_d7c20_row8_col2,#T_d7c20_row9_col0{
#             background-color:  #f1fafc;
#             color:  #000000;
#         }#T_d7c20_row9_col1{
#             background-color:  #e3f4f7;
#             color:  #000000;
#         }#T_d7c20_row9_col2,#T_d7c20_row40_col0,#T_d7c20_row40_col1{
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }#T_d7c20_row10_col0,#T_d7c20_row122_col2{
#             background-color:  #a5ddd0;
#             color:  #000000;
#         }#T_d7c20_row10_col1,#T_d7c20_row64_col1,#T_d7c20_row152_col2{
#             background-color:  #75c9af;
#             color:  #000000;
#         }#T_d7c20_row10_col2,#T_d7c20_row104_col2{
#             background-color:  #c5e9e2;
#             color:  #000000;
#         }#T_d7c20_row11_col0,#T_d7c20_row155_col2{
#             background-color:  #48b27f;
#             color:  #000000;
#         }#T_d7c20_row11_col1,#T_d7c20_row95_col1,#T_d7c20_row175_col0,#T_d7c20_row183_col1{
#             background-color:  #238b45;
#             color:  #000000;
#         }#T_d7c20_row12_col0,#T_d7c20_row69_col0{
#             background-color:  #e5f5f9;
#             color:  #000000;
#         }#T_d7c20_row12_col1,#T_d7c20_row104_col1,#T_d7c20_row108_col2,#T_d7c20_row132_col1{
#             background-color:  #d3eeeb;
#             color:  #000000;
#         }#T_d7c20_row12_col2{
#             background-color:  #ecf8fa;
#             color:  #000000;
#         }#T_d7c20_row13_col0{
#             background-color:  #dbf2f2;
#             color:  #000000;
#         }#T_d7c20_row13_col1{
#             background-color:  #c4e9e1;
#             color:  #000000;
#         }#T_d7c20_row13_col2,#T_d7c20_row56_col2,#T_d7c20_row132_col0{
#             background-color:  #e7f6f9;
#             color:  #000000;
#         }#T_d7c20_row14_col0,#T_d7c20_row42_col1,#T_d7c20_row133_col2,#T_d7c20_row163_col1{
#             background-color:  #80cdb7;
#             color:  #000000;
#         }#T_d7c20_row14_col2,#T_d7c20_row124_col2,#T_d7c20_row182_col0{
#             background-color:  #a0dbcd;
#             color:  #000000;
#         }#T_d7c20_row15_col0,#T_d7c20_row49_col0{
#             background-color:  #ceede8;
#             color:  #000000;
#         }#T_d7c20_row15_col1,#T_d7c20_row185_col1{
#             background-color:  #a7ddd1;
#             color:  #000000;
#         }#T_d7c20_row15_col2,#T_d7c20_row65_col1{
#             background-color:  #daf1f1;
#             color:  #000000;
#         }#T_d7c20_row16_col0,#T_d7c20_row60_col0,#T_d7c20_row85_col2,#T_d7c20_row87_col2,#T_d7c20_row140_col0,#T_d7c20_row159_col0,#T_d7c20_row181_col2{
#             background-color:  #5bbc96;
#             color:  #000000;
#         }#T_d7c20_row16_col2,#T_d7c20_row125_col0,#T_d7c20_row153_col2,#T_d7c20_row186_col1{
#             background-color:  #84cfb9;
#             color:  #000000;
#         }#T_d7c20_row17_col0,#T_d7c20_row57_col1,#T_d7c20_row88_col1,#T_d7c20_row94_col1,#T_d7c20_row106_col0,#T_d7c20_row112_col1,#T_d7c20_row128_col1{
#             background-color:  #7fcdb6;
#             color:  #000000;
#         }#T_d7c20_row18_col0,#T_d7c20_row87_col0,#T_d7c20_row98_col1,#T_d7c20_row141_col1,#T_d7c20_row176_col1{
#             background-color:  #59bb93;
#             color:  #000000;
#         }#T_d7c20_row18_col1,#T_d7c20_row23_col0,#T_d7c20_row31_col0,#T_d7c20_row59_col1,#T_d7c20_row105_col0,#T_d7c20_row117_col2,#T_d7c20_row155_col0{
#             background-color:  #3fab72;
#             color:  #000000;
#         }#T_d7c20_row18_col2,#T_d7c20_row52_col1,#T_d7c20_row64_col0,#T_d7c20_row66_col1,#T_d7c20_row71_col2,#T_d7c20_row74_col2,#T_d7c20_row118_col0,#T_d7c20_row118_col1{
#             background-color:  #72c7ad;
#             color:  #000000;
#         }#T_d7c20_row19_col0,#T_d7c20_row147_col2{
#             background-color:  #309b5b;
#             color:  #000000;
#         }#T_d7c20_row19_col1,#T_d7c20_row179_col1{
#             background-color:  #1d8640;
#             color:  #000000;
#         }#T_d7c20_row19_col2,#T_d7c20_row71_col1,#T_d7c20_row91_col2,#T_d7c20_row114_col0,#T_d7c20_row142_col0{
#             background-color:  #41ae77;
#             color:  #000000;
#         }#T_d7c20_row20_col1,#T_d7c20_row32_col2,#T_d7c20_row86_col0,#T_d7c20_row113_col1,#T_d7c20_row130_col1,#T_d7c20_row157_col0{
#             background-color:  #70c6ac;
#             color:  #000000;
#         }#T_d7c20_

# %%
add_style(gb_filter_monotonic(nasdaq_100))

# %%
add_style(gb_filter_neg(gb_filter_monotonic_partial(nasdaq_100)))

# %%
add_style(gb_filter_monotonic(dow_jones))

# %%
add_style(gb_filter_neg(gb_filter_monotonic_partial(dow_jones)))
