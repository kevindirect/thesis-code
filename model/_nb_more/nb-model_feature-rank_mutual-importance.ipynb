# %% [markdown]
# # nb-model_feature-rank_mutual-importance

# %% [markdown]
# ## Analyze Feature Ranking: Mutual Information Test Results.

# %%
import sys
import os
from os import sep
from os.path import dirname, realpath
from pathlib import Path
from collections import OrderedDict
from functools import partial, reduce
from itertools import product
import logging

def get_cwd(fname, subdir, crunch_dir=realpath(Path.home()) +sep +'crunch' +sep):
    """
    Convenience function to make a directory string for the current file based on inputs.
    Jupyter Notebook in Anaconda invokes the Python interpreter in Anaconda's subdirectory
    which is why changing sys.argv[0] is necessary. In the future a better way to do this
    should be preferred..
    """
    return crunch_dir +subdir +fname

def fix_path(cwd):
    """
    Convenience function to fix argv and python path so that jupyter notebook can run the same as
    any script in crunch.
    """
    sys.argv[0] = cwd
    module_path = os.path.abspath(os.path.join('..'))
    if module_path not in sys.path:
        sys.path.append(module_path)

fname = 'nb-model_xg-model-fr-mi.ipynb'
dir_name = 'model'
fix_path(get_cwd(fname, dir_name +sep))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from ipywidgets import interact, interactive, fixed
from IPython.display import display

pd.set_option("display.max_rows", 100)
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_colwidth', 500)

from common_util import MODEL_DIR, load_df, compose, isnt, is_type, remove_dups_list, NestedDefaultDict, benchmark
from model.common import FR_DIR
logging.basicConfig(stream=sys.stdout, level=logging.DEBUG)
# Out:
# CRITICAL:root:script location: /home/kev/crunch/model/nb-model_xg-model-fr-mi.ipynb
# CRITICAL:root:using project dir: /home/kev/crunch/

# %% [markdown]
# ## Load Reports

# %%
#pd.set_option('display.float_format', lambda x: '%8.2f' % x)
assets = ['sp_500', 'russell_2000', 'nasdaq_100', 'dow_jones']
freqs = ['d', 'h']
srcs = ['pba', 'vol', 'buzz', 'nonbuzz']

def df_scale(df, scalar=10**4):
    df[df.select_dtypes(include=['number']).columns] *= scalar
    return df

# %%
mi = NestedDefaultDict()
for path_root_dirs in product(assets, freqs, srcs):
    path_root = FR_DIR +sep.join(path_root_dirs) +sep
    for report_file in os.listdir(path_root):
        path = list(path_root_dirs)
        path.extend(report_file.split('.')[:-1])
        mi[path] = df_scale(load_df(report_file, dir_path=path_root))

# %%
mi_agg = NestedDefaultDict()
for kc, v in mi.items():
    #mi_agg[kc] = v.groupby(['sub', 'win', 'knn'])[['clf', 'reg']].agg(['mean', 'max', 'mad', 'std'])*10**4
    mi_agg[kc] = v.groupby(['sub', 'win', 'knn'])[['clf', 'reg']].agg(['max'])

# %%
mi_agg_dfs = NestedDefaultDict()
for asset in assets:
    for freq, src in product(freqs, srcs):
        kcs = mi_agg.childkeys([asset, freq, src])
        if (len(list(kcs)) > 0):
            mi_agg_dfs[[asset, freq, src]] = pd.concat([mi_agg[kc] for kc in mi_agg.childkeys([asset, freq, src])])

# %% [markdown]
# ## Analyze

# %%
def ntop_common(asset, freq, src, use_clf_reg=False, ntop=.2, show=True):
    freq_src_df = mi_agg_dfs[[asset, freq, src]]
    ntop = int(len(freq_src_df) * ntop) if (is_type(ntop, float)) else ntop
    print('{} {} {} unique subsets: {}'.format(asset, freq, src, len(freq_src_df.reset_index()['sub'].unique())))
    print('ntop: {}'.format(ntop))

    ntop_reg_df = freq_src_df['reg'].nlargest(columns='max', n=ntop).reset_index()
    if (use_clf_reg):
        ntop_clf_df = freq_src_df['clf'].nlargest(columns='max', n=ntop).reset_index()
        assert(len(ntop_clf_df)==len(ntop_reg_df))

        if (show):
            display(ntop_clf_df, ntop_reg_df)
        return np.intersect1d(ntop_clf_df['sub'], ntop_reg_df['sub'])
    else:
        if (show):
            display(ntop_reg_df)
        return ntop_reg_df['sub']

# %%
def ntop_common_subset(asset, freq, src, sub, use_clf_reg=False, ntop=.2, show=False):
    freq_src_sub_df = pd.concat([mi[kc] for kc in list(mi.childkeys([asset, freq, src, sub, 'mi']))])
    ntop = int(len(freq_src_sub_df) * ntop) if (is_type(ntop, float)) else ntop
    #print('{} {} {} unique subsets: {}'.format(asset, freq, src, len(freq_src_df.reset_index()['sub'].unique())))
    print('ntop: {}'.format(ntop))

    ntop_reg_df = freq_src_sub_df.nlargest(columns='reg', n=ntop).reset_index()
    if (use_clf_reg):
        ntop_clf_df = freq_src_sub_df.nlargest(columns='clf', n=ntop).reset_index()
        assert(len(ntop_clf_df)==len(ntop_reg_df))

        if (show):
            display(ntop_clf_df, ntop_reg_df)
        return np.intersect1d(ntop_clf_df['ser'], ntop_reg_df['ser'])
    else:
        if (show):
            display(ntop_reg_df)
        return ntop_reg_df['ser']

# %%
def extract_axe_name(string):
    try:
        end = string.index('(')
    except ValueError as e:
        end = len(string)
    finally:
        return string[:end].split('_')[-1]

# %% [markdown]
# ## Daily

# %%
freq = 'd'
ntop_common_dfs = NestedDefaultDict()
for asset, src in product(assets, srcs):
    ntop_common_dfs[[asset, freq, src]] = ntop_common(asset, freq, src, use_clf_reg=False, ntop=.05)
# Out:
# sp_500 d pba unique subsets: 83
# ntop: 41
#                                                                                                            sub  \
# 0                                                           pba_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 1                                                           pba_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 2                                    pba_hlh_hdxcret2(0.5*std,1)_dxfbcret2_hdxcret2(1*std,1)_hdxcret2(2*std,1)
# 3                                                           pba_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 4                                                           pba_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 5                                                           pba_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 6                                                           pba_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 7                                                           pba_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 8                                                           pba_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 9                                                           pba_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 10                                                          pba_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 11  pba_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 12  pba_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 13                                                          pba_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 14                                                                                             pba_dlh_dlogret
# 15                                                          pba_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 16  pba_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 17                                                          pba_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 18                                                          pba_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 19                                                          pba_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 20                                                          pba_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 21  pba_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 22                                                          pba_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 23                                                          pba_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 24                                                          pba_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 25                                   pba_hlh_hdxcret2(0.5*mad,1)_dxfbcret2_hdxcret2(1*mad,1)_hdxcret2(2*mad,1)
# 26                                                          pba_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 27                                                          pba_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 28                                                                                             pba_dlh_dlogret
# 29                                   pba_hlh_hdxcret2(0.5*mad,1)_dxfbcret2_hdxcret2(1*mad,1)_hdxcret2(2*mad,1)
# 30                                                          pba_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 31                                                          pba_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 32                                   pba_hlh_hdxcret2(0.5*max,1)_dxfbcret2_hdxcret2(1*max,1)_hdxcret2(2*max,1)
# 33                                                                                                  pba_dohlca
# 34                                                                                                  pba_dohlca
# 35                                   pba_hoc_hdxcret2(0.5*std,1)_dxfbcret2_hdxcret2(1*std,1)_hdxcret2(2*std,1)
# 36  pba_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 37                                                                                                  pba_dohlca
# 38                                   pba_hlh_hdxcret2(0.5*mad,1)_dxfbcret2_hdxcret2(1*mad,1)_hdxcret2(2*mad,1)
# 39  pba_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 40                                                          pba_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
#
#        win    knn          max
# 0    10000  30000  1648.862400
# 1    30000  30000  1383.673699
# 2    10000  30000  1361.548030
# 3    10000  70000  1252.564331
# 4    10000  30000  1230.856728
# 5    30000  30000  1177.153521
# 6    10000  70000  1158.231545
# 7    10000  70000  1150.518257
# 8    10000  70000  1137.992473
# 9    10000  30000  1105.095895
# 10   10000  30000  1093.140271
# 11   10000  30000  1083.288604
# 12   10000  70000  1068.001736
# 13   30000  70000  1040.481165
# 14   30000  30000  1027.451057
# 15   30000  70000  1022.720188
# 16   50000  30000   989.295467
# 17   50000  30000   980.476996
# 18   30000  70000   947.361155
# 19   30000  70000   944.033975
# 20   50000  70000   931.623918
# 21   30000  30000   912.265612
# 22  100000  30000   875.919449
# 23   30000  30000   866.604687
# 24   30000  30000   864.650116
# 25   50000  30000   862.227326
# 26  200000  30000   852.099349
# 27  200000  30000   850.307076
# 28   30000  70000   843.843393
# 29   10000  30000   841.791773
# 30   50000  30000   829.131528
# 31   50000  70000   815.876886
# 32   10000  30000   812.288488
# 33   30000  70000   804.495510
# 34   10000  30000   803.421741
# 35   50000  30000   801.692668
# 36   30000  70000   798.471294
# 37   10000  70000   785.713109
# 38   10000  70000   785.534068
# 39  100000  30000   785.408935
# 40  200000  70000   780.721906
# sp_500 d vol unique subsets: 83
# ntop: 41
#                                                                                                            sub  \
# 0   vol_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 1   vol_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 2                                                                                                   vol_dohlca
# 3                                                           vol_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 4                                                           vol_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 5                                                           vol_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 6                                                           vol_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 7                                                                                                   vol_dohlca
# 8                                                                                                   vol_dohlca
# 9                                                           vol_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 10                                                          vol_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 11                                                          vol_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 12                                                          vol_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 13                                                          vol_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 14                                                          vol_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 15                                                          vol_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 16                                                          vol_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 17                                                          vol_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 18  vol_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 19                                                                                                  vol_dohlca
# 20                                                          vol_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 21                                                          vol_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 22                                                          vol_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 23  vol_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 24  vol_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 25  vol_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 26                                                          vol_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 27                                                          vol_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 28                                                                                                  vol_dohlca
# 29                                                          vol_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 30                                                          vol_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 31                                                          vol_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 32                                                          vol_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 33                                                                                                  vol_dohlca
# 34                                                          vol_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 35  vol_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 36  vol_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 37                                                          vol_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 38                                                          vol_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 39                                                          vol_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 40                                                          vol_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
#
#        win    knn          max
# 0    10000  30000  1385.415514
# 1    50000  30000  1311.895091
# 2    10000  30000  1277.103774
# 3    10000  30000  1274.503070
# 4    10000  30000  1271.518603
# 5    50000  70000  1246.850749
# 6    50000  30000  1191.619884
# 7    50000  30000  1182.275293
# 8    50000  70000  1178.661405
# 9    50000  70000  1178.661405
# 10   50000  70000  1178.661405
# 11   50000  30000  1178.245957
# 12   50000  30000  1177.345823
# 13   10000  30000  1167.438049
# 14   10000  70000  1160.876021
# 15   50000  70000  1155.872616
# 16   10000  70000  1152.818003
# 17   50000  30000  1139.093315
# 18   30000  30000  1120.906309
# 19   10000  70000  1119.946372
# 20   10000  70000  1119.946372
# 21   10000  70000  1119.946372
# 22   10000  30000  1101.693293
# 23   50000  70000  1097.881866
# 24   30000  70000  1072.359674
# 25   10000  70000  1044.145221
# 26   30000  70000  1030.370061
# 27   30000  30000  1004.562881
# 28   30000  30000  1003.890926
# 29   30000  30000  1002.803361
# 30   30000  30000   998.303973
# 31  200000  30000   993.385667
# 32   30000  70000   931.821536
# 33   30000  70000   929.545463
# 34   30000  70000   927.574594
# 35  100000  30000   918.731651
# 36  200000  30000   918.184156
# 37  200000  30000   914.330443
# 38   30000  30000   895.601777
# 39   30000  70000   878.683515
# 40  100000  30000   877.160936
# sp_500 d buzz unique subsets: 14
# ntop: 7
#                                                                                                                                                                   sub  \
# 0                                                                                       trmi3_etf3_social_buzz_dohlca_ddiff(1)_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 1  trmi3_etf3_news_buzz_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 2                                                          trmi3_etf3_news_buzz_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 3                                                                                         trmi3_etf3_news_buzz_dohlca_ddiff(1)_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 4                                                          trmi3_etf3_news_buzz_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 5                                                        trmi3_etf3_social_buzz_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 6                                                          trmi3_etf3_news_buzz_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
#
#       win    knn         max
# 0   30000  30000  818.355469
# 1   30000  30000  756.000202
# 2  200000  30000  650.070896
# 3   50000  30000  632.830227
# 4  200000  30000  627.898248
# 5  200000  30000  627.408046
# 6  200000  30000  627.271865
# sp_500 d nonbuzz unique subsets: 10
# ntop: 5
#                                                                                                                                                                                    sub  \
# 0                                                                                                             trmi3_etf3_social_forecast_dc_fundamental_sentiment_mkt3_bank_bond_stock
# 1                                                                                                             trmi3_etf3_social_forecast_dc_fundamental_sentiment_mkt3_bank_bond_stock
# 2                                                                                                             trmi3_etf3_social_forecast_dc_fundamental_sentiment_mkt3_bank_bond_stock
# 3                                                                                                             trmi3_etf3_social_forecast_dc_fundamental_sentiment_mkt3_bank_bond_stock
# 4  trmi3_etf3_social_forecast_dc_dffd(0.200000,0.010000)_dwrxmx(-1)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)_fundamental_sentiment_mkt3_bank_bond_stock
#
#       win    knn         max
# 0   30000  30000  945.204591
# 1   10000  70000  940.994260
# 2  200000  30000  915.116848
# 3   10000  30000  908.058114
# 4   30000  30000  866.645640
# russell_2000 d pba unique subsets: 83
# ntop: 41
#                                                                                                            sub  \
# 0                                                           pba_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 1                                                           pba_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 2   pba_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 3                                                           pba_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 4                                                                                                   pba_dohlca
# 5                                                           pba_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 6                                                           pba_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 7                                                           pba_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 8                                                           pba_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 9                                                           pba_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 10                                                          pba_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 11                                                                                                  pba_dohlca
# 12                                                          pba_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 13                                                          pba_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 14  pba_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 15                                                                                             pba_dlh_dlogret
# 16  pba_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 17                                                          pba_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 18                                                          pba_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 19                                                                                                  pba_dohlca
# 20  pba_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 21                                                          pba_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 22  pba_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 23                                                          pba_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 24                                                          pba_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 25                                                          pba_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 26                                                          pba_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 27                                                                                                  pba_dohlca
# 28                                                          pba_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 29                                                          pba_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 30                                                          pba_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 31                                                          pba_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 32  pba_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 33                                                          pba_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 34                                                          pba_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 35                                                          pba_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 36                                                          pba_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 37                                                                                                  pba_dohlca
# 38                                                          pba_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 39                                                          pba_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 40                                                          pba_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
#
#        win    knn          max
# 0    10000  30000  1491.831754
# 1    10000  30000  1491.415986
# 2    10000  30000  1490.837943
# 3    10000  30000  1388.052117
# 4    10000  30000  1378.605926
# 5   100000  30000  1368.987712
# 6   100000  30000  1366.190134
# 7    50000  30000  1358.820888
# 8    50000  30000  1356.744691
# 9    30000  30000  1336.865797
# 10   30000  30000  1331.779856
# 11   10000  70000  1310.494891
# 12   30000  30000  1305.045962
# 13   50000  30000  1258.246837
# 14   50000  30000  1258.007318
# 15   10000  30000  1246.707959
# 16   10000  70000  1245.209414
# 17   30000  70000  1227.937800
# 18   10000  70000  1221.698064
# 19   50000  30000  1208.674564
# 20  100000  30000  1206.338341
# 21  200000  30000  1202.857068
# 22   50000  70000  1202.032568
# 23   10000  30000  1196.189982
# 24   10000  70000  1177.699430
# 25   10000  70000  1176.387135
# 26   10000  70000  1174.377891
# 27   50000  70000  1173.989871
# 28   30000  30000  1171.091874
# 29   50000  70000  1163.207239
# 30  200000  30000  1162.033482
# 31  200000  30000  1158.000167
# 32   30000  70000  1157.097037
# 33   50000  30000  1150.732704
# 34  200000  30000  1143.633165
# 35   50000  70000  1114.498290
# 36   30000  70000  1092.613121
# 37  200000  70000  1082.107787
# 38   30000  70000  1075.551753
# 39   50000  70000  1071.688861
# 40   50000  70000  1070.263287
# russell_2000 d vol unique subsets: 83
# ntop: 41
#                                                                                                            sub  \
# 0                                                           vol_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 1   vol_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 2                                                           vol_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 3                                                                                                   vol_dohlca
# 4                                                           vol_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 5                                                           vol_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 6   vol_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 7   vol_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 8                                                                                                   vol_dohlca
# 9                                                           vol_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 10                                                          vol_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 11                                                          vol_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 12                                                          vol_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 13                                                          vol_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 14                                                          vol_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 15                                                          vol_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 16                                                                                                  vol_dohlca
# 17                                                          vol_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 18                                                          vol_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 19                                                          vol_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 20                                                          vol_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 21                                                                                                  vol_dohlca
# 22                                                          vol_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 23  vol_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 24                                                          vol_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 25  vol_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 26                                                          vol_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 27                                                          vol_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 28                                                          vol_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 29  vol_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 30                                                          vol_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 31                                                          vol_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 32                                                          vol_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 33  vol_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 34                                                          vol_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 35                                                                                                  vol_dohlca
# 36                                                          vol_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 37                                                          vol_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 38                                                                                                  vol_dohlca
# 39  vol_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 40                                                          vol_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
#
#        win    knn          max
# 0    30000  30000  1737.219671
# 1    10000  30000  1721.054484
# 2    10000  30000  1662.347458
# 3    10000  30000  1556.072136
# 4    10000  30000  1549.288327
# 5    10000  30000  1549.176755
# 6    30000  30000  1547.028487
# 7    10000  70000  1528.912428
# 8    10000  70000  1519.538237
# 9    10000  70000  1510.131117
# 10   30000  70000  1492.980597
# 11   30000  70000  1492.781148
# 12   10000  70000  1491.437124
# 13   10000  70000  1489.903829
# 14   30000  30000  1469.605284
# 15   30000  30000  1465.910204
# 16   30000  30000  1439.376799
# 17   30000  70000  1418.091283
# 18   30000  30000  1408.108329
# 19   10000  70000  1400.898659
# 20   30000  70000  1396.361413
# 21   30000  70000  1382.915705
# 22   10000  30000  1364.826609
# 23   30000  70000  1335.859072
# 24   50000  70000  1316.659960
# 25   50000  30000  1309.060172
# 26   50000  30000  1302.666001
# 27   50000  30000  1281.503735
# 28  100000  30000  1258.156682
# 29  100000  30000  1225.570145
# 30  100000  30000  1221.291438
# 31   50000  30000  1186.479850
# 32   50000  30000  1184.712963
# 33   50000  70000  1160.035364
# 34   50000  70000  1129.208666
# 35   50000  30000  1122.857048
# 36  100000  70000  1107.743090
# 37  100000  70000  1103.591611
# 38   50000  70000  1098.243315
# 39  100000  70000  1097.627666
# 40   50000  70000  1070.319624
# russell_2000 d buzz unique subsets: 14
# ntop: 7
#                                                                                                                                                                     sub  \
# 0                                                                                                    trmi3_etf3_news_buzz_dohlca_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 1  trmi3_etf3_social_buzz_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 2                                                          trmi3_etf3_social_buzz_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 3                                                          trmi3_etf3_social_buzz_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 4                                                                                                    trmi3_etf3_news_buzz_dohlca_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 5                                                            trmi3_etf3_news_buzz_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 6                                                            trmi3_etf3_news_buzz_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
#
#      win    knn         max
# 0  30000  30000  890.595957
# 1  30000  30000  890.026029
# 2  50000  30000  879.096936
# 3  50000  30000  876.614579
# 4  50000  30000  807.958400
# 5  30000  30000  803.483462
# 6  30000  30000  802.803839
# russell_2000 d nonbuzz unique subsets: 10
# ntop: 5
#                                                                                                                                                                                    sub  \
# 0    trmi3_etf3_news_forecast_dc_dffd(0.200000,0.010000)_dwrxmx(-1)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)_fundamental_sentiment_mkt3_bank_bond_stock
# 1  trmi3_etf3_social_forecast_dc_dffd(0.200000,0.010000)_dwrxmx(-1)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)_fundamental_sentiment_mkt3_bank_bond_stock
# 2  trmi3_etf3_social_forecast_dc_dffd(0.200000,0.010000)_dwrxmx(-1)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)_fundamental_sentiment_mkt3_bank_bond_stock
# 3                                                                                                               trmi3_etf3_news_forecast_dc_fundamental_sentiment_mkt3_bank_bond_stock
# 4  trmi3_etf3_social_forecast_dc_dffd(0.200000,0.010000)_dwrxmx(-1)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)_fundamental_sentiment_mkt3_bank_bond_stock
#
#       win    knn         max
# 0  100000  30000  899.417719
# 1  100000  70000  896.840380
# 2  100000  30000  867.134436
# 3   10000  30000  852.607198
# 4  200000  70000  819.985275
# nasdaq_100 d pba unique subsets: 83
# ntop: 41
#                                                                                                                                                                                   sub  \
# 0                                                                                                                                  pba_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 1                                                                                                                                  pba_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 2                                                                                                                                  pba_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 3                                                                          pba_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 4                                                                                                                                  pba_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 5                                                                                                                                  pba_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 6                                                                                                                                  pba_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 7                                                                                                                                  pba_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 8                                                                                                                                  pba_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 9                                                                                                                                  pba_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 10                                                                                                                                 pba_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 11                                                                                                                                                                    pba_dlh_dlogret
# 12                                                                                                                                 pba_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 13                                                                                                                                 pba_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 14                                                                                                                                 pba_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 15                                                                                                                                 pba_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 16                                                                         pba_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 17                                                                                                                 pba_hoc_hdxret2(0.5*mad,1)_dret2_hdxret2(1*mad,1)_hdxret2(2*mad,1)
# 18                                                                                                          pba_hlh_hdxcret2(0.5*std,1)_dxfbcret2_hdxcret2(1*std,1)_hdxcret2(2*std,1)
# 19                                                                                                          pba_hlh_hdxcret2(0.5*mad,1)_dxfbcret2_hdxcret2(1*mad,1)_hdxcret2(2*mad,1)
# 20                                                                                                                                                                    pba_dlh_dlogret
# 21                                                                                                                 pba_hoc_hdxret2(0.5*avg,1)_dret2_hdxret2(1*avg,1)_hdxret2(2*avg,1)
# 22   pba_hoc_hdxcret1(0.062500%)_dxfbval1_hdxcret1(0.125000%)_hdxcret1(0.250000%)_hdxcret1(0.500000%)_hdxcret1(1.000000%)_hdxcret1(2.000000%)_hdxcret1(4.000000%)_hdxcret1(8.000000%)
# 23                                                                                                                                 pba_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 24                                                                         pba_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 25                                                                                                                 pba_hoc_hdxret2(0.5*min,1)_dret2_hdxret2(1*min,1)_hdxret2(2*min,1)
# 26                                                                                                          pba_hoc_hdxcret2(0.5*mad,1)_dxfbcret2_hdxcret2(1*mad,1)_hdxcret2(2*mad,1)
# 27  pba_hlh_hdxcret1(0.062500%)_dxfbcret1_hdxcret1(0.125000%)_hdxcret1(0.250000%)_hdxcret1(0.500000%)_hdxcret1(1.000000%)_hdxcret1(2.000000%)_hdxcret1(4.000000%)_hdxcret1(8.000000%)
# 28  pba_hlh_hdxcret1(1.000000%)_dxfbcret1_hdxcret1(2.000000%)_hdxcret1(3.000000%)_hdxcret1(4.000000%)_hdxcret1(5.000000%)_hdxcret1(6.000000%)_hdxcret1(7.000000%)_hdxcret1(8.000000%)
# 29   pba_hlh_hdxcret1(0.062500%)_dxfbdir1_hdxcret1(0.125000%)_hdxcret1(0.250000%)_hdxcret1(0.500000%)_hdxcret1(1.000000%)_hdxcret1(2.000000%)_hdxcret1(4.000000%)_hdxcret1(8.000000%)
# 30   pba_hlh_hdxcret1(1.000000%)_dxfbdir1_hdxcret1(2.000000%)_hdxcret1(3.000000%)_hdxcret1(4.000000%)_hdxcret1(5.000000%)_hdxcret1(6.000000%)_hdxcret1(7.000000%)_hdxcret1(8.000000%)
# 31   pba_hoc_hdxcret1(1.000000%)_dxfbval1_hdxcret1(2.000000%)_hdxcret1(3.000000%)_hdxcret1(4.000000%)_hdxcret1(5.000000%)_hdxcret1(6.000000%)_hdxcret1(7.000000%)_hdxcret1(8.000000%)
# 32                                                                                                                                 pba_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 33              pba_hoc_hdxret1(0.062500%)_dret1_hdxret1(0.125000%)_hdxret1(0.250000%)_hdxret1(0.500000%)_hdxret1(1.000000%)_hdxret1(2.000000%)_hdxret1(4.000000%)_hdxret1(8.000000%)
# 34                                                                                                          pba_hlh_hdxcret2(0.5*std,1)_dxfbcret2_hdxcret2(1*std,1)_hdxcret2(2*std,1)
# 35                                                                         pba_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 36                                                                                                          pba_hoc_hdxcret2(0.5*std,1)_dxfbcret2_hdxcret2(1*std,1)_hdxcret2(2*std,1)
# 37                                                                                                                                 pba_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 38                                                                                                                 pba_hoc_hdxret2(0.5*std,1)_dret2_hdxret2(1*std,1)_hdxret2(2*std,1)
# 39   pba_hlh_hdxcret1(0.062500%)_dxfbval1_hdxcret1(0.125000%)_hdxcret1(0.250000%)_hdxcret1(0.500000%)_hdxcret1(1.000000%)_hdxcret1(2.000000%)_hdxcret1(4.000000%)_hdxcret1(8.000000%)
# 40                                                                                                                                 pba_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
#
#        win    knn          max
# 0    10000  30000  1277.238129
# 1    30000  30000  1098.538203
# 2    30000  30000  1088.782178
# 3    10000  30000  1022.483934
# 4    10000  30000  1013.619600
# 5    10000  30000  1009.339854
# 6    10000  30000   965.820156
# 7    50000  30000   919.084118
# 8    10000  70000   913.331504
# 9    10000  70000   910.721043
# 10   50000  30000   897.452235
# 11   30000  30000   879.582193
# 12   10000  70000   870.562411
# 13   10000  70000   825.514741
# 14   30000  70000   803.124199
# 15   30000  70000   795.419490
# 16  100000  30000   771.882888
# 17   10000  30000   764.686485
# 18   30000  30000   760.908502
# 19   10000  30000   757.531748
# 20   30000  70000   754.563827
# 21   10000  30000   746.472119
# 22   30000  30000   744.703737
# 23   50000  30000   728.984165
# 24   50000  30000   723.765441
# 25   10000  30000   721.173858
# 26   50000  30000   718.629988
# 27   30000  30000   714.879939
# 28   30000  30000   714.879939
# 29   30000  30000   714.879939
# 30   30000  30000   714.879939
# 31   30000  30000   706.471936
# 32  100000  30000   691.371349
# 33   10000  30000   688.844593
# 34   50000  30000   663.338337
# 35   10000  70000   662.562990
# 36  100000  30000   652.973923
# 37   30000  30000   651.829798
# 38   10000  30000   643.387381
# 39   10000  70000   640.478348
# 40   30000  30000   639.673832
# nasdaq_100 d vol unique subsets: 83
# ntop: 41
#                                                                                                            sub  \
# 0                                                                                                   vol_dohlca
# 1   vol_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 2                                                           vol_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 3                                                           vol_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 4                                                           vol_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 5                                                           vol_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 6                                                           vol_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 7                                                           vol_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 8                                                           vol_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 9                                                                                                   vol_dohlca
# 10                                                          vol_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 11                                                                                                  vol_dohlca
# 12                                                          vol_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 13  vol_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 14                                                          vol_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 15  vol_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 16                                                                                                  vol_dohlca
# 17                                                          vol_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 18                                                          vol_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 19  vol_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 20                                                          vol_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 21                                                          vol_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 22  vol_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 23                                                          vol_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 24                                                          vol_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 25                                                          vol_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 26                                                                                                  vol_dohlca
# 27                                                          vol_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 28                                                          vol_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 29                                                          vol_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 30                                                          vol_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 31                                                          vol_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 32                                                                                                  vol_dohlca
# 33  vol_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 34  vol_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 35                                                                                                  vol_dohlca
# 36                                                          vol_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 37  vol_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 38                                                          vol_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 39                                                          vol_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 40                                                          vol_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
#
#        win    knn          max
# 0    10000  30000  1258.627425
# 1    10000  30000  1222.054476
# 2    10000  30000  1209.869204
# 3    10000  30000  1180.483461
# 4    10000  30000  1177.350573
# 5    10000  70000  1113.907073
# 6    10000  70000  1106.160921
# 7    10000  70000  1105.190634
# 8    10000  30000  1078.974949
# 9    10000  70000  1060.111326
# 10   50000  30000  1056.265392
# 11   30000  30000  1047.315001
# 12   10000  70000  1043.996579
# 13   30000  30000  1042.916897
# 14   30000  30000  1018.034492
# 15   10000  70000  1012.867728
# 16   50000  30000  1005.624260
# 17  100000  30000   999.481365
# 18  100000  30000   998.415880
# 19   50000  30000   996.383065
# 20   50000  30000   981.398699
# 21   50000  30000   980.222731
# 22   30000  70000   962.825084
# 23   30000  70000   957.377229
# 24   30000  30000   920.591291
# 25   30000  70000   911.013712
# 26   30000  70000   906.057374
# 27  200000  30000   877.278815
# 28   30000  70000   874.677556
# 29   30000  70000   874.631328
# 30   30000  30000   863.531508
# 31   30000  30000   862.390008
# 32  100000  30000   835.363106
# 33   50000  70000   817.324138
# 34  100000  30000   807.130084
# 35  200000  30000   802.431550
# 36   50000  30000   800.362689
# 37  200000  30000   788.426992
# 38   50000  70000   765.841058
# 39  100000  30000   765.593538
# 40  200000  30000   746.163497
# nasdaq_100 d buzz unique subsets: 14
# ntop: 7
#                                                                                                                                                                     sub  \
# 0  trmi3_etf3_social_buzz_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 1                                                          trmi3_etf3_social_buzz_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 2                                                          trmi3_etf3_social_buzz_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 3                                                            trmi3_etf3_news_buzz_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 4                                                          trmi3_etf3_social_buzz_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 5                                                          trmi3_etf3_social_buzz_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 6    trmi3_etf3_news_buzz_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
#
#       win    knn         max
# 0  200000  30000  983.506872
# 1  100000  30000  767.580271
# 2  100000  30000  756.069926
# 3   10000  30000  743.665164
# 4   30000  30000  729.892047
# 5   30000  30000  728.076317
# 6   10000  30000  724.000553
# nasdaq_100 d nonbuzz unique subsets: 10
# ntop: 5
# ...
# 3  trmi3_etf3_social_forecast_dc_dffd(0.200000,0.010000)_dwrxmx(-1)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)_fundamental_sentiment_mkt3_bank_bond_stock
# 4                                                                                                             trmi3_etf3_social_forecast_dc_fundamental_sentiment_mkt3_bank_bond_stock
#
#       win    knn         max
# 0   10000  30000  786.913738
# 1  200000  30000  717.919783
# 2   10000  30000  716.260350
# 3   30000  30000  707.795643
# 4  100000  30000  679.561534
# dow_jones d pba unique subsets: 83
# ntop: 41
#                                                                                                            sub  \
# 0                                                           pba_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 1                                                           pba_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 2                                                           pba_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 3                                                           pba_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 4                                                           pba_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 5                                                           pba_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 6                                                           pba_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 7                                                           pba_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 8                                                           pba_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 9                                                           pba_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 10                                                                                             pba_dlh_dlogret
# 11                                                          pba_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 12                                                          pba_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 13                                                          pba_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 14                                                          pba_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 15  pba_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 16                                                                                                  pba_dohlca
# 17                                                          pba_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 18                                                                                                  pba_dohlca
# 19                                   pba_hoc_hdxcret2(0.5*std,1)_dxfbcret2_hdxcret2(1*std,1)_hdxcret2(2*std,1)
# 20                                                          pba_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 21                                                          pba_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 22                                                          pba_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 23  pba_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 24                                                                                             pba_dlh_dlogret
# 25                                                          pba_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 26  pba_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 27                                                                                                  pba_dohlca
# 28                                   pba_hlh_hdxcret2(0.5*std,1)_dxfbcret2_hdxcret2(1*std,1)_hdxcret2(2*std,1)
# 29  pba_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 30                                   pba_hlh_hdxcret2(0.5*std,1)_dxfbcret2_hdxcret2(1*std,1)_hdxcret2(2*std,1)
# 31  pba_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 32                                                                                                  pba_dohlca
# 33                                                          pba_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 34                                                          pba_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 35                                                          pba_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 36                                                          pba_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 37                                                          pba_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 38                                                          pba_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 39                                                          pba_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 40                                                          pba_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
#
#        win    knn          max
# 0    10000  30000  1269.785067
# 1    10000  30000  1242.561843
# 2    10000  30000  1234.707134
# 3    30000  30000  1155.110227
# 4    30000  30000  1144.052697
# 5    10000  70000  1123.587772
# 6    30000  30000  1078.153771
# 7    10000  30000  1073.294718
# 8    30000  70000  1057.074169
# 9    30000  30000  1045.492365
# 10   50000  30000  1016.381302
# 11   50000  30000  1007.068090
# 12   10000  70000  1005.899573
# 13   10000  70000  1001.347476
# 14   10000  70000   999.515996
# 15   10000  30000   995.316664
# 16   10000  30000   994.322209
# 17   30000  70000   979.356427
# 18   30000  30000   930.022751
# 19   50000  30000   908.096014
# 20   50000  70000   900.612001
# 21   30000  70000   894.909773
# 22   30000  70000   894.892047
# 23   10000  70000   894.834956
# 24   30000  30000   893.410001
# 25   50000  30000   886.564979
# 26   30000  30000   869.133443
# 27   10000  70000   865.363441
# 28   10000  30000   830.347707
# 29   30000  70000   825.324697
# 30   10000  70000   819.782937
# 31   50000  30000   813.339574
# 32   30000  70000   801.708490
# 33   50000  30000   798.840052
# 34   50000  30000   796.889648
# 35  100000  30000   781.127286
# 36  100000  30000   780.830644
# 37   50000  70000   776.335869
# 38  100000  30000   776.053177
# 39   50000  70000   775.586312
# 40   50000  70000   775.024897
# dow_jones d vol unique subsets: 83
# ntop: 41
#                                                                                                            sub  \
# 0                                                           vol_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 1                                                           vol_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 2                                                           vol_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 3                                                                                                   vol_dohlca
# 4                                                           vol_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 5                                                           vol_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 6                                                           vol_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 7   vol_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 8   vol_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 9                                                           vol_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 10                                                          vol_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 11  vol_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 12                                                          vol_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 13                                                          vol_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 14                                                          vol_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 15                                                          vol_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 16                                                                                                  vol_dohlca
# 17                                                          vol_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 18                                                                                                  vol_dohlca
# 19                                                          vol_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 20  vol_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 21                                                          vol_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 22                                                                                                  vol_dohlca
# 23                                                          vol_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 24                                                          vol_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 25                                                          vol_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 26  vol_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 27                                                          vol_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 28  vol_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 29  vol_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 30                                                          vol_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
# 31                                                          vol_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)
# 32                                                          vol_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)
# 33  vol_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 34  vol_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)
# 35                                                          vol_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 36                                                          vol_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 37                                                          vol_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 38                                                                                                  vol_dohlca
# 39                                                          vol_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)
# 40                                                          vol_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)
#
#        win    knn          max
# 0    10000  70000  1409.231532
# 1    10000  70000  1271.415152
# 2    30000  70000  1195.294718
# 3    30000  30000  1189.558809
# 4    30000  30000  1189.558809
# 5    30000  30000  1189.464332
# 6    30000  30000  1182.345367
# 7    30000  30000  1179.730823
# 8    10000  70000  1157.591462
# 9    10000  30000  1123.550717
# 10   10000  30000  1122.314613
# 11   10000  30000  1106.187426
# 12   50000  30000  1081.836857
# 13   30000  70000  1063.495211
# 14   10000  70000  1058.727917
# 15   10000  70000  1058.007341
# 16   10000  70000  1057.192843
# 17   10000  30000  1048.527396
# 18   10000  30000  1047.029884
# 19  100000  70000  1045.001002
# 20   30000  70000  1040.833493
# 21   30000  70000  1040.553409
# 22   30000  70000  1040.478973
# 23   10000  30000  1040.462360
# 24   30000  70000  1040.444446
# 25   30000  30000  1026.059975
# 26  100000  30000  1004.682204
# 27  100000  30000   992.461882
# 28   50000  30000   981.500260
# 29  200000  30000   981.461981
# 30   50000  30000   945.361267
# 31   50000  30000   944.498177
# 32   50000  70000   896.620755
# 33   50000  70000   858.739262
# 34  100000  70000   854.593663
# 35   50000  70000   824.090608
# 36  100000  70000   814.921702
# 37   50000  30000   814.812333
# 38   50000  30000   808.355503
# 39  100000  30000   781.518457
# 40   50000  70000   764.897020
# dow_jones d buzz unique subsets: 14
# ntop: 7
#                                                                                                                                                                     sub  \
# 0                                                                                           trmi3_etf3_news_buzz_dohlca_ddiff(1)_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 1  trmi3_etf3_social_buzz_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 2                                                          trmi3_etf3_social_buzz_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 3                                                          trmi3_etf3_social_buzz_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 4  trmi3_etf3_social_buzz_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 5                                                            trmi3_etf3_news_buzz_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 6                                                                                                  trmi3_etf3_social_buzz_dohlca_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
#
#       win    knn         max
# 0   10000  30000  864.920199
# 1  200000  30000  820.123678
# 2   10000  30000  705.844329
# 3   30000  30000  699.103613
# 4   50000  30000  675.690337
# 5   30000  30000  648.226021
# 6   30000  30000  647.447499
# dow_jones d nonbuzz unique subsets: 10
# ntop: 5
#                                                                                                                                                                                  sub  \
# 0                                                                                                           trmi3_etf3_social_forecast_dc_fundamental_sentiment_mkt3_bank_bond_stock
# 1                                                                                                           trmi3_etf3_social_forecast_dc_fundamental_sentiment_mkt3_bank_bond_stock
# 2                                                                                                           trmi3_etf3_social_forecast_dc_fundamental_sentiment_mkt3_bank_bond_stock
# 3             trmi3_etf3_news_forecast_dc_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)_fundamental_sentiment_mkt3_bank_bond_stock
# 4  trmi3_etf3_news_forecast_dc_dffd(0.200000,0.010000)_dwrxmx(-1)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)_fundamental_sentiment_mkt3_bank_bond_stock
#
#      win    knn         max
# 0  10000  30000  971.700853
# 1  30000  30000  962.708192
# 2  50000  30000  869.243918
# 3  50000  30000  734.430939
# 4  50000  30000  734.430939

# %% [markdown]
# ### NTop Common Across Assets

# %%
d_pba = reduce(np.intersect1d, (ntop_common_dfs[[asset, 'd', 'pba']] for asset in assets))
display(len(d_pba), d_pba)
# Out:
# 6
# array(['pba_dlh_dlogret',
#        'pba_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)',
#        'pba_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)',
#        'pba_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)',
#        'pba_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)',
#        'pba_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)'], dtype=object)

# %%
d_pba_common_axe = list(set(map(extract_axe_name, d_pba)))
display(d_pba_common_axe)

d_pba_minimal = []
for axe in d_pba_common_axe:
    d_pba_minimal.extend(reduce(np.intersect1d, (ntop_common_subset(asset, 'd', 'pba', axe, use_clf_reg=False, ntop=.05) for asset in assets)))
display(d_pba_minimal)
# Out:
# ['dwrmx', 'dlogret', 'dffd', 'dwrzn', 'dwrod', 'dwrpt']
# ntop: 10
# ntop: 10
# ntop: 10
# ntop: 10
# ntop: 1
# ntop: 1
# ntop: 1
# ntop: 1
# ntop: 10
# ntop: 10
# ntop: 10
# ntop: 10
# ntop: 10
# ntop: 10
# ntop: 10
# ntop: 10
# ntop: 10
# ntop: 10
# ntop: 10
# ntop: 10
# ntop: 10
# ntop: 10
# ntop: 10
# ntop: 10
# ['pba_avgPrice_pba_dohlca_dwrmx(240)',
#  'pba_close_pba_dohlca_dwrmx(240)',
#  'pba_high_pba_dohlca_dwrmx(240)',
#  'pba_low_pba_dohlca_dwrmx(240)',
#  'pba_lh_pba_dlh_dlogret',
#  'pba_avgPrice_pba_dohlca_dwrzn(240)',
#  'pba_close_pba_dohlca_dwrzn(240)',
#  'pba_avgPrice_pba_dohlca_dwrod(240)',
#  'pba_high_pba_dohlca_dwrod(240)',
#  'pba_open_pba_dohlca_dwrod(240)',
#  'pba_avgPrice_pba_dohlca_dwrpt(240)',
#  'pba_close_pba_dohlca_dwrpt(240)',
#  'pba_high_pba_dohlca_dwrpt(240)',
#  'pba_low_pba_dohlca_dwrpt(240)']

# %%
d_vol = reduce(np.intersect1d, (ntop_common_dfs[[asset, 'd', 'vol']] for asset in assets))
display(len(d_vol), d_vol)
# Out:
# 6
# array(['vol_dohlca',
#        'vol_dohlca_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)',
#        'vol_dohlca_dwrmx(-1)_dwrmx(20)_dwrmx(240)_dwrmx(5)',
#        'vol_dohlca_dwrod(-1)_dwrod(20)_dwrod(240)_dwrod(5)',
#        'vol_dohlca_dwrpt(-1)_dwrpt(20)_dwrpt(240)_dwrpt(5)',
#        'vol_dohlca_dwrzn(-1)_dwrzn(20)_dwrzn(240)_dwrzn(5)'], dtype=object)

# %%
d_vol_common_axe = list(set(map(extract_axe_name, d_vol)))
display(d_vol_common_axe)

d_vol_minimal = []
for axe in d_vol_common_axe:
    d_vol_minimal.extend(reduce(np.intersect1d, (ntop_common_subset(asset, 'd', 'vol', axe, ntop=.2) for asset in assets)))
display(d_vol_minimal)
# Out:
# ['dwrmx', 'dffd', 'dwrzn', 'dwrod', 'dwrpt', 'dohlca']
# ntop: 40
# ntop: 40
# ntop: 40
# ntop: 40
# ntop: 40
# ntop: 40
# ntop: 40
# ntop: 40
# ntop: 40
# ntop: 40
# ntop: 40
# ntop: 40
# ntop: 40
# ntop: 40
# ntop: 40
# ntop: 40
# ntop: 40
# ntop: 40
# ntop: 40
# ntop: 40
# ntop: 10
# ntop: 10
# ntop: 10
# ntop: 10
# ['vol_avgPrice_vol_dohlca_dwrmx(-1)',
#  'vol_close_vol_dohlca_dwrmx(-1)',
#  'vol_high_vol_dohlca_dwrmx(-1)',
#  'vol_low_vol_dohlca_dwrmx(-1)',
#  'vol_open_vol_dohlca_dwrmx(-1)',
#  'vol_open_vol_dohlca_dwrmx(240)',
#  'vol_avgPrice_vol_dohlca_dffd(0.200000,0.010000)',
#  'vol_avgPrice_vol_dohlca_dffd(0.400000,0.010000)',
#  'vol_close_vol_dohlca_dffd(0.200000,0.010000)',
#  'vol_close_vol_dohlca_dffd(0.400000,0.010000)',
#  'vol_high_vol_dohlca_dffd(0.200000,0.010000)',
#  'vol_low_vol_dohlca_dffd(0.200000,0.010000)',
#  'vol_low_vol_dohlca_dffd(0.400000,0.010000)',
#  'vol_open_vol_dohlca_dffd(0.200000,0.010000)',
#  'vol_avgPrice_vol_dohlca_dwrzn(-1)',
#  'vol_close_vol_dohlca_dwrzn(-1)',
#  'vol_high_vol_dohlca_dwrzn(-1)',
#  'vol_high_vol_dohlca_dwrzn(240)',
#  'vol_low_vol_dohlca_dwrzn(-1)',
#  'vol_open_vol_dohlca_dwrzn(-1)',
#  'vol_avgPrice_vol_dohlca_dwrod(-1)',
#  'vol_close_vol_dohlca_dwrod(-1)',
#  'vol_high_vol_dohlca_dwrod(-1)',
#  'vol_low_vol_dohlca_dwrod(-1)',
#  'vol_open_vol_dohlca_dwrod(-1)',
#  'vol_avgPrice_vol_dohlca_dwrpt(-1)',
#  'vol_close_vol_dohlca_dwrpt(-1)',
#  'vol_high_vol_dohlca_dwrpt(-1)',
#  'vol_low_vol_dohlca_dwrpt(-1)',
#  'vol_open_vol_dohlca_dwrpt(-1)',
#  'vol_open_vol_dohlca_dwrpt(240)',
#  'vol_avgPrice_vol_dohlca',
#  'vol_close_vol_dohlca',
#  'vol_high_vol_dohlca',
#  'vol_open_vol_dohlca']

# %%
d_buzz = reduce(np.intersect1d, (ntop_common_dfs[[asset, 'd', 'buzz']] for asset in assets))
display(len(d_buzz), d_buzz)

# %%
d_buzz_common_axe = list(set(map(extract_axe_name, d_buzz)))
display(d_buzz_common_axe)

d_buzz_minimal = []
for axe in d_buzz_common_axe:
    d_buzz_minimal.extend(reduce(np.intersect1d, (ntop_common_subset(asset, 'd', 'buzz', axe, ntop=.05) for asset in assets)))
display(d_buzz_minimal)
# Out:
# ['dwrmx', 'dffd', 'dwrzn', 'dwrod', 'ddiff', 'dwrpt']
# ntop: 80
# ntop: 80
# ntop: 80
# ntop: 80
# ntop: 80
# ntop: 80
# ntop: 80
# ntop: 80
# ntop: 80
# ntop: 80
# ntop: 80
# ntop: 80
# ntop: 80
# ntop: 80
# ntop: 80
# ntop: 80
# ntop: 20
# ntop: 20
# ntop: 20
# ntop: 20
# ntop: 80
# ntop: 80
# ntop: 80
# ntop: 80
# ['etf3_buzz_N_open_trmi3_etf3_news_buzz_dohlca_dwrmx(-1)',
#  'etf3_buzz_S_avgPrice_trmi3_etf3_social_buzz_dohlca_dwrmx(240)',
#  'etf3_buzz_S_high_trmi3_etf3_social_buzz_dohlca_dwrmx(-1)',
#  'mkt3_bondBuzz_N_close_trmi3_mkt3_news_bondBuzz_dohlca_dwrmx(-1)',
#  'mkt3_stockIndexBuzz_S_close_trmi3_mkt3_social_stockIndexBuzz_dohlca_dwrmx(-1)',
#  'etf3_buzz_N_avgPrice_trmi3_etf3_news_buzz_dohlca_dffd(0.800000,0.010000)',
#  'etf3_buzz_N_close_trmi3_etf3_news_buzz_dohlca_dffd(0.200000,0.010000)',
#  'etf3_buzz_N_high_trmi3_etf3_news_buzz_dohlca_dffd(0.200000,0.010000)',
#  'etf3_buzz_N_low_trmi3_etf3_news_buzz_dohlca_dffd(0.600000,0.010000)',
#  'etf3_buzz_N_open_trmi3_etf3_news_buzz_dohlca_dffd(0.800000,0.010000)',
#  'mkt3_bondBuzz_S_avgPrice_trmi3_mkt3_social_bondBuzz_dohlca_dffd(0.400000,0.010000)',
#  'mkt3_bondBuzz_S_close_trmi3_mkt3_social_bondBuzz_dohlca_dffd(0.600000,0.010000)',
#  'mkt3_ratesBuzz_S_high_trmi3_mkt3_social_ratesBuzz_dohlca_dffd(0.800000,0.010000)',
#  'etf3_buzz_N_close_trmi3_etf3_news_buzz_dohlca_dwrzn(5)',
#  'mkt3_bondBuzz_S_close_trmi3_mkt3_social_bondBuzz_dohlca_dwrzn(20)',
#  'mkt3_ratesBuzz_N_close_trmi3_mkt3_news_ratesBuzz_dohlca_dwrzn(-1)',
#  'mkt3_stockIndexBuzz_N_open_trmi3_mkt3_news_stockIndexBuzz_dohlca_dwrzn(240)',
#  'etf3_buzz_S_high_trmi3_etf3_social_buzz_dohlca_dwrod(240)',
#  'mkt3_bondBuzz_S_high_trmi3_mkt3_social_bondBuzz_dohlca_dwrod(-1)',
#  'mkt3_bondBuzz_S_open_trmi3_mkt3_social_bondBuzz_dohlca_dwrod(-1)',
#  'mkt3_ratesBuzz_N_high_trmi3_mkt3_news_ratesBuzz_dohlca_dwrod(-1)',
#  'mkt3_ratesBuzz_S_avgPrice_trmi3_mkt3_social_ratesBuzz_dohlca_dwrod(-1)',
#  'mkt3_stockIndexBuzz_S_low_trmi3_mkt3_social_stockIndexBuzz_dohlca_dwrod(240)',
#  'mkt3_ratesBuzz_S_low_trmi3_mkt3_social_ratesBuzz_dohlca_ddiff(1)',
#  'etf3_buzz_N_open_trmi3_etf3_news_buzz_dohlca_dwrpt(-1)',
#  'etf3_buzz_S_avgPrice_trmi3_etf3_social_buzz_dohlca_dwrpt(240)',
#  'etf3_buzz_S_high_trmi3_etf3_social_buzz_dohlca_dwrpt(-1)',
#  'mkt3_bondBuzz_N_close_trmi3_mkt3_news_bondBuzz_dohlca_dwrpt(-1)',
#  'mkt3_stockIndexBuzz_S_close_trmi3_mkt3_social_stockIndexBuzz_dohlca_dwrpt(-1)']

# %%
d_nonbuzz = reduce(np.intersect1d, (ntop_common_dfs[[asset, 'd', 'nonbuzz']] for asset in assets))
display(len(d_nonbuzz), d_nonbuzz)
# Out:
# 6
# array(['trmi3_etf3_news_forecast_dc_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)_fundamental_sentiment_mkt3_bank_bond_stock',
#        'trmi3_etf3_news_forecast_dc_dffd(0.200000,0.010000)_dwrxmx(-1)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)_fundamental_sentiment_mkt3_bank_bond_stock',
#        'trmi3_etf3_news_forecast_dc_fundamental_sentiment_mkt3_bank_bond_stock',
#        'trmi3_etf3_social_forecast_dc_dffd(0.200000,0.010000)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)_fundamental_sentiment_mkt3_bank_bond_stock',
#        'trmi3_etf3_social_forecast_dc_dffd(0.200000,0.010000)_dwrxmx(-1)_dffd(0.400000,0.010000)_dffd(0.600000,0.010000)_dffd(0.800000,0.010000)_fundamental_sentiment_mkt3_bank_bond_stock',
#        'trmi3_etf3_social_forecast_dc_fundamental_sentiment_mkt3_bank_bond_stock'],
#       dtype=object)

# %%
d_nonbuzz_common_axe = list(set(map(extract_axe_name, d_nonbuzz)))
display(d_nonbuzz_common_axe)

d_nonbuzz_minimal = []
for axe in d_nonbuzz_common_axe:
    d_nonbuzz_minimal.extend(reduce(np.intersect1d, (ntop_common_subset(asset, 'd', 'nonbuzz', axe, ntop=.55) for asset in assets)))
display(d_nonbuzz_minimal)
# Out:
# ['dffd', 'stock']
# ntop: 2596
# ntop: 2596
# ntop: 2596
# ntop: 2596
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-5c5ebe85b426> in <module>
#       4 d_nonbuzz_minimal = []
#       5 for axe in d_nonbuzz_common_axe:
# ----> 6     d_nonbuzz_minimal.extend(reduce(np.intersect1d, (ntop_common_subset(asset, 'd', 'nonbuzz', axe, ntop=.55) for asset in assets)))
#       7 display(d_nonbuzz_minimal)
#
# <ipython-input-92-5c5ebe85b426> in <genexpr>(.0)
#       4 d_nonbuzz_minimal = []
#       5 for axe in d_nonbuzz_common_axe:
# ----> 6     d_nonbuzz_minimal.extend(reduce(np.intersect1d, (ntop_common_subset(asset, 'd', 'nonbuzz', axe, ntop=.55) for asset in assets)))
#       7 display(d_nonbuzz_minimal)
#
# <ipython-input-43-ac5eddb88c0c> in ntop_common_subset(asset, freq, src, sub, use_clf_reg, ntop, show)
#       1 def ntop_common_subset(asset, freq, src, sub, use_clf_reg=False, ntop=.2, show=False):
# ----> 2     freq_src_sub_df = pd.concat([mi[kc] for kc in list(mi.childkeys([asset, freq, src, sub, 'mi']))])
#       3     ntop = int(len(freq_src_sub_df) * ntop) if (is_type(ntop, float)) else ntop
#       4     #print('{} {} {} unique subsets: {}'.format(asset, freq, src, len(freq_src_df.reset_index()['sub'].unique())))
#       5     print('ntop: {}'.format(ntop))
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     279         verify_integrity=verify_integrity,
#     280         copy=copy,
# --> 281         sort=sort,
#     282     )
#     283
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     327
#     328         if len(objs) == 0:
# --> 329             raise ValueError("No objects to concatenate")
#     330
#     331         if keys is None:
#
# ValueError: No objects to concatenate

# %% [markdown]
# best ntop common for pba, vol, buzz: dffd, dwrmx, dwrod, dwrpt, dwrzn
#
# best ntop commo for nonbuzz: dffd
#
# In general regardless of the source or asset the following transforms rank highest for mutual information with daily data:
# * dffd
# * dwrmx
# * dwrod
# * dwrpt
# * dwrzn
#
# The fact that these performed the best isn't too surprising. The following transforms did not peform consistently well over all assets and sources, but might peform well with a more powerful model / test for a particular source:
#
# * dohlca (vol, pba)
# * dlh_logret (vol, pba)
# * ddiff(1) (vol, pba)
# * dc (nonbuzz)

# %%
d_minimal_set = d_pba_minimal + d_vol_minimal + d_buzz_minimal + d_nonbuzz_minimal

# %%
common_axefiles_set = ['dffd', 'dwrmx', 'dwrod', 'dwrpt', 'dwrzn']

# %%
extra_axefiles_set = ['dohlca', 'dlogret', 'ddiff', 'dc']
common_extra_axefiles_set = common_axefiles_set + extra_axefiles_set

# %% [markdown]
# ## Hourly

# %%
freq = 'h'
ntop_common_dfs = NestedDefaultDict()
for asset, src in product(assets, srcs):
    if (src == 'nonbuzz'): continue
    ntop_common_dfs[[asset, freq, src]] = ntop_common(asset, freq, src)
# Out:
# sp_500 h pba unique subsets: 19
# ntop: 19
#                                   sub     win    knn         max
# 0                          pba_hohlca   10000  30000  882.711090
# 1                          pba_hohlca   30000  70000  853.507221
# 2                          pba_hohlca   10000  70000  806.086291
# 3                     pba_hohlca_hdzn   10000  30000  694.282727
# 4                          pba_hohlca   50000  70000  689.934422
# 5                          pba_hohlca  200000  70000  662.315487
# 6            pba_hohlca_hdmx_hduni(8)   50000  30000  622.204770
# 7                          pba_hohlca   30000  30000  618.992181
# 8            pba_hohlca_hdzn_hdgau(8)  200000  30000  605.138457
# 9                          pba_hohlca  200000  30000  603.134296
# 10  pba_hlh_hlogret_hdod_hret_hspread   10000  30000  594.154950
# 11                         pba_hohlca  100000  70000  585.829792
# 12           pba_hohlca_hdmx_hduni(8)  200000  30000  568.265385
# 13                         pba_hohlca  100000  30000  567.904956
# 14                         pba_hohlca   50000  30000  532.760242
# 15                    pba_hohlca_hdzn   30000  30000  531.736547
# 16                    pba_hohlca_hdzn   50000  30000  521.906839
# 17           pba_hohlca_hdzn_hdgau(8)   30000  30000  507.434408
# 18                    pba_hohlca_hdmx   50000  30000  502.838544
# sp_500 h vol unique subsets: 19
# ntop: 19
#                                            sub     win    knn          max
# 0                                   vol_hohlca   10000  30000  1372.839991
# 1                                   vol_hohlca   50000  30000  1224.022436
# 2                                   vol_hohlca   50000  70000  1213.051313
# 3                                   vol_hohlca   10000  70000  1206.210251
# 4                                   vol_hohlca   30000  30000  1140.671530
# 5                                   vol_hohlca  100000  30000  1017.106089
# 6                                   vol_hohlca   30000  70000   940.733767
# 7                                   vol_hohlca  200000  30000   862.486170
# 8                                   vol_hohlca  200000  70000   789.705835
# 9                                   vol_hohlca  100000  70000   789.420277
# 10                             vol_hohlca_hdod  100000  30000   720.388845
# 11                    vol_hohlca_hdzn_hdgau(8)  100000  30000   678.789375
# 12  vol_hoc_hlogret_hdmx_hduni(8)_hret_hspread  200000  30000   641.117206
# 13                             vol_hohlca_hdzn   30000  30000   581.572536
# 14           vol_hoc_hlogret_hdpt_hret_hspread   50000  30000   573.412490
# 15           vol_hoc_hlogret_hdmx_hret_hspread   50000  30000   567.857074
# 16                             vol_hohlca_hdzn  200000  30000   540.440904
# 17                             vol_hohlca_hdod  200000  30000   530.071852
# 18  vol_hlh_hlogret_hdzn_hdgau(8)_hret_hspread  100000  30000   526.091510
# sp_500 h buzz unique subsets: 14
# ntop: 14
#                                                                                    sub  \
# 0              trmi3_etf3_news_buzz_hohlca_hdzn_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 1            trmi3_etf3_social_buzz_hohlca_hdod_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 2              trmi3_etf3_news_buzz_hohlca_hdzn_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 3            trmi3_etf3_social_buzz_hohlca_hdzn_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 4                 trmi3_etf3_social_buzz_hohlca_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 5            trmi3_etf3_social_buzz_hohlca_hdpt_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 6                 trmi3_etf3_social_buzz_hohlca_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 7            trmi3_etf3_social_buzz_hohlca_hdmx_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 8            trmi3_etf3_social_buzz_hohlca_hdod_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 9   trmi3_etf3_social_buzz_hohlca_hdzn_hdgau(8)_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 10           trmi3_etf3_social_buzz_hohlca_hdzn_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 11                  trmi3_etf3_news_buzz_hohlca_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 12             trmi3_etf3_news_buzz_hohlca_hdpt_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 13                  trmi3_etf3_news_buzz_hohlca_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
#
#        win    knn         max
# 0   200000  30000  614.978553
# 1    30000  30000  609.355249
# 2    50000  30000  585.782128
# 3    30000  30000  557.666496
# 4   200000  30000  542.145758
# 5   200000  30000  538.138824
# 6    30000  30000  534.743376
# 7   200000  30000  529.428671
# 8   200000  30000  528.192746
# 9   200000  30000  524.821318
# 10   50000  30000  512.258707
# 11   50000  30000  509.975678
# 12   30000  30000  506.152836
# 13   10000  30000  506.004354
# russell_2000 h pba unique subsets: 19
# ntop: 19
#                                   sub     win    knn          max
# 0                          pba_hohlca   10000  70000  1338.798845
# 1                          pba_hohlca   50000  30000  1322.981738
# 2                          pba_hohlca   10000  30000  1284.511030
# 3                          pba_hohlca   50000  70000  1221.640131
# 4                          pba_hohlca  200000  70000  1165.960403
# 5                          pba_hohlca   30000  70000  1100.217796
# 6                          pba_hohlca   30000  30000  1094.465045
# 7                          pba_hohlca  200000  30000  1060.699964
# 8                          pba_hohlca  100000  30000   927.548550
# 9                          pba_hohlca  100000  70000   850.813623
# 10                    pba_hohlca_hdzn   10000  30000   778.379327
# 11  pba_hoc_hlogret_hdzn_hret_hspread   50000  30000   699.300618
# 12           pba_hohlca_hdmx_hduni(8)   30000  30000   649.431195
# 13           pba_hohlca_hdmx_hduni(8)  200000  30000   631.842866
# 14           pba_hohlca_hdzn_hdgau(8)  100000  30000   606.088928
# 15                    pba_hohlca_hdod   10000  30000   583.214336
# 16                    pba_hohlca_hdmx   10000  30000   572.034483
# 17                    pba_hohlca_hdpt   10000  30000   543.735303
# 18  pba_hoc_hlogret_hdzn_hret_hspread   30000  30000   501.477274
# russell_2000 h vol unique subsets: 19
# ntop: 19
#                                            sub     win    knn          max
# 0                                   vol_hohlca   30000  30000  1779.068050
# 1                                   vol_hohlca   10000  30000  1693.814985
# 2                                   vol_hohlca   10000  70000  1557.376411
# 3                                   vol_hohlca   30000  70000  1380.793478
# 4                                   vol_hohlca   50000  30000  1351.772805
# 5                                   vol_hohlca  100000  30000  1260.713167
# 6                                   vol_hohlca  100000  70000  1205.580185
# 7                                   vol_hohlca   50000  70000  1177.567835
# 8                                   vol_hohlca  200000  30000  1008.627206
# 9                                   vol_hohlca  200000  70000   920.274028
# 10                             vol_hohlca_hdzn   50000  30000   658.120548
# 11                             vol_hohlca_hdpt   30000  30000   627.453473
# 12                             vol_hohlca_hdmx   30000  30000   625.965445
# 13                             vol_hohlca_hdmx  200000  30000   567.695774
# 14  vol_hlh_hlogret_hdmx_hduni(8)_hret_hspread  200000  30000   561.346281
# 15  vol_hoc_hlogret_hdmx_hduni(8)_hret_hspread  100000  30000   556.765552
# 16           vol_hlh_hlogret_hdzn_hret_hspread  200000  30000   554.131781
# 17                             vol_hohlca_hdpt  200000  30000   547.044806
# 18                    vol_hohlca_hdmx_hduni(8)  200000  30000   523.949618
# russell_2000 h buzz unique subsets: 14
# ntop: 14
#                                                                                    sub  \
# 0                   trmi3_etf3_news_buzz_hohlca_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 1                   trmi3_etf3_news_buzz_hohlca_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 2                   trmi3_etf3_news_buzz_hohlca_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 3                 trmi3_etf3_social_buzz_hohlca_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 4                 trmi3_etf3_social_buzz_hohlca_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 5                 trmi3_etf3_social_buzz_hohlca_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 6                   trmi3_etf3_news_buzz_hohlca_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 7                   trmi3_etf3_news_buzz_hohlca_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 8                 trmi3_etf3_social_buzz_hohlca_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 9                 trmi3_etf3_social_buzz_hohlca_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 10                trmi3_etf3_social_buzz_hohlca_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 11                  trmi3_etf3_news_buzz_hohlca_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 12  trmi3_etf3_social_buzz_hohlca_hdmx_hduni(8)_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 13  trmi3_etf3_social_buzz_hohlca_hdzn_hdgau(8)_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
#
#        win    knn          max
# 0    50000  30000  1129.461228
# 1    30000  30000   952.144922
# 2    10000  30000   839.539643
# 3    10000  30000   791.011014
# 4   200000  30000   755.023118
# 5    50000  30000   731.942167
# 6    50000  70000   727.864173
# 7    30000  70000   695.729177
# 8    30000  70000   641.019966
# 9    10000  70000   626.839850
# 10  200000  70000   621.900268
# 11   10000  70000   606.477648
# 12  200000  30000   605.410153
# 13  200000  30000   597.170791
# nasdaq_100 h pba unique subsets: 19
# ntop: 19
#                                            sub     win    knn         max
# 0                     pba_hohlca_hdmx_hduni(8)   30000  30000  743.854252
# 1                              pba_hohlca_hdzn   50000  30000  605.306208
# 2                              pba_hohlca_hdpt  100000  30000  601.838170
# 3                              pba_hohlca_hdmx  100000  30000  584.803072
# 4            pba_hoc_hlogret_hdzn_hret_hspread   10000  30000  552.540777
# 5                     pba_hohlca_hdmx_hduni(8)  100000  30000  548.275780
# 6                     pba_hohlca_hdzn_hdgau(8)  200000  30000  545.719236
# 7                              pba_hohlca_hdzn   30000  30000  538.391371
# 8                              pba_hohlca_hdmx   50000  30000  528.944866
# 9   pba_hoc_hlogret_hdzn_hdgau(8)_hret_hspread   30000  30000  527.742791
# 10                             pba_hohlca_hdpt   50000  30000  524.068178
# 11                             pba_hohlca_hdzn   10000  30000  520.619860
# 12  pba_hoc_hlogret_hdmx_hduni(8)_hret_hspread   30000  30000  520.567996
# 13                                  pba_hohlca  200000  30000  520.092312
# 14           pba_hoc_hlogret_hdmx_hret_hspread   10000  30000  519.785049
# 15           pba_hoc_hlogret_hdpt_hret_hspread   10000  30000  515.500378
# 16                    pba_hohlca_hdmx_hduni(8)  200000  30000  494.530289
# 17                    pba_hohlca_hdzn_hdgau(8)   10000  30000  489.154305
# 18           pba_hlh_hlogret_hdzn_hret_hspread  200000  30000  480.911613
# nasdaq_100 h vol unique subsets: 19
# ntop: 19
#                                            sub     win    knn          max
# 0                                   vol_hohlca   50000  30000  1535.497154
# 1                                   vol_hohlca   10000  30000  1452.099734
# 2                                   vol_hohlca   30000  30000  1308.109248
# 3                                   vol_hohlca   10000  70000  1123.377805
# 4                                   vol_hohlca  100000  30000  1013.009873
# 5                                   vol_hohlca   30000  70000   989.392634
# 6                              vol_hohlca_hdmx   10000  30000   901.421110
# 7                              vol_hohlca_hdpt   10000  30000   882.205841
# 8                                   vol_hohlca  200000  30000   854.987263
# 9                                   vol_hohlca   50000  70000   811.930637
# 10                                  vol_hohlca  100000  70000   756.791810
# 11           vol_hlh_hlogret_hdod_hret_hspread   30000  30000   728.676831
# 12                                  vol_hohlca  200000  70000   660.815804
# 13           vol_hoc_hlogret_hdzn_hret_hspread   50000  30000   614.425724
# 14                    vol_hohlca_hdzn_hdgau(8)  200000  30000   592.595754
# 15  vol_hlh_hlogret_hdzn_hdgau(8)_hret_hspread  200000  30000   568.038932
# 16                    vol_hohlca_hdzn_hdgau(8)   30000  30000   556.751723
# 17  vol_hlh_hlogret_hdzn_hdgau(8)_hret_hspread   50000  30000   550.696536
# 18                    vol_hohlca_hdzn_hdgau(8)  100000  30000   536.148719
# nasdaq_100 h buzz unique subsets: 14
# ntop: 14
#                                                                                    sub  \
# 0              trmi3_etf3_news_buzz_hohlca_hdzn_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 1                 trmi3_etf3_social_buzz_hohlca_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 2                   trmi3_etf3_news_buzz_hohlca_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 3              trmi3_etf3_news_buzz_hohlca_hdpt_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 4              trmi3_etf3_news_buzz_hohlca_hdmx_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 5            trmi3_etf3_social_buzz_hohlca_hdod_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 6            trmi3_etf3_social_buzz_hohlca_hdpt_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 7            trmi3_etf3_social_buzz_hohlca_hdmx_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 8            trmi3_etf3_social_buzz_hohlca_hdmx_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 9            trmi3_etf3_social_buzz_hohlca_hdpt_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 10                trmi3_etf3_social_buzz_hohlca_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 11                  trmi3_etf3_news_buzz_hohlca_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 12           trmi3_etf3_social_buzz_hohlca_hdzn_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 13  trmi3_etf3_social_buzz_hohlca_hdzn_hdgau(8)_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
#
#        win    knn         max
# 0    10000  30000  644.078230
# 1    50000  30000  629.817370
# 2    30000  30000  622.562370
# 3    30000  30000  567.925301
# 4    30000  30000  559.317782
# 5    10000  30000  557.521221
# 6    50000  30000  556.182888
# 7    50000  30000  547.725258
# 8   100000  30000  542.327867
# 9   100000  30000  541.415830
# 10  200000  30000  540.703815
# 11   50000  30000  533.194399
# 12   30000  30000  524.230286
# 13   10000  30000  518.074256
# dow_jones h pba unique subsets: 19
# ntop: 19
#                                            sub     win    knn          max
# 0                                   pba_hohlca   10000  30000  1049.255013
# 1                                   pba_hohlca   10000  70000   869.560063
# 2                                   pba_hohlca   30000  30000   837.219388
# 3                              pba_hohlca_hdmx   50000  30000   777.844865
# 4                                   pba_hohlca   30000  70000   774.141322
# 5                              pba_hohlca_hdpt   50000  30000   762.615100
# 6                                   pba_hohlca   50000  30000   723.221916
# 7   pba_hoc_hlogret_hdzn_hdgau(8)_hret_hspread  200000  30000   663.401609
# 8                                   pba_hohlca   50000  70000   655.249854
# 9                              pba_hohlca_hdzn   10000  30000   627.139150
# 10                                  pba_hohlca  100000  70000   611.625618
# 11                             pba_hohlca_hdpt   10000  30000   608.068187
# 12                                  pba_hohlca  100000  30000   586.575720
# 13           pba_hoc_hlogret_hdpt_hret_hspread   10000  30000   579.520665
# 14           pba_hoc_hlogret_hdmx_hret_hspread   10000  30000   578.505022
# 15                             pba_hohlca_hdmx   10000  30000   574.834568
# 16                             pba_hohlca_hdmx  100000  30000   559.354528
# 17                             pba_hohlca_hdpt  100000  30000   551.060259
# 18           pba_hlh_hlogret_hdpt_hret_hspread   30000  30000   535.632327
# dow_jones h vol unique subsets: 19
# ntop: 19
#                                            sub     win    knn          max
# 0                                   vol_hohlca   30000  30000  1402.938813
# 1                                   vol_hohlca   10000  30000  1163.016126
# 2                                   vol_hohlca   30000  70000  1151.158427
# 3                                   vol_hohlca   10000  70000  1118.116141
# 4                                   vol_hohlca   50000  30000   997.471273
# 5                                   vol_hohlca   50000  70000   897.003107
# 6                                   vol_hohlca  100000  30000   750.983049
# 7                                   vol_hohlca  100000  70000   737.437219
# 8                              vol_hohlca_hdod   30000  30000   721.444536
# 9                                   vol_hohlca  200000  30000   618.818765
# 10  vol_hoc_hlogret_hdmx_hduni(8)_hret_hspread  100000  30000   616.372671
# 11                                  vol_hohlca  200000  70000   579.705199
# 12                             vol_hohlca_hdpt  200000  30000   574.716869
# 13           vol_hoc_hlogret_hdod_hret_hspread  100000  30000   574.556811
# 14                             vol_hohlca_hdzn  200000  30000   564.669112
# 15                             vol_hohlca_hdmx  200000  30000   560.472546
# 16  vol_hlh_hlogret_hdmx_hduni(8)_hret_hspread  200000  30000   534.086723
# 17  vol_hlh_hlogret_hdmx_hduni(8)_hret_hspread   30000  30000   521.850314
# 18                    vol_hohlca_hdmx_hduni(8)   30000  30000   510.742457
# dow_jones h buzz unique subsets: 14
# ntop: 14
#                                                                                    sub  \
# 0   trmi3_etf3_social_buzz_hohlca_hdzn_hdgau(8)_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 1                 trmi3_etf3_social_buzz_hohlca_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 2                 trmi3_etf3_social_buzz_hohlca_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 3   trmi3_etf3_social_buzz_hohlca_hdzn_hdgau(8)_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 4                 trmi3_etf3_social_buzz_hohlca_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 5                   trmi3_etf3_news_buzz_hohlca_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 6            trmi3_etf3_social_buzz_hohlca_hdzn_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 7     trmi3_etf3_news_buzz_hohlca_hdmx_hduni(8)_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 8   trmi3_etf3_social_buzz_hohlca_hdmx_hduni(8)_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 9              trmi3_etf3_news_buzz_hohlca_hdod_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 10                trmi3_etf3_social_buzz_hohlca_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 11                  trmi3_etf3_news_buzz_hohlca_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 12           trmi3_etf3_social_buzz_hohlca_hdod_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
# 13    trmi3_etf3_news_buzz_hohlca_hdzn_hdgau(8)_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz
#
#        win    knn         max
# 0   100000  30000  728.930797
# 1   200000  30000  704.940471
# 2   100000  30000  690.629150
# 3    10000  30000  676.266578
# 4    30000  30000  647.032484
# 5    30000  30000  618.521139
# 6   200000  30000  581.741274
# 7   100000  30000  565.058937
# 8    30000  30000  561.240531
# 9    30000  30000  558.795627
# 10   10000  30000  558.438388
# 11   10000  30000  558.001214
# 12  100000  30000  538.780347
# 13   30000  30000  507.501960

# %% [markdown]
# ### NTop Common Across Assets

# %%
h_pba = reduce(np.intersect1d, (ntop_common_dfs[[asset, 'h', 'pba']] for asset in assets))
display(len(h_pba), h_pba)
# Out:
# 3
# array(['pba_hohlca', 'pba_hohlca_hdmx', 'pba_hohlca_hdzn'], dtype=object)

# %%
h_pba_common_axe = list(set(map(extract_axe_name, h_pba)))
display(h_pba_common_axe)

h_pba_minimal = []
for axe in h_pba_common_axe:
    h_pba_minimal.extend(reduce(np.intersect1d, (ntop_common_subset(asset, 'h', 'pba', axe) for asset in assets)))
display(h_pba_minimal)
# Out:
# ['hdzn', 'hdmx', 'hohlca']
# ntop: 88
# ntop: 88
# ntop: 88
# ntop: 88
# ntop: 88
# ntop: 88
# ntop: 88
# ntop: 88
# ntop: 40
# ntop: 40
# ntop: 40
# ntop: 40
# ['pba_avgPrice_pba_hohlca_hdzn',
#  'pba_close_pba_hohlca_hdzn',
#  'pba_high_pba_hohlca_hdzn',
#  'pba_lh_pba_hlh_hlogret_hdzn',
#  'pba_lh_pba_hlh_hret_hdzn',
#  'pba_lh_pba_hlh_hspread_hdzn',
#  'pba_low_pba_hohlca_hdzn',
#  'pba_oc_pba_hoc_hlogret_hdzn',
#  'pba_oc_pba_hoc_hret_hdzn',
#  'pba_oc_pba_hoc_hspread_hdzn',
#  'pba_open_pba_hohlca_hdzn',
#  'pba_avgPrice_pba_hohlca_hdmx',
#  'pba_close_pba_hohlca_hdmx',
#  'pba_high_pba_hohlca_hdmx',
#  'pba_lh_pba_hlh_hlogret_hdmx',
#  'pba_lh_pba_hlh_hret_hdmx',
#  'pba_lh_pba_hlh_hspread_hdmx',
#  'pba_low_pba_hohlca_hdmx',
#  'pba_oc_pba_hoc_hlogret_hdmx',
#  'pba_oc_pba_hoc_hret_hdmx',
#  'pba_oc_pba_hoc_hspread_hdmx',
#  'pba_open_pba_hohlca_hdmx',
#  'pba_avgPrice_pba_hohlca',
#  'pba_close_pba_hohlca',
#  'pba_high_pba_hohlca',
#  'pba_low_pba_hohlca',
#  'pba_open_pba_hohlca']

# %%
h_vol = reduce(np.intersect1d, (ntop_common_dfs[[asset, 'h', 'vol']] for asset in assets))
display(len(h_vol), h_vol)
# Out:
# 1
# array(['vol_hohlca'], dtype=object)

# %%
h_vol_common_axe = list(set(map(extract_axe_name, h_vol)))
display(h_vol_common_axe)

h_vol_minimal = []
for axe in h_vol_common_axe:
    h_vol_minimal.extend(reduce(np.intersect1d, (ntop_common_subset(asset, 'h', 'vol', axe) for asset in assets)))
display(h_vol_minimal)
# Out:
# ['hohlca']
# ntop: 40
# ntop: 40
# ntop: 40
# ntop: 40
# ['vol_avgPrice_vol_hohlca',
#  'vol_close_vol_hohlca',
#  'vol_high_vol_hohlca',
#  'vol_low_vol_hohlca',
#  'vol_open_vol_hohlca']

# %%
h_buzz = reduce(np.intersect1d, (ntop_common_dfs[[asset, 'h', 'buzz']] for asset in assets))
display(len(h_buzz), h_buzz)
# Out:
# 3
# array(['trmi3_etf3_news_buzz_hohlca_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz',
#        'trmi3_etf3_social_buzz_hohlca_hdzn_hdgau(8)_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz',
#        'trmi3_etf3_social_buzz_hohlca_mkt3_bondBuzz_ratesBuzz_stockIndexBuzz'],
#       dtype=object)

# %%
h_buzz_common_axe = ['hdzn', 'hduni', 'hdgau', 'hdmx', 'hdpt', 'hdod', 'hohlca'] # list(set(map(extract_axe_name, h_buzz)))
display(h_buzz_common_axe)

h_buzz_minimal = []
for axe in h_buzz_common_axe:
    h_buzz_minimal.extend(reduce(np.intersect1d, (ntop_common_subset(asset, 'h', 'buzz', axe) for asset in assets)))
display(h_buzz_minimal)
# Out:
# ['hdzn', 'hduni', 'hdgau', 'hdmx', 'hdpt', 'hdod', 'hohlca']
# ntop: 128
# ntop: 128
# ntop: 128
# ntop: 128
# ntop: 128
# ntop: 128
# ntop: 128
# ntop: 128
# ntop: 128
# ntop: 128
# ntop: 128
# ntop: 128
# ntop: 128
# ntop: 128
# ntop: 128
# ntop: 128
# ntop: 128
# ntop: 128
# ntop: 128
# ntop: 128
# ntop: 128
# ntop: 128
# ntop: 128
# ntop: 128
# ntop: 64
# ntop: 64
# ntop: 64
# ntop: 64
# ['etf3_buzz_N_avgPrice_trmi3_etf3_news_buzz_hohlca_hdzn',
#  'etf3_buzz_N_close_trmi3_etf3_news_buzz_hohlca_hdzn',
#  'etf3_buzz_N_high_trmi3_etf3_news_buzz_hohlca_hdzn',
#  'etf3_buzz_N_low_trmi3_etf3_news_buzz_hohlca_hdzn',
#  'etf3_buzz_N_open_trmi3_etf3_news_buzz_hohlca_hdzn',
#  'etf3_buzz_S_open_trmi3_etf3_social_buzz_hohlca_hdzn',
#  'mkt3_bondBuzz_N_open_trmi3_mkt3_news_bondBuzz_hohlca_hdzn',
#  'mkt3_bondBuzz_S_open_trmi3_mkt3_social_bondBuzz_hohlca_hdzn',
#  'mkt3_ratesBuzz_N_open_trmi3_mkt3_news_ratesBuzz_hohlca_hdzn',
#  'mkt3_ratesBuzz_S_open_trmi3_mkt3_social_ratesBuzz_hohlca_hdzn',
#  'mkt3_stockIndexBuzz_N_avgPrice_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdzn',
#  'mkt3_stockIndexBuzz_N_close_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdzn',
#  'mkt3_stockIndexBuzz_N_high_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdzn',
#  'mkt3_stockIndexBuzz_N_low_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdzn',
#  'mkt3_stockIndexBuzz_N_open_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdzn',
#  'mkt3_stockIndexBuzz_S_open_trmi3_mkt3_social_stockIndexBuzz_hohlca_hdzn',
#  'etf3_buzz_N_avgPrice_trmi3_etf3_news_buzz_hohlca_hdmx_hduni(8)',
#  'etf3_buzz_N_close_trmi3_etf3_news_buzz_hohlca_hdmx_hduni(8)',
#  'etf3_buzz_N_high_trmi3_etf3_news_buzz_hohlca_hdmx_hduni(8)',
#  'etf3_buzz_N_low_trmi3_etf3_news_buzz_hohlca_hdmx_hduni(8)',
#  'etf3_buzz_N_open_trmi3_etf3_news_buzz_hohlca_hdmx_hduni(8)',
#  'etf3_buzz_S_open_trmi3_etf3_social_buzz_hohlca_hdmx_hduni(8)',
#  'mkt3_bondBuzz_N_open_trmi3_mkt3_news_bondBuzz_hohlca_hdmx_hduni(8)',
#  'mkt3_bondBuzz_S_open_trmi3_mkt3_social_bondBuzz_hohlca_hdmx_hduni(8)',
#  'mkt3_ratesBuzz_N_open_trmi3_mkt3_news_ratesBuzz_hohlca_hdmx_hduni(8)',
#  'mkt3_ratesBuzz_S_open_trmi3_mkt3_social_ratesBuzz_hohlca_hdmx_hduni(8)',
#  'mkt3_stockIndexBuzz_N_avgPrice_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdmx_hduni(8)',
#  'mkt3_stockIndexBuzz_N_close_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdmx_hduni(8)',
#  'mkt3_stockIndexBuzz_N_high_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdmx_hduni(8)',
#  'mkt3_stockIndexBuzz_N_low_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdmx_hduni(8)',
#  'mkt3_stockIndexBuzz_N_open_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdmx_hduni(8)',
#  'mkt3_stockIndexBuzz_S_open_trmi3_mkt3_social_stockIndexBuzz_hohlca_hdmx_hduni(8)',
#  'etf3_buzz_N_avgPrice_trmi3_etf3_news_buzz_hohlca_hdzn_hdgau(8)',
#  'etf3_buzz_N_close_trmi3_etf3_news_buzz_hohlca_hdzn_hdgau(8)',
#  'etf3_buzz_N_high_trmi3_etf3_news_buzz_hohlca_hdzn_hdgau(8)',
#  'etf3_buzz_N_low_trmi3_etf3_news_buzz_hohlca_hdzn_hdgau(8)',
#  'etf3_buzz_N_open_trmi3_etf3_news_buzz_hohlca_hdzn_hdgau(8)',
#  'etf3_buzz_S_open_trmi3_etf3_social_buzz_hohlca_hdzn_hdgau(8)',
#  'mkt3_bondBuzz_N_open_trmi3_mkt3_news_bondBuzz_hohlca_hdzn_hdgau(8)',
#  'mkt3_bondBuzz_S_open_trmi3_mkt3_social_bondBuzz_hohlca_hdzn_hdgau(8)',
#  'mkt3_ratesBuzz_N_open_trmi3_mkt3_news_ratesBuzz_hohlca_hdzn_hdgau(8)',
#  'mkt3_ratesBuzz_S_open_trmi3_mkt3_social_ratesBuzz_hohlca_hdzn_hdgau(8)',
#  'mkt3_stockIndexBuzz_N_avgPrice_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdzn_hdgau(8)',
#  'mkt3_stockIndexBuzz_N_close_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdzn_hdgau(8)',
#  'mkt3_stockIndexBuzz_N_high_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdzn_hdgau(8)',
#  'mkt3_stockIndexBuzz_N_low_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdzn_hdgau(8)',
#  'mkt3_stockIndexBuzz_N_open_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdzn_hdgau(8)',
#  'mkt3_stockIndexBuzz_S_open_trmi3_mkt3_social_stockIndexBuzz_hohlca_hdzn_hdgau(8)',
#  'etf3_buzz_N_avgPrice_trmi3_etf3_news_buzz_hohlca_hdmx',
#  'etf3_buzz_N_close_trmi3_etf3_news_buzz_hohlca_hdmx',
#  'etf3_buzz_N_high_trmi3_etf3_news_buzz_hohlca_hdmx',
#  'etf3_buzz_N_low_trmi3_etf3_news_buzz_hohlca_hdmx',
#  'etf3_buzz_N_open_trmi3_etf3_news_buzz_hohlca_hdmx',
#  'etf3_buzz_S_open_trmi3_etf3_social_buzz_hohlca_hdmx',
#  'mkt3_bondBuzz_N_open_trmi3_mkt3_news_bondBuzz_hohlca_hdmx',
#  'mkt3_bondBuzz_S_open_trmi3_mkt3_social_bondBuzz_hohlca_hdmx',
#  'mkt3_ratesBuzz_N_open_trmi3_mkt3_news_ratesBuzz_hohlca_hdmx',
#  'mkt3_ratesBuzz_S_open_trmi3_mkt3_social_ratesBuzz_hohlca_hdmx',
#  'mkt3_stockIndexBuzz_N_avgPrice_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdmx',
#  'mkt3_stockIndexBuzz_N_close_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdmx',
#  'mkt3_stockIndexBuzz_N_high_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdmx',
#  'mkt3_stockIndexBuzz_N_low_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdmx',
#  'mkt3_stockIndexBuzz_N_open_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdmx',
#  'mkt3_stockIndexBuzz_S_open_trmi3_mkt3_social_stockIndexBuzz_hohlca_hdmx',
#  'etf3_buzz_N_avgPrice_trmi3_etf3_news_buzz_hohlca_hdpt',
#  'etf3_buzz_N_close_trmi3_etf3_news_buzz_hohlca_hdpt',
#  'etf3_buzz_N_high_trmi3_etf3_news_buzz_hohlca_hdpt',
#  'etf3_buzz_N_low_trmi3_etf3_news_buzz_hohlca_hdpt',
#  'etf3_buzz_N_open_trmi3_etf3_news_buzz_hohlca_hdpt',
#  'etf3_buzz_S_open_trmi3_etf3_social_buzz_hohlca_hdpt',
#  'mkt3_bondBuzz_N_open_trmi3_mkt3_news_bondBuzz_hohlca_hdpt',
#  'mkt3_bondBuzz_S_open_trmi3_mkt3_social_bondBuzz_hohlca_hdpt',
#  'mkt3_ratesBuzz_N_open_trmi3_mkt3_news_ratesBuzz_hohlca_hdpt',
#  'mkt3_ratesBuzz_S_open_trmi3_mkt3_social_ratesBuzz_hohlca_hdpt',
#  'mkt3_stockIndexBuzz_N_avgPrice_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdpt',
#  'mkt3_stockIndexBuzz_N_close_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdpt',
#  'mkt3_stockIndexBuzz_N_high_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdpt',
#  'mkt3_stockIndexBuzz_N_low_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdpt',
#  'mkt3_stockIndexBuzz_N_open_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdpt',
#  'mkt3_stockIndexBuzz_S_open_trmi3_mkt3_social_stockIndexBuzz_hohlca_hdpt',
#  'etf3_buzz_N_avgPrice_trmi3_etf3_news_buzz_hohlca_hdod',
#  'etf3_buzz_N_close_trmi3_etf3_news_buzz_hohlca_hdod',
#  'etf3_buzz_N_high_trmi3_etf3_news_buzz_hohlca_hdod',
#  'etf3_buzz_N_low_trmi3_etf3_news_buzz_hohlca_hdod',
#  'etf3_buzz_N_open_trmi3_etf3_news_buzz_hohlca_hdod',
#  'etf3_buzz_S_open_trmi3_etf3_social_buzz_hohlca_hdod',
#  'mkt3_bondBuzz_N_open_trmi3_mkt3_news_bondBuzz_hohlca_hdod',
#  'mkt3_bondBuzz_S_open_trmi3_mkt3_social_bondBuzz_hohlca_hdod',
#  'mkt3_ratesBuzz_N_open_trmi3_mkt3_news_ratesBuzz_hohlca_hdod',
#  'mkt3_ratesBuzz_S_open_trmi3_mkt3_social_ratesBuzz_hohlca_hdod',
#  'mkt3_stockIndexBuzz_N_avgPrice_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdod',
#  'mkt3_stockIndexBuzz_N_close_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdod',
#  'mkt3_stockIndexBuzz_N_high_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdod',
#  'mkt3_stockIndexBuzz_N_low_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdod',
#  'mkt3_stockIndexBuzz_N_open_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdod',
#  'mkt3_stockIndexBuzz_S_open_trmi3_mkt3_social_stockIndexBuzz_hohlca_hdod',
#  'etf3_buzz_N_open_trmi3_etf3_news_buzz_hohlca',
#  'mkt3_bondBuzz_N_open_trmi3_mkt3_news_bondBuzz_hohlca',
#  'mkt3_bondBuzz_S_open_trmi3_mkt3_social_bondBuzz_hohlca',
#  'mkt3_ratesBuzz_S_open_trmi3_mkt3_social_ratesBuzz_hohlca',
#  'mkt3_stockIndexBuzz_S_open_trmi3_mkt3_social_stockIndexBuzz_hohlca']

# %%
h_minimal_set = h_pba_minimal + h_vol_minimal + h_buzz_minimal

# %%
h_minimal_set
# Out:
# ['pba_avgPrice_pba_hohlca_hdzn',
#  'pba_close_pba_hohlca_hdzn',
#  'pba_high_pba_hohlca_hdzn',
#  'pba_lh_pba_hlh_hlogret_hdzn',
#  'pba_lh_pba_hlh_hret_hdzn',
#  'pba_lh_pba_hlh_hspread_hdzn',
#  'pba_low_pba_hohlca_hdzn',
#  'pba_oc_pba_hoc_hlogret_hdzn',
#  'pba_oc_pba_hoc_hret_hdzn',
#  'pba_oc_pba_hoc_hspread_hdzn',
#  'pba_open_pba_hohlca_hdzn',
#  'pba_avgPrice_pba_hohlca_hdmx',
#  'pba_close_pba_hohlca_hdmx',
#  'pba_high_pba_hohlca_hdmx',
#  'pba_lh_pba_hlh_hlogret_hdmx',
#  'pba_lh_pba_hlh_hret_hdmx',
#  'pba_lh_pba_hlh_hspread_hdmx',
#  'pba_low_pba_hohlca_hdmx',
#  'pba_oc_pba_hoc_hlogret_hdmx',
#  'pba_oc_pba_hoc_hret_hdmx',
#  'pba_oc_pba_hoc_hspread_hdmx',
#  'pba_open_pba_hohlca_hdmx',
#  'pba_avgPrice_pba_hohlca',
#  'pba_close_pba_hohlca',
#  'pba_high_pba_hohlca',
#  'pba_low_pba_hohlca',
#  'pba_open_pba_hohlca',
#  'vol_avgPrice_vol_hohlca',
#  'vol_close_vol_hohlca',
#  'vol_high_vol_hohlca',
#  'vol_low_vol_hohlca',
#  'vol_open_vol_hohlca',
#  'etf3_buzz_N_avgPrice_trmi3_etf3_news_buzz_hohlca_hdzn',
#  'etf3_buzz_N_close_trmi3_etf3_news_buzz_hohlca_hdzn',
#  'etf3_buzz_N_high_trmi3_etf3_news_buzz_hohlca_hdzn',
#  'etf3_buzz_N_low_trmi3_etf3_news_buzz_hohlca_hdzn',
#  'etf3_buzz_N_open_trmi3_etf3_news_buzz_hohlca_hdzn',
#  'etf3_buzz_S_open_trmi3_etf3_social_buzz_hohlca_hdzn',
#  'mkt3_bondBuzz_N_open_trmi3_mkt3_news_bondBuzz_hohlca_hdzn',
#  'mkt3_bondBuzz_S_open_trmi3_mkt3_social_bondBuzz_hohlca_hdzn',
#  'mkt3_ratesBuzz_N_open_trmi3_mkt3_news_ratesBuzz_hohlca_hdzn',
#  'mkt3_ratesBuzz_S_open_trmi3_mkt3_social_ratesBuzz_hohlca_hdzn',
#  'mkt3_stockIndexBuzz_N_avgPrice_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdzn',
#  'mkt3_stockIndexBuzz_N_close_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdzn',
#  'mkt3_stockIndexBuzz_N_high_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdzn',
#  'mkt3_stockIndexBuzz_N_low_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdzn',
#  'mkt3_stockIndexBuzz_N_open_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdzn',
#  'mkt3_stockIndexBuzz_S_open_trmi3_mkt3_social_stockIndexBuzz_hohlca_hdzn',
#  'etf3_buzz_N_avgPrice_trmi3_etf3_news_buzz_hohlca_hdmx_hduni(8)',
#  'etf3_buzz_N_close_trmi3_etf3_news_buzz_hohlca_hdmx_hduni(8)',
#  'etf3_buzz_N_high_trmi3_etf3_news_buzz_hohlca_hdmx_hduni(8)',
#  'etf3_buzz_N_low_trmi3_etf3_news_buzz_hohlca_hdmx_hduni(8)',
#  'etf3_buzz_N_open_trmi3_etf3_news_buzz_hohlca_hdmx_hduni(8)',
#  'etf3_buzz_S_open_trmi3_etf3_social_buzz_hohlca_hdmx_hduni(8)',
#  'mkt3_bondBuzz_N_open_trmi3_mkt3_news_bondBuzz_hohlca_hdmx_hduni(8)',
#  'mkt3_bondBuzz_S_open_trmi3_mkt3_social_bondBuzz_hohlca_hdmx_hduni(8)',
#  'mkt3_ratesBuzz_N_open_trmi3_mkt3_news_ratesBuzz_hohlca_hdmx_hduni(8)',
#  'mkt3_ratesBuzz_S_open_trmi3_mkt3_social_ratesBuzz_hohlca_hdmx_hduni(8)',
#  'mkt3_stockIndexBuzz_N_avgPrice_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdmx_hduni(8)',
#  'mkt3_stockIndexBuzz_N_close_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdmx_hduni(8)',
#  'mkt3_stockIndexBuzz_N_high_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdmx_hduni(8)',
#  'mkt3_stockIndexBuzz_N_low_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdmx_hduni(8)',
#  'mkt3_stockIndexBuzz_N_open_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdmx_hduni(8)',
#  'mkt3_stockIndexBuzz_S_open_trmi3_mkt3_social_stockIndexBuzz_hohlca_hdmx_hduni(8)',
#  'etf3_buzz_N_avgPrice_trmi3_etf3_news_buzz_hohlca_hdzn_hdgau(8)',
#  'etf3_buzz_N_close_trmi3_etf3_news_buzz_hohlca_hdzn_hdgau(8)',
#  'etf3_buzz_N_high_trmi3_etf3_news_buzz_hohlca_hdzn_hdgau(8)',
#  'etf3_buzz_N_low_trmi3_etf3_news_buzz_hohlca_hdzn_hdgau(8)',
#  'etf3_buzz_N_open_trmi3_etf3_news_buzz_hohlca_hdzn_hdgau(8)',
#  'etf3_buzz_S_open_trmi3_etf3_social_buzz_hohlca_hdzn_hdgau(8)',
#  'mkt3_bondBuzz_N_open_trmi3_mkt3_news_bondBuzz_hohlca_hdzn_hdgau(8)',
#  'mkt3_bondBuzz_S_open_trmi3_mkt3_social_bondBuzz_hohlca_hdzn_hdgau(8)',
#  'mkt3_ratesBuzz_N_open_trmi3_mkt3_news_ratesBuzz_hohlca_hdzn_hdgau(8)',
#  'mkt3_ratesBuzz_S_open_trmi3_mkt3_social_ratesBuzz_hohlca_hdzn_hdgau(8)',
#  'mkt3_stockIndexBuzz_N_avgPrice_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdzn_hdgau(8)',
#  'mkt3_stockIndexBuzz_N_close_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdzn_hdgau(8)',
#  'mkt3_stockIndexBuzz_N_high_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdzn_hdgau(8)',
#  'mkt3_stockIndexBuzz_N_low_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdzn_hdgau(8)',
#  'mkt3_stockIndexBuzz_N_open_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdzn_hdgau(8)',
#  'mkt3_stockIndexBuzz_S_open_trmi3_mkt3_social_stockIndexBuzz_hohlca_hdzn_hdgau(8)',
#  'etf3_buzz_N_avgPrice_trmi3_etf3_news_buzz_hohlca_hdmx',
#  'etf3_buzz_N_close_trmi3_etf3_news_buzz_hohlca_hdmx',
#  'etf3_buzz_N_high_trmi3_etf3_news_buzz_hohlca_hdmx',
#  'etf3_buzz_N_low_trmi3_etf3_news_buzz_hohlca_hdmx',
#  'etf3_buzz_N_open_trmi3_etf3_news_buzz_hohlca_hdmx',
#  'etf3_buzz_S_open_trmi3_etf3_social_buzz_hohlca_hdmx',
#  'mkt3_bondBuzz_N_open_trmi3_mkt3_news_bondBuzz_hohlca_hdmx',
#  'mkt3_bondBuzz_S_open_trmi3_mkt3_social_bondBuzz_hohlca_hdmx',
#  'mkt3_ratesBuzz_N_open_trmi3_mkt3_news_ratesBuzz_hohlca_hdmx',
#  'mkt3_ratesBuzz_S_open_trmi3_mkt3_social_ratesBuzz_hohlca_hdmx',
#  'mkt3_stockIndexBuzz_N_avgPrice_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdmx',
#  'mkt3_stockIndexBuzz_N_close_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdmx',
#  'mkt3_stockIndexBuzz_N_high_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdmx',
#  'mkt3_stockIndexBuzz_N_low_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdmx',
#  'mkt3_stockIndexBuzz_N_open_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdmx',
#  'mkt3_stockIndexBuzz_S_open_trmi3_mkt3_social_stockIndexBuzz_hohlca_hdmx',
#  'etf3_buzz_N_avgPrice_trmi3_etf3_news_buzz_hohlca_hdpt',
#  'etf3_buzz_N_close_trmi3_etf3_news_buzz_hohlca_hdpt',
#  'etf3_buzz_N_high_trmi3_etf3_news_buzz_hohlca_hdpt',
#  'etf3_buzz_N_low_trmi3_etf3_news_buzz_hohlca_hdpt',
#  'etf3_buzz_N_open_trmi3_etf3_news_buzz_hohlca_hdpt',
#  'etf3_buzz_S_open_trmi3_etf3_social_buzz_hohlca_hdpt',
#  'mkt3_bondBuzz_N_open_trmi3_mkt3_news_bondBuzz_hohlca_hdpt',
#  'mkt3_bondBuzz_S_open_trmi3_mkt3_social_bondBuzz_hohlca_hdpt',
#  'mkt3_ratesBuzz_N_open_trmi3_mkt3_news_ratesBuzz_hohlca_hdpt',
#  'mkt3_ratesBuzz_S_open_trmi3_mkt3_social_ratesBuzz_hohlca_hdpt',
#  'mkt3_stockIndexBuzz_N_avgPrice_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdpt',
#  'mkt3_stockIndexBuzz_N_close_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdpt',
#  'mkt3_stockIndexBuzz_N_high_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdpt',
#  'mkt3_stockIndexBuzz_N_low_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdpt',
#  'mkt3_stockIndexBuzz_N_open_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdpt',
#  'mkt3_stockIndexBuzz_S_open_trmi3_mkt3_social_stockIndexBuzz_hohlca_hdpt',
#  'etf3_buzz_N_avgPrice_trmi3_etf3_news_buzz_hohlca_hdod',
#  'etf3_buzz_N_close_trmi3_etf3_news_buzz_hohlca_hdod',
#  'etf3_buzz_N_high_trmi3_etf3_news_buzz_hohlca_hdod',
#  'etf3_buzz_N_low_trmi3_etf3_news_buzz_hohlca_hdod',
#  'etf3_buzz_N_open_trmi3_etf3_news_buzz_hohlca_hdod',
#  'etf3_buzz_S_open_trmi3_etf3_social_buzz_hohlca_hdod',
#  'mkt3_bondBuzz_N_open_trmi3_mkt3_news_bondBuzz_hohlca_hdod',
#  'mkt3_bondBuzz_S_open_trmi3_mkt3_social_bondBuzz_hohlca_hdod',
#  'mkt3_ratesBuzz_N_open_trmi3_mkt3_news_ratesBuzz_hohlca_hdod',
#  'mkt3_ratesBuzz_S_open_trmi3_mkt3_social_ratesBuzz_hohlca_hdod',
#  'mkt3_stockIndexBuzz_N_avgPrice_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdod',
#  'mkt3_stockIndexBuzz_N_close_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdod',
#  'mkt3_stockIndexBuzz_N_high_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdod',
#  'mkt3_stockIndexBuzz_N_low_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdod',
#  'mkt3_stockIndexBuzz_N_open_trmi3_mkt3_news_stockIndexBuzz_hohlca_hdod',
#  'mkt3_stockIndexBuzz_S_open_trmi3_mkt3_social_stockIndexBuzz_hohlca_hdod',
#  'etf3_buzz_N_open_trmi3_etf3_news_buzz_hohlca',
#  'mkt3_bondBuzz_N_open_trmi3_mkt3_news_bondBuzz_hohlca',
#  'mkt3_bondBuzz_S_open_trmi3_mkt3_social_bondBuzz_hohlca',
#  'mkt3_ratesBuzz_S_open_trmi3_mkt3_social_ratesBuzz_hohlca',
#  'mkt3_stockIndexBuzz_S_open_trmi3_mkt3_social_stockIndexBuzz_hohlca']
