# %% [markdown]
# # nb-model_exp-results-2-1 (h_pba_h)

# %%
import sys
import os
from os import sep
from os.path import dirname, realpath, exists, basename
from pathlib import Path
from glob import glob, iglob
import logging

def get_cwd(fname, subdir, crunch_dir=realpath(Path.home()) +sep +'crunch' +sep):
    """
    Convenience function to make a directory string for the current file based on inputs.
    Jupyter Notebook in Anaconda invokes the Python interpreter in Anaconda's subdirectory
    which is why changing sys.argv[0] is necessary. In the future a better way to do this
    should be preferred..
    """
    return crunch_dir +subdir +fname

def fix_path(cwd):
    """
    Convenience function to fix argv and python path so that jupyter notebook can run the same as
    any script in crunch.
    """
    sys.argv[0] = cwd
    module_path = os.path.abspath(os.path.join('..'))
    if module_path not in sys.path:
        sys.path.append(module_path)

fname = 'nb-model_exp-results-2-1.ipynb'
dir_name = 'model'
fix_path(get_cwd(fname, dir_name +sep))

import numpy as np
import pandas as pd

from ipywidgets import interact, interactive, fixed
from IPython.display import display

pd.set_option("display.max_rows", 300)
pd.set_option("display.max_columns", 50)

from common_util import MODEL_DIR, load_json, dump_json, rectify_json, load_df, str_now, makedir_if_not_exists, is_valid, isnt, compose, pd_split_ternary_to_binary, df_del_midx_level, midx_intersect, pd_get_midx_level, pd_rows, df_midx_restack
from common_util import NestedDefaultDict
from model.common import EXP_LOG_DIR, EXP_PARAMS_DIR, ASSETS, DATASET_DIR, XG_PROCESS_DIR, XG_DATA_DIR, XG_DIR, PYTORCH_MODELS_DIR, TRAIN_RATIO, EXPECTED_NUM_HOURS
from recon.viz import *
logging.basicConfig(stream=sys.stdout, level=logging.DEBUG)
# Out:
# CRITICAL:root:script location: /home/kev/crunch/model/nb-model_exp-results-2-1.ipynb
# CRITICAL:root:using project dir: /home/kev/crunch/

# %% [markdown]
# Prune the xg data down to the data of interest to use in further experiments.

# %%
def get_bench(pattern):
    ndd = NestedDefaultDict()
    for path in iglob(pattern, recursive=True):
        ndd[path.split('/')] = load_json(path)

    df_idx = [k[2] for k in ndd.keys()]
    df = pd.DataFrame.from_records([b['benchmark-hold'] for b in ndd.values()], index=df_idx)

    return df

# %%
def consolidate_results(pattern, bench_pattern=None):
    ndd = NestedDefaultDict()
    for path in iglob(pattern, recursive=True):
        ndd[path.split('/')] = load_json(path)
    df_keys = [(k[2], k[3], k[4], k[5], k[6]) for k in ndd.keys()]
    df_idx = pd.MultiIndex.from_tuples(df_keys, names=('asset', 'model', 'data', 'params', 'trial')) \
        .remove_unused_levels()
    df = pd.DataFrame.from_records(list(ndd.values()), index=df_idx) \
        .reset_index() \
        .groupby(['asset', 'model', 'params']).mean() # average across trials for each study

    if (is_valid(bench_pattern)):
        bench_df = get_bench(bench_pattern)
        mets = ['accuracy', 'precision', 'recall', 'f1']
        rets = ['profit', 'sharpe', 'cagr']
        for m in mets+rets:
            res_cols = [c for c in df.columns if (c.endswith(m))]
            bench_cols = [c for c in bench_df.columns if (c.endswith(m))]
            bench_col = bench_cols[0]

            for asset in bench_df.index:
#                 print(bench_df.loc[asset, bench_col])
#                 print(df.xs(asset, level=0, drop_level=False)[res_cols])
                df.xs(asset, level=0, drop_level=False).loc[:, res_cols] -= bench_df.loc[asset, bench_col]
#     df = df.style \
#         .background_gradient(subset=[c for c in df.columns if c.endswith(('accuracy', 'profit', 'sharpe', 'cagr'))], cmap='BuGn')
#     .set_sticky(axis="index") \
    return df

# %%
def agg_asset(res_df):
    agg_df = res_df.groupby(['model', 'params']).mean()
    return agg_df

# %%
def agg_model(res_df):
    agg_df = res_df.groupby(['params']).mean()
    return agg_df

# %%
def agg_asset_params(res_df):
    return res_df.groupby(['asset', 'params']).mean()

# %%
def add_style(df):
    df = df.style \
         .background_gradient(subset=[c for c in df.columns if c.endswith(('accuracy', 'f1', 'profit', 'sharpe', 'cagr'))], cmap='BuGn')
#     .set_sticky(axis="index") \
    return df

# %%
view = ('accuracy', 'f1', 'profit', 'sharpe', 'cagr')

def select_ends(df, ends=view):
    res_cols = [c for c in df.columns if (c.endswith(ends))]
#     for m in ends:
#         res_cols = [c for c in df.columns if (c.endswith(m))]
    return df.loc[:, res_cols]

# %%
def select_paramrange(df, r):
    params = map(str, r)
    return df.loc[(slice(None), slice(None), params), :]

# %%
def dropfirstmi(df):
    df.index = df.index.droplevel(0)
    return df

def gb_filter_monotonic(df, checkcol='val_binary_sharpe'):
    return dropfirstmi(df.reorder_levels(['asset', 'params', 'model']) \
            .groupby('params') \
            .apply(lambda g: g if (g[checkcol].is_monotonic_increasing) else None) \
            .sort_index())

subgt = lambda g, big, small='base': (g.xs(big, level=2) > g.xs(small, level=2)).all()
monotonic_partial = lambda g: (subgt(g, 'lnp') and subgt(g, 'np', 'lnp')) or (subgt(g, 'cnp') and subgt(g, 'np', 'cnp'))

def gb_filter_monotonic_partial(df, checkcol='val_binary_sharpe'):
    return dropfirstmi(df.reorder_levels(['asset', 'params', 'model']) \
            .groupby('params') \
            .apply(lambda g: g if (monotonic_partial(g[checkcol])) else None) \
            .sort_index())

nonneg = lambda g: (g.xs('np', level=2) > 0).all() and (g.xs('lnp', level=2) > 0).all()

def gb_filter_neg(df, checkcol='val_binary_sharpe'):
    return dropfirstmi(df.reorder_levels(['asset', 'params', 'model']) \
            .groupby('params') \
            .apply(lambda g: g if (nonneg(g[checkcol])) else None) \
            .sort_index())

def gb_filter_lf(df, checkcol='val_binary_longfreq'):
    return dropfirstmi(df.groupby('params') \
            .apply(lambda g: g if ((g[checkcol].between(.2, .8)).all()) else None))

# %%
# def get_params_per_dataset():
#     EXP_LOG_DIR

# %%
exp_base = basename(dirname(EXP_LOG_DIR))
sm_name = 'anp'

drange = '2009_2018'
xdata = 'h_pba_h'
ydata = 'ddir'
data_name = f'{drange}_{ydata}_{xdata}'
bench_data_name = f'{drange}_{ydata}'

path_train = f"{exp_base}/{sm_name}/**/{data_name}/**/train.json"
path_val =   f"{exp_base}/{sm_name}/**/{data_name}/**/val.json"
# path_test = f"{exp_base}/{sm_name}/**/{data_name}/**/test.json"

path_bench_train = f"{exp_base}/bench/*/{bench_data_name}/train.json"
path_bench_val = f"{exp_base}/bench/*/{bench_data_name}/val.json"
# path_bench_test = f"{exp_base}/bench/*/{bench_data_name}/test.json"

# %%
PRANGE = range(200, 270)

# absolute results
dt = select_paramrange(consolidate_results(path_train), PRANGE);
dv = select_paramrange(consolidate_results(path_val), PRANGE);

# benchmark adjusted results
dt_adj = select_paramrange(consolidate_results(path_train, path_bench_train), PRANGE);
dv_adj = select_paramrange(consolidate_results(path_val, path_bench_val), PRANGE);
# Out:
# /home/kev/miniconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1787: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, val, pi)

# %% [markdown]
# ## Results
# Parameter sets >= 200

# %%
# sp_500: 120, 56
# russell_2000: 60, 54, 83
# nasdaq_100: 14, 124
# dow_jones: 107, 124, 62
# +110

# *0 -> 62
# *1 -> 83

# *2 -> 14
# *3 -> 54
# *4 -> 124

# *5 -> 56

# *6 -> 107

# *7 -> 60
# *8 -> 110
# *9 -> 120

# %%
# (200-209) -> (210-219): output init set to kaiming_uniform
# (200-209) -> (220-229): all in2d replaced with in15d
# (200-209) -> (230-239): all in15d->in2d, in2d->in15d
# (200-209) -> (240-249): double batch size
# (230-239) -> (250-259): double batch size
# (202, 210-212, 214, 221-222, 234-246) -> (260-269): set window size to 40
# final

# %%
train_clf = [col for col in dt.columns if ('clf' in col)]
train_binary = [col for col in dt.columns if ('binary' in col)]
train_binary_sharpe = [col for col in train_binary if (col.endswith('sharpe'))]
trainb = train_binary_sharpe + ['train_binary_longfreq']

# %%
val_clf = [col for col in dv.columns if ('clf' in col)]
val_binary = [col for col in dv.columns if ('binary' in col)]
val_binary_sharpe = [col for col in val_binary if (col.endswith('sharpe'))]
val_binary_lf = ['val_binary_longfreq']
valb = val_binary_sharpe + ['val_binary_longfreq']

# %%
add_style(agg_model(agg_asset(dt_adj.loc[:, trainb])))
# Out:
# <style  type="text/css" >
# #T_cd4ca_row0_col0,#T_cd4ca_row64_col1{
#             background-color:  #68c3a6;
#             color:  #000000;
#         }#T_cd4ca_row0_col1,#T_cd4ca_row10_col2,#T_cd4ca_row64_col2{
#             background-color:  #5abb95;
#             color:  #000000;
#         }#T_cd4ca_row0_col2{
#             background-color:  #6fc6aa;
#             color:  #000000;
#         }#T_cd4ca_row1_col0,#T_cd4ca_row6_col0,#T_cd4ca_row13_col0{
#             background-color:  #e7f6f9;
#             color:  #000000;
#         }#T_cd4ca_row1_col1,#T_cd4ca_row3_col0,#T_cd4ca_row59_col1{
#             background-color:  #e3f4f7;
#             color:  #000000;
#         }#T_cd4ca_row1_col2,#T_cd4ca_row3_col2,#T_cd4ca_row23_col2,#T_cd4ca_row31_col1{
#             background-color:  #e8f6fa;
#             color:  #000000;
#         }#T_cd4ca_row2_col0,#T_cd4ca_row2_col2,#T_cd4ca_row47_col0,#T_cd4ca_row53_col2,#T_cd4ca_row57_col0,#T_cd4ca_row60_col2,#T_cd4ca_row63_col1,#T_cd4ca_row66_col2{
#             background-color:  #d8f0ef;
#             color:  #000000;
#         }#T_cd4ca_row2_col1,#T_cd4ca_row21_col2,#T_cd4ca_row55_col0,#T_cd4ca_row55_col1,#T_cd4ca_row59_col2{
#             background-color:  #dbf1f1;
#             color:  #000000;
#         }#T_cd4ca_row3_col1{
#             background-color:  #def2f4;
#             color:  #000000;
#         }#T_cd4ca_row4_col0,#T_cd4ca_row4_col1{
#             background-color:  #3da96f;
#             color:  #000000;
#         }#T_cd4ca_row4_col2{
#             background-color:  #3ba76c;
#             color:  #000000;
#         }#T_cd4ca_row5_col0{
#             background-color:  #ceede8;
#             color:  #000000;
#         }#T_cd4ca_row5_col1{
#             background-color:  #c8ebe4;
#             color:  #000000;
#         }#T_cd4ca_row5_col2,#T_cd4ca_row22_col0,#T_cd4ca_row37_col1,#T_cd4ca_row63_col2{
#             background-color:  #d1eeea;
#             color:  #000000;
#         }#T_cd4ca_row6_col1,#T_cd4ca_row46_col0{
#             background-color:  #e5f5f9;
#             color:  #000000;
#         }#T_cd4ca_row6_col2,#T_cd4ca_row43_col1{
#             background-color:  #ecf8fa;
#             color:  #000000;
#         }#T_cd4ca_row7_col0,#T_cd4ca_row58_col0{
#             background-color:  #c0e7df;
#             color:  #000000;
#         }#T_cd4ca_row7_col1,#T_cd4ca_row9_col0,#T_cd4ca_row18_col2,#T_cd4ca_row52_col0{
#             background-color:  #b5e3d9;
#             color:  #000000;
#         }#T_cd4ca_row7_col2{
#             background-color:  #cdece6;
#             color:  #000000;
#         }#T_cd4ca_row8_col0,#T_cd4ca_row39_col2{
#             background-color:  #bce6dd;
#             color:  #000000;
#         }#T_cd4ca_row8_col1,#T_cd4ca_row19_col0,#T_cd4ca_row36_col2{
#             background-color:  #b2e2d7;
#             color:  #000000;
#         }#T_cd4ca_row8_col2,#T_cd4ca_row48_col0,#T_cd4ca_row49_col1{
#             background-color:  #c4e9e1;
#             color:  #000000;
#         }#T_cd4ca_row9_col1,#T_cd4ca_row19_col1,#T_cd4ca_row40_col1{
#             background-color:  #b0e1d6;
#             color:  #000000;
#         }#T_cd4ca_row9_col2,#T_cd4ca_row18_col0,#T_cd4ca_row40_col0{
#             background-color:  #b4e2d8;
#             color:  #000000;
#         }#T_cd4ca_row10_col0{
#             background-color:  #60bf9c;
#             color:  #000000;
#         }#T_cd4ca_row10_col1{
#             background-color:  #63c0a0;
#             color:  #000000;
#         }#T_cd4ca_row11_col0{
#             background-color:  #57ba92;
#             color:  #000000;
#         }#T_cd4ca_row11_col1{
#             background-color:  #5bbc96;
#             color:  #000000;
#         }#T_cd4ca_row11_col2,#T_cd4ca_row54_col1{
#             background-color:  #4eb586;
#             color:  #000000;
#         }#T_cd4ca_row12_col0,#T_cd4ca_row45_col1,#T_cd4ca_row57_col1,#T_cd4ca_row63_col0{
#             background-color:  #d5efed;
#             color:  #000000;
#         }#T_cd4ca_row12_col1,#T_cd4ca_row27_col0,#T_cd4ca_row37_col0,#T_cd4ca_row47_col2,#T_cd4ca_row53_col1{
#             background-color:  #d3eeeb;
#             color:  #000000;
#         }#T_cd4ca_row12_col2,#T_cd4ca_row22_col2,#T_cd4ca_row25_col0,#T_cd4ca_row26_col1,#T_cd4ca_row37_col2{
#             background-color:  #d7f0ee;
#             color:  #000000;
#         }#T_cd4ca_row13_col1,#T_cd4ca_row16_col2,#T_cd4ca_row46_col2{
#             background-color:  #e4f5f8;
#             color:  #000000;
#         }#T_cd4ca_row13_col2,#T_cd4ca_row42_col0,#T_cd4ca_row65_col1{
#             background-color:  #ebf7fa;
#             color:  #000000;
#         }#T_cd4ca_row14_col0,#T_cd4ca_row20_col2{
#             background-color:  #65c2a3;
#             color:  #000000;
#         }#T_cd4ca_row14_col1{
#             background-color:  #6cc4a8;
#             color:  #000000;
#         }#T_cd4ca_row14_col2{
#             background-color:  #5cbd98;
#             color:  #000000;
#         }#T_cd4ca_row15_col0,#T_cd4ca_row28_col1,#T_cd4ca_row29_col1{
#             background-color:  #a4dccf;
#             color:  #000000;
#         }#T_cd4ca_row15_col1,#T_cd4ca_row36_col1{
#             background-color:  #9fdacc;
#             color:  #000000;
#         }#T_cd4ca_row15_col2,#T_cd4ca_row38_col1,#T_cd4ca_row68_col1{
#             background-color:  #a0dbcd;
#             color:  #000000;
#         }#T_cd4ca_row16_col0,#T_cd4ca_row41_col2{
#             background-color:  #dff3f5;
#             color:  #000000;
#         }#T_cd4ca_row16_col1,#T_cd4ca_row26_col0,#T_cd4ca_row57_col2{
#             background-color:  #dcf2f2;
#             color:  #000000;
#         }#T_cd4ca_row17_col0,#T_cd4ca_row22_col1{
#             background-color:  #ccece6;
#             color:  #000000;
#         }#T_cd4ca_row17_col1,#T_cd4ca_row35_col0,#T_cd4ca_row35_col1,#T_cd4ca_row49_col0{
#             background-color:  #c2e8e0;
#             color:  #000000;
#         }#T_cd4ca_row17_col2,#T_cd4ca_row33_col0{
#             background-color:  #cfede8;
#             color:  #000000;
#         }#T_cd4ca_row18_col1{
#             background-color:  #ade0d4;
#             color:  #000000;
#         }#T_cd4ca_row19_col2,#T_cd4ca_row36_col0{
#             background-color:  #aadfd3;
#             color:  #000000;
#         }#T_cd4ca_row20_col0{
#             background-color:  #72c7ad;
#             color:  #000000;
#         }#T_cd4ca_row20_col1{
#             background-color:  #70c6ac;
#             color:  #000000;
#         }#T_cd4ca_row21_col0,#T_cd4ca_row53_col0{
#             background-color:  #d6f0ee;
#             color:  #000000;
#         }#T_cd4ca_row21_col1{
#             background-color:  #d1eee9;
#             color:  #000000;
#         }#T_cd4ca_row23_col0{
#             background-color:  #e2f4f7;
#             color:  #000000;
#         }#T_cd4ca_row23_col1,#T_cd4ca_row55_col2,#T_cd4ca_row60_col0{
#             background-color:  #d9f1f0;
#             color:  #000000;
#         }#T_cd4ca_row24_col0,#T_cd4ca_row24_col2,#T_cd4ca_row34_col1{
#             background-color:  #2f9858;
#             color:  #000000;
#         }#T_cd4ca_row24_col1{
#             background-color:  #2b9452;
#             color:  #000000;
#         }#T_cd4ca_row25_col1{
#             background-color:  #d2eeeb;
#             color:  #000000;
#         }#T_cd4ca_row25_col2,#T_cd4ca_row45_col0,#T_cd4ca_row66_col0{
#             background-color:  #daf1f1;
#             color:  #000000;
#         }#T_cd4ca_row26_col2,#T_cd4ca_row46_col1{
#             background-color:  #e3f4f8;
#             color:  #000000;
#         }#T_cd4ca_row27_col1,#T_cd4ca_row33_col2{
#             background-color:  #d4efec;
#             color:  #000000;
#         }#T_cd4ca_row27_col2{
#             background-color:  #d0ede9;
#             color:  #000000;
#         }#T_cd4ca_row28_col0{
#             background-color:  #a2dcce;
#             color:  #000000;
#         }#T_cd4ca_row28_col2{
#             background-color:  #9cd9ca;
#             color:  #000000;
#         }#T_cd4ca_row29_col0,#T_cd4ca_row29_col2,#T_cd4ca_row39_col1{
#             background-color:  #afe1d5;
#             color:  #000000;
#         }#T_cd4ca_row30_col0{
#             background-color:  #95d6c6;
#             color:  #000000;
#         }#T_cd4ca_row30_col1,#T_cd4ca

# %%
add_style(agg_model(agg_asset(dv_adj.loc[:, valb])))
# Out:
# <style  type="text/css" >
# #T_76e1e_row0_col0,#T_76e1e_row53_col1,#T_76e1e_row64_col0{
#             background-color:  #78cab1;
#             color:  #000000;
#         }#T_76e1e_row0_col1{
#             background-color:  #b4e2d8;
#             color:  #000000;
#         }#T_76e1e_row0_col2,#T_76e1e_row40_col1{
#             background-color:  #63c0a0;
#             color:  #000000;
#         }#T_76e1e_row1_col0,#T_76e1e_row25_col0,#T_76e1e_row58_col0,#T_76e1e_row63_col2{
#             background-color:  #54b88e;
#             color:  #000000;
#         }#T_76e1e_row1_col1{
#             background-color:  #82ceb8;
#             color:  #000000;
#         }#T_76e1e_row1_col2,#T_76e1e_row38_col0{
#             background-color:  #51b689;
#             color:  #000000;
#         }#T_76e1e_row2_col0,#T_76e1e_row28_col0{
#             background-color:  #1e8741;
#             color:  #000000;
#         }#T_76e1e_row2_col1,#T_76e1e_row50_col1{
#             background-color:  #3aa66a;
#             color:  #000000;
#         }#T_76e1e_row2_col2,#T_76e1e_row11_col2{
#             background-color:  #17813d;
#             color:  #f1f1f1;
#         }#T_76e1e_row3_col0,#T_76e1e_row30_col1{
#             background-color:  #7dccb5;
#             color:  #000000;
#         }#T_76e1e_row3_col1{
#             background-color:  #5dbd99;
#             color:  #000000;
#         }#T_76e1e_row3_col2,#T_76e1e_row58_col2{
#             background-color:  #d0ede9;
#             color:  #000000;
#         }#T_76e1e_row4_col0,#T_76e1e_row17_col2,#T_76e1e_row69_col0{
#             background-color:  #53b88c;
#             color:  #000000;
#         }#T_76e1e_row4_col1{
#             background-color:  #55b98f;
#             color:  #000000;
#         }#T_76e1e_row4_col2{
#             background-color:  #5bbc96;
#             color:  #000000;
#         }#T_76e1e_row5_col0{
#             background-color:  #56ba91;
#             color:  #000000;
#         }#T_76e1e_row5_col1,#T_76e1e_row60_col0,#T_76e1e_row63_col0{
#             background-color:  #3ca86d;
#             color:  #000000;
#         }#T_76e1e_row5_col2,#T_76e1e_row61_col0{
#             background-color:  #95d6c6;
#             color:  #000000;
#         }#T_76e1e_row6_col0,#T_76e1e_row21_col2{
#             background-color:  #1f8742;
#             color:  #000000;
#         }#T_76e1e_row6_col1{
#             background-color:  #00692a;
#             color:  #f1f1f1;
#         }#T_76e1e_row6_col2,#T_76e1e_row47_col0{
#             background-color:  #61bf9e;
#             color:  #000000;
#         }#T_76e1e_row7_col0,#T_76e1e_row60_col1{
#             background-color:  #45b07b;
#             color:  #000000;
#         }#T_76e1e_row7_col1,#T_76e1e_row57_col1{
#             background-color:  #2d9655;
#             color:  #000000;
#         }#T
col2{
#             background-color:  #80cdb7;
#             color:  #000000;
#         }#T_9cc97_row14_col1,#T_9cc97_row28_col0,#T_9cc97_row162_col1,#T_9cc97_row188_col1,#T_9cc97_row207_col1{
#             background-color:  #60bf9c;
#             color:  #000000;
#         }#T_9cc97_row14_col2,#T_9cc97_row53_col1,#T_9cc97_row97_col2,#T_9cc97_row155_col2{
#             background-color:  #2e9756;
#             color:  #000000;
#         }#T_9cc97_row15_col0,#T_9cc97_row41_col1,#T_9cc97_row105_col0,#T_9cc97_row146_col0,#T_9cc97_row151_col0,#T_9cc97_row159_col2,#T_9cc97_row170_col0{
#             background-color:  #40ad75;
#             color:  #000000;
#         }#T_9cc97_row15_col1,#T_9cc97_row130_col0{
#             background-color:  #47b17e;
#             color:  #000000;
#         }#T_9cc97_row15_col2,#T_9cc97_row46_col1,#T_9cc97_row114_col1,#T_9cc97_row204_col1,#T_9cc97_row209_col2,#T_9cc97_row256_col2{
#             background-color:  #5bbc96;
#             color:  #000000;
#         }#T_9cc97_row16_col0,#T_9cc97_row132_col0{
#             background-color:  #d5efed;
#             color:  #000000;
#         }#T_9cc97_row16_col1,#T_9cc97_row108_col0,#T_9cc97_row228_col2,#T_9cc97_row268_col0{
#             background-color:  #e5f5f9;
#             color:  #000000;
#         }#T_9cc97_row16_col2,#T_9cc97_row172_col0{
#             background-color:  #a5ddd0;
#             color:  #000000;
#         }#T_9cc97_row17_col0,#T_9cc97_row65_col0,#T_9cc97_row74_col0,#T_9cc97_row214_col2,#T_9cc97_row231_col1{
#             background-color:  #1e8741;
#             color:  #000000;
#         }#T_9cc97_row17_col1,#T_9cc97_row48_col2,#T_9cc97_row94_col2,#T_9cc97_row115_col2,#T_9cc97_

# %% [markdown]
# ## Compare Results Over Val by Params

# %%
sel_param = lambda d, p: d.xs(p, level=2, drop_level=False)
sel_asset = lambda d, a: d.xs(a, level=0, drop_level=False)

# %%
sp_500 = sel_asset(dv_adj.loc[:, val_binary_sharpe], 'sp_500').sort_index(level=2)
russell_2000 = sel_asset(dv_adj.loc[:, val_binary_sharpe], 'russell_2000').sort_index(level=2)
nasdaq_100 = sel_asset(dv_adj.loc[:, val_binary_sharpe], 'nasdaq_100').sort_index(level=2)
dow_jones = sel_asset(dv_adj.loc[:, val_binary_sharpe], 'dow_jones').sort_index(level=2)

# %%
add_style(nasdaq_100)
# Out:
# <style  type="text/css" >
# #T_08044_row0_col0,#T_08044_row3_col2,#T_08044_row44_col2{
#             background-color:  #39a569;
#             color:  #000000;
#         }#T_08044_row0_col1,#T_08044_row47_col1,#T_08044_row54_col1,#T_08044_row69_col0,#T_08044_row69_col1,#T_08044_row98_col2,#T_08044_row108_col0,#T_08044_row143_col2,#T_08044_row218_col0,#T_08044_row220_col1{
#             background-color:  #45b07b;
#             color:  #000000;
#         }#T_08044_row0_col2,#T_08044_row51_col2,#T_08044_row66_col1,#T_08044_row178_col1,#T_08044_row204_col0,#T_08044_row217_col2,#T_08044_row223_col2{
#             background-color:  #28914d;
#             color:  #000000;
#         }#T_08044_row1_col0,#T_08044_row1_col1,#T_08044_row20_col1,#T_08044_row35_col0,#T_08044_row95_col2,#T_08044_row103_col2,#T_08044_row121_col2,#T_08044_row127_col2,#T_08044_row137_col0,#T_08044_row263_col2{
#             background-color:  #84cfb9;
#             color:  #000000;
#         }#T_08044_row1_col2,#T_08044_row11_col1,#T_08044_row25_col1,#T_08044_row89_col1,#T_08044_row93_col0,#T_08044_row102_col0,#T_08044_row160_col0,#T_08044_row214_col1,#T_08044_row232_col0{
#             background-color:  #6fc6aa;
#             color:  #000000;
#         }#T_08044_row2_col0,#T_08044_row4_col0,#T_08044_row15_col0,#T_08044_row84_col2,#T_08044_row100_col2,#T_08044_row105_col1,#T_08044_row170_col0,#T_08044_row182_col2,#T_08044_row246_col2,#T_08044_row278_col1{
#             background-color:  #5dbd99;
#             color:  #000000;
#         }#T_08044_row2_col1,#T_08044_row25_col0,#T_08044_row33_col1,#T_08044_row102_col2,#T_08044_row137_col2,#T_08044_row181_col0,#T_08044_row214_col0,#T_08044_row221_col1,#T_08044_row262_col2,#T_08044_row279_col2{
#             background-color:  #6cc4a8;
#             color:  #000000;
#         }#T_08044_row2_col2,#T_08044_row28_col2,#T_08044_row37_col0,#T_08044_row37_col1,#T_08044_row47_col0,#T_08044_row49_col2,#T_08044_row54_col2,#T_08044_row106_col0,#T_08044_row124_col2,#T_08044_row165_col0,#T_08044_row243_col2{
#             background-color:  #48b27f;
#             color:  #000000;
#         }#T_08044_row3_col0,#T_08044_row17_col1,#T_08044_row47_col2,#T_08044_row53_col0,#T_08044_row59_col1,#T_08044_row92_col1,#T_08044_row106_col2,#T_08044_row146_col2,#T_08044_row231_col1{
#             background-color:  #40ad75;
#             color:  #000000;
#         }#T_08044_row3_col1,#T_08044_row19_col2,#T_08044_row87_col0,#T_08044_row146_col0,#T_08044_row165_col2,#T_08044_row186_col2,#T_08044_row264_col2{
#             background-color:  #3fab72;
#             color:  #000000;
#         }#T_08044_row4_col1,#T_08044_row100_col0,#T_08044_row112_col2,#T_08044_row116_col2,#T_08044_row132_col2,#T_08044_row144_col1,#T_08044_row256_col2,#T_08044_row266_col1,#T_08044_row278_col0{
#             background-color:  #5ebe9b;
#             color:  #000000;
#         }#T_08044_row4_col2,#T_08044_row27_col2,#T_08044_row42_col1,#T_08044_row52_col2,#T_08044_row129_col0,#T_08044_row168_col0{
#             background-color:  #4fb688;
#             color:  #000000;
#         }#T_08044_row5_col0,#T_08044_row142_col1,#T_08044_row156_col2,#T_08044_row193_col2,#T_08044_row258_col0{
#             background-color:  #8cd2bf;
#             color:  #000000;
#         }#T_08044_row5_col1,#T_08044_row34_col0,#T_08044_row72_col0,#T_08044_row81_col0,#T_08044_row142_col0,#T_08044_row176_col2,#T_08044_row177_col2,#T_08044_row189_col0,#T_08044_row192_col1,#T_08044_row210_col1,#T_08044_row242_col0{
#             background-color:  #94d6c5;
#             color:  #000000;
#         }#T_08044_row5_col2,#T_08044_row33_col2,#T_08044_row145_col0{
#             background-color:  #72c7ad;
#             color:  #000000;
#         }#T_08044_row6_col0,#T_08044_row98_col1,#T_08044_row144_col2,#T_08044_row163_col2,#T_08044_row169_col0,#T_08044_row182_col1,#T_08044_row214_col2,#T_08044_row221_col2,#T_08044_row256_col1,#T_08044_row273_col0{
#             background-color:  #5cbd98;
#             color:  #000000;
#         }#T_08044_row6_col1,#T_08044_row12_col2,#T_08044_row43_col1,#T_08044_row60_col2,#T_08044_row68_col0,#T_08044_row75_col1,#T_08044_row76_col0,#T_08044_row105_col2,#T_08044_row107_col2,#T_08044_row112_col0,#T_08044_row113_col1,#T_08044_row114_col1,#T_08044_row155_col2,#T_08044_row262_col1,#T_08044_row266_col0{
#             background-color:  #65c2a3;
#             color:  #000000;
#         }#T_08044_row6_col2,#T_08044_row14_col2,#T_08044_row52_col0,#T_08044_row65_col2,#T_08044_row94_col0,#T_08044_row94_col2,#T_08044_row106_col1,#T_08044_row136_col1,#T_08044_row165_col1{
#             background-color:  #4bb382;
#             color:  #000000;
#         }#T_08044_row7_col0,#T_08044_row167_col0,#T_08044_row168_col1,#T_08044_row186_col1,#T_08044_row201_col0,#T_08044_row204_col1,#T_08044_row264_col1{
#             background-color:  #3ba76c;
#             color:  #000000;
#         }#T_08044_row7_col1,#T_08044_row66_col0,#T_08044_row139_col1,#T_08044_row178_col2,#T_08044_row199_col1{
#             background-color:  #2a9350;
#             color:  #000000;
#         }#T_08044_row7_col2,#T_08044_row19_col0,#T_08044_row59_col2,#T_08044_row136_col2{
#             background-color:  #3aa66a;
#             color:  #000000;
#         }#T_08044_row8_col0,#T_08044_row43_col2,#T_08044_row60_col1,#T_08044_row104_col1,#T_08044_row130_col2,#T_08044_row143_col1,#T_08044_row201_col1{
#             background-color:  #47b17e;
#             color:  #000000;
#         }#T_08044_row8_col1,#T_08044_row28_col1,#T_08044_row79_col1,#T_08044_row104_col0,#T_08044_row130_col0,#T_08044_row130_col1,#T_08044_row174_col0,#T_08044_row220_col0,#T_08044_row254_col2,#T_08044_row273_col2{
#             background-color:  #52b78b;
#             color:  #000000;
#         }#T_08044_row8_col2,#T_08044_row44_col0,#T_08044_row108_col2,#T_08044_row111_col2,#T_08044_row170_col1{
#             background-color:  #37a266;
#             color:  #000000;
#         }#T_08044_row9_col0{
#             background-color:  #19833e;
#             color:  #f1f1f1;
#         }#T_08044_row9_col1,#T_08044_row78_col1,#T_08044_row111_col1{
#             background-color:  #258d48;
#             color:  #000000;
#         }#T_08044_row9_col2,#T_08044_row131_col0{
#             background-color:  #0a7633;
#             color:  #f1f1f1;
#         }#T_08044_row10_col0,#T_08044_row134_col0{
#             background-color:  #18823d;
#             color:  #f1f1f1;
#         }#T_08044_row10_col1,#T_08044_row73_col2,#T_08044_row128_col2,#T_08044_row201_col2,#T_08044_row276_col1{
#             background-color:  #29924f;
#             color:  #000000;
#         }#T_08044_row10_col2,#T_08044_row40_col2{
#             background-color:  #016e2d;
#             color:  #f1f1f1;
#         }#T_08044_row11_col0,#T_08044_row12_col0,#T_08044_row107_col0,#T_08044_row155_col0,#T_08044_row173_col2,#T_08044_row219_col0,#T_08044_row219_col1,#T_08044_row246_col0,#T_08044_row256_col0{
#             background-color:  #68c3a6;
#             color:  #000000;
#         }#T_08044_row11_col2,#T_08044_row26_col2,#T_08044_row119_col0,#T_08044_row169_col2,#T_08044_row243_col0{
#             background-color:  #59bb93;
#             color:  #000000;
#         }#T_08044_row12_col1,#T_08044_row67_col2,#T_08044_row107_col1,#T_08044_row234_col2,#T_08044_row243_col1{
#             background-color:  #62c09f;
#             color:  #000000;
#         }#T_08044_row13_col0,#T_08044_row248_col1,#T_08044_row274_col2{
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }#T_08044_row13_col1{
#             background-color:  #f3fafc;
#             color:  #000000;
#         }#T_08044_row13_col2{
#             background-color:  #f0f9fb;
#             color:  #000000;
#         }#T_08044_row14_col0,#T_08044_row27_col1,#T_08044_row62_col0{
#             background-color:  #4eb586;
#             color:  #000000;
#         }#T_08044_row14_col1,#T_08044_row42_col0,#T_08044_row65_col0,#T_08044_row79_col2,#T_08044_row87_col1,#T_08044_row88_col2,#T_08044_row168_col2,#T_08044_row216_col0{
#             background-color:  #4cb484;
#             color:  #000000;
#         }#T_08044_row15_col1,#T_08044_row1

# %%
add_style(gb_filter_monotonic(sp_500))
# Out:
# <style  type="text/css" >
# #T_ee842_row0_col0{
#             background-color:  #acdfd4;
#             color:  #000000;
#         }#T_ee842_row0_col1{
#             background-color:  #98d8c9;
#             color:  #000000;
#         }#T_ee842_row0_col2{
#             background-color:  #d9f1f0;
#             color:  #000000;
#         }#T_ee842_row1_col0{
#             background-color:  #2e9756;
#             color:  #000000;
#         }#T_ee842_row1_col1{
#             background-color:  #3eaa70;
#             color:  #000000;
#         }#T_ee842_row1_col2{
#             background-color:  #3da96f;
#             color:  #000000;
#         }#T_ee842_row2_col0{
#             background-color:  #005c25;
#             color:  #f1f1f1;
#         }#T_ee842_row2_col1,#T_ee842_row3_col0,#T_ee842_row7_col2{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_ee842_row2_col2{
#             background-color:  #238b45;
#             color:  #000000;
#         }#T_ee842_row3_col1{
#             background-color:  #006729;
#             color:  #f1f1f1;
#         }#T_ee842_row3_col2{
#             background-color:  #005622;
#             color:  #f1f1f1;
#         }#T_ee842_row4_col0,#T_ee842_row4_col1,#T_ee842_row4_col2{
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }#T_ee842_row5_col0{
#             background-color:  #6ac4a7;
#             color:  #000000;
#         }#T_ee842_row5_col1{
#             background-color:  #a2dcce;
#             color:  #000000;
#         }#T_ee842_row5_col2{
#             background-color:  #4cb484;
#             color:  #000000;
#         }#T_ee842_row6_col0{
#             background-color:  #28914d;
#             color:  #000000;
#         }#T_ee842_row6_col1{
#             background-color:  #57ba92;
#             color:  #000000;
#         }#T_ee842_row6_col2{
#             background-color:  #087432;
#             color:  #f1f1f1;
#         }#T_ee842_row7_col0{
#             background-color:  #147e3a;
#             color:  #f1f1f1;
#         }#T_ee842_row7_col1{
#             background-color:  #51b689;
#             color:  #000000;
#         }</style><table id="T_ee842_" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >val_binary_sharpe</th>        <th class="col_heading level0 col1" >val_binary_long_sharpe</th>        <th class="col_heading level0 col2" >val_binary_short_sharpe</th>    </tr>    <tr>        <th class="index_name level0" >asset</th>        <th class="index_name level1" >params</th>        <th class="index_name level2" >model</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ee842_level0_row0" class="row_heading level0 row0" rowspan="8">sp_500</th>
#                         <th id="T_ee842_level1_row0" class="row_heading level1 row0" rowspan="4">219</th>
#                         <th id="T_ee842_level2_row0" class="row_heading level2 row0" >base</th>
#                         <td id="T_ee842_row0_col0" class="data row0 col0" >-0.012647</td>
#                         <td id="T_ee842_row0_col1" class="data row0 col1" >0.127001</td>
#                         <td id="T_ee842_row0_col2" class="data row0 col2" >-0.544383</td>
#             </tr>
#             <tr>
#                                         <th id="T_ee842_level2_row1" class="row_heading level2 row1" >cnp</th>
#                         <td id="T_ee842_row1_col0" class="data row1 col0" >0.624600</td>
#                         <td id="T_ee842_row1_col1" class="data row1 col1" >0.492095</td>
#                         <td id="T_ee842_row1_col2" class="data row1 col2" >0.000521</td>
#             </tr>
#             <tr>
#                                         <th id="T_ee842_level2_row2" class="row_heading level2 row2" >lnp</th>
#                         <td id="T_ee842_row2_col0" class="data row2 col0" >0.996988</td>
#                         <td id="T_ee842_row2_col1" class="data row2 col1" >1.000294</td>
#                         <td id="T_ee842_row2_col2" class="data row2 col2" >0.126419</td>
#             </tr>
#             <tr>
#                                         <th id="T_ee842_level2_row3" class="row_heading level2 row3" >np</th>
#                         <td id="T_ee842_row3_col0" class="data row3 col0" >1.123240</td>
#                         <td id="T_ee842_row3_col1" class="data row3 col1" >0.852172</td>
#                         <td id="T_ee842_row3_col2" class="data row3 col2" >0.359374</td>
#             </tr>
#             <tr>
#                                 <th id="T_ee842_level1_row4" class="row_heading level1 row4" rowspan="4">222</th>
#                         <th id="T_ee842_level2_row4" class="row_heading level2 row4" >base</th>
#                         <td id="T_ee842_row4_col0" class="data row4 col0" >-0.572212</td>
#                         <td id="T_ee842_row4_col1" class="data row4 col1" >-0.403901</td>
#                         <td id="T_ee842_row4_col2" class="data row4 col2" >-0.766301</td>
#             </tr>
#             <tr>
#                                         <th id="T_ee842_level2_row5" class="row_heading level2 row5" >cnp</th>
#                         <td id="T_ee842_row5_col0" class="data row5 col0" >0.260826</td>
#                         <td id="T_ee842_row5_col1" class="data row5 col1" >0.093074</td>
#                         <td id="T_ee842_row5_col2" class="data row5 col2" >-0.065904</td>
#             </tr>
#             <tr>
#                                         <th id="T_ee842_level2_row6" class="row_heading level2 row6" >lnp</th>
#                         <td id="T_ee842_row6_col0" class="data row6 col0" >0.666258</td>
#                         <td id="T_ee842_row6_col1" class="data row6 col1" >0.365598</td>
#                         <td id="T_ee842_row6_col2" class="data row6 col2" >0.242578</td>
#             </tr>
#             <tr>
#                                         <th id="T_ee842_level2_row7" class="row_heading level2 row7" >np</th>
#                         <td id="T_ee842_row7_col0" class="data row7 col0" >0.787448</td>
#                         <td id="T_ee842_row7_col1" class="data row7 col1" >0.397246</td>
#                         <td id="T_ee842_row7_col2" class="data row7 col2" >0.426659</td>
#             </tr>
#     </tbody></table>

# %%
add_style(gb_filter_neg(gb_filter_monotonic_partial(sp_500)))
# Out:
# <style  type="text/css" >
# #T_cc1ae_row0_col0,#T_cc1ae_row16_col0{
#             background-color:  #d2eeeb;
#             color:  #000000;
#         }#T_cc1ae_row0_col1,#T_cc1ae_row5_col2{
#             background-color:  #e8f6fa;
#             color:  #000000;
#         }#T_cc1ae_row0_col2,#T_cc1ae_row52_col0{
#             background-color:  #a4dccf;
#             color:  #000000;
#         }#T_cc1ae_row1_col0{
#             background-color:  #3eaa70;
#             color:  #000000;
#         }#T_cc1ae_row1_col1,#T_cc1ae_row46_col2,#T_cc1ae_row53_col1{
#             background-color:  #339e60;
#             color:  #000000;
#         }#T_cc1ae_row1_col2{
#             background-color:  #52b78b;
#             color:  #000000;
#         }#T_cc1ae_row2_col0,#T_cc1ae_row44_col2,#T_cc1ae_row49_col2{
#             background-color:  #7fcdb6;
#             color:  #000000;
#         }#T_cc1ae_row2_col1,#T_cc1ae_row17_col1{
#             background-color:  #78cab1;
#             color:  #000000;
#         }#T_cc1ae_row2_col2{
#             background-color:  #9cd9ca;
#             color:  #000000;
#         }#T_cc1ae_row3_col0{
#             background-color:  #127c39;
#             color:  #f1f1f1;
#         }#T_cc1ae_row3_col1,#T_cc1ae_row6_col2,#T_cc1ae_row27_col2{
#             background-color:  #0e7936;
#             color:  #f1f1f1;
#         }#T_cc1ae_row3_col2,#T_cc1ae_row13_col0,#T_cc1ae_row42_col0{
#             background-color:  #248c47;
#             color:  #000000;
#         }#T_cc1ae_row4_col0,#T_cc1ae_row8_col1,#T_cc1ae_row14_col1{
#             background-color:  #70c6ac;
#             color:  #000000;
#         }#T_cc1ae_row4_col1{
#             background-color:  #7acbb3;
#             color:  #000000;
#         }#T_cc1ae_row4_col2{
#             background-color:  #68c3a6;
#             color:  #000000;
#         }#T_cc1ae_row5_col0{
#             background-color:  #ecf8fa;
#             color:  #000000;
#         }#T_cc1ae_row5_col1{
#             background-color:  #edf8fb;
#             color:  #000000;
#         }#T_cc1ae_row6_col0,#T_cc1ae_row32_col0,#T_cc1ae_row53_col2{
#             background-color:  #3ba76c;
#             color:  #000000;
#         }#T_cc1ae_row6_col1,#T_cc1ae_row48_col0{
#             background-color:  #60bf9c;
#             color:  #000000;
#         }#T_cc1ae_row7_col0,#T_cc1ae_row43_col0{
#             background-color:  #067230;
#             color:  #f1f1f1;
#         }#T_cc1ae_row7_col1{
#             background-color:  #2b9452;
#             color:  #000000;
#         }#T_cc1ae_row7_col2{
#             background-color:  #00491d;
#             color:  #f1f1f1;
#         }#T_cc1ae_row8_col0{
#             background-color:  #82ceb8;
#             color:  #000000;
#         }#T_cc1ae_row8_col2{
#             background-color:  #9fdacc;
#             color:  #000000;
#         }#T_cc1ae_row9_col0,#T_cc1ae_row46_col1{
#             background-color:  #35a063;
#             color:  #000000;
#         }#T_cc1ae_row9_col1,#T_cc1ae_row40_col0{
#             background-color:  #37a266;
#             color:  #000000;
#         }#T_cc1ae_row9_col2{
#             background-color:  #3fab72;
#             color:  #000000;
#         }#T_cc1ae_row10_col0,#T_cc1ae_row11_col2,#T_cc1ae_row39_col1{
#             background-color:  #107a37;
#             color:  #f1f1f1;
#         }#T_cc1ae_row10_col1{
#             background-color:  #005924;
#             color:  #f1f1f1;
#         }#T_cc1ae_row10_col2,#T_cc1ae_row21_col2,#T_cc1ae_row43_col2{
#             background-color:  #2f9a59;
#             color:  #000000;
#         }#T_cc1ae_row11_col0{
#             background-color:  #026f2e;
#             color:  #f1f1f1;
#         }#T_cc1ae_row11_col1,#T_cc1ae_row31_col2{
#             background-color:  #05712f;
#             color:  #f1f1f1;
#         }#T_cc1ae_row12_col0{
#             background-color:  #f0f9fb;
#             color:  #000000;
#         }#T_cc1ae_row12_col1{
#             background-color:  #f4fbfc;
#             color:  #000000;
#         }#T_cc1ae_row12_col2{
#             background-color:  #e4f5f8;
#             color:  #000000;
#         }#T_cc1ae_row13_col1,#T_cc1ae_row19_col1,#T_cc1ae_row26_col0{
#             background-color:  #44af79;
#             color:  #000000;
#         }#T_cc1ae_row13_col2{
#             background-color:  #006c2c;
#             color:  #f1f1f1;
#         }#T_cc1ae_row14_col0,#T_cc1ae_row18_col1{
#             background-color:  #48b27f;
#             color:  #000000;
#         }#T_cc1ae_row14_col2,#T_cc1ae_row54_col0{
#             background-color:  #19833e;
#             color:  #f1f1f1;
#         }#T_cc1ae_row15_col0{
#             background-color:  #2a9350;
#             color:  #000000;
#         }#T_cc1ae_row15_col1{
#             background-color:  #3ca86d;
#             color:  #000000;
#         }#T_cc1ae_row15_col2{
#             background-color:  #1f8742;
#             color:  #000000;
#         }#T_cc1ae_row16_col1{
#             background-color:  #d8f0ef;
#             color:  #000000;
#         }#T_cc1ae_row16_col2{
#             background-color:  #cdece6;
#             color:  #000000;
#         }#T_cc1ae_row17_col0,#T_cc1ae_row40_col2{
#             background-color:  #5bbc96;
#             color:  #000000;
#         }#T_cc1ae_row17_col2{
#             background-color:  #47b17e;
#             color:  #000000;
#         }#T_cc1ae_row18_col0{
#             background-color:  #319c5c;
#             color:  #000000;
#         }#T_cc1ae_row18_col2,#T_cc1ae_row20_col1,#T_cc1ae_row37_col1{
#             background-color:  #218944;
#             color:  #000000;
#         }#T_cc1ae_row19_col0{
#             background-color:  #268f4a;
#             color:  #000000;
#         }#T_cc1ae_row19_col2{
#             background-color:  #077331;
#             color:  #f1f1f1;
#         }#T_cc1ae_row20_col0,#T_cc1ae_row55_col1{
#             background-color:  #2d9655;
#             color:  #000000;
#         }#T_cc1ae_row20_col2{
#             background-color:  #3fac74;
#             color:  #000000;
#         }#T_cc1ae_row21_col0{
#             background-color:  #36a164;
#             color:  #000000;
#         }#T_cc1ae_row21_col1{
#             background-color:  #43af78;
#             color:  #000000;
#         }#T_cc1ae_row22_col0,#T_cc1ae_row41_col2{
#             background-color:  #238b45;
#             color:  #000000;
#         }#T_cc1ae_row22_col1,#T_cc1ae_row34_col1,#T_cc1ae_row44_col1,#T_cc1ae_row46_col0{
#             background-color:  #329d5e;
#             color:  #000000;
#         }#T_cc1ae_row22_col2{
#             background-color:  #16803c;
#             color:  #f1f1f1;
#         }#T_cc1ae_row23_col0{
#             background-color:  #0a7633;
#             color:  #f1f1f1;
#         }#T_cc1ae_row23_col1{
#             background-color:  #0b7734;
#             color:  #f1f1f1;
#         }#T_cc1ae_row23_col2{
#             background-color:  #17813d;
#             color:  #f1f1f1;
#         }#T_cc1ae_row24_col0{
#             background-color:  #bde6de;
#             color:  #000000;
#         }#T_cc1ae_row24_col1{
#             background-color:  #cdece7;
#             color:  #000000;
#         }#T_cc1ae_row24_col2{
#             background-color:  #b2e2d7;
#             color:  #000000;
#         }#T_cc1ae_row25_col0,#T_cc1ae_row25_col1,#T_cc1ae_row25_col2{
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }#T_cc1ae_row26_col1,#T_cc1ae_row42_col2{
#             background-color:  #57ba92;
#             color:  #000000;
#         }#T_cc1ae_row26_col2,#T_cc1ae_row37_col0{
#             background-color:  #38a367;
#             color:  #000000;
#         }#T_cc1ae_row27_col0,#T_cc1ae_row36_col1,#T_cc1ae_row47_col2{
#             background-color:  #41ae77;
#             color:  #000000;
#         }#T_cc1ae_row27_col1,#T_cc1ae_row37_col2{
#             background-color:  #6ac4a7;
#             color:  #000000;
#         }#T_cc1ae_row28_col0,#T_cc1ae_row34_col0{
#             background-color:  #6dc5a9;
#             color:  #000000;
#         }#T_cc1ae_row28_col1{
#             background-color:  #5dbd99;
#             color:  #000000;
#         }#T_cc1ae_row28_col2{
#             background-color:  #8ad2be;
#             color:  #000000;
#         }#T_cc1ae_row29_col0{
#             background-color:  #84cfb9;
#             co

# %%
add_style(gb_filter_monotonic(russell_2000))
# Out:
# <style  type="text/css" >
# #T_0879b_row0_col0,#T_0879b_row0_col1,#T_0879b_row0_col2{
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }#T_0879b_row1_col0{
#             background-color:  #4bb382;
#             color:  #000000;
#         }#T_0879b_row1_col1{
#             background-color:  #4eb586;
#             color:  #000000;
#         }#T_0879b_row1_col2{
#             background-color:  #4ab381;
#             color:  #000000;
#         }#T_0879b_row2_col0{
#             background-color:  #3fab72;
#             color:  #000000;
#         }#T_0879b_row2_col1{
#             background-color:  #41ae77;
#             color:  #000000;
#         }#T_0879b_row2_col2{
#             background-color:  #3ba76c;
#             color:  #000000;
#         }#T_0879b_row3_col0,#T_0879b_row3_col1,#T_0879b_row3_col2{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }</style><table id="T_0879b_" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >val_binary_sharpe</th>        <th class="col_heading level0 col1" >val_binary_long_sharpe</th>        <th class="col_heading level0 col2" >val_binary_short_sharpe</th>    </tr>    <tr>        <th class="index_name level0" >asset</th>        <th class="index_name level1" >params</th>        <th class="index_name level2" >model</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0879b_level0_row0" class="row_heading level0 row0" rowspan="4">russell_2000</th>
#                         <th id="T_0879b_level1_row0" class="row_heading level1 row0" rowspan="4">254</th>
#                         <th id="T_0879b_level2_row0" class="row_heading level2 row0" >base</th>
#                         <td id="T_0879b_row0_col0" class="data row0 col0" >-0.285766</td>
#                         <td id="T_0879b_row0_col1" class="data row0 col1" >-0.263217</td>
#                         <td id="T_0879b_row0_col2" class="data row0 col2" >-0.135481</td>
#             </tr>
#             <tr>
#                                         <th id="T_0879b_level2_row1" class="row_heading level2 row1" >cnp</th>
#                         <td id="T_0879b_row1_col0" class="data row1 col0" >0.616289</td>
#                         <td id="T_0879b_row1_col1" class="data row1 col1" >0.371074</td>
#                         <td id="T_0879b_row1_col2" class="data row1 col2" >0.498444</td>
#             </tr>
#             <tr>
#                                         <th id="T_0879b_level2_row2" class="row_heading level2 row2" >lnp</th>
#                         <td id="T_0879b_row2_col0" class="data row2 col0" >0.685095</td>
#                         <td id="T_0879b_row2_col1" class="data row2 col1" >0.414963</td>
#                         <td id="T_0879b_row2_col2" class="data row2 col2" >0.553216</td>
#             </tr>
#             <tr>
#                                         <th id="T_0879b_level2_row3" class="row_heading level2 row3" >np</th>
#                         <td id="T_0879b_row3_col0" class="data row3 col0" >1.242215</td>
#                         <td id="T_0879b_row3_col1" class="data row3 col1" >0.827108</td>
#                         <td id="T_0879b_row3_col2" class="data row3 col2" >0.925561</td>
#             </tr>
#     </tbody></table>

# %%
add_style(gb_filter_neg(gb_filter_monotonic_partial(russell_2000)))
# Out:
# <style  type="text/css" >
# #T_d487e_row0_col0,#T_d487e_row26_col2{
#             background-color:  #d1eee9;
#             color:  #000000;
#         }#T_d487e_row0_col1{
#             background-color:  #98d8c9;
#             color:  #000000;
#         }#T_d487e_row0_col2,#T_d487e_row13_col2{
#             background-color:  #edf8fb;
#             color:  #000000;
#         }#T_d487e_row1_col0{
#             background-color:  #40ad75;
#             color:  #000000;
#         }#T_d487e_row1_col1{
#             background-color:  #29924f;
#             color:  #000000;
#         }#T_d487e_row1_col2,#T_d487e_row7_col2,#T_d487e_row23_col1,#T_d487e_row42_col0{
#             background-color:  #74c8ae;
#             color:  #000000;
#         }#T_d487e_row2_col0,#T_d487e_row12_col1,#T_d487e_row43_col1{
#             background-color:  #41ae77;
#             color:  #000000;
#         }#T_d487e_row2_col1{
#             background-color:  #228a44;
#             color:  #000000;
#         }#T_d487e_row2_col2{
#             background-color:  #80cdb7;
#             color:  #000000;
#         }#T_d487e_row3_col0{
#             background-color:  #3fac74;
#             color:  #000000;
#         }#T_d487e_row3_col1{
#             background-color:  #2b9452;
#             color:  #000000;
#         }#T_d487e_row3_col2{
#             background-color:  #68c3a6;
#             color:  #000000;
#         }#T_d487e_row4_col0,#T_d487e_row8_col2{
#             background-color:  #c0e7df;
#             color:  #000000;
#         }#T_d487e_row4_col1,#T_d487e_row28_col0,#T_d487e_row29_col1{
#             background-color:  #82ceb8;
#             color:  #000000;
#         }#T_d487e_row4_col2,#T_d487e_row36_col1{
#             background-color:  #e7f6f9;
#             color:  #000000;
#         }#T_d487e_row5_col0{
#             background-color:  #bae5dc;
#             color:  #000000;
#         }#T_d487e_row5_col1,#T_d487e_row42_col1,#T_d487e_row42_col2{
#             background-color:  #7dccb5;
#             color:  #000000;
#         }#T_d487e_row5_col2{
#             background-color:  #e4f5f8;
#             color:  #000000;
#         }#T_d487e_row6_col0{
#             background-color:  #48b27f;
#             color:  #000000;
#         }#T_d487e_row6_col1{
#             background-color:  #1d8640;
#             color:  #000000;
#         }#T_d487e_row6_col2{
#             background-color:  #94d6c5;
#             color:  #000000;
#         }#T_d487e_row7_col0,#T_d487e_row35_col1{
#             background-color:  #4ab381;
#             color:  #000000;
#         }#T_d487e_row7_col1{
#             background-color:  #349f61;
#             color:  #000000;
#         }#T_d487e_row8_col0,#T_d487e_row10_col0{
#             background-color:  #b8e4db;
#             color:  #000000;
#         }#T_d487e_row8_col1,#T_d487e_row10_col1,#T_d487e_row16_col0{
#             background-color:  #b7e4da;
#             color:  #000000;
#         }#T_d487e_row9_col0,#T_d487e_row22_col0{
#             background-color:  #85cfbb;
#             color:  #000000;
#         }#T_d487e_row9_col1,#T_d487e_row22_col2{
#             background-color:  #87d0bc;
#             color:  #000000;
#         }#T_d487e_row9_col2,#T_d487e_row26_col0{
#             background-color:  #92d5c4;
#             color:  #000000;
#         }#T_d487e_row10_col2{
#             background-color:  #c2e8e0;
#             color:  #000000;
#         }#T_d487e_row11_col0{
#             background-color:  #54b88e;
#             color:  #000000;
#         }#T_d487e_row11_col1{
#             background-color:  #61bf9e;
#             color:  #000000;
#         }#T_d487e_row11_col2,#T_d487e_row38_col1{
#             background-color:  #47b17e;
#             color:  #000000;
#         }#T_d487e_row12_col0{
#             background-color:  #70c6ac;
#             color:  #000000;
#         }#T_d487e_row12_col2{
#             background-color:  #bce6dd;
#             color:  #000000;
#         }#T_d487e_row13_col0{
#             background-color:  #d0ede9;
#             color:  #000000;
#         }#T_d487e_row13_col1{
#             background-color:  #95d6c6;
#             color:  #000000;
#         }#T_d487e_row14_col0{
#             background-color:  #45b07b;
#             color:  #000000;
#         }#T_d487e_row14_col1,#T_d487e_row15_col0{
#             background-color:  #1e8741;
#             color:  #000000;
#         }#T_d487e_row14_col2,#T_d487e_row29_col2,#T_d487e_row34_col2{
#             background-color:  #8cd2bf;
#             color:  #000000;
#         }#T_d487e_row15_col1,#T_d487e_row21_col1{
#             background-color:  #016e2d;
#             color:  #f1f1f1;
#         }#T_d487e_row15_col2,#T_d487e_row35_col0{
#             background-color:  #4bb382;
#             color:  #000000;
#         }#T_d487e_row16_col1,#T_d487e_row40_col1{
#             background-color:  #b5e3d9;
#             color:  #000000;
#         }#T_d487e_row16_col2{
#             background-color:  #d1eeea;
#             color:  #000000;
#         }#T_d487e_row17_col0,#T_d487e_row17_col2,#T_d487e_row27_col1{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_d487e_row17_col1{
#             background-color:  #005e26;
#             color:  #f1f1f1;
#         }#T_d487e_row18_col0{
#             background-color:  #6cc4a8;
#             color:  #000000;
#         }#T_d487e_row18_col1,#T_d487e_row38_col2{
#             background-color:  #6fc6aa;
#             color:  #000000;
#         }#T_d487e_row18_col2{
#             background-color:  #7ccbb4;
#             color:  #000000;
#         }#T_d487e_row19_col0{
#             background-color:  #64c1a2;
#             color:  #000000;
#         }#T_d487e_row19_col1{
#             background-color:  #65c2a3;
#             color:  #000000;
#         }#T_d487e_row19_col2,#T_d487e_row23_col0{
#             background-color:  #75c9af;
#             color:  #000000;
#         }#T_d487e_row20_col0,#T_d487e_row20_col1{
#             background-color:  #b4e2d8;
#             color:  #000000;
#         }#T_d487e_row20_col2{
#             background-color:  #b2e2d7;
#             color:  #000000;
#         }#T_d487e_row21_col0{
#             background-color:  #006227;
#             color:  #f1f1f1;
#         }#T_d487e_row21_col2{
#             background-color:  #05712f;
#             color:  #f1f1f1;
#         }#T_d487e_row22_col1,#T_d487e_row28_col1{
#             background-color:  #88d1bd;
#             color:  #000000;
#         }#T_d487e_row23_col2{
#             background-color:  #8ad2be;
#             color:  #000000;
#         }#T_d487e_row24_col0{
#             background-color:  #3ba76c;
#             color:  #000000;
#         }#T_d487e_row24_col1{
#             background-color:  #006328;
#             color:  #f1f1f1;
#         }#T_d487e_row24_col2{
#             background-color:  #8dd3c0;
#             color:  #000000;
#         }#T_d487e_row25_col0{
#             background-color:  #27904c;
#             color:  #000000;
#         }#T_d487e_row25_col1{
#             background-color:  #006529;
#             color:  #f1f1f1;
#         }#T_d487e_row25_col2{
#             background-color:  #63c0a0;
#             color:  #000000;
#         }#T_d487e_row26_col1,#T_d487e_row37_col0{
#             background-color:  #5dbd99;
#             color:  #000000;
#         }#T_d487e_row27_col0{
#             background-color:  #005c25;
#             color:  #f1f1f1;
#         }#T_d487e_row27_col2{
#             background-color:  #218944;
#             color:  #000000;
#         }#T_d487e_row28_col2{
#             background-color:  #78cab1;
#             color:  #000000;
#         }#T_d487e_row29_col0,#T_d487e_row31_col0,#T_d487e_row37_col2{
#             background-color:  #7fcdb6;
#             color:  #000000;
#         }#T_d487e_row30_col0,#T_d487e_row30_col1{
#             background-color:  #a8ded2;
#             color:  #000000;
#         }#T_d487e_row30_col2{
#             background-color:  #ade0d4;
#             color:  #000000;
#         }#T_d487e_row31_col1,#T_d487e_row31_col2{
#             background-color:  #84cfb9;
#             color:  #000000;
#         }#T_d487e_row32_col0,#T_d487e_row32_col1{
#             background-color:  #d8f0ef;
#             color:  #000000;
#         }#T_d487e_row32_col2{
#             background-color:  #dbf2f2;
#             color:  #000000;

# %%
add_style(gb_filter_monotonic(nasdaq_100))
# Out:
# <style  type="text/css" >
# #T_0638c_row0_col0{
#             background-color:  #bfe7de;
#             color:  #000000;
#         }#T_0638c_row0_col1{
#             background-color:  #aadfd3;
#             color:  #000000;
#         }#T_0638c_row0_col2{
#             background-color:  #c7eae3;
#             color:  #000000;
#         }#T_0638c_row1_col0{
#             background-color:  #8fd4c2;
#             color:  #000000;
#         }#T_0638c_row1_col1{
#             background-color:  #94d6c5;
#             color:  #000000;
#         }#T_0638c_row1_col2{
#             background-color:  #87d0bc;
#             color:  #000000;
#         }#T_0638c_row2_col0,#T_0638c_row2_col1{
#             background-color:  #6fc6aa;
#             color:  #000000;
#         }#T_0638c_row2_col2{
#             background-color:  #68c3a6;
#             color:  #000000;
#         }#T_0638c_row3_col0{
#             background-color:  #51b689;
#             color:  #000000;
#         }#T_0638c_row3_col1{
#             background-color:  #4bb382;
#             color:  #000000;
#         }#T_0638c_row3_col2{
#             background-color:  #53b88c;
#             color:  #000000;
#         }#T_0638c_row4_col0{
#             background-color:  #f0f9fb;
#             color:  #000000;
#         }#T_0638c_row4_col1{
#             background-color:  #eaf7fa;
#             color:  #000000;
#         }#T_0638c_row4_col2{
#             background-color:  #e1f4f6;
#             color:  #000000;
#         }#T_0638c_row5_col0{
#             background-color:  #eff9fb;
#             color:  #000000;
#         }#T_0638c_row5_col1{
#             background-color:  #e9f7fa;
#             color:  #000000;
#         }#T_0638c_row5_col2{
#             background-color:  #e0f3f5;
#             color:  #000000;
#         }#T_0638c_row6_col0{
#             background-color:  #00692a;
#             color:  #f1f1f1;
#         }#T_0638c_row6_col1,#T_0638c_row15_col0{
#             background-color:  #006529;
#             color:  #f1f1f1;
#         }#T_0638c_row6_col2{
#             background-color:  #00682a;
#             color:  #f1f1f1;
#         }#T_0638c_row7_col0,#T_0638c_row7_col1,#T_0638c_row7_col2{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_0638c_row8_col0,#T_0638c_row8_col1,#T_0638c_row8_col2{
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }#T_0638c_row9_col0,#T_0638c_row13_col0,#T_0638c_row13_col1{
#             background-color:  #dbf2f2;
#             color:  #000000;
#         }#T_0638c_row9_col1{
#             background-color:  #bde6de;
#             color:  #000000;
#         }#T_0638c_row9_col2{
#             background-color:  #cdece6;
#             color:  #000000;
#         }#T_0638c_row10_col0{
#             background-color:  #329d5e;
#             color:  #000000;
#         }#T_0638c_row10_col1{
#             background-color:  #258d48;
#             color:  #000000;
#         }#T_0638c_row10_col2{
#             background-color:  #309b5b;
#             color:  #000000;
#         }#T_0638c_row11_col0{
#             background-color:  #016e2d;
#             color:  #f1f1f1;
#         }#T_0638c_row11_col1{
#             background-color:  #107a37;
#             color:  #f1f1f1;
#         }#T_0638c_row11_col2{
#             background-color:  #005e26;
#             color:  #f1f1f1;
#         }#T_0638c_row12_col0{
#             background-color:  #e8f6fa;
#             color:  #000000;
#         }#T_0638c_row12_col1{
#             background-color:  #e5f5f9;
#             color:  #000000;
#         }#T_0638c_row12_col2{
#             background-color:  #d9f1f0;
#             color:  #000000;
#         }#T_0638c_row13_col2{
#             background-color:  #ccece6;
#             color:  #000000;
#         }#T_0638c_row14_col0{
#             background-color:  #0c7735;
#             color:  #f1f1f1;
#         }#T_0638c_row14_col1{
#             background-color:  #005c25;
#             color:  #f1f1f1;
#         }#T_0638c_row14_col2{
#             background-color:  #147e3a;
#             color:  #f1f1f1;
#         }#T_0638c_row15_col1{
#             background-color:  #006b2b;
#             color:  #f1f1f1;
#         }#T_0638c_row15_col2{
#             background-color:  #005f26;
#             color:  #f1f1f1;
#         }</style><table id="T_0638c_" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >val_binary_sharpe</th>        <th class="col_heading level0 col1" >val_binary_long_sharpe</th>        <th class="col_heading level0 col2" >val_binary_short_sharpe</th>    </tr>    <tr>        <th class="index_name level0" >asset</th>        <th class="index_name level1" >params</th>        <th class="index_name level2" >model</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0638c_level0_row0" class="row_heading level0 row0" rowspan="16">nasdaq_100</th>
#                         <th id="T_0638c_level1_row0" class="row_heading level1 row0" rowspan="4">206</th>
#                         <th id="T_0638c_level2_row0" class="row_heading level2 row0" >base</th>
#                         <td id="T_0638c_row0_col0" class="data row0 col0" >0.062327</td>
#                         <td id="T_0638c_row0_col1" class="data row0 col1" >0.147911</td>
#                         <td id="T_0638c_row0_col2" class="data row0 col2" >-0.309236</td>
#             </tr>
#             <tr>
#                                         <th id="T_0638c_level2_row1" class="row_heading level2 row1" >cnp</th>
#                         <td id="T_0638c_row1_col0" class="data row1 col0" >0.252508</td>
#                         <td id="T_0638c_row1_col1" class="data row1 col1" >0.217440</td>
#                         <td id="T_0638c_row1_col2" class="data row1 col2" >-0.118216</td>
#             </tr>
#             <tr>
#                                         <th id="T_0638c_level2_row2" class="row_heading level2 row2" >lnp</th>
#                         <td id="T_0638c_row2_col0" class="data row2 col0" >0.380472</td>
#                         <td id="T_0638c_row2_col1" class="data row2 col1" >0.321332</td>
#                         <td id="T_0638c_row2_col2" class="data row2 col2" >-0.029497</td>
#             </tr>
#             <tr>
#                                         <th id="T_0638c_level2_row3" class="row_heading level2 row3" >np</th>
#                         <td id="T_0638c_row3_col0" class="data row3 col0" >0.531959</td>
#                         <td id="T_0638c_row3_col1" class="data row3 col1" >0.460816</td>
#                         <td id="T_0638c_row3_col2" class="data row3 col2" >0.058215</td>
#             </tr>
#             <tr>
#                                 <th id="T_0638c_level1_row4" class="row_heading level1 row4" rowspan="4">244</th>
#                         <th id="T_0638c_level2_row4" class="row_heading level2 row4" >base</th>
#                         <td id="T_0638c_row4_col0" class="data row4 col0" >-0.310570</td>
#                         <td id="T_0638c_row4_col1" class="data row4 col1" >-0.139561</td>
#                         <td id="T_0638c_row4_col2" class="data row4 col2" >-0.450835</td>
#             </tr>
#             <tr>
#                                         <th id="T_0638c_level2_row5" class="row_heading level2 row5" >cnp</th>
#                         <td id="T_0638c_row5_col0" class="data row5 col0" >-0.295290</td>
#                         <td id="T_0638c_row5_col1" class="data row5 col1" >-0.134093</td>
#                         <td id="T_0638c_row5_col2" class="data row5 col2" >-0.443407</td>
#             </tr>
#             <tr>
#                                         <th id="T_0638c_level2_row6" class="row_heading level2 row6" >lnp</th>
#                         <td id="T_0638c_row6_col0" class="data row6 col0" >1.033421</td>
#                         <td id="T_0638c_row6_col1" class="data row6 col1" >0.826986</td>
#                         <td id="T_0638c_row6_col2" class="data row6 col2" >0.449136</td>
#             </tr>
#             <tr>

# %%
add_style(gb_filter_neg(gb_filter_monotonic_partial(nasdaq_100)))
# Out:
# <style  type="text/css" >
# #T_c1f72_row0_col0,#T_c1f72_row0_col1,#T_c1f72_row2_col0{
#             background-color:  #9cd9ca;
#             color:  #000000;
#         }#T_c1f72_row0_col2{
#             background-color:  #9ad8ca;
#             color:  #000000;
#         }#T_c1f72_row1_col0{
#             background-color:  #d5efed;
#             color:  #000000;
#         }#T_c1f72_row1_col1{
#             background-color:  #daf1f1;
#             color:  #000000;
#         }#T_c1f72_row1_col2{
#             background-color:  #d2eeeb;
#             color:  #000000;
#         }#T_c1f72_row2_col1{
#             background-color:  #a8ded2;
#             color:  #000000;
#         }#T_c1f72_row2_col2,#T_c1f72_row6_col0,#T_c1f72_row16_col2{
#             background-color:  #90d4c3;
#             color:  #000000;
#         }#T_c1f72_row3_col0,#T_c1f72_row31_col0{
#             background-color:  #5dbd99;
#             color:  #000000;
#         }#T_c1f72_row3_col1,#T_c1f72_row27_col1,#T_c1f72_row43_col1{
#             background-color:  #40ad75;
#             color:  #000000;
#         }#T_c1f72_row3_col2{
#             background-color:  #6ac4a7;
#             color:  #000000;
#         }#T_c1f72_row4_col0,#T_c1f72_row13_col0{
#             background-color:  #6dc5a9;
#             color:  #000000;
#         }#T_c1f72_row4_col1{
#             background-color:  #7ccbb4;
#             color:  #000000;
#         }#T_c1f72_row4_col2{
#             background-color:  #62c09f;
#             color:  #000000;
#         }#T_c1f72_row5_col0{
#             background-color:  #60bf9c;
#             color:  #000000;
#         }#T_c1f72_row5_col1{
#             background-color:  #65c2a3;
#             color:  #000000;
#         }#T_c1f72_row5_col2{
#             background-color:  #59bb93;
#             color:  #000000;
#         }#T_c1f72_row6_col1,#T_c1f72_row22_col2{
#             background-color:  #84cfb9;
#             color:  #000000;
#         }#T_c1f72_row6_col2,#T_c1f72_row20_col2{
#             background-color:  #94d6c5;
#             color:  #000000;
#         }#T_c1f72_row7_col0,#T_c1f72_row42_col2{
#             background-color:  #5cbd98;
#             color:  #000000;
#         }#T_c1f72_row7_col1,#T_c1f72_row14_col2{
#             background-color:  #05712f;
#             color:  #f1f1f1;
#         }#T_c1f72_row7_col2,#T_c1f72_row29_col2,#T_c1f72_row38_col2{
#             background-color:  #75c9af;
#             color:  #000000;
#         }#T_c1f72_row8_col0{
#             background-color:  #cfede8;
#             color:  #000000;
#         }#T_c1f72_row8_col1{
#             background-color:  #c5e9e2;
#             color:  #000000;
#         }#T_c1f72_row8_col2{
#             background-color:  #dbf2f2;
#             color:  #000000;
#         }#T_c1f72_row9_col0,#T_c1f72_row9_col1,#T_c1f72_row12_col2,#T_c1f72_row17_col1{
#             background-color:  #b5e3d9;
#             color:  #000000;
#         }#T_c1f72_row9_col2{
#             background-color:  #c0e7df;
#             color:  #000000;
#         }#T_c1f72_row10_col0,#T_c1f72_row17_col2{
#             background-color:  #a0dbcd;
#             color:  #000000;
#         }#T_c1f72_row10_col1,#T_c1f72_row20_col1{
#             background-color:  #9fdacc;
#             color:  #000000;
#         }#T_c1f72_row10_col2{
#             background-color:  #ade0d4;
#             color:  #000000;
#         }#T_c1f72_row11_col0{
#             background-color:  #88d1bd;
#             color:  #000000;
#         }#T_c1f72_row11_col1{
#             background-color:  #7fcdb6;
#             color:  #000000;
#         }#T_c1f72_row11_col2,#T_c1f72_row20_col0,#T_c1f72_row22_col1{
#             background-color:  #98d8c9;
#             color:  #000000;
#         }#T_c1f72_row12_col0{
#             background-color:  #bae5dc;
#             color:  #000000;
#         }#T_c1f72_row12_col1{
#             background-color:  #c2e8e0;
#             color:  #000000;
#         }#T_c1f72_row13_col1{
#             background-color:  #87d0bc;
#             color:  #000000;
#         }#T_c1f72_row13_col2,#T_c1f72_row23_col2{
#             background-color:  #56ba91;
#             color:  #000000;
#         }#T_c1f72_row14_col0{
#             background-color:  #03702e;
#             color:  #f1f1f1;
#         }#T_c1f72_row14_col1{
#             background-color:  #006d2c;
#             color:  #f1f1f1;
#         }#T_c1f72_row15_col0{
#             background-color:  #63c0a0;
#             color:  #000000;
#         }#T_c1f72_row15_col1{
#             background-color:  #7acbb3;
#             color:  #000000;
#         }#T_c1f72_row15_col2{
#             background-color:  #52b78b;
#             color:  #000000;
#         }#T_c1f72_row16_col0{
#             background-color:  #85cfbb;
#             color:  #000000;
#         }#T_c1f72_row16_col1{
#             background-color:  #61bf9e;
#             color:  #000000;
#         }#T_c1f72_row17_col0{
#             background-color:  #aadfd3;
#             color:  #000000;
#         }#T_c1f72_row18_col0,#T_c1f72_row27_col0{
#             background-color:  #4eb586;
#             color:  #000000;
#         }#T_c1f72_row18_col1,#T_c1f72_row39_col1{
#             background-color:  #4cb484;
#             color:  #000000;
#         }#T_c1f72_row18_col2{
#             background-color:  #4db585;
#             color:  #000000;
#         }#T_c1f72_row19_col0{
#             background-color:  #228a44;
#             color:  #000000;
#         }#T_c1f72_row19_col1{
#             background-color:  #329d5e;
#             color:  #000000;
#         }#T_c1f72_row19_col2{
#             background-color:  #107a37;
#             color:  #f1f1f1;
#         }#T_c1f72_row21_col0{
#             background-color:  #8ad2be;
#             color:  #000000;
#         }#T_c1f72_row21_col1{
#             background-color:  #67c2a5;
#             color:  #000000;
#         }#T_c1f72_row21_col2{
#             background-color:  #95d6c6;
#             color:  #000000;
#         }#T_c1f72_row22_col0{
#             background-color:  #8dd3c0;
#             color:  #000000;
#         }#T_c1f72_row23_col0{
#             background-color:  #5ebe9b;
#             color:  #000000;
#         }#T_c1f72_row23_col1,#T_c1f72_row24_col2{
#             background-color:  #68c3a6;
#             color:  #000000;
#         }#T_c1f72_row24_col0{
#             background-color:  #70c6ac;
#             color:  #000000;
#         }#T_c1f72_row24_col1,#T_c1f72_row29_col1{
#             background-color:  #78cab1;
#             color:  #000000;
#         }#T_c1f72_row25_col0{
#             background-color:  #d0ede9;
#             color:  #000000;
#         }#T_c1f72_row25_col1{
#             background-color:  #d4efec;
#             color:  #000000;
#         }#T_c1f72_row25_col2{
#             background-color:  #cdece7;
#             color:  #000000;
#         }#T_c1f72_row26_col0,#T_c1f72_row38_col0{
#             background-color:  #6cc4a8;
#             color:  #000000;
#         }#T_c1f72_row26_col1{
#             background-color:  #64c1a2;
#             color:  #000000;
#         }#T_c1f72_row26_col2{
#             background-color:  #6fc6aa;
#             color:  #000000;
#         }#T_c1f72_row27_col2{
#             background-color:  #54b88e;
#             color:  #000000;
#         }#T_c1f72_row28_col0,#T_c1f72_row28_col1,#T_c1f72_row36_col2{
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }#T_c1f72_row28_col2{
#             background-color:  #f1fafc;
#             color:  #000000;
#         }#T_c1f72_row29_col0,#T_c1f72_row31_col1{
#             background-color:  #77c9b0;
#             color:  #000000;
#         }#T_c1f72_row30_col0,#T_c1f72_row30_col1,#T_c1f72_row30_col2{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_c1f72_row31_col2,#T_c1f72_row43_col0{
#             background-color:  #44af79;
#             color:  #000000;
#         }#T_c1f72_row32_col0{
#             background-color:  #eaf7fa;
#             color:  #000000;
#         }#T_c1f72_row32_col1,#T_c1f72_row33_col1{
#             background-color:  #e7f6f9;
#             color:  #000000;
#         }#T_c1f72_row32_col2,#T_c1f72_row33_col0,#T_c1f72_row33_col2{
#             background-color:  #e9f7fa;
#             color:  #000000;
#         }#T_c1f72_row34_col0,#T_c1f72_row43_col2{
#             back

# %%
add_style(gb_filter_monotonic(dow_jones))
# Out:
# <style  type="text/css" >
# #T_ec184_row0_col0,#T_ec184_row0_col1,#T_ec184_row0_col2{
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }#T_ec184_row1_col0{
#             background-color:  #bfe7de;
#             color:  #000000;
#         }#T_ec184_row1_col1{
#             background-color:  #b8e4db;
#             color:  #000000;
#         }#T_ec184_row1_col2{
#             background-color:  #d9f1f0;
#             color:  #000000;
#         }#T_ec184_row2_col0{
#             background-color:  #48b27f;
#             color:  #000000;
#         }#T_ec184_row2_col1{
#             background-color:  #4cb484;
#             color:  #000000;
#         }#T_ec184_row2_col2{
#             background-color:  #5abb95;
#             color:  #000000;
#         }#T_ec184_row3_col0,#T_ec184_row3_col1,#T_ec184_row3_col2{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }</style><table id="T_ec184_" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >val_binary_sharpe</th>        <th class="col_heading level0 col1" >val_binary_long_sharpe</th>        <th class="col_heading level0 col2" >val_binary_short_sharpe</th>    </tr>    <tr>        <th class="index_name level0" >asset</th>        <th class="index_name level1" >params</th>        <th class="index_name level2" >model</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ec184_level0_row0" class="row_heading level0 row0" rowspan="4">dow_jones</th>
#                         <th id="T_ec184_level1_row0" class="row_heading level1 row0" rowspan="4">269</th>
#                         <th id="T_ec184_level2_row0" class="row_heading level2 row0" >base</th>
#                         <td id="T_ec184_row0_col0" class="data row0 col0" >-0.963561</td>
#                         <td id="T_ec184_row0_col1" class="data row0 col1" >-0.571537</td>
#                         <td id="T_ec184_row0_col2" class="data row0 col2" >-1.080683</td>
#             </tr>
#             <tr>
#                                         <th id="T_ec184_level2_row1" class="row_heading level2 row1" >cnp</th>
#                         <td id="T_ec184_row1_col0" class="data row1 col0" >-0.550794</td>
#                         <td id="T_ec184_row1_col1" class="data row1 col1" >-0.312646</td>
#                         <td id="T_ec184_row1_col2" class="data row1 col2" >-0.856717</td>
#             </tr>
#             <tr>
#                                         <th id="T_ec184_level2_row2" class="row_heading level2 row2" >lnp</th>
#                         <td id="T_ec184_row2_col0" class="data row2 col0" >-0.095523</td>
#                         <td id="T_ec184_row2_col1" class="data row2 col1" >-0.060866</td>
#                         <td id="T_ec184_row2_col2" class="data row2 col2" >-0.426762</td>
#             </tr>
#             <tr>
#                                         <th id="T_ec184_level2_row3" class="row_heading level2 row3" >np</th>
#                         <td id="T_ec184_row3_col0" class="data row3 col0" >0.486466</td>
#                         <td id="T_ec184_row3_col1" class="data row3 col1" >0.295724</td>
#                         <td id="T_ec184_row3_col2" class="data row3 col2" >0.124122</td>
#             </tr>
#     </tbody></table>

# %%
add_style(gb_filter_neg(gb_filter_monotonic_partial(dow_jones)))
# Out:
# <style  type="text/css" >
# #T_61634_row0_col0{
#             background-color:  #88d1bd;
#             color:  #000000;
#         }#T_61634_row0_col1{
#             background-color:  #82ceb8;
#             color:  #000000;
#         }#T_61634_row0_col2{
#             background-color:  #8ad2be;
#             color:  #000000;
#         }#T_61634_row1_col0{
#             background-color:  #157f3b;
#             color:  #f1f1f1;
#         }#T_61634_row1_col1{
#             background-color:  #137d39;
#             color:  #f1f1f1;
#         }#T_61634_row1_col2{
#             background-color:  #29924f;
#             color:  #000000;
#         }#T_61634_row2_col0{
#             background-color:  #2c9553;
#             color:  #000000;
#         }#T_61634_row2_col1{
#             background-color:  #36a164;
#             color:  #000000;
#         }#T_61634_row2_col2,#T_61634_row7_col0{
#             background-color:  #37a266;
#             color:  #000000;
#         }#T_61634_row3_col0,#T_61634_row3_col2,#T_61634_row14_col1{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_61634_row3_col1,#T_61634_row15_col1{
#             background-color:  #005e26;
#             color:  #f1f1f1;
#         }#T_61634_row4_col0,#T_61634_row4_col1,#T_61634_row4_col2{
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }#T_61634_row5_col0{
#             background-color:  #3fab72;
#             color:  #000000;
#         }#T_61634_row5_col1{
#             background-color:  #43af78;
#             color:  #000000;
#         }#T_61634_row5_col2,#T_61634_row12_col1{
#             background-color:  #4eb586;
#             color:  #000000;
#         }#T_61634_row6_col0{
#             background-color:  #05712f;
#             color:  #f1f1f1;
#         }#T_61634_row6_col1,#T_61634_row15_col0{
#             background-color:  #1c8540;
#             color:  #000000;
#         }#T_61634_row6_col2,#T_61634_row11_col0{
#             background-color:  #03702e;
#             color:  #f1f1f1;
#         }#T_61634_row7_col1{
#             background-color:  #39a569;
#             color:  #000000;
#         }#T_61634_row7_col2{
#             background-color:  #46b17c;
#             color:  #000000;
#         }#T_61634_row8_col0{
#             background-color:  #cfede8;
#             color:  #000000;
#         }#T_61634_row8_col1{
#             background-color:  #bde6de;
#             color:  #000000;
#         }#T_61634_row8_col2{
#             background-color:  #ade0d4;
#             color:  #000000;
#         }#T_61634_row9_col0{
#             background-color:  #2f9a59;
#             color:  #000000;
#         }#T_61634_row9_col1{
#             background-color:  #3ca86d;
#             color:  #000000;
#         }#T_61634_row9_col2{
#             background-color:  #4bb382;
#             color:  #000000;
#         }#T_61634_row10_col0{
#             background-color:  #006227;
#             color:  #f1f1f1;
#         }#T_61634_row10_col1{
#             background-color:  #00481d;
#             color:  #f1f1f1;
#         }#T_61634_row10_col2{
#             background-color:  #1d8640;
#             color:  #000000;
#         }#T_61634_row11_col1{
#             background-color:  #00451c;
#             color:  #f1f1f1;
#         }#T_61634_row11_col2{
#             background-color:  #2a9350;
#             color:  #000000;
#         }#T_61634_row12_col0{
#             background-color:  #74c8ae;
#             color:  #000000;
#         }#T_61634_row12_col2{
#             background-color:  #b7e4da;
#             color:  #000000;
#         }#T_61634_row13_col0{
#             background-color:  #6cc4a8;
#             color:  #000000;
#         }#T_61634_row13_col1{
#             background-color:  #4db585;
#             color:  #000000;
#         }#T_61634_row13_col2{
#             background-color:  #bae5dc;
#             color:  #000000;
#         }#T_61634_row14_col0{
#             background-color:  #1a843f;
#             color:  #000000;
#         }#T_61634_row14_col2{
#             background-color:  #48b27f;
#             color:  #000000;
#         }#T_61634_row15_col2{
#             background-color:  #4ab381;
#             color:  #000000;
#         }</style><table id="T_61634_" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >val_binary_sharpe</th>        <th class="col_heading level0 col1" >val_binary_long_sharpe</th>        <th class="col_heading level0 col2" >val_binary_short_sharpe</th>    </tr>    <tr>        <th class="index_name level0" >asset</th>        <th class="index_name level1" >params</th>        <th class="index_name level2" >model</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_61634_level0_row0" class="row_heading level0 row0" rowspan="16">dow_jones</th>
#                         <th id="T_61634_level1_row0" class="row_heading level1 row0" rowspan="4">207</th>
#                         <th id="T_61634_level2_row0" class="row_heading level2 row0" >base</th>
#                         <td id="T_61634_row0_col0" class="data row0 col0" >-0.578718</td>
#                         <td id="T_61634_row0_col1" class="data row0 col1" >-0.214046</td>
#                         <td id="T_61634_row0_col2" class="data row0 col2" >-0.851722</td>
#             </tr>
#             <tr>
#                                         <th id="T_61634_level2_row1" class="row_heading level2 row1" >cnp</th>
#                         <td id="T_61634_row1_col0" class="data row1 col0" >0.403866</td>
#                         <td id="T_61634_row1_col1" class="data row1 col1" >0.410287</td>
#                         <td id="T_61634_row1_col2" class="data row1 col2" >-0.142422</td>
#             </tr>
#             <tr>
#                                         <th id="T_61634_level2_row2" class="row_heading level2 row2" >lnp</th>
#                         <td id="T_61634_row2_col0" class="data row2 col0" >0.184441</td>
#                         <td id="T_61634_row2_col1" class="data row2 col1" >0.185311</td>
#                         <td id="T_61634_row2_col2" class="data row2 col2" >-0.274922</td>
#             </tr>
#             <tr>
#                                         <th id="T_61634_level2_row3" class="row_heading level2 row3" >np</th>
#                         <td id="T_61634_row3_col0" class="data row3 col0" >0.920105</td>
#                         <td id="T_61634_row3_col1" class="data row3 col1" >0.598148</td>
#                         <td id="T_61634_row3_col2" class="data row3 col2" >0.475043</td>
#             </tr>
#             <tr>
#                                 <th id="T_61634_level1_row4" class="row_heading level1 row4" rowspan="4">235</th>
#                         <th id="T_61634_level2_row4" class="row_heading level2 row4" >base</th>
#                         <td id="T_61634_row4_col0" class="data row4 col0" >-1.654968</td>
#                         <td id="T_61634_row4_col1" class="data row4 col1" >-0.928798</td>
#                         <td id="T_61634_row4_col2" class="data row4 col2" >-1.779070</td>
#             </tr>
#             <tr>
#                                         <th id="T_61634_level2_row5" class="row_heading level2 row5" >cnp</th>
#                         <td id="T_61634_row5_col0" class="data row5 col0" >-0.021072</td>
#                         <td id="T_61634_row5_col1" class="data row5 col1" >0.099051</td>
#                         <td id="T_61634_row5_col2" class="data row5 col2" >-0.470758</td>
#             </tr>
#             <tr>
#                                         <th id="T_61634_level2_row6" class="row_heading level2 row6" >lnp</th>
#                         <td id="T_61634_row6_col0" class="data row6 col0" >0.548024</td>
#                         <td id="T_61634_row6_col1" class="data row6 col1" >0.360185</td>
#                         <td id="T_61634_row6_col2" class="data row6 col2" >0.161880</td>
#             </tr>
#             <tr>
#                                         <th id="T_61634_level2_row7" class="row_heading level

# %%
#add_style(dow_jones)
